# %% [markdown]
# **Importing the recipe data:**
#  the recipes.json data might be a JSON file dumped from MongoDB. It got an error "JSONDecoder error: Extra data: line 2 column 1" when I used normal json.loads method. The MongoDB JSON dump has one object per line. So the code below worked.

# %%
import json
data = [json.loads(line) for line in open('recipes.json', 'r')]
for i in range(len(data)):
    data[i]['Name'] = data[i]['Name'].lower()
    for j in range(len(data[i]['Method'])):
        data[i]['Method'][j] = data[i]['Method'][j].lower()

count = 0
count1 = 0

expected_data =[]
for i in range(len(data)):
    if "cake" in data[i]['Name']:
        expected_data.append("Baked Good")
        count1 += 2.8
    elif "cookie" in data[i]['Name']:
        expected_data.append("Baked Good")
        count1 += 2.8
    elif "pie" in data[i]['Name']:
        expected_data.append("Baked Good")
        count1 += 2.8
    elif "pudding" in data[i]['Name']:
        expected_data.append("Baked Good")
        count1 += 2.8
    elif "brownie" in data[i]['Name']:
        expected_data.append("Baked Good")
        count1 += 2.8
    elif "biscuit" in data[i]['Name']:
        expected_data.append("Baked Good")
        count1 += 2.8
    elif "scone" in data[i]['Name']:
        expected_data.append("Baked Good")
        count1 += 2.8
    elif "muffin" in data[i]['Name']:
        expected_data.append("Baked Good")
        count1 += 2.8
    elif "tart" in data[i]['Name']:
        expected_data.append("Baked Good")
        count1 += 2.8
    elif "bread" in data[i]['Name']:
        expected_data.append("Baked Good")
        count1 += 2.8
    elif "Bread" in data[i]['Name']:
        expected_data.append("Baked Good")
        count1 += 2.8
    elif "roll" in data[i]['Name']:
        expected_data.append("Baked Good")
        count1 += 2.8
    else:
        expected_data.append("Other")
        count += 1
        
print(expected_data)
# Out:
# ['Baked Good', 'Baked Good', 'Baked Good', 'Other', 'Baked Good', 'Other', 'Other', 'Baked Good', 'Other', 'Other', 'Other', 'Other', 'Baked Good', 'Baked Good', 'Baked Good', 'Baked Good', 'Baked Good', 'Baked Good', 'Baked Good', 'Other', 'Baked Good', 'Baked Good', 'Baked Good', 'Baked Good', 'Baked Good', 'Baked Good', 'Baked Good', 'Other', 'Other', 'Baked Good', 'Other', 'Baked Good', 'Baked Good', 'Baked Good', 'Other', 'Baked Good', 'Baked Good', 'Baked Good', 'Baked Good', 'Baked Good', 'Other', 'Baked Good', 'Baked Good', 'Baked Good', 'Baked Good', 'Baked Good', 'Other', 'Baked Good', 'Baked Good', 'Baked Good', 'Baked Good', 'Other', 'Other', 'Baked Good', 'Baked Good', 'Other', 'Other', 'Other', 'Other', 'Baked Good', 'Baked Good', 'Other', 'Baked Good', 'Other', 'Other', 'Baked Good', 'Other', 'Other', 'Other', 'Other', 'Baked Good', 'Baked Good', 'Baked Good', 'Other', 'Other', 'Baked Good', 'Other', 'Baked Good', 'Other', 'Baked Good', 'Other', 'Baked Good', 'Other', 'Other', 'Other', 'Other', 'Baked Good', 'Baked Good', 'Baked Good', 'Baked Good', 'Other', 'Other', 'Other', 'Baked Good', 'Baked Good', 'Baked Good', 'Baked Good', 'Baked Good', 'Baked Good', 'Baked Good', 'Baked Good', 'Other', 'Other', 'Other', 'Other', 'Baked Good', 'Other', 'Baked Good', 'Other', 'Baked Good', 'Other', 'Baked Good', 'Other', 'Baked Good', 'Baked Good', 'Other', 'Other', 'Other', 'Other', 'Baked Good', 'Other', 'Other', 'Baked Good', 'Baked Good', 'Baked Good', 'Other', 'Baked Good', 'Baked Good', 'Other', 'Baked Good', 'Other', 'Other', 'Other', 'Other', 'Baked Good', 'Baked Good', 'Other', 'Baked Good', 'Other', 'Baked Good', 'Baked Good', 'Other', 'Other', 'Other', 'Other', 'Baked Good', 'Baked Good', 'Baked Good', 'Baked Good', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Baked Good', 'Other', 'Baked Good', 'Other', 'Other', 'Other', 'Other', 'Other', 'Baked Good', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Baked Good', 'Other', 'Baked Good', 'Baked Good', 'Other', 'Other', 'Other', 'Other', 'Other', 'Baked Good', 'Baked Good', 'Other', 'Other', 'Baked Good', 'Baked Good', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Baked Good', 'Baked Good', 'Other', 'Baked Good', 'Baked Good', 'Other', 'Other', 'Baked Good', 'Baked Good', 'Other', 'Other', 'Other', 'Other', 'Baked Good', 'Other', 'Other', 'Other', 'Other', 'Baked Good', 'Other', 'Other', 'Other', 'Other', 'Baked Good', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Baked Good', 'Other', 'Other', 'Baked Good', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Baked Good', 'Other', 'Other', 'Baked Good', 'Baked Good', 'Baked Good', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Baked Good', 'Other', 'Other', 'Other', 'Other', 'Baked Good', 'Other', 'Other', 'Other', 'Baked Good', 'Other', 'Other', 'Baked Good', 'Baked Good', 'Baked Good', 'Other', 'Baked Good', 'Other', 'Other', 'Baked Good', 'Other', 'Other', 'Baked Good', 'Baked Good', 'Baked Good', 'Other', 'Other', 'Other', 'Other', 'Baked Good', 'Other', 'Baked Good', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Baked Good', 'Other', 'Baked Good', 'Other', 'Other', 'Other', 'Other', 'Baked Good', 'Baked Good', 'Other', 'Baked Good', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Baked Good', 'Baked Good', 'Other', 'Baked Good', 'Other', 'Other', 'Other', 'Baked Good', 'Baked Good', 'Baked Good', 'Other', 'Baked Good', 'Other', 'Other', 'Other', 'Other', 'Baked Good', 'Baked Good', 'Baked Good', 'Other', 'Other', 'Other', 'Baked Good', 'Other', 'Other', 'Other', 'Other', 'Baked Good', 'Other', 'Other', 'Baked Good', 'Baked Good', 'Other', 'Other', 'Other', 'Other', 'Baked Good', 'Baked Good', 'Other', 'Other', 'Baked G ...

# %%
from collections import Counter
import numpy as np

count = Counter()
for i in range(len(data)):       
    if data[i]['Name'] != None:
        for word in data[i]['Name'].split(" "):
            count[word] += 1
count.most_common()
# Out:
# [('&', 616),
#  ('with', 321),
#  ('christmas', 114),
#  ('cake', 103),
#  ('chocolate', 84),
#  ('cranberry', 79),
#  ('roast', 73),
#  ('sauce', 65),
#  ('turkey', 62),
#  ('cheese', 57),
#  ('salad', 55),
#  ('spiced', 51),
#  ('red', 45),
#  ('pudding', 43),
#  ('stuffing', 41),
#  ('cream', 40),
#  ('salmon', 40),
#  ('potato', 38),
#  ('apple', 37),
#  ('smoked', 37),
#  ('ham', 36),
#  ('cabbage', 35),
#  ('sticky', 35),
#  ('orange', 34),
#  ('pie', 33),
#  ('pies', 33),
#  ('mince', 33),
#  ('potatoes', 32),
#  ('ginger', 30),
#  ('sprouts', 29),
#  ('butter', 27),
#  ('chestnut', 27),
#  ('wine', 27),
#  ('mini', 26),
#  ('bacon', 25),
#  ('tart', 24),
#  ('onion', 24),
#  ('pork', 24),
#  ('bread', 23),
#  ('gravy', 23),
#  ('creamy', 23),
#  ('mushroom', 23),
#  ('clementine', 22),
#  ('baked', 22),
#  ('mulled', 22),
#  ('gingerbread', 21),
#  ('in', 21),
#  ('mustard', 21),
#  ('soup', 21),
#  ('easy', 20),
#  ('parsnip', 20),
#  ('chicken', 20),
#  ('mincemeat', 20),
#  ('beef', 19),
#  ('beetroot', 19),
#  ('lemon', 19),
#  ('squash', 19),
#  ('winter', 19),
#  ('gratin', 19),
#  ('pear', 18),
#  ('carrots', 18),
#  ('coconut', 18),
#  ('ice', 17),
#  ('cakes', 17),
#  ('pecan', 17),
#  ('duck', 17),
#  ('sausage', 17),
#  ('pancetta', 17),
#  ('festive', 17),
#  ('trifle', 16),
#  ('fruit', 16),
#  ('sweet', 16),
#  ('chilli', 16),
#  ('cocktail', 16),
#  ('hazelnut', 16),
#  ('dressing', 16),
#  ('sage', 16),
#  ('chutney', 15),
#  ('of', 15),
#  ('spinach', 15),
#  ('roasted', 15),
#  ('white', 14),
#  ('biscuits', 14),
#  ('nut', 14),
#  ('caramel', 14),
#  ('celeriac', 14),
#  ('brussels', 14),
#  ('hot', 13),
#  ('vegan', 13),
#  ('wreath', 13),
#  ('crispy', 13),
#  ('crunchy', 13),
#  ('rice', 13),
#  ('syrup', 13),
#  ('wild', 13),
#  ('sprout', 13),
#  ('apricot', 13),
#  ('meringue', 13),
#  ('almond', 12),
#  ('cheesecake', 12),
#  ('classic', 12),
#  ('pud', 12),
#  ('garlic', 12),
#  ('crumble', 12),
#  ('star', 12),
#  ('stuffed', 12),
#  ('herby', 12),
#  ('roasties', 12),
#  ('cauliflower', 12),
#  ('spice', 11),
#  ('honey', 11),
#  ('stollen', 11),
#  ('loaf', 11),
#  ('pears', 11),
#  ('bake', 11),
#  ('port', 11),
#  ('pomegranate', 11),
#  ('chorizo', 11),
#  ('spicy', 11),
#  ('seed', 11),
#  ('kit', 11),
#  ('onions', 11),
#  ('dip', 11),
#  ('cupcakes', 10),
#  ('puddings', 10),
#  ('cherry', 10),
#  ('tree', 10),
#  ('marzipan', 10),
#  ('coffee', 10),
#  ('root', 10),
#  ('maple', 10),
#  ('glazed', 10),
#  ('truffles', 10),
#  ('blue', 10),
#  ('braised', 10),
#  ('apples', 10),
#  ('raspberry', 10),
#  ('truffle', 10),
#  ('carrot', 10),
#  ('caramelised', 10),
#  ('walnut', 10),
#  ('black', 9),
#  ("goat's", 9),
#  ('salted', 9),
#  ('leek', 9),
#  ('terrine', 9),
#  ('pancakes', 9),
#  ('rosemary', 9),
#  ('lime', 9),
#  ('custard', 9),
#  ('pickled', 9),
#  ('passion', 9),
#  ('fennel', 9),
#  ('prawn', 9),
#  ('cinnamon', 9),
#  ('vanilla', 8),
#  ('cookies', 8),
#  ('goose', 8),
#  ('iced', 8),
#  ('boozy', 8),
#  ('log', 8),
#  ('toffee', 8),
#  ('simple', 8),
#  ('panettone', 8),
#  ('slice', 8),
#  ('marmalade', 8),
#  ('peppermint', 8),
#  ('baby', 8),
#  ('fruitcake', 8),
#  ('chestnuts', 8),
#  ('sesame', 8),
#  ('mango', 8),
#  ('rolls', 8),
#  ('pineapple', 8),
#  ('bites', 8),
#  ('skewers', 8),
#  ('crème', 8),
#  ('thyme', 8),
#  ('vegetables', 8),
#  ('feta', 8),
#  ('walnuts', 8),
#  ('stilton', 8),
#  ('horseradish', 8),
#  ('shallots', 8),
#  ('fig', 7),
#  ('little', 7),
#  ('fruity', 7),
#  ('lamb', 7),
#  ('buttered', 7),
#  ('rum', 7),
#  ('forest', 7),
#  ('bombe', 7),
#  ('wellington', 7),
#  ('torte', 7),
#  ('pistachio', 7),
#  ('toast', 7),
#  ('camembert', 7),
#  ('prosciutto', 7),
#  ('mash', 7),
#  ('mint', 7),
#  ('butternut', 7),
#  ('cups', 7),
#  ('goat’s', 7),
#  ('chicory', 7),
#  ('parsnips', 7),
#  ('cider', 7),
#  ('date', 7),
#  ('warm', 7),
#  ('fresh', 7),
#  ('green', 7),
#  ('liver', 7),
#  ('peas', 7),
#  ('snowman', 7),
#  ('bubble', 7),
#  ('squeak', 7),
#  ('pâté', 7),
#  ('crab', 7),
#  ('brownies', 6),
#  ('golden', 6),
#  ('almonds', 6),
#  ('chocolate,', 6),
#  ('jam', 6),
#  ('muffins', 6),
#  ('brandy', 6),
#  ('triple', 6),
#  ('roll', 6),
#  ('fudge', 6),
#  ('poppy', 6),
#  ('jelly', 6),
#  ('crown', 6),
#  ('olive', 6),
#  ('prawns', 6),
#  ('venison', 6),
#  ('brioche', 6),
#  ('brie', 6),
#  ('jewelled', 6),
#  ('berry', 6),
#  ('slow', 6),
#  ('dippers', 6),
#  ('roulade', 6),
#  ('relish', 6),
#  ('shallot', 6),
#  ('yogurt', 6),
#  ('pine', 6),
#  ('nuts', 6),
#  ('cucumber', 6),
#  ('parcels', 6),
#  ('toasts', 6),
#  ('spring', 6),
#  ('bean', 6),
#  ('buns', 5),
#  ('citrus', 5),
#  ('saffron', 5),
#  ('glaze', 5),
#  ('gammon', 5),
#  ('yule', 5),
#  ('chunky', 5),
#  ('vegetable', 5),
#  ('snowball', 5),
#  ('cheeseboard', 5),
#  ('peanut', 5),
#  ('candy', 5),
#  ('whisky', 5),
#  ('toasted', 5),
#  ('really', 5),
#  ('shortbread', 5),
#  ('creamed', 5),
#  ('homemade', 5),
#  ('reindeer', 5),
#  ('poached', 5),
#  ('crunch', 5),
#  ('eggs', 5),
#  ('martini', 5),
#  ('tomato', 5),
#  ('sour', 5),
#  ('thai', 5),
#  ('turkey,', 5),
#  ('fraîche', 5),
#  ('salmon,', 5),
#  ('dill', 5),
#  ('crisp', 5),
#  ('quick', 5),
#  ('kale', 5),
#  ('polenta', 5),
#  ('make-ahead', 5),
#  ('parfait', 5),
#  ('mont', 5),
#  ('tarts', 5),
#  ('fizz', 5),
#  ('risotto', 5),
#  ('treacle', 5),
#  ('leeks', 5),
#  ('hash', 5),
#  ('candied', 5),
#  ('sorbet', 5),
#  ('pepper', 5),
#  ('roots', 5),
#  ('punch', 5),
#  ('pots', 5),
#  ('juniper', 5),
#  ('platter', 5),
#  ('and', 5),
#  ('herb', 5),
#  ('slaw', 4),
#  ('sparkling', 4),
#  ('pops', 4),
#  ('rudolph', 4),
#  ('traybake', 4),
#  ('veg', 4),
#  ('brownie', 4),
#  ('bay', 4),
#  ('ultimate', 4),
#  ('ham,', 4),
#  ('melting', 4),
#  ('balls', 4),
#  ('compote', 4),
#  ('avocado', 4),
#  ('buttery', 4),
#  ('pigs', 4),
#  ('pastry', 4),
#  ('blankets', 4),
#  ('chestnut,', 4),
#  ('sugar-dusted', 4),
#  ('snowflake', 4),
#  ('pavlova', 4),
#  ('fritters', 4),
#  ('wings', 4),
#  ('potted', 4),
#  ('cookie', 4),
#  ('sugar', 4),
#  ('ricotta', 4),
#  ('chipolatas', 4),
#  ('eccles', 4),
#  ('truffled', 4),
#  ('vodka', 4),
#  ('recipe', 4),
#  ('bramley', 4),
#  ('parsley', 4),
#  ('double', 4),
#  ('caraway', 4),
#  ('tarragon', 4),
#  ('cranberry,', 4),
#  ('curry', 4),
#  ('mushrooms', 4),
#  ('blinis', 4),
#  ('greens', 4),
#  ('cooker', 4),
#  ('bark', 4),
#  ('turkish', 4),
#  ('tea', 4),
#  ('charred', 4),
#  ('party', 4),
#  ('choc', 4),
#  ('squares', 4),
#  ('anise', 4),
#  ('celery', 4),
#  ('salt', 4),
#  ('raisin', 4),
#  ('brown', 4),
#  ('sharing', 4),
#  ('plum', 4),
#  ('lentil', 4),
#  ('artichoke', 4),
#  ('madeira', 4),
#  ('scallops', 4),
#  ('coriander', 4),
#  ('savoy', 4),
#  ('fish', 4),
#  ('beans', 4),
#  ('twists', 4),
#  ('cheesy', 4),
#  ('rye', 4),
#  ('loin', 4),
#  ('grilled', 4),
#  ('mary', 3),
#  ('mix', 3),
#  ('strudel', 3),
#  ('mousse', 3),
#  ('amaretti', 3),
#  ('trees', 3),
#  ('soufflés', 3),
#  ('the', 3),
#  ('nutmeg', 3),
#  ('a', 3),
#  ('crostini', 3),
#  ('ho,', 3),
#  ('clotted', 3),
#  ('semifreddo', 3),
#  ('breast', 3),
#  ('wrapped', 3),
#  ('bauble', 3),
#  ('chip', 3),
#  ('eggnog', 3),
#  ('de', 3),
#  ('milk', 3),
#  ('sausage,', 3),
#  ('persian', 3),
#  ('fondue', 3),
#  ('pot', 3),
#  ('st', 3),
#  ('bundt', 3),
#  ('lobster', 3),
#  ('remoulade', 3),
#  ('stacks', 3),
#  ('biscuit', 3),
#  ('cardamom', 3),
#  ('stem', 3),
#  ('thins', 3),
#  ('french', 3),
#  ('banana', 3),
#  ('soufflé', 3),
#  ('fillet', 3),
#  ('baileys', 3),
#  ('limoncello', 3),
#  ('cranberries', 3),
#  ('tatin', 3),
#  ('slow-cooked', 3),
#  ('dauphinoise', 3),
#  ('pilaf', 3),
#  ('tagine', 3),
#  ('prosecco', 3),
#  ('english', 3),
#  ('healthy', 3),
#  ('sourdough', 3),
#  ('celeriac,', 3),
#  ('gravadlax', 3),
#  ('filled', 3),
#  ('creams', 3),
#  ('partridge', 3),
#  ('sloe', 3),
#  ('mayo', 3),
#  ('boxing', 3),
#  ('day', 3),
#  ('scones', 3),
#  ('oatcakes', 3),
#  ('ripple', 3),
#  ('gin', 3),
#  ('purée', 3),
#  ('honey-roasted', 3),
#  ('raisins', 3),
#  ('parmesan', 3),
#  ('bruschetta', 3),
#  ('delight', 3),
#  ('carbonara', 3),
#  ('stars', 3),
#  ('on', 3),
#  ('decoration', 3),
#  ('mashed', 3),
#  ('leaf', 3),
#  ('hasselback', 3),
#  ('pumpkin', 3),
#  ('slices', 3),
#  ('cointreau', 3),
#  ('pear,', 3),
#  ('stir-fried', 3),
#  ('prunes', 3),
#  ('giant', 3),
#  ('palmiers', 3),
#  ('confit', 3),
#  ('tartlets', 3),
#  ('yorkies', 3),
#  ('rose', 3),
#  ('irish', 3),
#  ('pheasant', 3),
#  ('sticks', 3),
#  ('chips', 3),
#  ('croutons', 3),
#  ('elderflower', 3),
#  ('artichokes', 3),
#  ('quince', 3),
#  ('beetroot,', 3),
#  ('jaffa', 3),
#  ('layer', 3),
#  ('broccoli', 3),
#  ('filo', 3),
#  ('egg', 3),
#  ('shoulder', 3),
#  ('redcurrant', 3),
#  ('muffin', 2),
#  ('gingery', 2),
#  ('granny', 2),
#  ('light', 2),
#  ('frosty', 2),
#  ('friands', 2),
#  ('cupcake', 2),
#  ('morning', 2),
#  ("mum's", 2),
#  ('for', 2),
#  ('fool', 2),
#  ('penguins', 2),
#  ('last-minute', 2),
#  ('tortilla', 2),
#  ('lollipops', 2),
#  ('membrillo', 2),
#  ('tiramisu', 2),
#  ('match', 2),
#  ('biscotti', 2),
#  ('malt', 2),
#  ('ciabatta', 2),
#  ('moroccan', 2),
#  ('house', 2),
#  ('man', 2),
#  ('holly', 2),
#  ('glam', 2),
#  ('fancies', 2),
#  ('shooting', 2),
#  ('mexican', 2),
#  ('cane', 2),
#  ('slow-roasted', 2),
#  ('rib', 2),
#  ('perfect', 2),
#  ('dough', 2),
#  ('toddy', 2),
#  ('crumbs', 2),
#  ('rocky', 2),
#  ('puff', 2),
#  ('bûche', 2),
#  ('noël', 2),
#  ('burnt', 2),
#  ('spritzer', 2),
#  ('fragrant', 2),
#  ('en', 2),
#  ('croûte', 2),
#  ('zesty', 2),
#  ('snow', 2),
#  ('macadamia', 2),
#  ('american', 2),
#  ('parsnip,', 2),
#  ('prawns,', 2),
#  ('chillies', 2),
#  ('chelsea', 2),
#  ('satay', 2),
#  ('rich', 2),
#  ('butter-basted', 2),
#  ('hollandaise', 2),
#  ('watercress', 2),
#  ('people', 2),
#  ('doughnuts', 2),
#  ('croquettes', 2),
#  ('juice', 2),
#  ('bellini', 2),
#  ('halloumi', 2),
#  ('deep-fried', 2),
#  ('guinea', 2),
#  ('fowl', 2),
#  ('icing', 2),
#  ('spirals', 2),
#  ('mincemeat,', 2),
#  ('whiskey', 2),
#  ('croque', 2),
#  ('maple-roasted', 2),
#  ('bacon,', 2),
#  ('comté', 2),
#  ('sherried', 2),
#  ('beer', 2),
#  ('tangerine', 2),
#  ('florentines', 2),
#  ('pea', 2),
#  ('food', 2),
#  ('pistachios', 2),
#  ('squash,', 2),
#  ('barley', 2),
#  ('traditional', 2),
#  ('squidgy', 2),
#  ('tarte', 2),
#  ('legs', 2),
#  ('straws', 2),
#  ('wellingtons', 2),
#  ('pesto', 2),
#  ('marsala', 2),
#  ('deep-filled', 2),
#  ('nougat', 2),
#  ('profiteroles', 2),
#  ('ivy', 2),
#  ('sparkle', 2),
#  ('full', 2),
#  ('twist', 2),
#  ('hock', 2),
#  ('peppered', 2),
#  ('mackerel', 2),
#  ('pink', 2),
#  ('leftover', 2),
#  ('casserole', 2),
#  ('cauliflower,', 2),
#  ('honey-roast', 2),
#  ('smashed', 2),
#  ('grapefruit', 2),
#  ('fruit,', 2),
#  ('flatbread', 2),
#  ('marshmallow', 2),
#  ('perky', 2),
#  ('blanc', 2),
#  ('faux', 2),
#  ('salsa', 2),
#  ('peppercorn', 2),
#  ('rillettes', 2),
#  ('savoury', 2),
#  ('mushroom,', 2),
#  ('dates', 2),
#  ('cottage', 2),
#  ('damson', 2),
#  ('orange,', 2),
#  ('garlicky', 2),
#  ('belly', 2),
#  ('chunks', 2),
#  ('mojito', 2),
#  ('buttermilk', 2),
#  ('freeze-ahead', 2),
#  ('rösti', 2),
#  ('swede', 2),
#  ('aubergine', 2),
#  ('hotpot', 2),
#  ('whipped', 2),
#  ('frosted', 2),
#  ('prune', 2),
#  ('all-the-trimmings', 2),
#  ('carrot,', 2),
#  ('potato,', 2),
#  ('dhal', 2),
#  ('stirrers', 2),
#  ('fridge', 2),
#  ('clementine,', 2),
#  ('bitter', 2),
#  ('chinese', 2),
#  ('rice,', 2),
#  ('ice-cream', 2),
#  ('seared', 2),
#  ('falafel', 2),
#  ('silky', 2),
#  ("santa's", 2),
#  ('samosas', 2),
#  ('alaska', 2),
#  ('haddock', 2),
#  ('kedgeree', 2),
#  ('breeze', 2),
#  ('sponge', 2),
#  ('spuds', 2),
#  ('paprika', 2),
#  ('sea', 2),
#  ('tangy', 2),
#  ('from-the-freezer', 2),
#  ('squashed', 2),
#  ('bourbon', 2),
#  ('courgette', 2),
#  ('minty', 2),
#  ('rainbow', 2),
#  ('crackers', 2),
#  ('microwave', 2),
#  ('butternut,', 2),
#  ('’n’', 2),
#  ('steamed', 2),
#  ('vinaigrette', 2),
#  ('bloody', 2),
#  ('cheddar', 2),
#  ('toastie', 2),
#  ('courgettes', 2),
#  ('fondant', 2),
#  ('rudolph’s', 2),
#  ('dark', 2),
#  ('honeyed', 2),
#  ('beetroot-cured', 2),
#  ('sandwiches', 2),
#  ('apricots', 2),
#  ('mocktail', 2),
#  ('oysters', 2),
#  ('meringues', 2),
#  ('bresaola', 2),
#  ('pecans', 2),
#  ('leaves', 2),
#  ('maple-glazed', 2),
#  ('griddled', 2),
#  ('hazelnuts', 2),
#  ('jerusalem', 2),
#  ('celebration', 2),
#  ('sautéed', 2),
#  ('tropical', 2),
#  ('blancs', 2),
#  ('korean', 2),
#  ('shots', 2),
#  ('sliders', 2),
#  ('sirloin', 2),
#  ('pasta', 2),
#  ('brie,', 2),
#  ('quiche', 2),
#  ('crust', 2),
#  ('next', 2),
#  ('level', 2),
#  ('cured', 2),
#  ('crackling', 2),
#  ('burgers', 2),
#  ('cocktails', 2),
#  ('porridge', 2),
#  ('nutty', 2),
#  ('rhubarb', 2),
#  ('tatins', 2),
#  ('piña', 2),
#  ('colada', 2),
#  ('vinegar', 2),
#  ('browns', 2),
#  ('asian', 2),
#  ('tzatziki', 2),
#  ('tomatoes', 2),
#  ('au', 2),
#  ('flavoured', 2),
#  ('butters', 2),
#  ('simmer-&-stir', 1),
#  ('mess', 1),
#  ('cosmopolitan', 1),
#  ('pizza', 1),
#  ('poussin', 1),
#  ("berry's", 1),
#  ('make', 1),
#  ('mature', 1),
#  ('angela', 1),
#  ("nilsen's", 1),
#  ("gordon's", 1),
#  ('sherry', 1),
#  ('liqueur', 1),
#  ("martin's", 1),
#  ('individual', 1),
#  ('christmas-pudding', 1),
#  ('figgy', 1),
#  ("chocoholic's", 1),
#  ('spices', 1),
#  ('suits-all', 1),
#  ("cook's", 1),
#  ('nancy’s', 1),
#  ('orange-stuffed', 1),
#  ('puds', 1),
#  ('enchanted', 1),
#  ('latte', 1),
#  ('buttercream', 1),
#  ('lunch', 1),
#  ('jar', 1),
#  ('isaac', 1),
#  ("scout's", 1),
#  ('lightly', 1),
#  ('tutti', 1),
#  ('frutti', 1),
#  ('ceviche', 1),
#  ('guacamole', 1),
#  ('rockies', 1),
#  ('unbelievably', 1),
#  ('krispie', 1),
#  ('snowy', 1),
#  ('owl', 1),
#  ('orlando', 1),
#  ("murrin's", 1),
#  ('deluxe', 1),
#  ('let-it-glow', 1),
#  ('pure', 1),
#  ('gold', 1),
#  ('drip', 1),
#  ('sundaes', 1),
#  ('as-you-like-it', 1),
#  ('blitz-&-bake', 1),
#  ('mandarin-in-the-middle', 1),
#  ('merry', 1),
#  ('veg,', 1),
#  ('bramble', 1),
#  ('cola', 1),
#  ('biryani', 1),
#  ('parmesan-roasted', 1),
#  ('middle', 1),
#  ('glitz', 1),
#  ('plait', 1),
#  ('orange-glazed', 1),
#  ('bacon-wrapped', 1),
#  ('breadsticks', 1),
#  ('bonbons', 1),
#  ('koftas', 1),
#  ('pressed', 1),
#  ('mississippi', 1),
#  ('mud', 1),
#  ('alaskan', 1),
#  ('herb-scented', 1),
#  ('shallot-stuffed', 1),
#  ('terrines', 1),
#  ('robin', 1),
#  ('bottle', 1),
#  ('sours', 1),
#  ('scallop', 1),
#  ('baubles', 1),
#  ('lebkuchen', 1),
#  ('globe', 1),
#  ('velvet', 1),
#  ('melty', 1),
#  ('mulling', 1),
#  ('lucia', 1),
#  ('croquetas', 1),
#  ('corn', 1),
#  ('marzipan-in-the-middle', 1),
#  ('fajitas', 1),
#  ('crumpets', 1),
#  ('magical', 1),
#  ('three-bird', 1),
#  ('oatmeal', 1),
#  ('rillette', 1),
#  ('slashed', 1),
#  ('egg,', 1),
#  ('caviar,', 1),
#  ('cashew', 1),
#  ('caramels', 1),
#  ('ramen', 1),
#  ('sunday', 1),
#  ('elf', 1),
#  ('panforte', 1),
#  ('yummy', 1),
#  ('naan,', 1),
#  ('reverse', 1),
#  ('espresso', 1),
#  ('olives', 1),
#  ('gnocchi,', 1),
#  ('sundried', 1),
#  ('arancello', 1),
#  ('set', 1),
#  ('favourite', 1),
#  ('tapenade', 1),
#  ('lattice', 1),
#  ('charms', 1),
#  ('monsieurs', 1),
#  ('coulibiac', 1),
#  ('raymond’s', 1),
#  ('spanish', 1),
#  ('blueberry', 1),
#  ('dogs', 1),
#  ('sage-wrapped', 1),
#  ('pineapple,', 1),
#  ('benedict', 1),
#  ('chives', 1),
#  ('mango,', 1),
#  ('coconut,', 1),
#  ('ponche', 1),
#  ('stained', 1),
#  ('glass', 1),
#  ('meatloaf', 1),
#  ('trifles', 1),
#  ('semi-freddo', 1),
#  ('snow-topped', 1),
#  ('devil’s', 1),
#  ('millionaire’s', 1),
#  ('layered', 1),
#  ('potage', 1),
#  ('dubarry', 1),
#  ('(creamy', 1),
#  ('soup)', 1),
#  ('oil-baked', 1),
#  ('cranachan', 1),
#  ('jalousie', 1),
#  ('cobbler', 1),
#  ('marbled', 1),
#  ('bacon-basted', 1),
#  ('sparkly', 1),
#  ('midwinter', 1),
#  ('candle', 1),
#  ('decadent', 1),
#  ('snowfetti', 1),
#  ('bunting', 1),
#  ('sandham', 1),
#  ('family', 1),
#  ('smoothie', 1),
#  ('sage,', 1),
#  ('open', 1),
#  ('ravioli', 1),
#  ('porcini', 1),
#  ('shukhi', 1),
#  ('–', 1),
#  ('jellies', 1),
#  ('very', 1),
#  ('cacciatore', 1),
#  ('whirls', 1),
#  ('florentine', 1),
#  ('chestnuts,', 1),
#  ('lemon,', 1),
#  ('margarita', 1),
#  ('topping', 1),
#  ('starter', 1),
#  ('mixed', 1),
#  ('houses', 1),
#  ('breasts', 1),
#  ('75', 1),
#  ('jamaican', 1),
#  ('frozen', 1),
#  ('unicorn', 1),
#  ('blanc-tini', 1),
#  ('crisp-topped', 1),
#  ("nick's", 1),
#  ('flip', 1),
#  ('wonderland', 1),
#  ('hedgerow', 1),
#  ('royale', 1),
#  ('sherry,', 1),
#  ('pandoro', 1),
#  ('spritz', 1),
#  ('prosciutto-wrapped', 1),
#  ('babka', 1),
#  ('bun', 1),
#  ('bespoke', 1),
#  ('centrepiece', 1),
#  ('super-simple', 1),
#  ('vegetarian', 1),
#  ('posh', 1),
#  ('cranberry-topped', 1),
#  ('raised', 1),
#  ('jolly', 1),
#  ('snowmen', 1),
#  ('mint-choc', 1),
#  ('gras', 1),
#  ('pickles', 1),
#  ('one-pot', 1),
#  ('drunken', 1),
#  ('royales', 1),
#  ('icy', 1),
#  ('kir', 1),
#  ('roquefort', 1),
#  ('coco', 1),
#  ('mead', 1),
#  ('jackfruit', 1),
#  ('tacos', 1),
#  ('sweetcorn', 1),
#  ('gochujang', 1),
#  ('madame', 1),
#  ('treacle-glazed', 1),
#  ('almond-topped', 1),
#  ('10-minute', 1),
#  ("barney's", 1),
#  ('roly-poly', 1),
#  ('gooey', 1),
#  ('noodle', 1),
#  ('pecan-stuffed', 1),
#  ('cheese-cupcakes', 1),
#  ('bourbon-glazed', 1),
#  ('zimtsterne', 1),
#  ('(cinnamon', 1),
#  ('stars)', 1),
#  ('clements', 1),
#  ('old', 1),
#  ('fashioned', 1),
#  ('bananas', 1),
#  ('brazils', 1),
#  ('sablés', 1),
#  ('oven-baked', 1),
#  ('garland', 1),
#  ('praline', 1),
#  ('nigella', 1),
#  ('appleberry', 1),
#  ('aïoli', 1),
#  ('pancetta-wrapped', 1),
#  ('two', 1),
#  ('ways', 1),
#  ('timbales', 1),
#  ('couscous', 1),
#  ('glossy', 1),
#  ('four', 1),
#  ('twenty', 1),
#  ('polar', 1),
#  ('bear', 1),
#  ('spinach,', 1),
#  ('guinness,', 1),
#  ('gingered', 1),
#  ('makeover:', 1),
#  ('sultanas', 1),
#  ('snowballs', 1),
#  ('flapjack', 1),
#  ('gremolata', 1),
#  ('garden', 1),
#  ('rosemary-spiked', 1),
#  ('pithivier', 1),
#  ('nibbles', 1),
#  ('choc-cherry', 1),
#  ('pepper-crusted', 1),
#  ('chickpeas', 1),
#  ('espresso,', 1),
#  ('decorative', 1),
#  ('bombes', 1),
#  ('chilli-charred', 1),
#  ('golden-glazed', 1),
#  ('serrano-wrapped', 1),
#  ('tassies', 1),
#  ('all-in-one', 1),
#  ('friends', 1),
#  ('colcannon', 1),
#  ('vodka-baked', 1),
#  ('peppers', 1),
#  ('corn,', 1),
#  ('after-dinner', 1),
#  ('tiffin', 1),
#  ('herb-roast', 1),
#  ('martinis', 1),
#  ('butter-roasted', 1),
#  ('supreme', 1),
#  ('gnocchi', 1),
#  ('fondants', 1),
#  ('rotolo', 1),
#  ('jumpers', 1),
#  ("lover's", 1),
#  ('cracker', 1),
#  ('angel', 1),
#  ('frosting', 1),
#  ('pernod', 1),
#  ...]

# %% [markdown]
# The recipes are categorized into: pie, cake/cupcake/pancake, cookies, biscuits, rolls, scones, (possibly) brownies and tarts.

# %%
baked_ingredients = Counter()
total_ingredients = Counter()
for i in range(len(data)):
    if expected_data[i] == "Baked Good":
        for j in range(len(data[i]['Ingredients'])):       
            if data[i]['Ingredients'] != None:
                for word in data[i]['Ingredients'][j].split(" "):
                    baked_ingredients[word] += 1
                    total_ingredients[word] += 1
                
baked_ingredients.most_common()
# Out:
# [('1', 832),
#  ('tbsp', 527),
#  ('tsp', 517),
#  ('2', 476),
#  ('sugar', 401),
#  ('100g', 354),
#  ('for', 332),
#  ('chopped', 282),
#  ('and', 282),
#  ('plus', 279),
#  ('200g', 239),
#  ('50g', 236),
#  ('butter,', 225),
#  ('extra', 225),
#  ('flour', 221),
#  ('icing', 219),
#  ('ground', 211),
#  ('3', 200),
#  ('plain', 196),
#  ('caster', 183),
#  ('or', 182),
#  ('to', 177),
#  ('of', 169),
#  ('4', 169),
#  ('large', 166),
#  ('white', 158),
#  ('½', 155),
#  ('mixed', 152),
#  ('golden', 152),
#  ('a', 147),
#  ('140g', 137),
#  ('finely', 135),
#  ('beaten', 127),
#  ('butter', 126),
#  ('dark', 126),
#  ('zest', 124),
#  ('small', 124),
#  ('dusting', 123),
#  ('cream', 123),
#  ('85g', 119),
#  ('dried', 118),
#  ('250g', 117),
#  ('sugar,', 116),
#  ('grated', 115),
#  ('pack', 115),
#  ('into', 113),
#  ('milk', 110),
#  ('orange', 108),
#  ('175g', 103),
#  ('greasing', 97),
#  ('the', 97),
#  ('muscovado', 96),
#  ('juice', 95),
#  ('eggs', 95),
#  ('egg', 95),
#  ('vanilla', 91),
#  ('500g', 90),
#  ('powder', 90),
#  ('300g', 88),
#  ('light', 87),
#  ('cinnamon', 86),
#  ('25g', 85),
#  ('flour,', 83),
#  ('double', 83),
#  ('self-raising', 80),
#  ('eggs,', 79),
#  ('soft', 72),
#  ('serve', 71),
#  ('baking', 70),
#  ('ginger', 70),
#  ('roughly', 70),
#  ('extract', 70),
#  ('chocolate', 69),
#  ('spice', 67),
#  ('unsalted', 67),
#  ('cut', 66),
#  ('fresh', 64),
#  ('softened', 64),
#  ('brown', 64),
#  ('225g', 63),
#  ('syrup', 63),
#  ('sliced', 60),
#  ('lemon', 59),
#  ('egg,', 59),
#  ('6', 59),
#  ('almond', 58),
#  ('whole', 58),
#  ('used', 56),
#  ('oil', 54),
#  ('x', 54),
#  ('little', 54),
#  ('leaves', 54),
#  ('400g', 53),
#  ('pastry', 52),
#  ('100ml', 49),
#  ('(optional)', 49),
#  ('olive', 48),
#  ('red', 48),
#  ('150g', 47),
#  ('chocolate,', 47),
#  ('oil,', 47),
#  ('black', 43),
#  ('5', 43),
#  ('medium', 42),
#  ('glacé', 41),
#  ('with', 41),
#  ('almonds', 40),
#  ('cocoa', 40),
#  ('150ml', 40),
#  ('75g', 40),
#  ('brandy', 39),
#  ('¼', 39),
#  ('bicarbonate', 39),
#  ('pinch', 39),
#  ('pot', 38),
#  ('cloves', 38),
#  ('soda', 38),
#  ('melted', 38),
#  ('pieces', 37),
#  ('nutmeg', 36),
#  ('decorate', 36),
#  ('from', 36),
#  ('apricot', 36),
#  ('diced', 36),
#  ('green', 35),
#  ('onion,', 34),
#  ('edible', 34),
#  ('in', 34),
#  ('halved', 34),
#  ('chunks', 34),
#  ('350g', 32),
#  ('peeled', 31),
#  ('1½', 31),
#  ('few', 30),
#  ('375g', 30),
#  ('handful', 30),
#  ('full-fat', 30),
#  ('cake', 30),
#  ('ready-to-roll', 30),
#  ('fondant', 29),
#  ('silver', 29),
#  ('food', 29),
#  ('if', 29),
#  ('about', 29),
#  ('marzipan', 29),
#  ('garlic', 29),
#  ('mincemeat', 29),
#  ('fruit', 28),
#  ('peel', 28),
#  ('sifted', 28),
#  ('softened,', 28),
#  ('cheese', 28),
#  ('cranberries', 28),
#  ('bay', 28),
#  ('broken', 27),
#  ('200ml', 27),
#  ('jar', 27),
#  ('puff', 27),
#  ('thyme', 26),
#  ('125g', 26),
#  ('salted', 26),
#  ('300ml', 26),
#  ('crushed', 25),
#  ('flaked', 25),
#  ('jam', 25),
#  ('frozen', 24),
#  ('you', 24),
#  ('(we', 24),
#  ('seeds', 24),
#  ('toasted', 24),
#  ('can', 24),
#  ('stem', 24),
#  ('(see', 24),
#  ('750g', 23),
#  ('very', 23),
#  ('natural', 23),
#  ('Christmas', 23),
#  ('each', 23),
#  ('8', 23),
#  ('shortcrust', 22),
#  ('maple', 22),
#  ('rum', 22),
#  ('coconut', 22),
#  ('gold', 21),
#  ('blanched', 21),
#  ('well', 21),
#  ('room', 21),
#  ('orange,', 21),
#  ('12', 21),
#  ('50ml', 21),
#  ('cold', 21),
#  ('sunflower', 21),
#  ('breadcrumbs', 20),
#  ('lightly', 20),
#  ('ready-rolled', 20),
#  ('colouring', 20),
#  ('tin', 20),
#  ('use', 20),
#  ('bunch', 20),
#  ('water', 20),
#  ('wine', 20),
#  ('cranberry', 20),
#  ('balls', 19),
#  ('raisins', 19),
#  ('salt', 19),
#  ('tub', 19),
#  ('rolling', 19),
#  ('at', 18),
#  ('cubes', 18),
#  ('ribbon', 18),
#  ('sultanas', 18),
#  ('as', 18),
#  ('zested', 18),
#  ('450g', 18),
#  ('mini', 18),
#  ('whites', 18),
#  ('good-quality', 18),
#  ('vegetable', 18),
#  ('glaze', 17),
#  ('cherry,', 17),
#  ('honey', 17),
#  ('sweet', 17),
#  ('raisin', 17),
#  ('yolks', 17),
#  ('thinly', 17),
#  ('cooked', 17),
#  ('cored', 17),
#  ('below)', 17),
#  ('round', 17),
#  ('chopped,', 17),
#  ('mustard', 17),
#  ('onions,', 17),
#  ('ready-made', 16),
#  ('freshly', 16),
#  ('slices', 16),
#  ('bag', 16),
#  ('half', 16),
#  ('ginger,', 16),
#  ('out', 16),
#  ('peeled,', 16),
#  ('cream,', 16),
#  ('jam,', 16),
#  ('(or', 16),
#  ('cubed', 16),
#  ('crème', 16),
#  ('smoked', 16),
#  ('280g', 15),
#  ('yogurt', 15),
#  ('yolk', 15),
#  ('thin', 15),
#  ('treacle', 15),
#  ('temperature', 15),
#  ('30g', 15),
#  ('drained', 15),
#  ('vinegar', 15),
#  ('chicken', 14),
#  ('cherries', 14),
#  ('sprigs', 14),
#  ('sieved', 14),
#  ('clear', 14),
#  ('(about', 14),
#  ('leftover', 14),
#  ('284ml', 14),
#  ('leaves,', 14),
#  ('apple', 14),
#  ('cloves,', 14),
#  ('paste', 14),
#  ('1kg', 13),
#  ('cherries,', 13),
#  ('candied', 13),
#  ('sultana', 13),
#  ('soured', 13),
#  ('20cm', 13),
#  ('leaf', 13),
#  ('stock', 13),
#  ('streaky', 13),
#  ('gluten-free', 13),
#  ('cherry', 12),
#  ('700g', 12),
#  ('such', 12),
#  ('breadcrumb', 12),
#  ('mascarpone', 12),
#  ('crumbled', 12),
#  ('eating', 12),
#  ('strong', 12),
#  ('parsley,', 12),
#  ('120g', 12),
#  ('600g', 12),
#  ('warmed', 12),
#  ('pork', 12),
#  ('lemon,', 12),
#  ('knob', 11),
#  ('mix', 11),
#  ('currant', 11),
#  ('thick', 11),
#  ('good', 11),
#  ('142ml', 11),
#  ('splash', 11),
#  ('fine', 11),
#  ('shelled', 11),
#  ('dust', 11),
#  ("'Goes", 11),
#  ('buttermilk', 11),
#  ('frying', 11),
#  ('500ml', 11),
#  ('fraîche', 11),
#  ('sauce', 11),
#  ('pepper', 11),
#  ('apricots,', 10),
#  ('allspice', 10),
#  ('pecan', 10),
#  ('quartered', 10),
#  ('clementines', 10),
#  ('600ml', 10),
#  ('ice', 10),
#  ('carton', 10),
#  ('writing', 10),
#  ('packs', 10),
#  ('2-3', 10),
#  ('40g', 10),
#  ('nuts', 10),
#  ('cumin', 10),
#  ('rashers', 10),
#  ('bacon', 10),
#  ('biscuit', 10),
#  ('block', 10),
#  ('picked', 10),
#  ('deseeded', 10),
#  ('raisins,', 9),
#  ('approx', 9),
#  ('oranges', 9),
#  ('custard', 9),
#  ('apples,', 9),
#  ('vegetarian', 9),
#  ('sheets', 9),
#  ('melted,', 9),
#  ('bar', 9),
#  ('bread', 9),
#  ('yeast', 9),
#  ('like', 9),
#  ('pitted', 9),
#  ('sprinkles,', 9),
#  ('225ml', 9),
#  ('shallots,', 9),
#  ('wholegrain', 9),
#  ('star', 9),
#  ('stoned', 9),
#  ('rice', 9),
#  ('milk,', 9),
#  ('desiccated', 9),
#  ('sage', 9),
#  ('see', 9),
#  ('10', 9),
#  ('cranberries,', 8),
#  ('luxury', 8),
#  ('more', 8),
#  ('biscuits,', 8),
#  ('almond,', 8),
#  ('cup', 8),
#  ('almonds,', 8),
#  ('tubs', 8),
#  ('sprinkling', 8),
#  ('shredded', 8),
#  ('suet', 8),
#  ('jelly', 8),
#  ('separated', 8),
#  ('then', 8),
#  ('royal', 8),
#  ('liqueur', 8),
#  ('wholemeal', 8),
#  ('date,', 8),
#  ('cooled', 8),
#  ('cake(see', 8),
#  ('make', 8),
#  ('granulated', 8),
#  ('80g', 8),
#  ('slightly', 8),
#  ("with'", 8),
#  ('juiced', 8),
#  ('peppercorns', 8),
#  ('your', 8),
#  ('ham,', 8),
#  ('grating', 8),
#  ('hot', 8),
#  ('butternut', 8),
#  ('cheese,', 8),
#  ('shallot,', 8),
#  ('320g', 8),
#  ('chilli', 8),
#  ('digestive', 8),
#  ('all-butter', 8),
#  ('lime', 8),
#  ('ripe', 8),
#  ('9', 7),
#  ('peel,', 7),
#  ('walnut', 7),
#  ('scraped', 7),
#  ('demerara', 7),
#  ('split', 7),
#  ('packet', 7),
#  ('mace', 7),
#  ('potato,', 7),
#  ('filo', 7),
#  ('walnuts,', 7),
#  ('800g', 7),
#  ('left', 7),
#  ('biscuits', 7),
#  ('rest', 7),
#  ('clove,', 7),
#  ('nutmeg,', 7),
#  ('sifted,', 7),
#  ('ribbon,', 7),
#  ('pistachio', 7),
#  ('liquid', 7),
#  ('75ml', 7),
#  ('apple,', 7),
#  ('bean', 7),
#  ('hazelnuts,', 7),
#  ('crystallised', 7),
#  ('250ml', 7),
#  ('square', 7),
#  ('glitter', 7),
#  ('cutter', 7),
#  ('chilled', 7),
#  ('sage,', 7),
#  ('syrup,', 7),
#  ('180g', 7),
#  ('is', 7),
#  ('gelatine', 7),
#  ('strips', 7),
#  ('65cm', 7),
#  ('pineapple', 7),
#  ('pine', 7),
#  ('parsley', 7),
#  ('ready-to-eat', 6),
#  ('chestnut,', 6),
#  ('skinless', 6),
#  ('root', 6),
#  ('sprinkles', 6),
#  ('sweets,', 6),
#  ('amaretti', 6),
#  ('1-2', 6),
#  ('brandy,', 6),
#  ('currants', 6),
#  ('Grand', 6),
#  ('rinsed', 6),
#  ('sea', 6),
#  ('Bramley', 6),
#  ('it', 6),
#  ('beaten,', 6),
#  ('sprigs,', 6),
#  ('Waitrose', 6),
#  ('temperature,', 6),
#  ('cocktail', 6),
#  ('sticks', 6),
#  ('sprig', 6),
#  ('rolled', 6),
#  ('heaped', 6),
#  ('<a', 6),
#  ('apricot,', 6),
#  ('pecan,', 6),
#  ('pears,', 6),
#  ('juice,', 6),
#  ('glazing', 6),
#  ('coriander', 6),
#  ('125ml', 6),
#  ('chestnut', 6),
#  ('meat', 6),
#  ('–', 6),
#  ('fork', 6),
#  ('coloured', 6),
#  ('other', 6),
#  ('kg', 6),
#  ('tomato', 6),
#  ('seed', 6),
#  ('185g', 6),
#  ('chilli,', 6),
#  ('sesame', 6),
#  ('cornflour', 6),
#  ('bread,', 6),
#  ('that', 5),
#  ('includes', 5),
#  ('cherries)', 5),
#  ('oz', 5),
#  ('nut', 5),
#  ('rum,', 5),
#  ('lustre', 5),
#  ('buttons', 5),
#  ('sultanas,', 5),
#  ('feeding', 5),
#  ('carrot,', 5),
#  ('Marnier', 5),
#  ('fig,', 5),
#  ('have', 5),
#  ('nuts,', 5),
#  ('pudding', 5),
#  ('an', 5),
#  ('pod,', 5),
#  ('pudding,', 5),
#  ('custard,', 5),
#  ('sour', 5),
#  ('powder,', 5),
#  ('Cointreau', 5),
#  ('holly', 5),
#  ('figs', 5),
#  ('solids)', 5),
#  ('quantity', 5),
#  ('link', 5),
#  ('16', 5),
#  ('rosemary,', 5),
#  ('lemons,', 5),
#  ('7g', 5),
#  ('sachet', 5),
#  ('fast-action', 5),
#  ('smooth', 5),
#  ('drops', 5),
#  ('glucose', 5),
#  ('wide', 5),
#  ('20g', 5),
#  ('oats', 5),
#  ('coarsely', 5),
#  ('Granny', 5),
#  ("'goes", 5),
#  ('icing,', 5),
#  ('single', 5),
#  ('1cm', 5),
#  ('semi-dried', 5),
#  ('figs,', 5),
#  ('walnut,', 5),
#  ('recipe)', 5),
#  ('piece', 5),
#  ('per', 5),
#  ('fat', 5),
#  ('not', 5),
#  ('wedges', 5),
#  ('175ml', 5),
#  ('marzipan,', 5),
#  ('English', 5),
#  ('tea', 5),
#  ('semi-skimmed', 5),
#  ('white,', 5),
#  ('nut,', 5),
#  ('hazelnut', 5),
#  ('squash', 5),
#  ('onion', 5),
#  ('red,', 5),
#  ('polenta', 5),
#  ('hazelnuts', 5),
#  ('creamor', 5),
#  ('Doves', 5),
#  ('raspberry', 5),
#  ('boiled', 5),
#  ('brushing', 5),
#  ('anise', 5),
#  ('vegan', 5),
#  ('piping', 5),
#  ('removed', 5),
#  ('400ml', 5),
#  ('spring', 5),
#  ('stick', 5),
#  ('trimmed', 5),
#  ('flat-leaf', 5),
#  ('removed,', 5),
#  ('mince', 5),
#  ('board', 5),
#  ('Maris', 5),
#  ('tube', 5),
#  ('tip)', 5),
#  ('chives,', 5),
#  ('salmon', 5),
#  ('macadamia', 4),
#  ('warm', 4),
#  ('snowflake', 4),
#  ('spray', 4),
#  ('currants,', 4),
#  ('prunes', 4),
#  ('optional', 4),
#  ('sherry,', 4),
#  ('rosewater', 4),
#  ('hazelnut,', 4),
#  ('(from', 4),
#  ('one', 4),
#  ('240g', 4),
#  ('30ml', 4),
#  ('stout', 4),
#  ('box', 4),
#  ('fridge', 4),
#  ('sticks,', 4),
#  ('leek,', 4),
#  ('mushroom,', 4),
#  ('pinches', 4),
#  ('madeira', 4),
#  ('paper', 4),
#  ('fruits', 4),
#  ('cocoa,', 4),
#  ('espresso', 4),
#  ('(70%', 4),
#  ('pecansor', 4),
#  ('toasted,', 4),
#  ('cloudy', 4),
#  ('fruit(the', 4),
#  ('kind', 4),
#  ('peel)', 4),
#  ('balls,', 4),
#  ('drizzle', 4),
#  ('¾', 4),
#  ('yolk,', 4),
#  ('brown,', 4),
#  ('tie', 4),
#  ('sauce,', 4),
#  ('molasses', 4),
#  ('170g', 4),
#  ('Kilner', 4),
#  ('410g', 4),
#  ("with')", 4),
#  ('thawed', 4),
#  ('425g', 4),
#  ('pear,', 4),
#  ('chip', 4),
#  ('glitter(optional)', 4),
#  ('dates,', 4),
#  ('pud)', 4),
#  ('oranges,', 4),
#  ('jar,', 4),
#  ('Greek', 4),
#  ('generous', 4),
#  ('dates', 4),
#  ('pistachios,', 4),
#  ('rings', 4),
#  ('cayenne', 4),
#  ('peppermintextract', 4),
#  ('on', 4),
#  ('2½', 4),
#  ('vacuum-packed', 4),
#  ('24', 4),
#  ('clove', 4),
#  ('15g', 4),
#  ('yolks,', 4),
#  ('together', 4),
#  ('Smarties', 4),
#  ('turkey', 4),
#  ('mature', 4),
#  ('flakes', 4),
#  ('gingerbread', 4),
#  ('colours', 4),
#  ('411g', 4),
#  ('thickly', 4),
#  ('sweets', 4),
#  ('dill,', 4),
#  ('Brazil', 4),
#  ('wateror', 4),
#  ('plastic', 4),
#  ('lengthways', 4),
#  ('purée', 4),
#  ('drizzling', 4),
#  ('cider', 4),
#  ('rapeseed', 4),
#  ('icingcoloured', 4),
#  ('beef', 4),
#  ('blue', 4),
#  ('preferably', 4),
#  ('leaf,', 4),
#  ('sherry', 4),
#  ('cranberrysauce', 4),
#  ('prunes,', 4),
#  ('shop-bought', 4),
#  ('homemade', 4),
#  ('cheddar,', 4),
#  ('fruit,', 4),
#  ('dessert', 4),
#  ('chutney', 4),
#  ('cm', 4),
#  ('only', 4),
#  ('are', 4),
#  ('need', 4),
#  ('salad', 4),
#  ('bought', 4),
#  ('snipped', 4),
#  ('fruitcake', 4),
#  ('sausagemeat', 3),
#  ('skinned', 3),
#  ('sausages', 3),
#  ('1tsp', 3),
#  ('boneless,', 3),
#  ('fl', 3),
#  ('pecannuts,', 3),
#  ('marmalade', 3),
#  ('available', 3),
#  ('whisky', 3),
#  ('walnuts', 3),
#  ('raisin,', 3),
#  ('natural-coloured', 3),
#  ('around', 3),
#  ('pod', 3),
#  ('pods,', 3),
#  ('find', 3),
#  ('quarters', 3),
#  ('caraway', 3),
#  ('cranberry,', 3),
#  ('20', 3),
#  ('honey,', 3),
#  ('250g/9oz', 3),
#  ('satsumas,', 3),
#  ('decorations', 3),
#  ('coffee', 3),
#  ('Tia', 3),
#  ('curls', 3),
#  ('cake,', 3),
#  ('clementines,', 3),
#  ('blossom', 3),
#  ('mango,', 3),
#  ('balls)', 3),
#  ('cans', 3),
#  ('tomatoes', 3),
#  ('like)', 3),
#  ('cases', 3),
#  ('segments', 3),
#  ('pieces,', 3),
#  ('1.2kg', 3),
#  ('pretzels,', 3),
#  ('string', 3),
#  ('brandyor', 3),
#  ('fruitcake,', 3),
#  ('spice,', 3),
#  ('Cointreauor', 3),
#  ('chia', 3),
#  ('sticking', 3),
#  ('icingor', 3),
#  ('1l', 3),
#  ('gift', 3),
#  ('bars', 3),
#  ('20cm-wide', 3),
#  ('runny', 3),
#  ('stand', 3),
#  ('sheet', 3),
#  ('dice', 3),
#  ('grated,', 3),
#  ('giant', 3),
#  ('hanging', 3),
#  ('pineapple,', 3),
#  ('(including', 3),
#  ('tubes', 3),
#  ('different', 3),
#  ('60g', 3),
#  ('pistachios', 3),
#  ('900g', 3),
#  ('mixture', 3),
#  ('pecans,', 3),
#  ('lemons', 3),
#  ('(use', 3),
#  ('any', 3),
#  ('ball', 3),
#  ('gingerfrom', 3),
#  ('regal', 3),
#  ('malt', 3),
#  ('270g', 3),
#  ('loaf', 3),
#  ('clotted', 3),
#  ('squash,', 3),
#  ('mint,', 3),
#  ('harissa', 3),
#  ('7', 3),
#  ('own', 3),
#  ('roll', 3),
#  ('leeks,', 3),
#  ('potatoes,', 3),
#  ('ham', 3),
#  ('boiling', 3),
#  ('whipped', 3),
#  ('crustless', 3),
#  ('l', 3),
#  ('pancetta', 3),
#  ('200g/7oz', 3),
#  ('18cm', 3),
#  ("with',", 3),
#  ('milkor', 3),
#  ('pearl', 3),
#  ('preserving', 3),
#  ('cutters', 3),
#  ('15', 3),
#  ('sageleaves,', 3),
#  ('cinnamon,', 3),
#  ('tip,', 3),
#  ('baby', 3),
#  ('tarragon', 3),
#  ('taste', 3),
#  ('buttons,', 3),
#  ('cellophane', 3),
#  ('squares', 3),
#  ('celery', 3),
#  ('whipping', 3),
#  ('Dijon', 3),
#  ('Brussels', 3),
#  ('long', 3),
#  ("goat's", 3),
#  ('salad,', 3),
#  ('ricotta', 3),
#  ('350ml', 3),
#  ('prosecco', 3),
#  ('scattering', 3),
#  ('new', 3),
#  ('torn', 3),
#  ('curd', 3),
#  ('chocolate(70%', 3),
#  ('colourless', 3),
#  ('alcohol', 3),
#  ('sugarpaste(fondant)', 3),
#  ('lid', 3),
#  ('bags', 3),
#  ('length', 3),
#  ('firm', 3),
#  ('plum', 3),
#  ('carrots,', 3),
#  ('goes', 3),
#  ('rye', 3),
#  ('wooden', 3),
#  ('weight),', 3),
#  ('parmesan(or', 3),
#  ('alternative),', 3),
#  ('cookie', 3),
#  ('juice(from', 3),
#  ('above)', 3),
#  ('colouringpaste', 3),
#  ('breast', 3),
#  ('lean', 3),
#  ('poppy', 3),
#  ('skin', 3),
#  ('2cm/¾', 3),
#  ('300g/11oz', 3),
#  ('bones', 3),
#  ('650g', 3),
#  ('(save', 3),
#  ('dry', 3),
#  ('seedless', 3),
#  ('2x', 3),
#  ('marshmallows', 3),
#  ('low-fat', 3),
#  ('squeezed', 3),
#  ('apricots', 3),
#  ('paprika', 3),
#  ('below', 3),
#  ('roasted', 3),
#  ('garnish', 3),
#  ('potatoes', 3),
#  ('paste)', 3),
#  ('tins', 3),
#  ('mint', 3),
#  ('topping', 3),
#  ('18-23cm', 3),
#  ('drained,', 3),
#  ('(you', 3),
#  ('sparkles,', 3),
#  ('pistachio,', 3),
#  ('crusts', 3),
#  ('minced', 3),
#  ('cheese)', 3),
#  ('160g', 3),
#  ('Savoy', 3),
#  ('coconut,', 3),
#  ('100ml/3½', 2),
#  ('4tbsp', 2),
#  ('85g/3oz', 2),
#  ('Dr', 2),
#  ('pens,', 2),
#  ('cubes,', 2),
#  ('rosemary', 2),
#  ('Lindt', 2),
#  ('fruit(use', 2),
#  ('figs)', 2),
#  ('tropical', 2),
#  ('10cm', 2),
#  ('hollysprig,', 2),
#  ('feed', 2),
#  ('Sundora)', 2),
#  ('big', 2),
#  ('wine,', 2),
#  ('bread)', 2),
#  ('flaky', 2),
#  ('110g', 2),
#  ('cooking', 2),
#  ('pieces)', 2),
#  ('all', 2),
#  ('three', 2),
#  ('lumpy', 2),
#  ('taken', 2),
#  ('straight', 2),
#  ('bowl', 2),
#  ('can,', 2),
#  ('berries', 2),
#  ('Baileys', 2),
#  ('solids,', 2),
#  ('Maria', 2),
#  ('beans', 2),
#  ('uncooked', 2),
#  ('fronds', 2),
#  ('1m', 2),
#  ('whole,', 2),
#  ('pear', 2),
#  ('120ml', 2),
#  ('brandy(optional)', 2),
#  ('cranberriesor', 2),
#  ('crisp', 2),
#  ('Christmassy', 2),
#  ('cornmeal', 2),
#  ('muffin', 2),
#  ('48', 2),
#  ('across', 2),
#  ('top)', 2),
#  ('12cm', 2),
#  ('Disaronno', 2),
#  ('easy-blend', 2),
#  ('below),', 2),
#  ('base', 2),
#  ('fig', 2),
#  ('flower', 2),
#  ('dairy-free', 2),
#  ('yellow', 2),
#  ('colour', 2),
#  ('shred', 2),
#  ('enough', 2),
#  ('boardor', 2),
#  ('pastry,', 2),
#  ('sheets)', 2),
#  ("Sainsbury's", 2),
#  ('button', 2),
#  ('string,', 2),
#  ('100g/4oz', 2),
#  ('colourful', 2),
#  ('ones', 2),
#  ('slices,', 2),
#  ('pineapple)', 2),
#  ('Suits-all', 2),
#  ('sizes', 2),
#  ('colours,', 2),
#  ('115g', 2),
#  ('we', 2),
#  ('our', 2),
#  ('recipe</a>', 2),
#  ('carrot', 2),
#  ('currant,', 2),
#  ('light,', 2),
#  ('flavourless', 2),
#  ("don't", 2),
#  ('rich', 2),
#  ('malted', 2),
#  ('full', 2),
#  ('cheese(we', 2),
#  ('mincemeat(about', 2),
#  ('ciabatta', 2),
#  ('spinach', 2),
#  ('medjool', 2),
#  ('slices)', 2),
#  ('stilton,', 2),
#  ('brie', 2),
#  ('undyed)', 2),
#  ('1¼kg', 2),
#  ('plenty', 2),
#  ('bundt', 2),
#  ('camembertin', 2),
#  ('325g', 2),
#  ('chestnuts,', 2),
#  ('thyme,', 2),
#  ('stripped', 2),
#  ('raspberryor', 2),
#  ('1.3kg', 2),
#  ('fraîche,', 2),
#  ('frothed', 2),
#  ('made', 2),
#  ('sugaror', 2),
#  ('glitter,', 2),
#  ('sausagemeator', 2),
#  ('Regal-Ice', 2),
#  ('Ready', 2),
#  ('Roll', 2),
#  ('reserving', 2),
#  ('black,', 2),
#  ('top', 2),
#  ('right)', 2),
#  ('spinach,', 2),
#  ('washed', 2),
#  ('semolina,', 2),
#  ('pepper,', 2),
#  ('cardboard', 2),
#  ('gravy', 2),
#  ('25g/1oz', 2),
#  ('sprinkle', 2),
#  ('sprouts,', 2),
#  ('mashed', 2),
#  ('gin', 2),
#  ('vermouth', 2),
#  ('20ml', 2),
#  ('cupcake', 2),
#  ('using', 2),
#  ('25ml', 2),
#  ('275g', 2),
#  ('cardamom', 2),
#  ('pods', 2),
#  ('tip', 2),
#  ('ribbonor', 2),
#  ('chocolatecurls', 2),
#  ...]

# %%
total_method = Counter()
baked_method = Counter()

for i in range(len(data)):
    if expected_data[i] == "Baked Good":
        for j in range(len(data[i]['Method'])):       
            if data[i]['Method'] != None:
                for word in data[i]['Method'][j].split(" "):
                    baked_method[word] += 2.8
                    total_method[word] += 2.8
                
baked_method.most_common()
# Out:
# [('the', 26919.19999999551),
#  ('and', 12101.59999999936),
#  ('a', 11661.999999999474),
#  ('to', 8458.800000000307),
#  ('in', 5773.600000000219),
#  ('with', 5516.000000000202),
#  ('of', 5146.400000000178),
#  ('for', 4169.200000000114),
#  ('then', 4132.800000000112),
#  ('until', 3371.2000000000626),
#  ('into', 3040.800000000041),
#  ('on', 2158.799999999984),
#  ('out', 1696.7999999999822),
#  ('over', 1693.9999999999823),
#  ('or', 1660.3999999999828),
#  ('it', 1517.5999999999851),
#  ('heat', 1503.5999999999854),
#  ('mins', 1475.5999999999858),
#  ('cake', 1450.3999999999862),
#  ('you', 1363.5999999999876),
#  ('oven', 1357.9999999999877),
#  ('icing', 1332.7999999999881),
#  ('add', 1313.1999999999884),
#  ('baking', 1293.5999999999888),
#  ('make', 1240.3999999999896),
#  ('mix', 1142.3999999999912),
#  ('sugar', 1125.5999999999915),
#  ('put', 1063.9999999999925),
#  ('leave', 1044.3999999999928),
#  ('butter', 1041.5999999999929),
#  ('bake', 1027.599999999993),
#  ('top', 1021.9999999999932),
#  ('cool', 957.5999999999942),
#  ('pastry', 929.5999999999947),
#  ('up', 929.5999999999947),
#  ('each', 907.199999999995),
#  ('stir', 904.3999999999951),
#  ('from', 859.5999999999958),
#  ('tin', 848.399999999996),
#  ('if', 837.1999999999962),
#  ('little', 831.5999999999963),
#  ('is', 820.3999999999965),
#  ('large', 806.3999999999967),
#  ('your', 778.3999999999971),
#  ('roll', 769.9999999999973),
#  ('mixture', 753.1999999999975),
#  ('1', 750.3999999999976),
#  ('cut', 750.3999999999976),
#  ('together', 730.7999999999979),
#  ('cover', 719.5999999999981),
#  ('2', 719.5999999999981),
#  ('use', 716.7999999999981),
#  ('remaining', 694.3999999999985),
#  ('bowl', 677.5999999999988),
#  ('as', 666.399999999999),
#  ('fan/gas', 666.399999999999),
#  ('at', 663.599999999999),
#  ('onto', 660.799999999999),
#  ('remove', 652.3999999999992),
#  ('spoon', 621.5999999999997),
#  ('all', 618.7999999999997),
#  ('using', 618.7999999999997),
#  ('line', 613.1999999999998),
#  ('pour', 613.1999999999998),
#  ('tip', 607.5999999999999),
#  ('will', 596.4000000000001),
#  ('an', 585.2000000000003),
#  ('small', 582.4000000000003),
#  ('set', 562.8000000000006),
#  ('–', 557.2000000000007),
#  ('water', 554.4000000000008),
#  ('about', 543.200000000001),
#  ('beat', 540.400000000001),
#  ('', 540.400000000001),
#  ('brush', 523.6000000000013),
#  ('chocolate', 515.2000000000014),
#  ('mins.', 506.80000000000143),
#  ('flour', 506.80000000000143),
#  ('half', 501.2000000000014),
#  ('dough', 495.6000000000014),
#  ('cook', 487.20000000000135),
#  ('be', 487.20000000000135),
#  ('egg', 484.40000000000134),
#  ('one', 481.60000000000133),
#  ('pan', 481.60000000000133),
#  ('can', 478.8000000000013),
#  ('mins,', 476.0000000000013),
#  ('them', 453.6000000000012),
#  ('place', 450.8000000000012),
#  ('lightly', 445.2000000000012),
#  ('around', 439.60000000000116),
#  ('30', 428.4000000000011),
#  ('gently', 428.4000000000011),
#  ('whisk', 420.0000000000011),
#  ('off', 408.80000000000103),
#  ('so', 408.80000000000103),
#  ('cream', 406.000000000001),
#  ('turn', 403.200000000001),
#  ('chill', 403.200000000001),
#  ('any', 403.200000000001),
#  ('keep', 397.600000000001),
#  ('when', 397.600000000001),
#  ('flour,', 392.00000000000097),
#  ('this', 389.20000000000095),
#  ('10', 386.40000000000094),
#  ('tbsp', 383.60000000000093),
#  ('surface', 383.60000000000093),
#  ('serve', 380.8000000000009),
#  ('down', 378.0000000000009),
#  ('just', 372.4000000000009),
#  ('cling', 372.4000000000009),
#  ('have', 369.6000000000009),
#  ('5', 364.00000000000085),
#  ('before', 364.00000000000085),
#  ('few', 364.00000000000085),
#  ('golden', 361.20000000000084),
#  ('well', 361.20000000000084),
#  ('some', 355.6000000000008),
#  ('smooth', 352.8000000000008),
#  ('tin.', 344.4000000000008),
#  ('are', 344.4000000000008),
#  ('sugar,', 341.60000000000076),
#  ('bowl,', 341.60000000000076),
#  ('pudding', 338.80000000000075),
#  ('bring', 336.00000000000074),
#  ('base', 336.00000000000074),
#  ('sides', 336.00000000000074),
#  ('more', 336.00000000000074),
#  ('stick', 330.4000000000007),
#  ('press', 327.6000000000007),
#  ('food', 324.8000000000007),
#  ('fold', 319.20000000000067),
#  ('orange', 316.40000000000066),
#  ('by', 316.40000000000066),
#  ('spread', 308.0000000000006),
#  ('two', 305.2000000000006),
#  ('comes', 299.6000000000006),
#  ('sheet', 296.8000000000006),
#  ('3', 296.8000000000006),
#  ('butter,', 288.40000000000055),
#  ('cake.', 288.40000000000055),
#  ('melt', 285.60000000000053),
#  ('tin,', 282.8000000000005),
#  ('has', 280.0000000000005),
#  ('skewer', 280.0000000000005),
#  ('once', 277.2000000000005),
#  ('enough', 277.2000000000005),
#  ('milk', 274.4000000000005),
#  ('4.', 271.6000000000005),
#  ('oil', 268.80000000000047),
#  ('wrap', 268.80000000000047),
#  ('centre', 260.40000000000043),
#  ('eggs', 260.40000000000043),
#  ('film', 257.6000000000004),
#  ('another', 254.80000000000044),
#  ('4', 252.00000000000043),
#  ('cool.', 249.20000000000041),
#  ('but', 249.20000000000041),
#  ('tsp', 249.20000000000041),
#  ('dry', 246.4000000000004),
#  ('warm', 246.4000000000004),
#  ('20', 246.4000000000004),
#  ('15', 243.6000000000004),
#  ('fridge', 243.6000000000004),
#  ('parchment.', 243.6000000000004),
#  ('bowl.', 240.80000000000038),
#  ('180c/160c', 240.80000000000038),
#  ('between', 240.80000000000038),
#  ('melted', 238.00000000000037),
#  ('edges', 235.20000000000036),
#  ('round', 235.20000000000036),
#  ('sprinkle', 235.20000000000036),
#  ('rest', 232.40000000000035),
#  ('white', 232.40000000000035),
#  ('6.', 232.40000000000035),
#  ('layer', 229.60000000000034),
#  ('foil', 229.60000000000034),
#  ('transfer', 226.80000000000032),
#  ('that', 224.0000000000003),
#  ('while', 221.2000000000003),
#  ('trim', 218.4000000000003),
#  ('syrup', 218.4000000000003),
#  ('back', 215.60000000000028),
#  ('fruit', 212.80000000000027),
#  ('parchment', 212.80000000000027),
#  ('x', 212.80000000000027),
#  ('dust', 212.80000000000027),
#  ('they', 210.00000000000026),
#  ('wire', 210.00000000000026),
#  ('top.', 210.00000000000026),
#  ('carefully', 210.00000000000026),
#  ('20cm', 207.20000000000024),
#  ('marzipan', 207.20000000000024),
#  ('ingredients', 207.20000000000024),
#  ('grease', 207.20000000000024),
#  ('through', 207.20000000000024),
#  ('scatter', 207.20000000000024),
#  ('floured', 204.40000000000023),
#  ('middle', 204.40000000000023),
#  ('tray', 204.40000000000023),
#  ('sugar.', 201.60000000000022),
#  ('vanilla', 201.60000000000022),
#  ('lift', 201.60000000000022),
#  ('biscuits', 201.60000000000022),
#  ('knead', 201.60000000000022),
#  ('pie', 198.8000000000002),
#  ('meanwhile,', 198.8000000000002),
#  ('knife', 198.8000000000002),
#  ('very', 196.0000000000002),
#  ('smooth.', 193.2000000000002),
#  ('paper', 193.2000000000002),
#  ('hr', 193.2000000000002),
#  ('work', 190.40000000000018),
#  ('need', 187.60000000000016),
#  ('take', 187.60000000000016),
#  ('side', 187.60000000000016),
#  ('hot', 184.80000000000015),
#  ('least', 184.80000000000015),
#  ('stirring', 182.00000000000014),
#  ('electric', 182.00000000000014),
#  ('cake,', 182.00000000000014),
#  ('water.', 179.20000000000013),
#  ('200c/180c', 179.20000000000013),
#  ('season', 176.40000000000012),
#  ('eggs,', 176.40000000000012),
#  ('aside', 176.40000000000012),
#  ('everything', 173.6000000000001),
#  ('divide', 173.6000000000001),
#  ('golden.', 173.6000000000001),
#  ('thick', 173.6000000000001),
#  ('aside.', 173.6000000000001),
#  ('not', 173.6000000000001),
#  ('decorate', 170.8000000000001),
#  ('zest', 170.8000000000001),
#  ('clean.', 170.8000000000001),
#  ('medium', 170.8000000000001),
#  ('time,', 170.8000000000001),
#  ('sit', 170.8000000000001),
#  ('lemon', 168.00000000000009),
#  ('salt', 162.40000000000006),
#  ('bottom', 162.40000000000006),
#  ('lay', 162.40000000000006),
#  ('pipe', 162.40000000000006),
#  ('soft', 162.40000000000006),
#  ('brown', 162.40000000000006),
#  ('excess', 159.60000000000005),
#  ('slice', 159.60000000000005),
#  ('together.', 159.60000000000005),
#  ('cool,', 156.80000000000004),
#  ('water,', 156.80000000000004),
#  ('like', 156.80000000000004),
#  ('icing.', 156.80000000000004),
#  ('shape', 156.80000000000004),
#  ('fill', 156.80000000000004),
#  ('pan,', 154.00000000000003),
#  ('tart', 154.00000000000003),
#  ('pinch', 154.00000000000003),
#  ('completely', 154.00000000000003),
#  ('don’t', 154.00000000000003),
#  ('rack', 151.20000000000002),
#  ('arrange', 151.20000000000002),
#  ('icing,', 151.20000000000002),
#  ('dough.', 148.4),
#  ('together,', 148.4),
#  ('circle', 148.4),
#  ('sauce', 148.4),
#  ('juice', 145.6),
#  ('stamp', 145.6),
#  ('processor', 145.6),
#  ('ready', 145.6),
#  ('days', 145.6),
#  ('end', 145.6),
#  ('thickness', 142.79999999999998),
#  ('cheese', 142.79999999999998),
#  ('boil', 142.79999999999998),
#  ('repeat', 142.79999999999998),
#  ('tins', 142.79999999999998),
#  ('piece', 142.79999999999998),
#  ('leaving', 142.79999999999998),
#  ('peel', 139.99999999999997),
#  ('muffin', 139.99999999999997),
#  ('cakes', 139.99999999999997),
#  ('mixing', 139.99999999999997),
#  ('6', 139.99999999999997),
#  ('allow', 139.99999999999997),
#  ('drizzle', 139.99999999999997),
#  ('deep', 137.19999999999996),
#  ('evenly', 137.19999999999996),
#  ('ground', 137.19999999999996),
#  ('it.', 137.19999999999996),
#  ('along', 137.19999999999996),
#  ('saucepan', 137.19999999999996),
#  ('leaves', 137.19999999999996),
#  ('firm', 134.39999999999995),
#  ('12', 134.39999999999995),
#  ('should', 134.39999999999995),
#  ('circles', 134.39999999999995),
#  ('get', 134.39999999999995),
#  ('plate', 134.39999999999995),
#  ('completely.', 131.59999999999994),
#  ('simmer', 131.59999999999994),
#  ('give', 131.59999999999994),
#  ('clean', 131.59999999999994),
#  ('mincemeat', 131.59999999999994),
#  ('pan.', 128.79999999999993),
#  ('butter.', 128.79999999999993),
#  ('other', 128.79999999999993),
#  ('help', 128.79999999999993),
#  ('fine', 125.99999999999991),
#  ('holes', 125.99999999999991),
#  ('batter', 125.99999999999991),
#  ('inserted', 125.99999999999991),
#  ('cold', 125.99999999999991),
#  ('balls', 125.99999999999991),
#  ('greaseproof', 125.99999999999991),
#  ('pieces', 123.19999999999992),
#  ('almonds', 123.19999999999992),
#  ('sift', 123.19999999999992),
#  ('cutter', 123.19999999999992),
#  ('same', 123.19999999999992),
#  ('airtight', 123.19999999999992),
#  ('(see', 123.19999999999992),
#  ('serve.', 123.19999999999992),
#  ('star', 123.19999999999992),
#  ('edge', 123.19999999999992),
#  ('serve,', 123.19999999999992),
#  ('made', 123.19999999999992),
#  ('well.', 120.39999999999992),
#  ('microwave', 120.39999999999992),
#  ('pulse', 120.39999999999992),
#  ('serving', 120.39999999999992),
#  ('spoon.', 120.39999999999992),
#  ('whizz', 120.39999999999992),
#  ('bag', 120.39999999999992),
#  ('egg,', 117.59999999999992),
#  ('again', 117.59999999999992),
#  ('powder', 117.59999999999992),
#  ('come', 117.59999999999992),
#  ('pale', 117.59999999999992),
#  ('filling', 117.59999999999992),
#  ('piping', 117.59999999999992),
#  ('slices', 117.59999999999992),
#  ('black', 117.59999999999992),
#  ('onion', 114.79999999999993),
#  ('brandy', 114.79999999999993),
#  ('boiling', 114.79999999999993),
#  ('biscuit', 114.79999999999993),
#  ('flat', 114.79999999999993),
#  ('non-stick', 114.79999999999993),
#  ('like.', 114.79999999999993),
#  ('overnight.', 114.79999999999993),
#  ('hand', 114.79999999999993),
#  ('return', 114.79999999999993),
#  ('whole', 111.99999999999993),
#  ('set.', 111.99999999999993),
#  ('prepared', 111.99999999999993),
#  ('paper.', 111.99999999999993),
#  ('pies', 111.99999999999993),
#  ('dish', 111.99999999999993),
#  ('now', 109.19999999999993),
#  ('level', 109.19999999999993),
#  ('rack.', 109.19999999999993),
#  ('it’s', 109.19999999999993),
#  ('mixed', 109.19999999999993),
#  ('wooden', 109.19999999999993),
#  ('frozen', 109.19999999999993),
#  ('away', 109.19999999999993),
#  ('rolling', 109.19999999999993),
#  ('simmering', 106.39999999999993),
#  ('ice', 106.39999999999993),
#  ('(or', 106.39999999999993),
#  ('sheets', 106.39999999999993),
#  ('still', 106.39999999999993),
#  ('ginger', 106.39999999999993),
#  ('slightly', 106.39999999999993),
#  ('sharp', 106.39999999999993),
#  ('cream,', 106.39999999999993),
#  ('big', 106.39999999999993),
#  ('low', 106.39999999999993),
#  ('surface.', 106.39999999999993),
#  ('thin', 106.39999999999993),
#  ('frying', 103.59999999999994),
#  ('beaten', 103.59999999999994),
#  ('dark', 103.59999999999994),
#  ('dried', 103.59999999999994),
#  ('top,', 103.59999999999994),
#  ('create', 103.59999999999994),
#  ('tie', 103.59999999999994),
#  ('making', 103.59999999999994),
#  ('mixture.', 103.59999999999994),
#  ('temperature', 103.59999999999994),
#  ('too', 100.79999999999994),
#  ('double', 100.79999999999994),
#  ('mixture,', 100.79999999999994),
#  ('steam', 100.79999999999994),
#  ('time', 100.79999999999994),
#  ('up.', 100.79999999999994),
#  ('its', 100.79999999999994),
#  ('let', 100.79999999999994),
#  ('chopped', 100.79999999999994),
#  ('cranberries', 100.79999999999994),
#  ('180c/gas', 100.79999999999994),
#  ('cooked', 100.79999999999994),
#  ('heat.', 97.99999999999994),
#  ('dip', 97.99999999999994),
#  ('light', 97.99999999999994),
#  ('pastry,', 97.99999999999994),
#  ('surface,', 97.99999999999994),
#  ('fluffy.', 97.99999999999994),
#  ('squeeze', 97.99999999999994),
#  ('three', 95.19999999999995),
#  ('nuts', 95.19999999999995),
#  ('further', 95.19999999999995),
#  ('freeze', 95.19999999999995),
#  ('juice,', 95.19999999999995),
#  ('risen', 95.19999999999995),
#  ('green', 95.19999999999995),
#  ('1-2', 95.19999999999995),
#  ('hole', 95.19999999999995),
#  ('soak', 95.19999999999995),
#  ('basin', 95.19999999999995),
#  ('roasting', 95.19999999999995),
#  ('3.', 95.19999999999995),
#  ('room', 95.19999999999995),
#  ('bay', 95.19999999999995),
#  ('oil,', 95.19999999999995),
#  ('fry', 92.39999999999995),
#  ('salt.', 92.39999999999995),
#  ('spices', 92.39999999999995),
#  ('extra', 92.39999999999995),
#  ('sure', 92.39999999999995),
#  ('£1', 92.39999999999995),
#  ('stars', 92.39999999999995),
#  ('want', 92.39999999999995),
#  ('brown.', 92.39999999999995),
#  ('bread', 92.39999999999995),
#  ('trimmings', 89.59999999999995),
#  ('reduce', 89.59999999999995),
#  ('every', 89.59999999999995),
#  ('parchment,', 89.59999999999995),
#  ('hrs', 89.59999999999995),
#  ('sieve', 89.59999999999995),
#  ('bit', 89.59999999999995),
#  ('roughly', 89.59999999999995),
#  ('200c/fan', 89.59999999999995),
#  ('rub', 89.59999999999995),
#  ('push', 89.59999999999995),
#  ('23cm', 89.59999999999995),
#  ('shapes', 86.79999999999995),
#  ('fruit,', 86.79999999999995),
#  ('minutes', 86.79999999999995),
#  ('there', 86.79999999999995),
#  ('first', 86.79999999999995),
#  ('foil.', 86.79999999999995),
#  ('almonds,', 86.79999999999995),
#  ('hrs,', 86.79999999999995),
#  ('day', 86.79999999999995),
#  ('8', 86.79999999999995),
#  ('salt,', 86.79999999999995),
#  ('case', 86.79999999999995),
#  ('combined.', 83.99999999999996),
#  ('caster', 83.99999999999996),
#  ('hrs.', 83.99999999999996),
#  ('cooled', 83.99999999999996),
#  ('cream.', 83.99999999999996),
#  ('strip', 83.99999999999996),
#  ('gradually', 83.99999999999996),
#  ('edges.', 83.99999999999996),
#  ('hands', 83.99999999999996),
#  ('pastry.', 81.19999999999996),
#  ('dusted', 81.19999999999996),
#  ('after', 81.19999999999996),
#  ('look', 81.19999999999996),
#  ('string', 81.19999999999996),
#  ('ribbon', 81.19999999999996),
#  ('halfway', 81.19999999999996),
#  ('crumbs', 81.19999999999996),
#  ('form', 81.19999999999996),
#  ('jam', 81.19999999999996),
#  ('combine', 81.19999999999996),
#  ('ball', 81.19999999999996),
#  ('smaller', 81.19999999999996),
#  ('trays', 81.19999999999996),
#  ('re-roll', 81.19999999999996),
#  ('potatoes', 81.19999999999996),
#  ('20-25', 78.39999999999996),
#  ('kitchen', 78.39999999999996),
#  ('may', 78.39999999999996),
#  ('custard', 78.39999999999996),
#  ('than', 78.39999999999996),
#  ('covered', 78.39999999999996),
#  ('sauce,', 78.39999999999996),
#  ('smooth,', 78.39999999999996),
#  ('tray.', 78.39999999999996),
#  ('mix.', 78.39999999999996),
#  ('(if', 78.39999999999996),
#  ('lid', 78.39999999999996),
#  ('scrape', 78.39999999999996),
#  ('160c/gas', 78.39999999999996),
#  ('slowly', 75.59999999999997),
#  ('check', 75.59999999999997),
#  ('fondant', 75.59999999999997),
#  ('12-hole', 75.59999999999997),
#  ('powder,', 75.59999999999997),
#  ('stand', 75.59999999999997),
#  ('liquid', 75.59999999999997),
#  ('days.', 75.59999999999997),
#  ('little.', 75.59999999999997),
#  ('start', 75.59999999999997),
#  ('180c/fan', 75.59999999999997),
#  ('cinnamon', 75.59999999999997),
#  ('cookie', 75.59999999999997),
#  ('pressing', 75.59999999999997),
#  ('5.', 72.79999999999997),
#  ('adding', 72.79999999999997),
#  ('hold', 61.59999999999997),
#  ('whites', 61.59999999999997),
#  ('rum', 61.59999999999997),
#  ('square', 61.59999999999997),
#  ('ahead', 61.59999999999997),
#  ('loaf', 61.59999999999997),
#  ('12-15', 61.59999999999997),
#  ('good', 61.59999999999997),
#  ('15-20', 61.59999999999997),
#  ('syrup.', 61.59999999999997),
#  ('serving.', 61.59999999999997),
#  ('egg.', 58.799999999999976),
#  ('soaked', 58.799999999999976),
#  ('colouring', 58.799999999999976),
#  ('lower', 58.799999999999976),
#  ('oven,', 58.799999999999976),
#  ('yolk', 58.799999999999976),
#  ('day,', 58.799999999999976),
#  ('next', 58.799999999999976),
#  ('through.', 58.799999999999976),
#  ('overnight', 58.799999999999976),
#  ('cooling', 58.799999999999976),
#  ('processor,', 58.799999999999976),
#  ('potato', 58.799999999999976),
#  ('best', 58.799999999999976),
#  ('crumbs.', 58.799999999999976),
#  ('under', 58.799999999999976),
#  ('maple', 58.799999999999976),
#  ('1cm', 58.799999999999976),
#  ('palette', 58.799999999999976),
#  ('garlic', 58.799999999999976),
#  ('base.', 58.799999999999976),
#  ('breadcrumbs.', 58.799999999999976),
#  ('starting', 58.799999999999976),
#  ('40', 58.799999999999976),
#  ('sandwich', 58.799999999999976),
#  ('onions', 58.799999999999976),
#  ('bacon', 58.799999999999976),
#  ('springform', 55.99999999999998),
#  ('scoop', 55.99999999999998),
#  ('cases.', 55.99999999999998),
#  ('second', 55.99999999999998),
#  ('looks', 55.99999999999998),
#  ('chilled', 55.99999999999998),
#  ('flour.', 55.99999999999998),
#  ('cheesecake', 55.99999999999998),
#  ('generously', 55.99999999999998),
#  ('fingers', 55.99999999999998),
#  ('kept', 55.99999999999998),
#  ('saucepan,', 55.99999999999998),
#  ('really', 55.99999999999998),
#  ('freezer', 55.99999999999998),
#  ('their', 55.99999999999998),
#  ('stiff', 55.99999999999998),
#  ('sides.', 55.99999999999998),
#  ('25-30', 55.99999999999998),
#  ('fridge.', 55.99999999999998),
#  ('two-thirds', 53.19999999999998),
#  ('-', 53.19999999999998),
#  ('gas', 53.19999999999998),
#  ('25', 53.19999999999998),
#  ('chocolate.', 53.19999999999998),
#  ('softened', 53.19999999999998),
#  ('plain', 53.19999999999998),
#  ('store', 53.19999999999998),
#  ('peel,', 53.19999999999998),
#  ('it,', 53.19999999999998),
#  ('slight', 53.19999999999998),
#  ('strips', 53.19999999999998),
#  ('seeds', 53.19999999999998),
#  ('third', 53.19999999999998),
#  ('10cm', 53.19999999999998),
#  ('apple', 53.19999999999998),
#  ('snip', 53.19999999999998),
#  ('drop', 53.19999999999998),
#  ('golden,', 53.19999999999998),
#  ('mini', 53.19999999999998),
#  ('worry', 53.19999999999998),
#  ('couple', 53.19999999999998),
#  ('halve', 53.19999999999998),
#  ('milk.', 53.19999999999998),
#  ('hr.', 53.19999999999998),
#  ('bun', 53.19999999999998),
#  ('ahead.', 53.19999999999998),
#  ('breadcrumbs,', 50.399999999999984),
#  ('pepper', 50.399999999999984),
#  ('silver', 50.399999999999984),
#  ('outside', 50.399999999999984),
#  ('film.', 50.399999999999984),
#  ('feed', 50.399999999999984),
#  ('honey', 50.399999999999984),
#  ('left', 50.399999999999984),
#  ('secure', 50.399999999999984),
#  ('thinly', 50.399999999999984),
#  ('film,', 50.399999999999984),
#  ('ends', 50.399999999999984),
#  ('7.', 50.399999999999984),
#  ('decorate,', 50.399999999999984),
#  ('pop', 50.399999999999984),
#  ('keeping', 50.399999999999984),
#  ('kettle', 50.399999999999984),
#  ('overhanging', 50.399999999999984),
#  ('basin.', 50.399999999999984),
#  ('size', 50.399999999999984),
#  ('soft,', 50.399999999999984),
#  ('and,', 50.399999999999984),
#  ('almond', 50.399999999999984),
#  ('trees', 50.399999999999984),
#  ('8cm', 50.399999999999984),
#  ('shelf', 50.399999999999984),
#  ('shallow', 50.399999999999984),
#  ('olive', 50.399999999999984),
#  ('prick', 50.399999999999984),
#  ('christmas', 47.59999999999999),
#  ('brownie', 47.59999999999999),
#  ('either', 47.59999999999999),
#  ('100g', 47.59999999999999),
#  ('grate', 47.59999999999999),
#  ('round,', 47.59999999999999),
#  ('mixer', 47.59999999999999),
#  ('loose-bottomed', 47.59999999999999),
#  ('edges,', 47.59999999999999),
#  ('1½', 47.59999999999999),
#  ('crumble', 47.59999999999999),
#  ('rounds', 47.59999999999999),
#  ('larger', 47.59999999999999),
#  ('time.', 47.59999999999999),
#  ('crisp.', 47.59999999999999),
#  ('ingredients,', 47.59999999999999),
#  ('tins.', 47.59999999999999),
#  ('splash', 47.59999999999999),
#  ('tea', 47.59999999999999),
#  ('beans', 47.59999999999999),
#  ('wet', 47.59999999999999),
#  ('5cm', 47.59999999999999),
#  ('shape,', 47.59999999999999),
#  ('pull', 47.59999999999999),
#  ('sauce.', 47.59999999999999),
#  ('reheat', 47.59999999999999),
#  ('sticky', 47.59999999999999),
#  ('jam.', 47.59999999999999),
#  ('coat', 47.59999999999999),
#  ('190c/170c', 47.59999999999999),
#  ('roof', 47.59999999999999),
#  ('crème', 47.59999999999999),
#  ('leaves,', 47.59999999999999),
#  ('sage', 47.59999999999999),
#  ('rectangle', 47.59999999999999),
#  ('minutes.', 44.79999999999999),
#  ('preheat', 44.79999999999999),
#  ('metal', 44.79999999999999),
#  ('spice', 44.79999999999999),
#  ('150ml', 44.79999999999999),
#  ('week', 44.79999999999999),
#  ('centre.', 44.79999999999999),
#  ('string.', 44.79999999999999),
#  ('quarter', 44.79999999999999),
#  ('(the', 44.79999999999999),
#  ('2cm', 44.79999999999999),
#  ('layers', 44.79999999999999),
#  ('warm,', 44.79999999999999),
#  ('caramel', 44.79999999999999),
#  ('(you', 44.79999999999999),
#  ('disc', 44.79999999999999),
#  ('out.', 44.79999999999999),
#  ('them.', 44.79999999999999),
#  ('more,', 44.79999999999999),
#  ('see', 44.79999999999999),
#  ('lumps', 44.79999999999999),
#  ('more.', 44.79999999999999),
#  ('fitted', 44.79999999999999),
#  ('pile', 44.79999999999999),
#  ('whisking', 44.79999999999999),
#  ('reserved', 44.79999999999999),
#  ('finely', 44.79999999999999),
#  ('wedges', 39.199999999999996),
#  ('170c/gas', 36.4),
#  ('pepper.', 36.4),
#  ('(about', 36.4),
#  ('cold,', 36.4),
#  ('months.', 36.4),
#  ('ready.', 36.4),
#  ('extract', 36.4),
#  ('creamy', 36.4),
#  (',', 36.4),
#  ('cloves,', 36.4),
#  ('flaked', 36.4),
#  ('10-12', 36.4),
#  ('drops', 36.4),
#  ('oven.', 36.4),
#  ('raisins,', 36.4),
#  ('bottom.', 36.4),
#  ('spices,', 36.4),
#  ('pleat', 36.4),
#  ('eggs.', 36.4),
#  ('leftover', 36.4),
#  ('handle,', 36.4),
#  ('(this', 36.4),
#  ('5-10', 36.4),
#  ('almost', 36.4),
#  ('24', 36.4),
#  ('needed.', 36.4),
#  ('soured', 36.4),
#  ('one,', 36.4),
#  ('oil.', 36.4),
#  ('later.', 36.4),
#  ('one.', 36.4),
#  ('rise', 36.4),
#  ('you’ll', 36.4),
#  ('seal.', 36.4),
#  ('dish.', 36.4),
#  ('tins,', 36.4),
#  ('0.5cm', 36.4),
#  ('18', 36.4),
#  ('ready-to-roll', 36.4),
#  ('pretty', 36.4),
#  ('30cm', 36.4),
#  ('slices,', 36.4),
#  ('pat', 36.4),
#  ('saucepan.', 36.4),
#  ('cutting', 36.4),
#  ('7cm', 36.4),
#  ('roast', 36.4),
#  ('topping.', 36.4),
#  ('stock', 36.4),
#  ('fish', 36.4),
#  ('occasionally.', 33.6),
#  ('been', 33.6),
#  ('hours', 33.6),
#  ('jam,', 33.6),
#  ('buttons', 33.6),
#  ('fluffy', 33.6),
#  ('balls.', 33.6),
#  ('½', 33.6),
#  ('spice,', 33.6),
#  ('coloured', 33.6),
#  ('out,', 33.6),
#  ('zest.', 33.6),
#  ('hours.', 33.6),
#  ('creamy.', 33.6),
#  ('mascarpone', 33.6),
#  ('fork', 33.6),
#  ('individual', 33.6),
#  ('fan/', 33.6),
#  ('puffed', 33.6),
#  ('little,', 33.6),
#  ('excess.', 33.6),
#  ('week.', 33.6),
#  ('quite', 33.6),
#  ('cakes,', 33.6),
#  ('place.', 33.6),
#  ('feels', 33.6),
#  ('four', 33.6),
#  ('size.', 33.6),
#  ('sheet,', 33.6),
#  ('ball,', 33.6),
#  ('cooked,', 33.6),
#  ('tiny', 33.6),
#  ('fairly', 33.6),
#  ('overnight,', 33.6),
#  ('where', 33.6),
#  ('cutters', 33.6),
#  ('sifted', 33.6),
#  ('min,', 33.6),
#  ('corners', 33.6),
#  ('plate,', 33.6),
#  ('leaves.', 33.6),
#  ('measure', 33.6),
#  ('mince', 33.6),
#  ('seasoning', 33.6),
#  ('shallots', 33.6),
#  ('garlic,', 33.6),
#  ('large,', 33.6),
#  ('layer.', 33.6),
#  ('cloves', 33.6),
#  ('unroll', 33.6),
#  ('buttercream', 33.6),
#  ('thickness.', 33.6),
#  ('pie,', 33.6),
#  ('lime', 33.6),
#  ('nutmeg,', 33.6),
#  ('softened.', 30.800000000000004),
#  ('hands,', 30.800000000000004),
#  ('lid.', 30.800000000000004),
#  ('minutes,', 30.800000000000004),
#  ('fan', 30.800000000000004),
#  ('cooked.', 30.800000000000004),
#  ('150c/130c', 30.800000000000004),
#  ('6cm', 30.800000000000004),
#  ('weeks.', 30.800000000000004),
#  ('tree,', 30.800000000000004),
#  ('pale,', 30.800000000000004),
#  ('attach', 30.800000000000004),
#  ('20-30', 30.800000000000004),
#  ('biscuits,', 30.800000000000004),
#  ('carrot', 30.800000000000004),
#  ('length', 30.800000000000004),
#  ('140c/120c', 30.800000000000004),
#  ('dissolve', 30.800000000000004),
#  ('stop', 30.800000000000004),
#  ('slightly,', 30.800000000000004),
#  ('double-line', 30.800000000000004),
#  ('whip', 30.800000000000004),
#  ('fridge,', 30.800000000000004),
#  ('spoon,', 30.800000000000004),
#  ('fruit.', 30.800000000000004),
#  ('filo', 30.800000000000004),
#  ('processor.', 30.800000000000004),
#  ('peaks', 30.800000000000004),
#  ('dissolved.', 30.800000000000004),
#  ('puds', 30.800000000000004),
#  ...]

# %%
other_ingredients = Counter()

for i in range(len(data)):
    if expected_data[i] == "Other":
        for j in range(len(data[i]['Ingredients'])):       
            if data[i]['Ingredients'] != None:
                for word in data[i]['Ingredients'][j].split(" "):
                    other_ingredients[word] += 1
                    total_ingredients[word] += 1
                
other_ingredients.most_common()
# Out:
# [('1', 2063),
#  ('tbsp', 1678),
#  ('2', 1519),
#  ('chopped', 970),
#  ('and', 833),
#  ('tsp', 794),
#  ('or', 501),
#  ('3', 490),
#  ('finely', 463),
#  ('of', 454),
#  ('sugar', 453),
#  ('100g', 451),
#  ('to', 447),
#  ('oil', 444),
#  ('4', 440),
#  ('large', 412),
#  ('50g', 390),
#  ('into', 386),
#  ('small', 376),
#  ('for', 361),
#  ('sliced', 359),
#  ('olive', 316),
#  ('½', 310),
#  ('plus', 306),
#  ('red', 300),
#  ('a', 300),
#  ('butter', 287),
#  ('cut', 282),
#  ('200g', 260),
#  ('grated', 255),
#  ('extra', 251),
#  ('juice', 251),
#  ('serve', 251),
#  ('white', 246),
#  ('leaves', 246),
#  ('caster', 242),
#  ('cream', 241),
#  ('garlic', 241),
#  ('fresh', 236),
#  ('ground', 230),
#  ('peeled', 230),
#  ('the', 210),
#  ('25g', 197),
#  ('pack', 193),
#  ('6', 191),
#  ('wine', 190),
#  ('dried', 188),
#  ('roughly', 187),
#  ('double', 186),
#  ('butter,', 184),
#  ('zest', 183),
#  ('vinegar', 173),
#  ('halved', 171),
#  ('golden', 162),
#  ('handful', 161),
#  ('flour', 158),
#  ('plain', 155),
#  ('onion,', 154),
#  ('vegetable', 153),
#  ('500g', 152),
#  ('lemon', 151),
#  ('250g', 151),
#  ('milk', 149),
#  ('crushed', 147),
#  ('stock', 143),
#  ('cinnamon', 137),
#  ('onions,', 137),
#  ('cloves,', 131),
#  ('chicken', 130),
#  ('icing', 129),
#  ('140g', 129),
#  ('85g', 128),
#  ('orange', 127),
#  ('thyme', 124),
#  ('300g', 122),
#  ('mustard', 119),
#  ('bay', 118),
#  ('x', 114),
#  ('100ml', 114),
#  ('5', 109),
#  ('oil,', 107),
#  ('in', 107),
#  ('thinly', 107),
#  ('egg', 106),
#  ('used', 105),
#  ('smoked', 105),
#  ('sunflower', 102),
#  ('8', 100),
#  ('400g', 100),
#  ('whole', 100),
#  ('light', 99),
#  ('mixed', 98),
#  ('seeds', 98),
#  ('bunch', 95),
#  ('dark', 95),
#  ('if', 92),
#  ('diced', 91),
#  ('from', 89),
#  ('200ml', 89),
#  ('pinch', 88),
#  ('chunks', 88),
#  ('slices', 88),
#  ('cooked', 87),
#  ('150ml', 87),
#  ('(optional)', 87),
#  ('brown', 86),
#  ('toasted', 86),
#  ('shredded', 85),
#  ('sauce', 85),
#  ('beaten', 85),
#  ('pieces', 85),
#  ('cloves', 84),
#  ('few', 84),
#  ('black', 84),
#  ('300ml', 83),
#  ('honey', 83),
#  ('with', 83),
#  ('greasing', 82),
#  ('medium', 81),
#  ('dusting', 80),
#  ('sugar,', 79),
#  ('vanilla', 78),
#  ('1kg', 78),
#  ('frozen', 77),
#  ('leaves,', 77),
#  ('1½', 74),
#  ('about', 73),
#  ('powder', 72),
#  ('chocolate,', 72),
#  ('softened', 71),
#  ('soft', 71),
#  ('clove,', 71),
#  ('salt', 70),
#  ('¼', 70),
#  ('150g', 70),
#  ('500ml', 68),
#  ('175g', 68),
#  ('nutmeg', 68),
#  ('removed', 68),
#  ('parsley,', 68),
#  ('carrots,', 67),
#  ('trimmed', 66),
#  ('unsalted', 65),
#  ('cored', 65),
#  ('sprigs', 64),
#  ('you', 63),
#  ('crème', 63),
#  ('syrup', 61),
#  ('eggs', 61),
#  ('coriander', 60),
#  ('parsley', 60),
#  ('good', 58),
#  ('can', 58),
#  ('pot', 57),
#  ('12', 57),
#  ('75g', 56),
#  ('streaky', 56),
#  ('deseeded', 55),
#  ('muscovado', 55),
#  ('egg,', 55),
#  ('potatoes,', 55),
#  ('little', 54),
#  ('as', 54),
#  ('ginger', 53),
#  ('quartered', 53),
#  ('sea', 53),
#  ('50ml', 53),
#  ('green', 52),
#  ('brandy', 52),
#  ('eggs,', 52),
#  ('ginger,', 52),
#  ('fraîche', 52),
#  ('cranberries', 50),
#  ('clear', 50),
#  ('freshly', 50),
#  ('Brussels', 50),
#  ('on', 50),
#  ('peeled,', 50),
#  ('450g', 49),
#  ('broken', 49),
#  ('250ml', 49),
#  ('cider', 48),
#  ('leftover', 48),
#  ('fat', 48),
#  ('star', 48),
#  ('flour,', 47),
#  ('600ml', 47),
#  ('cranberry', 47),
#  ('rashers', 47),
#  ('350g', 47),
#  ('kg', 47),
#  ('sage', 47),
#  ('lemon,', 47),
#  ('piece', 47),
#  ('chocolate', 47),
#  ('chilli', 47),
#  ('each', 45),
#  ('good-quality', 45),
#  ('shallots,', 45),
#  ('wedges', 45),
#  ('cheese', 45),
#  ('400ml', 45),
#  ('wholegrain', 45),
#  ('water', 44),
#  ('bacon', 44),
#  ('half', 44),
#  ('vegetarian', 44),
#  ('thin', 44),
#  ('tub', 43),
#  ('turkey', 43),
#  ('decorate', 43),
#  ('knob', 43),
#  ('225g', 42),
#  ('leaf', 42),
#  ('(about', 41),
#  ('zested', 41),
#  ('bag', 40),
#  ('stick', 40),
#  ('extract', 40),
#  ('dry', 40),
#  ('baby', 40),
#  ('jar', 40),
#  ('cumin', 40),
#  ('rice', 40),
#  ('lime', 40),
#  ('anise', 40),
#  ('breadcrumbs', 39),
#  ('pork', 39),
#  ('rosemary', 39),
#  ('coconut', 39),
#  ('spring', 38),
#  ('picked', 38),
#  ('sesame', 38),
#  ('1l', 37),
#  ('chopped,', 37),
#  ('cocoa', 37),
#  ('drizzle', 37),
#  ('drained', 37),
#  ('(we', 36),
#  ('very', 36),
#  ('juiced', 36),
#  ('separated', 36),
#  ('peppercorns', 36),
#  ('chilli,', 36),
#  ('such', 36),
#  ('cabbage,', 35),
#  ('Dijon', 35),
#  ('left', 35),
#  ('pastry', 34),
#  ('cheese,', 34),
#  ('maple', 33),
#  ('tomato', 33),
#  ('apples,', 33),
#  ('orange,', 33),
#  ('potato,', 33),
#  ('apple,', 33),
#  ('seed', 33),
#  ('soy', 33),
#  ('salmon', 33),
#  ('port', 32),
#  ('sticks', 32),
#  ('cubes', 32),
#  ('10', 32),
#  ('ice', 32),
#  ('Bramley', 32),
#  ('puff', 32),
#  ('rapeseed', 32),
#  ('melted', 31),
#  ('pepper', 31),
#  ('goose', 31),
#  ('whites', 31),
#  ('(or', 31),
#  ('spice', 31),
#  ('strips', 31),
#  ('sweet', 31),
#  ('chestnut', 31),
#  ('garnish', 30),
#  ('almond', 30),
#  ('carton', 30),
#  ('apple', 30),
#  ('your', 30),
#  ('hot', 30),
#  ('600g', 30),
#  ('grating', 29),
#  ('bread', 29),
#  ('bread,', 29),
#  ('thickly', 29),
#  ('sherry', 29),
#  ('Maris', 29),
#  ('&', 29),
#  ('taste', 29),
#  ('shallot,', 29),
#  ('turkey,', 28),
#  ('bacon,', 28),
#  ('thick', 28),
#  ('almonds', 28),
#  ('beef', 28),
#  ('yogurt', 28),
#  ('use', 28),
#  ('24', 28),
#  ('fennel', 28),
#  ('bottle', 28),
#  ('paprika', 27),
#  ('cardamom', 27),
#  ('duck', 27),
#  ('balsamic', 27),
#  ('cornflour', 27),
#  ('mini', 27),
#  ('sticks,', 27),
#  ('ripe', 27),
#  ('coriander,', 27),
#  ('breadcrumb', 27),
#  ('parsnips,', 27),
#  ('cherry', 27),
#  ('packs', 27),
#  ('jelly', 27),
#  ('well', 26),
#  ('root', 26),
#  ('carrot,', 26),
#  ('flaked', 26),
#  ('baking', 26),
#  ('yolks', 26),
#  ('heaped', 26),
#  ('pepper,', 26),
#  ('other', 26),
#  ('pomegranate', 26),
#  ('horseradish', 26),
#  ('potatoes', 26),
#  ('strong', 25),
#  ('crumbled', 25),
#  ('allspice', 25),
#  ('walnut', 25),
#  ('lightly', 25),
#  ('flat-leaf', 25),
#  ('sprouts,', 25),
#  ('vodka', 24),
#  ('cayenne', 24),
#  ('virgin', 24),
#  ('cold', 24),
#  ('284ml', 24),
#  ('celery', 24),
#  ('leeks,', 24),
#  ('but', 24),
#  ('raw', 24),
#  ('onion', 24),
#  ('mayonnaise', 24),
#  ('stalks', 24),
#  ('yeast', 23),
#  ('coffee', 23),
#  ('dill,', 23),
#  ('lengthways', 23),
#  ('1-2', 23),
#  ('like', 23),
#  ('2½', 23),
#  ('any', 23),
#  ('splash', 23),
#  ('is', 23),
#  ('English', 23),
#  ('butternut', 23),
#  ('long', 23),
#  ('skin', 23),
#  ('800g', 23),
#  ('food', 22),
#  ('sprigs,', 22),
#  ('sprig', 22),
#  ('sprinkling', 22),
#  ('mint', 22),
#  ('cubed', 22),
#  ('full-fat', 22),
#  ('(see', 21),
#  ('granulated', 21),
#  ('16', 21),
#  ('peel', 21),
#  ('oven-ready', 21),
#  ('spinach', 21),
#  ('rum', 21),
#  ('salted', 21),
#  ('purée', 21),
#  ('jam', 21),
#  ('flakes', 21),
#  ('oz', 20),
#  ('ready-to-eat', 20),
#  ('self-raising', 20),
#  ('pine', 20),
#  ('eating', 20),
#  ('blanched', 20),
#  ('tin', 20),
#  ('giblets', 20),
#  ('quartered,', 20),
#  ('mushroom,', 20),
#  ('wild', 20),
#  ('paste', 20),
#  ('floury', 20),
#  ('-', 20),
#  ('pancetta', 20),
#  ('125g', 20),
#  ('juniper', 20),
#  ('redcurrant', 20),
#  ('7g', 19),
#  ('Greek', 19),
#  ("goat's", 19),
#  ('blue', 19),
#  ('Piper', 19),
#  ('cooking', 19),
#  ('nutmeg,', 19),
#  ('unpeeled', 19),
#  ('squash,', 19),
#  ('all', 19),
#  ('sage,', 18),
#  ('demerara', 18),
#  ('clementines,', 18),
#  ('salad', 18),
#  ('mascarpone', 18),
#  ('torn', 18),
#  ('shelled', 18),
#  ('cheddar,', 18),
#  ('washed', 18),
#  ('thyme,', 18),
#  ('snipped', 18),
#  ('parmesan,', 18),
#  ('then', 18),
#  ('natural', 18),
#  ('75ml', 18),
#  ('stem', 17),
#  ('lemons', 17),
#  ('cream,', 17),
#  ('stoned', 17),
#  ('30g', 17),
#  ('chestnuts,', 17),
#  ('pared', 17),
#  ('curry', 17),
#  ('out', 17),
#  ('coarsely', 17),
#  ('edible', 17),
#  ('have', 17),
#  ('frying', 17),
#  ('madeira', 17),
#  ('watercress', 17),
#  ('below)', 17),
#  ('pitted', 16),
#  ('sprout,', 16),
#  ('ham', 16),
#  ('it', 16),
#  ('bar', 16),
#  ('pears,', 16),
#  ('coarse', 16),
#  ('tomatoes', 16),
#  ('2kg', 16),
#  ('fine', 16),
#  ('turmeric', 16),
#  ('defrosted', 16),
#  ('2-3', 16),
#  ('extra-virgin', 16),
#  ('125ml', 16),
#  ('375g', 16),
#  ('sliced,', 16),
#  ('25ml', 16),
#  ('King', 16),
#  ('new', 16),
#  ('at', 15),
#  ('seeds,', 15),
#  ('single', 15),
#  ('oranges', 15),
#  ('vegan', 15),
#  ('raisin', 15),
#  ('20', 15),
#  ('halved,', 15),
#  ('nuts', 15),
#  ('parmesan(or', 15),
#  ('are', 15),
#  ('stock,', 15),
#  ('bulb,', 15),
#  ('parsnip,', 15),
#  ('oranges,', 15),
#  ('sheets', 15),
#  ('nut', 15),
#  ('rinsed', 15),
#  ('20g', 15),
#  ('more', 15),
#  ('celeriac,', 15),
#  ('Worcestershire', 14),
#  ('Christmas', 14),
#  ('fruit', 14),
#  ('sultanas', 14),
#  ('drizzling', 14),
#  ('80g', 14),
#  ('sauce,', 14),
#  ('soaked', 14),
#  ('split', 14),
#  ('almonds,', 14),
#  ('chillies,', 14),
#  ('prosciutto', 14),
#  ('potato', 14),
#  ('15g', 14),
#  ('mushrooms,', 14),
#  ('basmati', 14),
#  ('yellow', 14),
#  ('cocktail', 14),
#  ('gelatine', 14),
#  ('berries', 14),
#  ('soured', 14),
#  ('their', 14),
#  ('removed,', 14),
#  ('alternative)', 14),
#  ('bone', 14),
#  ('basil', 14),
#  ('pod', 14),
#  ('4½', 14),
#  ('120g', 14),
#  ('fast-action', 13),
#  ('room', 13),
#  ('pecans,', 13),
#  ('pods', 13),
#  ('cake', 13),
#  ('mix', 13),
#  ('pods,', 13),
#  ('see', 13),
#  ('custard', 13),
#  ('boneless', 13),
#  ('pod,', 13),
#  ('only', 13),
#  ('walnuts,', 13),
#  ('ones', 13),
#  ('beetroot,', 13),
#  ('skins', 13),
#  ('gold', 13),
#  ('ham,', 13),
#  ('dill', 13),
#  ('apricots,', 13),
#  ('hazelnuts,', 13),
#  ('flaky', 13),
#  ('chives,', 13),
#  ('dice', 13),
#  ('carrots', 13),
#  ('parmesan', 13),
#  ('drops', 13),
#  ('60g', 13),
#  ('rocket', 13),
#  ('temperature', 12),
#  ('apricot', 12),
#  ('700g', 12),
#  ('de', 12),
#  ('soda', 12),
#  ('raisins', 12),
#  ('suet', 12),
#  ('generous', 12),
#  ('cranberries,', 12),
#  ('banana', 12),
#  ('roast', 12),
#  ('firm', 12),
#  ('beetroot', 12),
#  ('clove', 12),
#  ('neck', 12),
#  ('liqueur', 12),
#  ('bags', 12),
#  ('bashed', 12),
#  ('chives', 12),
#  ('chilled', 12),
#  ('cube', 12),
#  ('candied', 12),
#  ('skinless', 12),
#  ('cucumber,', 12),
#  ('stick,', 12),
#  ('pistachios', 12),
#  ('oilor', 12),
#  ('Edward', 12),
#  ('175ml', 12),
#  ('hard', 12),
#  ('made', 12),
#  ('berries,', 12),
#  ('squeeze', 12),
#  ('chunky', 12),
#  ('40g', 11),
#  ('instant', 11),
#  ('Cointreau', 11),
#  ('nuts,', 11),
#  ('lemons,', 11),
#  ('vacuum-packed', 11),
#  ('boiled', 11),
#  ('beans,', 11),
#  ('oregano', 11),
#  ('roasted', 11),
#  ('up', 11),
#  ('alternative),', 11),
#  ('all-butter', 11),
#  ('60ml', 11),
#  ('peppermint', 11),
#  ('gruyère,', 11),
#  ('will', 11),
#  ('onions', 11),
#  ('thumb-sized', 11),
#  ('rind', 11),
#  ('clementines', 11),
#  ('oats', 11),
#  ('desiccated', 11),
#  ('an', 11),
#  ('1¼kg', 11),
#  ('2cm', 11),
#  ('thymesprigs', 11),
#  ('handfuls', 11),
#  ('truffle', 11),
#  ('cleaned', 11),
#  ('need', 11),
#  ('heads', 11),
#  ('diagonal', 11),
#  ('1cm', 11),
#  ('3-4', 11),
#  ('sachet', 10),
#  ('limes,', 10),
#  ('optional', 10),
#  ('packet', 10),
#  ('passion', 10),
#  ('sifted', 10),
#  ('brushing', 10),
#  ('reserved', 10),
#  ('142ml', 10),
#  ('head', 10),
#  ('butcher', 10),
#  ('whipping', 10),
#  ('750g', 10),
#  ('celery,', 10),
#  ('florets', 10),
#  ('quarters', 10),
#  ('squeezed', 10),
#  ('not', 10),
#  ('whisky', 10),
#  ('mild', 10),
#  ('rounded', 10),
#  ('ready-rolled', 10),
#  ('chutney', 10),
#  ('pineapple,', 10),
#  ('chestnuts', 10),
#  ('apricot,', 10),
#  ('350ml', 10),
#  ('mango', 10),
#  ('7', 10),
#  ('sprouts', 10),
#  ('Savoy', 10),
#  ('feta', 10),
#  ('gluten-free', 10),
#  ('18', 10),
#  ('preferably', 10),
#  ('gin', 10),
#  ('pink', 10),
#  ('polenta', 10),
#  ('filo', 10),
#  ('pumpkin', 10),
#  ('900g', 9),
#  ('Grand', 9),
#  ('bicarbonate', 9),
#  ('clementine', 9),
#  ('4-5', 9),
#  ('cm', 9),
#  ('peppercorn', 9),
#  ('walnuts', 9),
#  ('170g', 9),
#  ('mature', 9),
#  ('unsmoked', 9),
#  ('top', 9),
#  ('glass', 9),
#  ('trimmed,', 9),
#  ('buy', 9),
#  ('make', 9),
#  ('1.2l', 9),
#  ('prosecco', 9),
#  ('rosemarysprigs', 9),
#  ('seed,', 9),
#  ('yolk', 9),
#  ('marshmallows', 9),
#  ('one', 9),
#  ('poppy', 9),
#  ('salmon,', 9),
#  ('chestnut,', 9),
#  ('mixture', 9),
#  ('creamed', 9),
#  ('280g', 9),
#  ('mushrooms', 9),
#  ('mint,', 9),
#  ('walnut,', 9),
#  ('sausages', 9),
#  ('wine,', 9),
#  ('pea', 9),
#  ('shallots', 9),
#  ('rosemary,', 9),
#  ('rose', 9),
#  ('rounds', 9),
#  ('wedges,', 9),
#  ('this', 9),
#  ('pistachios,', 9),
#  ('70%', 9),
#  ('flatleaf', 9),
#  ('Gem', 9),
#  ('peppers,', 8),
#  ('garlic,', 8),
#  ('Chinese', 8),
#  ('fl', 8),
#  ('pecans', 8),
#  ('rye', 8),
#  ('strip', 8),
#  ('sultana', 8),
#  ('quality', 8),
#  ('bulb', 8),
#  ('prawns,', 8),
#  ('middle', 8),
#  ('celerysticks,', 8),
#  ('powder,', 8),
#  ('meat', 8),
#  ("'Goes", 8),
#  ('marzipan', 8),
#  ('marmalade', 8),
#  ('scrubbed', 8),
#  ('kept', 8),
#  ('(from', 8),
#  ('juice,', 8),
#  ('size', 8),
#  ('chipolatas', 8),
#  ('big', 8),
#  ('button', 8),
#  ('we', 8),
#  ('mace', 8),
#  ('tomatoes,', 8),
#  ('ready-made', 8),
#  ('breasts,', 8),
#  ('rolled', 8),
#  ('yogurt,', 8),
#  ('sourdough', 8),
#  ('warm', 8),
#  ('nut,', 8),
#  ('3kg', 8),
#  ('fillet', 8),
#  ('raspberry', 8),
#  ('raspberries', 8),
#  ('batons', 8),
#  ('750ml', 8),
#  ('l', 8),
#  ('15', 8),
#  ('pineapple', 8),
#  ('core', 8),
#  ('chicory,', 8),
#  ('halves', 8),
#  ('sparkling', 8),
#  ("'goes", 7),
#  ("with')", 7),
#  ('cabbage', 7),
#  ('1kg/2lb', 7),
#  ('slightly', 7),
#  ('Marnier', 7),
#  ('pecan', 7),
#  ('5cm', 7),
#  ('850ml', 7),
#  ('apricots', 7),
#  ('watercress,', 7),
#  ('fronds', 7),
#  ('cherries', 7),
#  ('rolling', 7),
#  ('milk,', 7),
#  ('red-skinned', 7),
#  ('marzipan,', 7),
#  ('mince', 7),
#  ('skinned', 7),
#  ('marsala', 7),
#  ('tubs', 7),
#  ('5-5½', 7),
#  ('4oz', 7),
#  ('hazelnuts', 7),
#  ('glacé', 7),
#  ('roasting', 7),
#  ('turnips,', 7),
#  ('some', 7),
#  ('lentils', 7),
#  ('700ml', 7),
#  ('fondant', 7),
#  ('ready-to-roll', 7),
#  ('glaze', 7),
#  ('peanut', 7),
#  ('shop-bought', 7),
#  ('apples', 7),
#  ('over', 7),
#  ('stripped', 7),
#  ('squash', 7),
#  ('parsnips', 7),
#  ('–', 7),
#  ('condensed', 7),
#  ('molasses', 7),
#  ('sausages,', 7),
#  ('back', 7),
#  ('550g', 7),
#  ('prawns', 7),
#  ('Thai', 7),
#  ('saltflakes', 7),
#  ('matchsticks', 7),
#  ('lime,', 7),
#  ('tarragon,', 7),
#  ('celeriac', 7),
#  ('serving', 7),
#  ('chorizo', 7),
#  ('using', 7),
#  ('livers,', 7),
#  ('jumbo', 7),
#  ('leek,', 7),
#  ('70g', 7),
#  ('biscuits,', 7),
#  ('rings', 7),
#  ('cans', 7),
#  ('approx', 7),
#  ('get', 7),
#  ('chicory', 7),
#  ('lardons', 7),
#  ('ends', 7),
#  ('400g/14oz', 7),
#  ('depending', 7),
#  ('(you', 7),
#  ('slice', 7),
#  ('unwaxed', 7),
#  ('cooled', 7),
#  ('harissa', 7),
#  ('another', 7),
#  ('groundnut', 7),
#  ('cornichons,', 7),
#  ('stuffing', 6),
#  ('weight', 6),
#  ('boiling', 6),
#  ('fruits', 6),
#  ('fillets,', 6),
#  ('saffron', 6),
#  ('currants', 6),
#  ('block', 6),
#  ('colouring', 6),
#  ('wineor', 6),
#  ('100g/4oz', 6),
#  ('rosemarysprigs,', 6),
#  ('cabbage(about', 6),
#  ('pear', 6),
#  ('loaf', 6),
#  ('stilton,', 6),
#  ('leaf,', 6),
#  ('syrup,', 6),
#  ('caramel', 6),
#  ('give', 6),
#  ('goose,', 6),
#  ('find', 6),
#  ('around', 6),
#  ('500g/1lb', 6),
#  ('pastry,', 6),
#  ('thawed', 6),
#  ('pistachio', 6),
#  ('salt,', 6),
#  ('biscuits', 6),
#  ('397g', 6),
#  ('cauliflower,', 6),
#  ('bean,', 6),
#  ('Disaronno', 6),
#  ('5oz', 6),
#  ('beaten,', 6),
#  ('minced', 6),
#  ('tarragon', 6),
#  ('treacle', 6),
#  ('parsnip', 6),
#  ('650g', 6),
#  ('swede,', 6),
#  ('too', 6),
#  ('wings', 6),
#  ('sheet', 6),
#  ('ice,', 6),
#  ('240g', 6),
#  ('450ml', 6),
#  ('brie,', 6),
#  ('rest', 6),
#  ('jars', 6),
#  ('porcinimushrooms', 6),
#  ('toast,', 6),
#  ('Piper,', 6),
#  ('sachets', 6),
#  ('peel,', 6),
#  ('Tabasco', 6),
#  ('squares', 6),
#  ('olives', 6),
#  ('prepared', 6),
#  ('320g', 6),
#  ('excess', 6),
#  ('legs', 6),
#  ('gammon', 6),
#  ('peeler', 6),
#  ('Granny', 6),
#  ('bottles', 6),
#  ('quantity', 6),
#  ('pancetta,', 6),
#  ('8oz', 6),
#  ('6-8', 6),
#  ('porridge', 6),
#  ('Puy', 6),
#  ('thymesprigs,', 6),
#  ('amaretti', 6),
#  ('parmesan-style', 6),
#  ('(available', 6),
#  ('peas', 6),
#  ('do', 6),
#  ('120ml', 6),
#  ('rosemarysprig,', 6),
#  ('ketchup', 6),
#  ('only,', 6),
#  ('Little', 6),
#  ('shallot', 6),
#  ('lengthways,', 6),
#  ('90g', 6),
#  ('rosewater', 6),
#  ('larger', 6),
#  ('fingers', 6),
#  ('peppercorns,', 6),
#  ('wholemeal', 6),
#  ('plump', 6),
#  ('hazelnut', 6),
#  ('sweetened', 6),
#  ('want', 6),
#  ('crabmeat', 6),
#  ('olives,', 6),
#  ('tiger', 6),
#  ('limes', 5),
#  ('five-spice', 5),
#  ('dulce', 5),
#  ('Merchant', 5),
#  ('Gourmet)', 5),
#  ('litre', 5),
#  ('100ml/3½', 5),
#  ('lolly', 5),
#  ('writing', 5),
#  ('shortcrust', 5),
#  ('sifted,', 5),
#  ('dust', 5),
#  ('liquid', 5),
#  ('dates', 5),
#  ('frozen)', 5),
#  ('crusts', 5),
#  ('sausagemeat', 5),
#  ('1⁄2', 5),
#  ('crusty', 5),
#  ('scooped', 5),
#  ('on,', 5),
#  ('wedge', 5),
#  ('tied', 5),
#  ('paste)', 5),
#  ('scattering', 5),
#  ('softened,', 5),
#  ('2oz', 5),
#  ('2l', 5),
#  ('good)', 5),
#  ('seeded', 5),
#  ('5kg', 5),
#  ('200g/7oz', 5),
#  ('breast', 5),
#  ('grated,', 5),
#  ('assorted', 5),
#  ('choice', 5),
#  ('water,', 5),
#  ('brandy,', 5),
#  ('bouillon', 5),
#  ('outer', 5),
#  ('same', 5),
#  ('don’t', 5),
#  ('essence', 5),
#  ('Cumberland', 5),
#  ('topping', 5),
#  ('gift', 5),
#  ('long,', 5),
#  ('balls', 5),
#  ("don't", 5),
#  ('kirsch', 5),
#  ('8-10', 5),
#  ('cooked,', 5),
#  ('avocado,', 5),
#  ('36', 5),
#  ('label', 5),
#  ('five', 5),
#  ('mincemeat', 5),
#  ('cherry,', 5),
#  ('bruised', 5),
#  ('tip', 5),
#  ('dry-cured', 5),
#  ('noodles', 5),
#  ('flavourless', 5),
#  ('small,', 5),
#  ('naan', 5),
#  ('160g', 5),
#  ('vegetables,', 5),
#  ('fork', 5),
#  ('40', 5),
#  ('sundried', 5),
#  ('king', 5),
#  ('free-range', 5),
#  ('2cm/¾', 5),
#  ('scraped', 5),
#  ('garlicbulb,', 5),
#  ('cranberry,', 5),
#  ('elderflower', 5),
#  ('cordial', 5),
#  ('32', 5),
#  ('Desirée', 5),
#  ('almond,', 5),
#  ('French', 5),
#  ('porcini', 5),
#  ...]

# %%
other_method = Counter()

for i in range(len(data)):
    if expected_data[i] == "Other":
        for j in range(len(data[i]['Method'])):       
            if data[i]['Method'] != None:
                for word in data[i]['Method'][j].split(" "):
                    other_method[word] += 1
                    total_method[word] += 1
                
other_method.most_common()
# Out:
# [('the', 19457),
#  ('and', 9454),
#  ('a', 7414),
#  ('to', 5763),
#  ('in', 4307),
#  ('with', 3600),
#  ('for', 3473),
#  ('of', 3146),
#  ('then', 2832),
#  ('until', 2547),
#  ('into', 2042),
#  ('heat', 1419),
#  ('on', 1343),
#  ('over', 1329),
#  ('add', 1316),
#  ('mins', 1305),
#  ('or', 1196),
#  ('it', 992),
#  ('put', 925),
#  ('oven', 918),
#  ('you', 831),
#  ('pan', 822),
#  ('large', 817),
#  ('cook', 778),
#  ('from', 762),
#  ('up', 731),
#  ('stir', 699),
#  ('is', 698),
#  ('pour', 690),
#  ('leave', 670),
#  ('1', 629),
#  ('if', 626),
#  ('mix', 610),
#  ('each', 580),
#  ('remove', 576),
#  ('all', 568),
#  ('baking', 557),
#  ('cover', 551),
#  ('2', 549),
#  ('tip', 531),
#  ('make', 518),
#  ('oil', 511),
#  ('top', 502),
#  ('butter', 491),
#  ('out', 491),
#  ('mins.', 490),
#  ('as', 468),
#  ('water', 463),
#  ('tin', 458),
#  ('sugar', 452),
#  ('bring', 449),
#  ('bowl', 439),
#  ('cut', 433),
#  ('fan/gas', 427),
#  ('be', 414),
#  ('mins,', 413),
#  ('your', 409),
#  ('set', 406),
#  ('mixture', 405),
#  ('serve', 405),
#  ('about', 404),
#  ('remaining', 403),
#  ('place', 399),
#  ('are', 392),
#  ('at', 392),
#  ('little', 378),
#  ('can', 378),
#  ('–', 373),
#  ('cool', 367),
#  ('will', 364),
#  ('season', 363),
#  ('', 355),
#  ('spoon', 350),
#  ('them', 343),
#  ('before', 342),
#  ('10', 340),
#  ('cream', 337),
#  ('gently', 335),
#  ('turn', 332),
#  ('bake', 331),
#  ('small', 331),
#  ('5', 326),
#  ('together', 309),
#  ('some', 303),
#  ('so', 303),
#  ('tbsp', 296),
#  ('half', 295),
#  ('off', 295),
#  ('when', 294),
#  ('simmer', 288),
#  ('onto', 282),
#  ('roasting', 282),
#  ('potatoes', 281),
#  ('just', 280),
#  ('turkey', 276),
#  ('keep', 275),
#  ('few', 275),
#  ('30', 273),
#  ('this', 273),
#  ('use', 270),
#  ('roll', 263),
#  ('more', 262),
#  ('using', 262),
#  ('through', 260),
#  ('salt', 258),
#  ('fry', 258),
#  ('one', 255),
#  ('any', 252),
#  ('scatter', 251),
#  ('well', 248),
#  ('but', 247),
#  ('roast', 245),
#  ('egg', 244),
#  ('frying', 242),
#  ('has', 241),
#  ('chocolate', 240),
#  ('golden', 239),
#  ('whisk', 239),
#  ('have', 239),
#  ('chill', 234),
#  ('pan,', 234),
#  ('rest', 233),
#  ('stirring', 233),
#  ('boil', 233),
#  ('fridge', 230),
#  ('juice', 230),
#  ('they', 228),
#  ('cling', 223),
#  ('3', 222),
#  ('lemon', 221),
#  ('20', 221),
#  ('that', 220),
#  ('an', 220),
#  ('drain', 218),
#  ('bowl,', 215),
#  ('by', 213),
#  ('toss', 212),
#  ('hot', 208),
#  ('lightly', 206),
#  ('sprinkle', 204),
#  ('down', 203),
#  ('around', 203),
#  ('meanwhile,', 201),
#  ('brush', 200),
#  ('return', 191),
#  ('warm', 190),
#  ('back', 189),
#  ('drizzle', 189),
#  ('spread', 188),
#  ('icing', 187),
#  ('tray', 187),
#  ('sauce', 185),
#  ('transfer', 182),
#  ('carefully', 181),
#  ('garlic', 180),
#  ('once', 179),
#  ('6.', 179),
#  ('fat', 177),
#  ('4', 174),
#  ('slice', 174),
#  ('line', 174),
#  ('15', 170),
#  ('melt', 169),
#  ('ingredients', 169),
#  ('200c/180c', 169),
#  ('golden.', 168),
#  ('pan.', 167),
#  ('onion', 167),
#  ('take', 166),
#  ('another', 165),
#  ('not', 163),
#  ('serving', 163),
#  ('pastry', 163),
#  ('serve.', 162),
#  ('orange', 162),
#  ('dough', 161),
#  ('bowl.', 159),
#  ('stock', 159),
#  ('cooking', 158),
#  ('medium', 157),
#  ('film', 155),
#  ('while', 155),
#  ('cool.', 155),
#  ('very', 155),
#  ('skin', 154),
#  ('side', 153),
#  ('foil', 152),
#  ('cake', 152),
#  ('flour', 151),
#  ('saucepan', 151),
#  ('slices', 149),
#  ('well.', 149),
#  ('ready', 149),
#  ('water.', 148),
#  ('should', 148),
#  ('chopped', 147),
#  ('milk', 146),
#  ('boil,', 146),
#  ('fold', 146),
#  ('food', 145),
#  ('juices', 144),
#  ('between', 144),
#  ('leaves', 143),
#  ('aside', 140),
#  ('everything', 140),
#  ('beat', 139),
#  ('two', 139),
#  ('layer', 138),
#  ('peel', 137),
#  ('tsp', 136),
#  ('dry', 136),
#  ('heat,', 135),
#  ('serve,', 135),
#  ('thick', 134),
#  ('sugar,', 132),
#  ('tin,', 132),
#  ('cold', 132),
#  ('tin.', 130),
#  ('soft', 128),
#  ('sheet', 128),
#  ('now', 128),
#  ('enough', 128),
#  ('zest', 126),
#  ('cheese', 125),
#  ('aside.', 124),
#  ('tender.', 123),
#  ('top.', 123),
#  ('onions', 122),
#  ('piece', 122),
#  ('6', 121),
#  ('bacon', 119),
#  ('butter,', 118),
#  ('boil.', 118),
#  ('cooked', 118),
#  ('least', 117),
#  ('along', 117),
#  ('allow', 117),
#  ('dish', 117),
#  ('end', 116),
#  ('surface', 116),
#  ('don’t', 115),
#  ('lift', 114),
#  ('arrange', 114),
#  ('knife', 113),
#  ('smooth', 113),
#  ('completely', 113),
#  ('ice', 112),
#  ('brown', 111),
#  ('water,', 110),
#  ('low', 110),
#  ('heat.', 110),
#  ('cool,', 109),
#  ('liquid', 109),
#  ('parchment', 109),
#  ('divide', 109),
#  ('meat', 109),
#  ('strain', 109),
#  ('x', 108),
#  ('olive', 108),
#  ('bay', 108),
#  ('paper', 107),
#  ('under', 107),
#  ('sides', 107),
#  ('white', 106),
#  ('finely', 106),
#  ('thyme', 105),
#  ('chicken', 105),
#  ('away', 104),
#  ('further', 104),
#  ('180c/160c', 102),
#  ('hrs', 101),
#  ('salmon', 101),
#  ('ham', 101),
#  ('minutes', 99),
#  ('oil.', 98),
#  ('stuffing', 98),
#  ('sit', 98),
#  ('continue', 98),
#  ('wine', 97),
#  ('base', 97),
#  ('pinch', 97),
#  ('its', 96),
#  ('cream,', 96),
#  ('oil,', 96),
#  ('crisp', 96),
#  ('boiling', 96),
#  ('turning', 96),
#  ('pepper', 96),
#  ('made', 95),
#  ('4.', 95),
#  ('good', 95),
#  ('lay', 95),
#  ('reduce', 94),
#  ('press', 94),
#  ('starting', 94),
#  ('need', 93),
#  ('other', 93),
#  ('pack', 93),
#  ('bottom', 91),
#  ('freeze', 91),
#  ('day', 91),
#  ('duck', 91),
#  ('really', 91),
#  ('seasoning.', 91),
#  ('black', 91),
#  ('parchment.', 90),
#  ('seeds', 90),
#  ('covered', 89),
#  ('hr', 89),
#  ('like.', 89),
#  ('chop', 89),
#  ('give', 89),
#  ('sprouts', 89),
#  ('let', 88),
#  ('pieces', 88),
#  ('butter.', 87),
#  ('stick', 87),
#  ('garlic,', 87),
#  ('repeat', 86),
#  ('fruit', 86),
#  ('syrup', 86),
#  ('leaving', 85),
#  ('too', 85),
#  ('do', 85),
#  ('days', 85),
#  ('together.', 84),
#  ('wrap', 84),
#  ('roughly', 84),
#  ('sieve', 83),
#  ('slightly', 83),
#  ('push', 83),
#  ('goose', 82),
#  ('paper.', 82),
#  ('middle', 82),
#  ('making', 82),
#  ('melted', 81),
#  ('220c/200c', 81),
#  ('sauce.', 81),
#  ('plate', 81),
#  ('processor', 80),
#  ('squeeze', 80),
#  ('salted', 80),
#  ('time', 79),
#  ('edges', 79),
#  ('pork', 79),
#  ('through.', 78),
#  ('high', 78),
#  ('it.', 77),
#  ('time,', 77),
#  ('foil,', 77),
#  ('salt.', 77),
#  ('2-3', 77),
#  ('room', 77),
#  ('pepper.', 77),
#  ('kitchen', 77),
#  ('7.', 76),
#  ('still', 76),
#  ('couple', 76),
#  ('sugar.', 76),
#  ('clean', 76),
#  ('seasoning', 76),
#  ('extra', 75),
#  ('sharp', 75),
#  ('serving.', 75),
#  ('brown.', 74),
#  ('get', 74),
#  ('centre', 73),
#  ('like', 73),
#  ('every', 73),
#  ('eggs', 73),
#  ('shallots', 73),
#  ('vinegar', 73),
#  ('carrots', 72),
#  ('fill', 72),
#  ('non-stick', 72),
#  ('start', 72),
#  ('gravy', 71),
#  ('both', 71),
#  ('their', 71),
#  ('thin', 71),
#  ('(see', 71),
#  ('grill', 71),
#  ('crème', 71),
#  ('whites', 70),
#  ('rice', 70),
#  ('8', 69),
#  ('40', 69),
#  ('breast', 69),
#  ('rub', 69),
#  ('long', 69),
#  ('nuts', 69),
#  ('hrs.', 69),
#  ('vegetables', 69),
#  ('lime', 68),
#  ('inside', 68),
#  ('(or', 68),
#  ('red', 68),
#  ('cabbage', 68),
#  ('smooth.', 68),
#  ('shallow', 68),
#  ('potato', 68),
#  ('grease', 67),
#  ('break', 67),
#  ('discard', 67),
#  ('slowly', 67),
#  ('sure', 67),
#  ('3-4', 67),
#  ('ginger', 66),
#  ('min', 66),
#  ('45', 66),
#  ('dish.', 66),
#  ('excess', 66),
#  ('frozen', 65),
#  ('splash', 65),
#  ('salt,', 65),
#  ('well,', 65),
#  ('parsley', 65),
#  ('it’s', 64),
#  ('scoop', 64),
#  ('cranberries', 64),
#  ('flour,', 64),
#  ('adding', 63),
#  ('5.', 63),
#  ('dressing', 63),
#  ('juice,', 63),
#  ('tie', 63),
#  ('sauce,', 63),
#  ('trim', 63),
#  ('meringue', 62),
#  ('veg', 62),
#  ('leaves.', 62),
#  ('vanilla', 62),
#  ('freezer', 62),
#  ('ground', 62),
#  ('again', 62),
#  ('shape', 62),
#  ('mixture.', 62),
#  ('beef', 62),
#  ('evenly', 62),
#  ('squash', 62),
#  ('cinnamon', 61),
#  ('bubble', 61),
#  ('honey', 61),
#  ('after', 61),
#  ('scrape', 61),
#  ('reserved', 61),
#  ('work', 61),
#  ('mash', 61),
#  ('ahead', 61),
#  ('mushrooms', 61),
#  ('reheat', 60),
#  ('apple', 60),
#  ('shake', 59),
#  ('taste.', 59),
#  ('saucepan,', 59),
#  ('board', 59),
#  ('bread', 59),
#  ('whole', 59),
#  ('dust', 58),
#  ('wooden', 58),
#  ('temperature', 58),
#  ('cocktail', 58),
#  ('dark', 57),
#  ('hrs,', 57),
#  ('loaf', 57),
#  ('mustard', 57),
#  ('sage', 56),
#  ('dried', 56),
#  ('lined', 56),
#  ('fridge.', 56),
#  ('up.', 56),
#  ('dish,', 56),
#  ('way', 56),
#  ('piping', 56),
#  ('over.', 55),
#  ('gradually', 55),
#  ('first', 55),
#  ('dip', 55),
#  ('oven,', 55),
#  ('tender', 55),
#  ('tray.', 55),
#  ('cranberry', 54),
#  ('crisp.', 54),
#  ('taste', 54),
#  ('onions,', 54),
#  ('big', 54),
#  ('overnight.', 54),
#  ('chilled', 54),
#  ('coat', 54),
#  ('salad', 53),
#  ('vinegar,', 53),
#  ('1-2', 53),
#  ('grate', 52),
#  ('more.', 52),
#  ('minutes,', 52),
#  ('cook,', 52),
#  ('skewer', 52),
#  ('24', 52),
#  ('bag', 52),
#  ('floured', 51),
#  ('wire', 51),
#  ('lid', 51),
#  ('together,', 51),
#  ('softened.', 51),
#  ('whizz', 51),
#  ('toast', 51),
#  ('onion,', 51),
#  ('parsnips', 51),
#  ('mixture,', 51),
#  ('tightly', 51),
#  ('chilli', 51),
#  ('no', 50),
#  ('whip', 50),
#  ('seal', 50),
#  ('bird', 50),
#  ('sea', 50),
#  ('want', 50),
#  ('loosely', 50),
#  ('pudding', 50),
#  ('separate', 50),
#  ('(if', 50),
#  ('soak', 50),
#  ('overnight', 50),
#  ('blitz', 50),
#  ('caster', 50),
#  ('soft.', 50),
#  ('seasoning,', 49),
#  ('container', 49),
#  ('sticky', 49),
#  ('mixing', 49),
#  ('run', 49),
#  ('10-15', 49),
#  ('coriander', 49),
#  ('minutes.', 49),
#  ('pat', 49),
#  ('leaves,', 49),
#  ('simmering', 49),
#  ('knead', 48),
#  ('days.', 48),
#  ('turkey,', 48),
#  ('legs', 48),
#  ('round', 48),
#  ('halfway', 48),
#  ('pile', 48),
#  ('cream.', 48),
#  ('help', 48),
#  ('bit', 48),
#  ('deep', 48),
#  ('stock,', 48),
#  ('most', 48),
#  ('plenty', 48),
#  ('180c/gas', 48),
#  ('juice.', 48),
#  ('rosemary', 48),
#  ('come', 47),
#  ('smooth,', 47),
#  ('season,', 47),
#  ('check', 47),
#  ('pepper,', 47),
#  ('.', 47),
#  ('bits', 47),
#  ('cooked,', 47),
#  ('hand', 47),
#  ('than', 47),
#  ('tray,', 47),
#  ('balls', 47),
#  ('needed.', 47),
#  ('hot.', 46),
#  ('fine', 46),
#  ('comes', 46),
#  ('top,', 46),
#  ('halve', 46),
#  ('rack', 46),
#  ('gas', 46),
#  ('8-10', 46),
#  ('ends', 46),
#  ('side.', 46),
#  ('firm', 46),
#  ('milk,', 46),
#  ('season.', 46),
#  ('almost', 46),
#  ('up,', 46),
#  ('coconut', 46),
#  ('fish', 46),
#  ('zest,', 45),
#  ('per', 45),
#  ('filling', 45),
#  ('star', 45),
#  ('and,', 45),
#  ('ovenproof', 45),
#  ('final', 45),
#  ('apples', 45),
#  ('beaten', 45),
#  ('prepared', 44),
#  ('knife,', 44),
#  ('quickly', 44),
#  ('much', 44),
#  ('ahead.', 44),
#  ('set.', 44),
#  ('spinach', 44),
#  ('shape.', 44),
#  ('film.', 44),
#  ('flesh', 44),
#  ('rolling', 44),
#  ('marzipan', 44),
#  ('you’re', 43),
#  ('may', 43),
#  ('heatproof', 43),
#  ('glasses', 43),
#  ('month.', 43),
#  ('starts', 43),
#  ('thick.', 43),
#  ('serving,', 43),
#  ('large,', 43),
#  ('again.', 43),
#  ('increase', 43),
#  ('platter', 43),
#  ('tea', 42),
#  ('sliced', 42),
#  ('fan/', 42),
#  ('same', 42),
#  ('sausage', 42),
#  ('clementine', 42),
#  ('straight', 42),
#  ('plate.', 42),
#  ('hold', 42),
#  ('third', 42),
#  ('preheat', 42),
#  ('soften', 42),
#  ('hours', 42),
#  ('finish', 42),
#  ('jug', 42),
#  ('completely.', 41),
#  ('gravy.', 41),
#  ('generously', 41),
#  ('thinly', 41),
#  ('store', 41),
#  ('saucepan.', 41),
#  ('edge', 41),
#  ('over,', 41),
#  ('metal', 41),
#  ('slices.', 41),
#  ('25', 41),
#  ('15-20', 41),
#  ('wedges', 41),
#  ('drop', 41),
#  ('fresh', 41),
#  ('herbs', 41),
#  ('rinse', 41),
#  ('sheets', 41),
#  ('190c/170c', 40),
#  ('combine', 40),
#  ('double', 40),
#  ('simmer,', 40),
#  ('spices', 40),
#  ('½', 40),
#  ('hands', 40),
#  ('oven.', 40),
#  ('grated', 40),
#  ('mustard,', 40),
#  ('jars', 39),
#  ('bowls', 39),
#  ('reduced', 39),
#  ('hr.', 39),
#  ('form', 39),
#  ('spoon.', 39),
#  ('microwave', 39),
#  ('neck', 39),
#  ('casserole', 39),
#  ('yolks', 39),
#  ('tender,', 39),
#  ('fraîche', 39),
#  ('glass', 38),
#  ('score', 38),
#  ('go', 38),
#  ('airtight', 38),
#  ('spring', 38),
#  ('200c/fan', 38),
#  ('beetroot', 38),
#  ('joint', 38),
#  ('softened', 38),
#  ('risen', 37),
#  ('glaze', 37),
#  ('jam', 37),
#  ('foil.', 37),
#  ('3.', 37),
#  ('outside', 37),
#  ('cloves', 37),
#  ('custard', 37),
#  ('soften.', 37),
#  ('reserve', 37),
#  ('even', 37),
#  ('next', 37),
#  ('blend', 37),
#  ('surface.', 36),
#  ('garnish', 36),
#  ('months.', 36),
#  ('used', 36),
#  ('length', 36),
#  ('(the', 36),
#  ('25-30', 36),
#  ('chocolate.', 36),
#  ('electric', 36),
#  ('thigh', 36),
#  ('spoonful', 36),
#  ('last', 36),
#  ('slotted', 36),
#  ('jelly', 36),
#  ('cheese,', 36),
#  ('sterilised', 35),
#  ('almonds', 35),
#  ('dough.', 35),
#  ('mix.', 35),
#  ('pop', 35),
#  ('mixed', 35),
#  ('syrup,', 35),
#  ('breadcrumbs', 35),
#  ('sausages', 35),
#  ('pears', 35),
#  ('pulse', 35),
#  ('smoked', 35),
#  ('cooking,', 35),
#  ('little.', 35),
#  ('whisking', 35),
#  ('day,', 35),
#  ('strips', 34),
#  ('jug.', 34),
#  ('occasionally,', 34),
#  ('strip', 34),
#  ('20cm', 34),
#  ('spoon,', 34),
#  ('chill.', 34),
#  ('5-10', 34),
#  (',', 34),
#  ('half.', 34),
#  ('prawns', 34),
#  ('three', 34),
#  ('time.', 34),
#  ('hot,', 34),
#  ('paste.', 34),
#  ('sponge', 34),
#  ('wash', 34),
#  ('nutmeg', 34),
#  ('test', 34),
#  ('gelatine', 34),
#  ('second', 34),
#  ('down,', 34),
#  ('yogurt', 33),
#  ('melted.', 33),
#  ('(you', 33),
#  ('brandy', 33),
#  ('best', 33),
#  ('160c/140c', 33),
#  ('7', 33),
#  ('dill', 33),
#  ('12', 33),
#  ('warm.', 33),
#  ('doesn’t', 33),
#  ('sprigs', 33),
#  ('sizzle', 33),
#  ('fillet', 33),
#  ('single', 33),
#  ('purée', 33),
#  ('oiled', 33),
#  ('pancetta', 33),
#  ('doubled', 32),
#  ('size', 32),
#  ('stock.', 32),
#  ('lower', 32),
#  ('plus', 32),
#  ('string', 32),
#  ('handful', 32),
#  ('cooled', 32),
#  ('decorate', 32),
#  ('melted,', 32),
#  ('point', 32),
#  ('kept', 32),
#  ('mini', 32),
#  ('light', 32),
#  ('except', 32),
#  ('golden,', 32),
#  ('slices,', 32),
#  ('potatoes,', 32),
#  ('parchment,', 32),
#  ('stand', 32),
#  ('dry.', 32),
#  ('rectangle', 32),
#  ('paste', 32),
#  ('thickened.', 32),
#  ('4-5', 32),
#  ('chutney', 31),
#  ('cavity', 31),
#  ('sift', 31),
#  ('eggs,', 31),
#  ('create', 31),
#  ('there', 31),
#  ('mint', 31),
#  ('mix,', 31),
#  ('been', 31),
#  ('rashers', 31),
#  ('browned', 31),
#  ('pipe', 31),
#  ('chestnuts', 31),
#  ('pomegranate', 31),
#  ('eat', 30),
#  ('stirring,', 30),
#  ('pull', 30),
#  ('skin,', 30),
#  ('greaseproof', 30),
#  ('breadcrumbs,', 30),
#  ('knife.', 30),
#  ('stop', 30),
#  ('circle', 30),
#  ('fit', 30),
#  ('cake,', 30),
#  ('fat,', 30),
#  ('ahead,', 30),
#  ('weigh', 30),
#  ('lengthways', 30),
#  ('more,', 30),
#  ('sides.', 30),
#  ('then,', 30),
#  ('chunks', 30),
#  ('wine,', 30),
#  ('quarter', 30),
#  ('open', 30),
#  ('potatoes.', 30),
#  ('leaf', 30),
#  ('dressing.', 30),
#  ('prepare', 29),
#  ('powder', 29),
#  ('stuff', 29),
#  ('them.', 29),
#  ('cranberries,', 29),
#  ('without', 29),
#  ('100ml', 29),
#  ('nuts,', 29),
#  ('nutmeg,', 29),
#  ('it,', 29),
#  ('become', 29),
#  ('crumble', 29),
#  ('coffee', 29),
#  ('freshly', 29),
#  ('green', 29),
#  ('gentle', 29),
#  ('done', 29),
#  ('caramel', 29),
#  ('uncovered,', 29),
#  ('shelf', 29),
#  ('leeks', 29),
#  ('these', 29),
#  ('celeriac', 29),
#  ('cheese.', 29),
#  ('rise', 28),
#  ('20-25', 28),
#  ('syrupy.', 28),
#  ('four', 28),
#  ('ladle', 28),
#  ('cocoa', 28),
#  ('film,', 28),
#  ('hr,', 28),
#  ('colour.', 28),
#  ('biscuits', 28),
#  ('stiff', 28),
#  ('min.', 28),
#  ('thyme,', 28),
#  ('sweet', 28),
#  ('sesame', 28),
#  ('seeds,', 28),
#  ('jar', 28),
#  ('breasts', 27),
#  ('smaller', 27),
#  ('steam', 27),
#  ('little,', 27),
#  ('through,', 27),
#  ('hour', 27),
#  ('working', 27),
#  ('dressing,', 27),
#  ('unwrap', 27),
#  ('simmer.', 27),
#  ('grind', 27),
#  ('min,', 27),
#  ('edges.', 27),
#  ('200c/gas', 27),
#  ('prosciutto', 27),
#  ('truffle', 27),
#  ('slightly.', 27),
#  ('skin.', 27),
#  ('colander', 27),
#  ('cauliflower', 27),
#  ('longer', 26),
#  ('holding', 26),
#  ('following', 26),
#  ('190c/fan', 26),
#  ('170c/gas', 26),
#  ('out.', 26),
#  ('week', 26),
#  ('firm.', 26),
#  ('drain,', 26),
#  ('dissolve', 26),
#  ('(this', 26),
#  ('flat', 26),
#  ('pieces.', 26),
#  ('colour', 26),
#  ('trays', 26),
#  ('layers', 26),
#  ('liquid.', 26),
#  ('pastry.', 26),
#  ('pressing', 26),
#  ('drain.', 26),
#  ('terrine', 26),
#  ('egg,', 26),
#  ('vegetable', 25),
#  ('glasses.', 25),
#  ('immediately.', 25),
#  ('pasta', 25),
#  ('softened,', 25),
#  ('occasionally', 25),
#  ('secure', 25),
#  ('(about', 25),
#  ('crispy', 25),
#  ('vinegar.', 25),
#  ('zest.', 25),
#  ('pastry,', 25),
#  ('short', 25),
#  ('across', 25),
#  ('thick,', 25),
#  ('followed', 25),
#  ('alongside', 25),
#  ('fingers', 25),
#  ('ingredients,', 25),
#  ('celery', 25),
#  ('ginger,', 25),
#  ('peppercorns', 25),
#  ('worry', 25),
#  ('times', 25),
#  ('mushroom', 25),
#  ('syrup.', 25),
#  ('hands.', 25),
#  ('herbs,', 25),
#  ('left', 25),
#  ('shred', 25),
#  ('peas', 25),
#  ('soup', 25),
#  ('chocolate,', 25),
#  ('space', 24),
#  ('heavy-based', 24),
#  ('150ml', 24),
#  ('icing.', 24),
#  ('plate,', 24),
#  ('half,', 24),
#  ('cornflour', 24),
#  ('cakes', 24),
#  ('cutting', 24),
#  ('halves', 24),
#  ('scraping', 24),
#  ('combined.', 24),
#  ('tear', 24),
#  ('part', 24),
#  ('tomato', 24),
#  ('fan', 24),
#  ('gammon', 24),
#  ('beans', 24),
#  ('overlapping', 24),
#  ('set,', 24),
#  ('allowing', 24),
#  ('possible.', 24),
#  ('batches', 24),
#  ('throw', 24),
#  ('crown', 24),
#  ('ingredients.', 24),
#  ('thread', 24),
#  ('hard', 24),
#  ('sticky.', 23),
#  ('sheet,', 23),
#  ('care', 23),
#  ('loosen', 23),
#  ('wings', 23),
#  ('looks', 23),
#  ('topping', 23),
#  ('tins', 23),
#  ('immediately', 23),
#  ('can.', 23),
#  ('quite', 23),
#  ('holds', 23),
#  ('square', 23),
#  ('in.', 23),
#  ('dot', 23),
#  ('sprig', 23),
#  ('spice', 23),
#  ('first,', 23),
#  ('keeping', 23),
#  ('swirl', 23),
#  ('gravy,', 23),
#  ('processor,', 23),
#  ('larger', 23),
#  ('fork', 23),
#  ('100g', 23),
#  ('coated', 23),
#  ('plastic', 23),
#  ...]

# %%
total_method.most_common()
# Out:
# [('the', 46376.199999995515),
#  ('and', 21555.59999999936),
#  ('a', 19075.999999999476),
#  ('to', 14221.800000000307),
#  ('in', 10080.600000000219),
#  ('with', 9116.000000000202),
#  ('of', 8292.400000000178),
#  ('for', 7642.200000000114),
#  ('then', 6964.800000000112),
#  ('until', 5918.200000000063),
#  ('into', 5082.800000000041),
#  ('on', 3501.799999999984),
#  ('over', 3022.9999999999823),
#  ('heat', 2922.5999999999854),
#  ('or', 2856.399999999983),
#  ('mins', 2780.599999999986),
#  ('add', 2629.1999999999884),
#  ('it', 2509.599999999985),
#  ('oven', 2275.9999999999877),
#  ('you', 2194.5999999999876),
#  ('out', 2187.799999999982),
#  ('put', 1988.9999999999925),
#  ('baking', 1850.5999999999888),
#  ('make', 1758.3999999999896),
#  ('mix', 1752.3999999999912),
#  ('leave', 1714.3999999999928),
#  ('up', 1660.5999999999947),
#  ('large', 1623.3999999999967),
#  ('from', 1621.5999999999958),
#  ('stir', 1603.399999999995),
#  ('cake', 1602.3999999999862),
#  ('sugar', 1577.5999999999915),
#  ('butter', 1532.5999999999929),
#  ('top', 1523.9999999999932),
#  ('icing', 1519.7999999999881),
#  ('is', 1518.3999999999965),
#  ('each', 1487.199999999995),
#  ('if', 1463.1999999999962),
#  ('1', 1379.3999999999976),
#  ('bake', 1358.599999999993),
#  ('cool', 1324.5999999999942),
#  ('tin', 1306.399999999996),
#  ('pan', 1303.6000000000013),
#  ('pour', 1303.1999999999998),
#  ('cover', 1270.599999999998),
#  ('2', 1268.599999999998),
#  ('cook', 1265.2000000000014),
#  ('remove', 1228.3999999999992),
#  ('little', 1209.5999999999963),
#  ('your', 1187.3999999999971),
#  ('all', 1186.7999999999997),
#  ('cut', 1183.3999999999976),
#  ('mixture', 1158.1999999999975),
#  ('tip', 1138.6),
#  ('as', 1134.399999999999),
#  ('bowl', 1116.5999999999988),
#  ('remaining', 1097.3999999999985),
#  ('fan/gas', 1093.399999999999),
#  ('pastry', 1092.5999999999947),
#  ('at', 1055.599999999999),
#  ('together', 1039.799999999998),
#  ('roll', 1032.9999999999973),
#  ('water', 1017.4000000000008),
#  ('mins.', 996.8000000000014),
#  ('use', 986.7999999999981),
#  ('spoon', 971.5999999999997),
#  ('set', 968.8000000000006),
#  ('will', 960.4000000000001),
#  ('about', 947.200000000001),
#  ('onto', 942.799999999999),
#  ('–', 930.2000000000007),
#  ('small', 913.4000000000003),
#  ('be', 901.2000000000014),
#  ('', 895.400000000001),
#  ('mins,', 889.0000000000014),
#  ('using', 880.7999999999997),
#  ('can', 856.8000000000013),
#  ('place', 849.8000000000012),
#  ('an', 805.2000000000003),
#  ('them', 796.6000000000013),
#  ('half', 796.2000000000014),
#  ('line', 787.1999999999998),
#  ('serve', 785.8000000000009),
#  ('bring', 785.0000000000007),
#  ('oil', 779.8000000000004),
#  ('gently', 763.4000000000011),
#  ('chocolate', 755.2000000000014),
#  ('cream', 743.000000000001),
#  ('one', 736.6000000000013),
#  ('are', 736.4000000000008),
#  ('turn', 735.200000000001),
#  ('egg', 728.4000000000013),
#  ('10', 726.400000000001),
#  ('brush', 723.6000000000013),
#  ('so', 711.8000000000011),
#  ('before', 706.0000000000009),
#  ('off', 703.8000000000011),
#  ('30', 701.4000000000011),
#  ('when', 691.600000000001),
#  ('5', 690.0000000000009),
#  ('tbsp', 679.6000000000009),
#  ('beat', 679.400000000001),
#  ('keep', 672.600000000001),
#  ('this', 662.200000000001),
#  ('whisk', 659.0000000000011),
#  ('some', 658.6000000000008),
#  ('flour', 657.8000000000014),
#  ('dough', 656.6000000000014),
#  ('any', 655.200000000001),
#  ('just', 652.4000000000009),
#  ('lightly', 651.2000000000012),
#  ('around', 642.6000000000012),
#  ('few', 639.0000000000009),
#  ('chill', 637.200000000001),
#  ('well', 609.2000000000008),
#  ('have', 608.6000000000008),
#  ('golden', 600.2000000000008),
#  ('more', 598.0000000000007),
#  ('cling', 595.4000000000009),
#  ('down', 581.0000000000009),
#  ('bowl,', 556.6000000000008),
#  ('season', 539.4000000000001),
#  ('by', 529.4000000000007),
#  ('has', 521.0000000000005),
#  ('3', 518.8000000000006),
#  ('surface', 499.60000000000093),
#  ('but', 496.2000000000004),
#  ('spread', 496.0000000000006),
#  ('orange', 478.40000000000066),
#  ('tin.', 474.4000000000008),
#  ('sugar,', 473.60000000000076),
#  ('fridge', 473.60000000000036),
#  ('food', 469.8000000000007),
#  ('20', 467.40000000000043),
#  ('through', 467.2000000000003),
#  ('smooth', 465.8000000000008),
#  ('rest', 465.4000000000003),
#  ('fold', 465.20000000000067),
#  ('scatter', 458.2000000000003),
#  ('once', 456.2000000000005),
#  ('flour,', 456.00000000000097),
#  ('melt', 454.60000000000053),
#  ('two', 444.2000000000006),
#  ('that', 444.00000000000034),
#  ('sides', 443.00000000000074),
#  ('sprinkle', 439.2000000000004),
#  ('they', 438.0000000000002),
#  ('warm', 436.40000000000043),
#  ('base', 433.00000000000074),
#  ('4', 426.00000000000045),
#  ('sheet', 424.8000000000006),
#  ('press', 421.6000000000007),
#  ('milk', 420.4000000000005),
#  ('salt', 420.4000000000001),
#  ('another', 419.8000000000004),
#  ('simmer', 419.5999999999999),
#  ('stick', 417.4000000000007),
#  ('stirring', 415.0000000000001),
#  ('tin,', 414.8000000000005),
#  ('15', 413.60000000000036),
#  ('film', 412.6000000000004),
#  ('6.', 411.4000000000003),
#  ('transfer', 408.8000000000003),
#  ('butter,', 406.40000000000055),
#  ('enough', 405.2000000000005),
#  ('back', 404.60000000000025),
#  ('cool.', 404.2000000000004),
#  ('bowl.', 399.8000000000004),
#  ('meanwhile,', 399.8000000000002),
#  ('hot', 392.8000000000002),
#  ('tray', 391.4000000000002),
#  ('carefully', 391.0000000000002),
#  ('lemon', 389.0000000000001),
#  ('pudding', 388.80000000000075),
#  ('pan,', 388.0),
#  ('tsp', 385.2000000000004),
#  ('between', 384.8000000000004),
#  ('dry', 382.40000000000043),
#  ('foil', 381.60000000000036),
#  ('roasting', 377.19999999999993),
#  ('ingredients', 376.2000000000003),
#  ('while', 376.2000000000003),
#  ('boil', 375.79999999999995),
#  ('juice', 375.6),
#  ('layer', 367.60000000000036),
#  ('4.', 366.6000000000005),
#  ('potatoes', 362.19999999999993),
#  ('take', 353.60000000000014),
#  ('wrap', 352.80000000000047),
#  ('very', 351.0000000000002),
#  ('fry', 350.4),
#  ('200c/180c', 348.20000000000016),
#  ('comes', 345.6000000000006),
#  ('frying', 345.5999999999999),
#  ('180c/160c', 342.8000000000004),
#  ('golden.', 341.60000000000014),
#  ('side', 340.60000000000014),
#  ('white', 338.4000000000003),
#  ('not', 336.60000000000014),
#  ('parchment.', 333.60000000000036),
#  ('slice', 333.6),
#  ('centre', 333.40000000000043),
#  ('eggs', 333.40000000000043),
#  ('sauce', 333.4),
#  ('top.', 333.0000000000002),
#  ('skewer', 332.0000000000005),
#  ('drizzle', 329.0),
#  ('medium', 327.80000000000007),
#  ('water.', 327.20000000000016),
#  ('parchment', 321.8000000000003),
#  ('x', 320.8000000000003),
#  ('melted', 319.00000000000034),
#  ('aside', 316.4000000000001),
#  ('lift', 315.60000000000025),
#  ('edges', 314.2000000000004),
#  ('everything', 313.60000000000014),
#  ('knife', 311.8000000000002),
#  ('thick', 307.60000000000014),
#  ('return', 305.79999999999995),
#  ('cake.', 305.40000000000055),
#  ('syrup', 304.4000000000003),
#  ('least', 301.8000000000002),
#  ('paper', 300.20000000000016),
#  ('fruit', 298.8000000000003),
#  ('aside.', 297.60000000000014),
#  ('zest', 296.80000000000007),
#  ('pan.', 295.79999999999995),
#  ('turkey', 295.6),
#  ('ready', 294.6),
#  ('soft', 290.4000000000001),
#  ('saucepan', 288.19999999999993),
#  ('middle', 286.4000000000002),
#  ('serve.', 285.19999999999993),
#  ('serving', 283.3999999999999),
#  ('round', 283.2000000000004),
#  ('divide', 282.60000000000014),
#  ('should', 282.4),
#  ('drain', 282.4),
#  ('hr', 282.20000000000016),
#  ('toss', 282.0),
#  ('onion', 281.79999999999995),
#  ('trim', 281.4000000000003),
#  ('roast', 281.4),
#  ('need', 280.60000000000014),
#  ('leaves', 280.19999999999993),
#  ('sugar.', 277.60000000000025),
#  ('peel', 277.0),
#  ('grease', 274.2000000000003),
#  ('brown', 273.4000000000001),
#  ('dust', 270.8000000000003),
#  ('well.', 269.3999999999999),
#  ('don’t', 269.0),
#  ('sit', 268.80000000000007),
#  ('cheese', 267.79999999999995),
#  ('completely', 267.0),
#  ('water,', 266.80000000000007),
#  ('slices', 266.5999999999999),
#  ('cool,', 265.80000000000007),
#  ('arrange', 265.20000000000005),
#  ('piece', 264.79999999999995),
#  ('vanilla', 263.60000000000025),
#  ('end', 261.6),
#  ('smooth.', 261.20000000000016),
#  ('wire', 261.0000000000002),
#  ('6', 261.0),
#  ('serve,', 258.19999999999993),
#  ('cold', 257.9999999999999),
#  ('lay', 257.4000000000001),
#  ('allow', 257.0),
#  ('floured', 255.40000000000023),
#  ('along', 254.19999999999996),
#  ('bottom', 253.40000000000006),
#  ('work', 251.40000000000018),
#  ('marzipan', 251.20000000000024),
#  ('pinch', 251.00000000000003),
#  ('knead', 249.60000000000022),
#  ('time,', 247.8000000000001),
#  ('chopped', 247.79999999999995),
#  ('together.', 243.60000000000005),
#  ('20cm', 241.20000000000024),
#  ('garlic', 238.79999999999998),
#  ('now', 237.19999999999993),
#  ('days', 230.6),
#  ('like', 229.80000000000004),
#  ('biscuits', 229.60000000000022),
#  ('dish', 228.99999999999994),
#  ('fill', 228.80000000000004),
#  ('repeat', 228.79999999999998),
#  ('leaving', 227.79999999999998),
#  ('excess', 225.60000000000005),
#  ('processor', 225.6),
#  ('other', 221.79999999999993),
#  ('give', 220.59999999999994),
#  ('shape', 218.80000000000004),
#  ('cooked', 218.79999999999995),
#  ('ice', 218.39999999999992),
#  ('made', 218.19999999999993),
#  ('electric', 218.00000000000014),
#  ('low', 216.39999999999992),
#  ('boil,', 215.99999999999997),
#  ('butter.', 215.79999999999993),
#  ('plate', 215.39999999999995),
#  ('it.', 214.19999999999996),
#  ('away', 213.19999999999993),
#  ('cake,', 212.00000000000014),
#  ('pieces', 211.19999999999993),
#  ('boiling', 210.79999999999993),
#  ('black', 208.5999999999999),
#  ('get', 208.39999999999995),
#  ('heat.', 207.99999999999994),
#  ('clean', 207.59999999999994),
#  ('eggs,', 207.40000000000012),
#  ('like.', 203.79999999999993),
#  ('bay', 203.19999999999993),
#  ('decorate', 202.8000000000001),
#  ('cream,', 202.39999999999992),
#  ('heat,', 202.2),
#  ('pie', 201.8000000000002),
#  ('together,', 199.4),
#  ('evenly', 199.19999999999996),
#  ('ground', 199.19999999999996),
#  ('further', 199.19999999999993),
#  ('rack', 197.20000000000002),
#  ('its', 196.79999999999995),
#  ('stock', 195.4),
#  ('(see', 194.19999999999993),
#  ('paper.', 193.99999999999994),
#  ('pipe', 193.40000000000006),
#  ('oil,', 191.19999999999993),
#  ('hrs', 190.59999999999997),
#  ('slightly', 189.39999999999992),
#  ('mixing', 188.99999999999997),
#  ('let', 188.79999999999995),
#  ('non-stick', 186.79999999999993),
#  ('freeze', 186.19999999999993),
#  ('minutes', 185.79999999999995),
#  ('too', 185.79999999999995),
#  ('making', 185.59999999999994),
#  ('deep', 185.19999999999996),
#  ('liquid', 184.59999999999997),
#  ('reduce', 183.59999999999997),
#  ('dough.', 183.4),
#  ('cooking', 183.2),
#  ('boil.', 182.39999999999998),
#  ('still', 182.39999999999992),
#  ('sharp', 181.39999999999992),
#  ('icing.', 180.80000000000004),
#  ('onions', 180.79999999999998),
#  ('firm', 180.39999999999995),
#  ('clean.', 179.8000000000001),
#  ('fat', 179.8),
#  ('time', 179.79999999999995),
#  ('again', 179.5999999999999),
#  ('circle', 178.4),
#  ('squeeze', 177.99999999999994),
#  ('bacon', 177.79999999999998),
#  ('day', 177.79999999999995),
#  ('thin', 177.39999999999992),
#  ('help', 176.79999999999993),
#  ('thyme', 174.99999999999997),
#  ('(or', 174.39999999999992),
#  ('frozen', 174.19999999999993),
#  ('roughly', 173.59999999999997),
#  ('piping', 173.5999999999999),
#  ('it’s', 173.19999999999993),
#  ('balls', 172.99999999999991),
#  ('sieve', 172.59999999999997),
#  ('push', 172.59999999999997),
#  ('completely.', 172.59999999999994),
#  ('ginger', 172.39999999999992),
#  ('bag', 172.39999999999992),
#  ('room', 172.19999999999993),
#  ('fine', 171.99999999999991),
#  ('whizz', 171.39999999999992),
#  ('whole', 170.99999999999994),
#  ('salt.', 169.39999999999995),
#  ('overnight.', 168.79999999999993),
#  ('star', 168.19999999999993),
#  ('covered', 167.39999999999998),
#  ('extra', 167.39999999999995),
#  ('12', 167.39999999999995),
#  ('wooden', 167.19999999999993),
#  ('tie', 166.59999999999994),
#  ('brown.', 166.39999999999995),
#  ('crisp', 165.99999999999997),
#  ('tins', 165.79999999999998),
#  ('under', 165.79999999999998),
#  ('mixture.', 165.59999999999994),
#  ('continue', 165.2),
#  ('same', 165.19999999999993),
#  ('cranberries', 164.79999999999995),
#  ('come', 164.5999999999999),
#  ('nuts', 164.19999999999993),
#  ('edge', 164.19999999999993),
#  ('cakes', 163.99999999999997),
#  ('every', 162.59999999999997),
#  ('filling', 162.5999999999999),
#  ('tender.', 162.2),
#  ('chop', 161.79999999999995),
#  ('hand', 161.79999999999993),
#  ('temperature', 161.59999999999994),
#  ('icing,', 161.20000000000002),
#  ('airtight', 161.19999999999993),
#  ('dark', 160.59999999999994),
#  ('turning', 160.39999999999998),
#  ('big', 160.39999999999992),
#  ('stamp', 159.6),
#  ('dried', 159.59999999999994),
#  ('sure', 159.39999999999995),
#  ('microwave', 159.39999999999992),
#  ('spoon.', 159.39999999999992),
#  ('rub', 158.59999999999997),
#  ('olive', 158.39999999999998),
#  ('almonds', 158.19999999999993),
#  ('juice,', 158.19999999999993),
#  ('tart', 158.00000000000003),
#  ('up.', 156.79999999999995),
#  ('good', 156.59999999999997),
#  ('circles', 156.39999999999995),
#  ('set.', 155.99999999999994),
#  ('prepared', 155.99999999999994),
#  ('greaseproof', 155.99999999999991),
#  ('thickness', 155.79999999999998),
#  ('8', 155.79999999999995),
#  ('kitchen', 155.39999999999998),
#  ('simmering', 155.39999999999992),
#  ('pulse', 155.39999999999992),
#  ('juices', 155.2),
#  ('muffin', 154.99999999999997),
#  ('sift', 154.19999999999993),
#  ('skin', 154),
#  ('rolling', 153.19999999999993),
#  ('hrs.', 152.99999999999994),
#  ('dip', 152.99999999999994),
#  ('starting', 152.79999999999998),
#  ('do', 152.2),
#  ('mixture,', 151.79999999999995),
#  ('salt,', 151.79999999999995),
#  ('bread', 151.39999999999995),
#  ('strain', 151.0),
#  ('meat', 151.0),
#  ('finely', 150.79999999999998),
#  ('top,', 149.59999999999994),
#  ('180c/gas', 148.79999999999995),
#  ('beaten', 148.59999999999994),
#  ('1-2', 148.19999999999993),
#  ('brandy', 147.79999999999993),
#  ('start', 147.59999999999997),
#  ('sheets', 147.39999999999992),
#  ('really', 146.99999999999997),
#  ('batter', 146.99999999999991),
#  ('powder', 146.5999999999999),
#  ('pepper', 146.39999999999998),
#  ('mincemeat', 145.59999999999994),
#  ('soak', 145.19999999999993),
#  ('holes', 144.99999999999991),
#  ('foil,', 144.2),
#  ('mixed', 144.19999999999993),
#  ('hrs,', 143.79999999999995),
#  ('egg,', 143.5999999999999),
#  ('seeds', 143.2),
#  ('slowly', 142.59999999999997),
#  ('high', 142.39999999999998),
#  ('want', 142.39999999999995),
#  ('surface.', 142.39999999999992),
#  ('after', 142.19999999999996),
#  ('first', 141.79999999999995),
#  ('long', 141.79999999999995),
#  ('sauce,', 141.39999999999998),
#  ('double', 140.79999999999995),
#  ('flat', 140.79999999999993),
#  ('scrape', 139.39999999999998),
#  ('gradually', 138.99999999999994),
#  ('45', 138.79999999999995),
#  ('2-3', 138.59999999999997),
#  ('pale', 138.5999999999999),
#  ('bit', 137.59999999999997),
#  ('through.', 136.79999999999998),
#  ('cinnamon', 136.59999999999997),
#  ('serving.', 136.59999999999997),
#  ('5.', 135.79999999999995),
#  ('adding', 135.79999999999995),
#  ('inside', 135.2),
#  ('red', 135.2),
#  ('inserted', 134.99999999999991),
#  ('squash', 134.79999999999995),
#  ('create', 134.59999999999994),
#  ('oil.', 134.4),
#  ('break', 134.2),
#  ('cutter', 134.19999999999993),
#  ('caster', 133.99999999999994),
#  ('tray.', 133.39999999999998),
#  ('both', 132.59999999999997),
#  ('spices', 132.39999999999995),
#  ('risen', 132.19999999999993),
#  ('3.', 132.19999999999993),
#  ('cream.', 131.99999999999994),
#  ('whites', 131.59999999999997),
#  ('rack.', 131.19999999999993),
#  ('light', 129.99999999999994),
#  ('biscuit', 129.79999999999993),
#  ('well,', 129.39999999999998),
#  ('lid', 129.39999999999998),
#  ('couple', 129.2),
#  ('halfway', 129.19999999999996),
#  ('three', 129.19999999999993),
#  ('ham', 129.0),
#  ('sauce.', 128.6),
#  ('(if', 128.39999999999998),
#  ('cocktail', 127.99999999999997),
#  ('40', 127.79999999999998),
#  ('steam', 127.79999999999994),
#  ('200c/fan', 127.59999999999995),
#  ('their', 126.99999999999997),
#  ('potato', 126.79999999999998),
#  ('7.', 126.39999999999998),
#  ('salmon', 126.2),
#  ('board', 126.19999999999997),
#  ('stuffing', 126.0),
#  ('bubble', 125.39999999999998),
#  ('than', 125.39999999999996),
#  ('smooth,', 125.39999999999996),
#  ('chicken', 124.6),
#  ('green', 124.19999999999995),
#  ('hands', 123.99999999999996),
#  ('foil.', 123.79999999999995),
#  ('days.', 123.59999999999997),
#  ('way', 123.19999999999997),
#  ('level', 123.19999999999993),
#  ('220c/200c', 123.0),
#  ('pastry,', 122.99999999999994),
#  ('soft.', 122.79999999999997),
#  ('check', 122.59999999999997),
#  ('ahead', 122.59999999999997),
#  ('wine', 122.2),
#  ('parchment,', 121.59999999999995),
#  ('may', 121.39999999999996),
#  ('combine', 121.19999999999996),
#  ('tightly', 120.99999999999997),
#  ('garlic,', 120.6),
#  ('lined', 120.39999999999998),
#  ('form', 120.19999999999996),
#  ('no', 119.99999999999997),
#  ('scoop', 119.99999999999997),
#  ('container', 118.99999999999997),
#  ('crème', 118.6),
#  ('loaf', 118.59999999999997),
#  ('shallow', 118.39999999999998),
#  ('jam', 118.19999999999996),
#  ('freezer', 117.99999999999997),
#  ('strip', 117.99999999999996),
#  ('there', 117.79999999999995),
#  ('quickly', 116.79999999999997),
#  ('knife,', 116.79999999999997),
#  ('coconut', 115.99999999999997),
#  ('cooled', 115.99999999999996),
#  ('surface,', 115.99999999999994),
#  ('starts', 115.79999999999997),
#  ('thick.', 115.79999999999997),
#  ('pack', 115.4),
#  ('custard', 115.39999999999996),
#  ('final', 114.99999999999997),
#  ('saucepan,', 114.99999999999997),
#  ('plate.', 114.79999999999997),
#  ('oven,', 113.79999999999998),
#  ('pepper.', 113.4),
#  ('seasoning.', 113.4),
#  ('mix.', 113.39999999999996),
#  ('apple', 113.19999999999999),
#  ('string', 113.19999999999996),
#  ('basin', 113.19999999999995),
#  ('again.', 112.99999999999997),
#  ('month.', 112.99999999999997),
#  ('splash', 112.6),
#  ('zest,', 112.19999999999997),
#  ('fridge.', 111.99999999999997),
#  ('pies', 111.99999999999993),
#  ('separate', 111.59999999999997),
#  ('loosely', 111.59999999999997),
#  ('seal', 111.59999999999997),
#  ('blitz', 111.59999999999997),
#  ('honey', 111.39999999999998),
#  ('.', 111.39999999999998),
#  ('shape.', 111.19999999999997),
#  ('edges.', 110.99999999999996),
#  ('little.', 110.59999999999997),
#  ('you’re', 110.19999999999997),
#  ('chilled', 109.99999999999997),
#  ('seasoning', 109.6),
#  ('trimmings', 109.59999999999995),
#  ('finish', 109.19999999999997),
#  ('hole', 109.19999999999995),
#  ('overnight', 108.79999999999998),
#  ('smaller', 108.19999999999996),
#  ('combined.', 107.99999999999996),
#  ('syrup,', 107.79999999999997),
#  ('reheat', 107.6),
#  ('stand', 107.59999999999997),
#  ('milk,', 107.59999999999997),
#  ('pastry.', 107.19999999999996),
#  ('trays', 107.19999999999996),
#  ('shallots', 106.6),
#  ('straight', 106.39999999999998),
#  ('20-25', 106.39999999999996),
#  ('fluffy.', 105.99999999999994),
#  ('reserved', 105.79999999999998),
#  ('160c/140c', 105.79999999999997),
#  ('salted', 105.2),
#  ('min', 105.19999999999999),
#  ('sage', 103.6),
#  ('sausage', 103.59999999999997),
#  ('hold', 103.59999999999997),
#  ('stars', 103.39999999999995),
#  ('warm.', 102.99999999999997),
#  ('knife.', 102.79999999999997),
#  ('15-20', 102.59999999999997),
#  ('dish.', 102.4),
#  ('shapes', 101.79999999999995),
#  ('crisp.', 101.6),
#  ('coat', 101.6),
#  ('lime', 101.6),
#  ('pressing', 101.59999999999997),
#  ('pork', 101.4),
#  ('even', 101.39999999999998),
#  ('shake', 101.0),
#  ('vinegar', 101.0),
#  ('mix,', 100.99999999999997),
#  ('cocoa', 100.79999999999997),
#  ('jar', 100.79999999999997),
#  ('yolks', 100.59999999999997),
#  ('sprouts', 100.2),
#  ('mash', 100.19999999999999),
#  ('almonds,', 99.79999999999995),
#  ('grate', 99.6),
#  ('£1', 99.39999999999995),
#  ('gas', 99.19999999999999),
#  ('halve', 99.19999999999999),
#  ('dry.', 99.19999999999997),
#  ('ball', 99.19999999999996),
#  ('cranberry', 98.79999999999998),
#  ('colour', 98.79999999999997),
#  ('ahead.', 97.19999999999999),
#  ('look', 97.19999999999996),
#  ('generously', 96.99999999999997),
#  ('more.', 96.79999999999998),
#  ('fruit,', 96.79999999999995),
#  ('sticky', 96.6),
#  ('leaves,', 96.6),
#  ('23cm', 96.59999999999995),
#  ('ends', 96.39999999999998),
#  ('nuts,', 96.19999999999997),
#  ('these', 96.19999999999997),
#  ('parsley', 95.80000000000001),
#  ('next', 95.79999999999998),
#  ('leaves.', 95.6),
#  ('powder,', 95.59999999999997),
#  ('and,', 95.39999999999998),
#  ('third', 95.19999999999999),
#  ('crumbs', 95.19999999999996),
#  ('3-4', 95.0),
#  ('case', 94.79999999999995),
#  ('doesn’t', 94.59999999999997),
#  ('film.', 94.39999999999998),
#  ('25', 94.19999999999999),
#  ('store', 94.19999999999999),
#  ('drop', 94.19999999999999),
#  ('minutes.', 93.79999999999998),
#  ('day,', 93.79999999999998),
#  ('grill', 93.4),
#  ('cabbage', 93.2),
#  ('ribbon', 93.19999999999996),
#  ('meringue', 92.80000000000001),
#  ('pile', 92.79999999999998),
#  ('rice', 92.4),
#  ('160c/gas', 92.39999999999996),
#  ('hr.', 92.19999999999999),
#  ('followed', 92.19999999999997),
#  ('25-30', 91.99999999999997),
#  ('best', 91.79999999999998),
#  ('fit', 91.59999999999997),
#  ('thinly', 91.39999999999998),
#  ('softened', 91.19999999999999),
#  ('10-15', 91.0),
#  ('duck', 91),
#  ('lower', 90.79999999999998),
#  ('tops', 90.79999999999997),
#  ('juice.', 90.0),
#  ('second', 89.99999999999997),
#  ('tea', 89.6),
#  ('discard', 89.4),
#  ('chocolate.', 89.19999999999999),
#  ('sheet.', 89.19999999999997),
#  ('dusted', 89.19999999999996),
#  ('re-roll', 89.19999999999996),
#  ('mushrooms', 89.0),
#  ('24', 88.4),
#  ('kept', 87.99999999999997),
#  ('190c/170c', 87.6),
#  ('outside', 87.39999999999998),
#  ('strips', 87.19999999999999),
#  ('most', 87.19999999999999),
#  ('paper,', 87.19999999999997),
#  ('buttered', 87.19999999999997),
#  ('preheat', 86.79999999999998),
#  ('chocolate,', 86.59999999999997),
#  ('syrup.', 86.59999999999997),
#  ('sides.', 85.99999999999997),
#  ('metal', 85.79999999999998),
#  ('180c/fan', 85.59999999999997),
#  ('pat', 85.4),
#  ('pop', 85.39999999999998),
#  ('up,', 85.19999999999999),
#  ('golden,', 85.19999999999999),
#  ('mini', 85.19999999999999),
#  ('mustard', 85.0),
#  ('swirl', 84.59999999999997),
#  ('topping', 84.59999999999997),
#  ('square', 84.59999999999997),
#  ('taste.', 84.2),
#  ('stiff', 83.99999999999997),
#  ('needed.', 83.4),
#  ('carrots', 83.2),
#  ('over.', 83.0),
#  ('minutes,', 82.80000000000001),
#  ('almost', 82.4),
#  ('fish', 82.4),
#  ('size', 82.39999999999998),
#  ('it,', 82.19999999999999),
#  ('simmer,', 82.0),
#  ('goose', 82),
#  ('beating', 81.99999999999997),
#  ('softened.', 81.80000000000001),
#  ('processor,', 81.79999999999998),
#  ('maple', 81.79999999999998),
#  ('time.', 81.6),
#  ('veg', 81.6),
#  ('12-hole', 81.59999999999997),
#  ('poke', 81.39999999999998),
#  ('dish,', 81.2),
#  ('clementine', 81.19999999999999),
#  ('fingers', 80.99999999999997),
#  ('whip', 80.80000000000001),
#  ('(the', 80.79999999999998),
#  ('cooked,', 80.6),
#  ('breadcrumbs,', 80.39999999999998),
#  ('fresh', 80.19999999999999),
#  ('wedges', 80.19999999999999),
#  ('gold', 79.99999999999997),
#  ('egg.', 79.79999999999998),
#  ('whisking', 79.79999999999998),
#  ('apricot', 79.79999999999997),
#  ('rectangle', 79.6),
#  ('fondant', 79.59999999999997),
#  ('cookie', 79.59999999999997),
#  ('shelf', 79.39999999999998),
#  ('grated', 79.19999999999999),
#  ('edible', 79.19999999999997),
#  ('onion,', 79.0),
#  ('looks', 78.99999999999997),
#  ('runny', 78.99999999999997),
#  ('soaked', 78.79999999999998),
#  ('gelatine', 78.79999999999998),
#  ('cases', 78.79999999999997),
#  ('film,', 78.39999999999998),
#  ('worry', 78.19999999999999),
#  ('spoonful', 78.0),
#  ('jelly', 78.0),
#  ('colouring', 77.79999999999998),
#  ('(you', 77.79999999999998),
#  ('1cm', 77.79999999999998),
#  ('palette', 77.79999999999998),
#  ('pull', 77.6),
#  ('saucepan.', 77.4),
#  ('glass', 77.19999999999999),
#  ('flour.', 76.99999999999997),
#  ('side.', 76.80000000000001),
#  ('hot.', 76.80000000000001),
#  ('crumble', 76.6),
#  ('large,', 76.6),
#  ('12-15', 76.59999999999997),
#  ('oven.', 76.4),
#  ('onions,', 76.4),
#  ('toast', 76.2),
#  ('sponge', 76.0),
#  ('breadcrumbs.', 75.79999999999998),
#  ('sandwich', 75.79999999999998),
#  ('hours', 75.6),
#  ('fan/', 75.6),
#  ('left', 75.39999999999998),
#  ('secure', 75.39999999999998),
#  ('two-thirds', 75.19999999999999),
#  ('-', 75.19999999999999),
#  ('used', 75.19999999999999),
#  ('melted.', 75.0),
#  ('bits', 75.0),
#  ('quarter', 74.79999999999998),
#  ('more,', 74.79999999999998),
#  ('breast', 74.6),
#  ('cherries', 74.59999999999997),
#  ('rum', 74.59999999999997),
#  ('dressing', 74.2),
#  ('8-10', 74.0),
#  ('doubled', 74.0),
#  ('heatproof', 73.80000000000001),
#  ('yolk', 73.79999999999998),
#  ('caramel', 73.79999999999998),
#  ('them.', 73.79999999999998),
#  ('½', 73.6),
#  ('keeping', 73.39999999999998),
#  ('rosemary', 73.2),
#  ('down,', 73.19999999999999),
#  ('jug.', 73.19999999999999),
#  ('bicarbonate', 72.99999999999997),
#  ('base.', 72.79999999999998),
#  ('ingredients,', 72.6),
#  ('vinegar,', 72.6),
#  ('months.', 72.4),
#  ('oiled', 72.19999999999999),
#  ('spinach', 72.0),
#  ('much', 72.0),
#  ('cutter,', 71.99999999999997),
#  ('tender', 71.8),
#  ('vegetables', 71.8),
#  ('beans', 71.6),
#  ('gravy', 71),
#  ('week', 70.79999999999998),
#  ('layers', 70.79999999999998),
#  ('out.', 70.79999999999998),
#  ('100g', 70.6),
#  ('larger', 70.6),
#  ('cloves', 70.6),
#  ('chilli', 70.6),
#  (',', 70.4),
#  ('5-10', 70.4),
#  ('beef', 70.4),
#  ('ovenproof', 70.2),
#  ('soften', 70.0),
#  ('jug', 70.0),
#  ('tray,', 69.4),
#  ('pepper,', 69.4),
#  ('soft,', 69.39999999999998),
#  ('peel,', 69.19999999999999),
#  ('eat', 69.19999999999999),
#  ('snip', 69.19999999999999),
#  ('gingerbread', 69.19999999999997),
#  ('slightly.', 69.0),
#  ('cook,', 68.8),
#  ('150ml', 68.79999999999998),
#  ('shape,', 68.6),
#  ('slices,', 68.4),
#  ('season.', 68.4),
#  ('serving,', 68.2),
#  ('done', 68.19999999999999),
#  ('gentle', 68.19999999999999),
#  ('spice', 67.79999999999998),
#  ('see', 67.79999999999998),
#  ('crumbs.', 67.79999999999998),
#  ('plenty', 67.6),
#  ('either', 67.6),
#  ('stock,', 67.6),
#  ('apples', 67.4),
#  ('sliced', 67.2),
#  ('plain', 67.19999999999999),
#  ('salad', 67.0),
#  ('thick,', 67.0),
#  ('length', 66.80000000000001),
#  ('cooling', 66.79999999999998),
#  ('1½', 66.6),
#  ('prick', 66.39999999999998),
#  ('unwrap', 66.19999999999999),
#  ('overlapping', 66.0),
#  ('go', 66.0),
#  ('run', 65.8),
#  ('wet', 65.6),
#  ('increase', 65.4),
#  ('190c/fan', 65.19999999999999),
#  ('firm.', 65.19999999999999),
#  ('in.', 65.0),
#  ('first,', 65.0),
#  ('glaze', 65.0),
#  ('spoon,', 64.80000000000001),
#  ('paste.', 64.80000000000001),
#  ('chill.', 64.80000000000001),
#  ('turkey,', 64.8),
#  ('been', 64.6),
#  ('5cm', 64.6),
#  ('puddings', 64.59999999999997),
#  ('rise', 64.4),
#  ('kettle', 64.39999999999998),
#  ('tender,', 64.2),
#  ('ginger,', 64.19999999999999),
#  ('across', 64.19999999999999),
#  ('milk.', 64.19999999999999),
#  ('cheese,', 64.0),
#  ('last', 64.0),
#  ('sea', 64.0),
#  ('filling,', 63.99999999999999),
#  ('dollop', 63.99999999999999),
#  ('briefly', 63.99999999999999),
#  ('yogurt', 63.800000000000004),
#  ('christmas', 63.59999999999999),
#  ('over,', 63.400000000000006),
#  ('nutmeg,', 62.6),
#  ('170c/gas', 62.4),
#  ('(this', 62.4),
#  ('taste', 62.4),
#  ('blend', 62.2),
#  ('dot', 62.199999999999996),
#  ('nutmeg', 62.0),
#  ('half.', 62.0),
#  ('per', 61.8),
#  ('2cm', 61.79999999999999),
#  ('four', 61.6),
#  ('fraîche', 61.400000000000006),
#  ('(about', 61.4),
#  ('almond', 61.399999999999984),
#  ('crush', 61.199999999999996),
#  ('10cm', 61.19999999999998),
#  ('bun', 61.19999999999998),
#  ('season,', 61.0),
#  ('flip', 60.99999999999999),
#  ('stop', 60.800000000000004),
#  ('centre.', 60.79999999999999),
#  ('little,', 60.6),
#  ('min,', 60.6),
#  ('spring', 60.400000000000006),
#  ('cutting', 60.4),
#  ('seasoning,', 60.2),
#  ('like,', 60.199999999999996),
#  ('melted,', 60.0),
#  ('pushing', 59.99999999999999),
#  ('springform', 59.99999999999998),
#  ('cases.', 59.99999999999998),
#  ('without', 59.800000000000004),
#  ('cheese.', 59.800000000000004),
#  ('rounds', 59.59999999999999),
#  ('leftover', 59.4),
#  ('hot,', 59.2),
#  ('colour.', 58.800000000000004),
#  ('warm,', 58.79999999999999),
#  ('rough', 58.79999999999999),
#  ('zest.', 58.6),
#  ('reduced', 58.6),
#  ('edges,', 58.59999999999999),
#  ('cold,', 58.4),
#  ('spices,', 58.4),
#  ('seal.', 58.4),
#  ('basin.', 58.399999999999984),
#  ('pin', 58.199999999999996),
#  ('dry,', 58.199999999999996),
#  ('then,', 58.0),
#  ('ahead,', 58.0),
#  ('simmer.', 57.800000000000004),
#  ('200c/gas', 57.800000000000004),
#  ('herbs', 57.8),
#  ('score', 57.6),
#  ('plate,', 57.6),
#  ('mixer', 57.59999999999999),
#  ('coriander', 57.4),
#  ('decorate,', 57.399999999999984),
#  ('overhanging', 57.399999999999984),
#  ('except', 57.2),
#  ('plus', 57.2),
#  ('slight', 57.19999999999998),
#  ('cranberries,', 57.0),
#  ('100ml', 57.0),
#  ('dissolve', 56.800000000000004),
#  ('liquid.', 56.800000000000004),
#  ('edge.', 56.79999999999999),
#  ('fork', 56.6),
#  ('quite', 56.6),
#  ('sheet,', 56.6),
#  ('test', 56.400000000000006),
#  ('split', 56.199999999999996),
#  ('cheesecake', 55.99999999999998),
#  ('dates', 55.79999999999999),
#  ('out,', 55.6),
#  ('size.', 55.6),
#  ('layer.', 55.6),
#  ('handle,', 55.4),
#  ('stirring,', 55.2),
#  ('weigh', 55.2),
#  ('flesh', 55.2),
#  ('filling.', 55.199999999999996),
#  ('careful', 55.199999999999996),
#  ('slices.', 55.0),
#  ('fan', 54.800000000000004),
#  ('string.', 54.79999999999999),
#  ('cooking,', 54.6),
#  ('mascarpone', 54.6),
#  ('feels', 54.6),
#  ('where', 54.6),
#  ('breadcrumbs', 54.6),
#  ('pears', 54.6),
#  ('thickened.', 54.400000000000006),
#  ('paste', 54.400000000000006),
#  ('point', 54.400000000000006),
#  ('ready.', 54.4),
#  ('creamy', 54.4),
#  ('10-12', 54.4),
#  ...]

# %% [markdown]
# **Cake Ingredients:**
#  : sugar, flour, butter, milk, vanilla extract, egg, baking powder, zest

# %%
name_count = Counter()
for i in range(len(data)):     
    if data[i]['Name'] != None:
        for word in data[i]['Name'].split(" "):
            name_count[word] += 1
name_count.most_common()
# Out:
# [('&', 616),
#  ('with', 321),
#  ('christmas', 114),
#  ('cake', 103),
#  ('chocolate', 84),
#  ('cranberry', 79),
#  ('roast', 73),
#  ('sauce', 65),
#  ('turkey', 62),
#  ('cheese', 57),
#  ('salad', 55),
#  ('spiced', 51),
#  ('red', 45),
#  ('pudding', 43),
#  ('stuffing', 41),
#  ('cream', 40),
#  ('salmon', 40),
#  ('potato', 38),
#  ('apple', 37),
#  ('smoked', 37),
#  ('ham', 36),
#  ('cabbage', 35),
#  ('sticky', 35),
#  ('orange', 34),
#  ('pie', 33),
#  ('pies', 33),
#  ('mince', 33),
#  ('potatoes', 32),
#  ('ginger', 30),
#  ('sprouts', 29),
#  ('butter', 27),
#  ('chestnut', 27),
#  ('wine', 27),
#  ('mini', 26),
#  ('bacon', 25),
#  ('tart', 24),
#  ('onion', 24),
#  ('pork', 24),
#  ('bread', 23),
#  ('gravy', 23),
#  ('creamy', 23),
#  ('mushroom', 23),
#  ('clementine', 22),
#  ('baked', 22),
#  ('mulled', 22),
#  ('gingerbread', 21),
#  ('in', 21),
#  ('mustard', 21),
#  ('soup', 21),
#  ('easy', 20),
#  ('parsnip', 20),
#  ('chicken', 20),
#  ('mincemeat', 20),
#  ('beef', 19),
#  ('beetroot', 19),
#  ('lemon', 19),
#  ('squash', 19),
#  ('winter', 19),
#  ('gratin', 19),
#  ('pear', 18),
#  ('carrots', 18),
#  ('coconut', 18),
#  ('ice', 17),
#  ('cakes', 17),
#  ('pecan', 17),
#  ('duck', 17),
#  ('sausage', 17),
#  ('pancetta', 17),
#  ('festive', 17),
#  ('trifle', 16),
#  ('fruit', 16),
#  ('sweet', 16),
#  ('chilli', 16),
#  ('cocktail', 16),
#  ('hazelnut', 16),
#  ('dressing', 16),
#  ('sage', 16),
#  ('chutney', 15),
#  ('of', 15),
#  ('spinach', 15),
#  ('roasted', 15),
#  ('white', 14),
#  ('biscuits', 14),
#  ('nut', 14),
#  ('caramel', 14),
#  ('celeriac', 14),
#  ('brussels', 14),
#  ('hot', 13),
#  ('vegan', 13),
#  ('wreath', 13),
#  ('crispy', 13),
#  ('crunchy', 13),
#  ('rice', 13),
#  ('syrup', 13),
#  ('wild', 13),
#  ('sprout', 13),
#  ('apricot', 13),
#  ('meringue', 13),
#  ('almond', 12),
#  ('cheesecake', 12),
#  ('classic', 12),
#  ('pud', 12),
#  ('garlic', 12),
#  ('crumble', 12),
#  ('star', 12),
#  ('stuffed', 12),
#  ('herby', 12),
#  ('roasties', 12),
#  ('cauliflower', 12),
#  ('spice', 11),
#  ('honey', 11),
#  ('stollen', 11),
#  ('loaf', 11),
#  ('pears', 11),
#  ('bake', 11),
#  ('port', 11),
#  ('pomegranate', 11),
#  ('chorizo', 11),
#  ('spicy', 11),
#  ('seed', 11),
#  ('kit', 11),
#  ('onions', 11),
#  ('dip', 11),
#  ('cupcakes', 10),
#  ('puddings', 10),
#  ('cherry', 10),
#  ('tree', 10),
#  ('marzipan', 10),
#  ('coffee', 10),
#  ('root', 10),
#  ('maple', 10),
#  ('glazed', 10),
#  ('truffles', 10),
#  ('blue', 10),
#  ('braised', 10),
#  ('apples', 10),
#  ('raspberry', 10),
#  ('truffle', 10),
#  ('carrot', 10),
#  ('caramelised', 10),
#  ('walnut', 10),
#  ('black', 9),
#  ("goat's", 9),
#  ('salted', 9),
#  ('leek', 9),
#  ('terrine', 9),
#  ('pancakes', 9),
#  ('rosemary', 9),
#  ('lime', 9),
#  ('custard', 9),
#  ('pickled', 9),
#  ('passion', 9),
#  ('fennel', 9),
#  ('prawn', 9),
#  ('cinnamon', 9),
#  ('vanilla', 8),
#  ('cookies', 8),
#  ('goose', 8),
#  ('iced', 8),
#  ('boozy', 8),
#  ('log', 8),
#  ('toffee', 8),
#  ('simple', 8),
#  ('panettone', 8),
#  ('slice', 8),
#  ('marmalade', 8),
#  ('peppermint', 8),
#  ('baby', 8),
#  ('fruitcake', 8),
#  ('chestnuts', 8),
#  ('sesame', 8),
#  ('mango', 8),
#  ('rolls', 8),
#  ('pineapple', 8),
#  ('bites', 8),
#  ('skewers', 8),
#  ('crème', 8),
#  ('thyme', 8),
#  ('vegetables', 8),
#  ('feta', 8),
#  ('walnuts', 8),
#  ('stilton', 8),
#  ('horseradish', 8),
#  ('shallots', 8),
#  ('fig', 7),
#  ('little', 7),
#  ('fruity', 7),
#  ('lamb', 7),
#  ('buttered', 7),
#  ('rum', 7),
#  ('forest', 7),
#  ('bombe', 7),
#  ('wellington', 7),
#  ('torte', 7),
#  ('pistachio', 7),
#  ('toast', 7),
#  ('camembert', 7),
#  ('prosciutto', 7),
#  ('mash', 7),
#  ('mint', 7),
#  ('butternut', 7),
#  ('cups', 7),
#  ('goat’s', 7),
#  ('chicory', 7),
#  ('parsnips', 7),
#  ('cider', 7),
#  ('date', 7),
#  ('warm', 7),
#  ('fresh', 7),
#  ('green', 7),
#  ('liver', 7),
#  ('peas', 7),
#  ('snowman', 7),
#  ('bubble', 7),
#  ('squeak', 7),
#  ('pâté', 7),
#  ('crab', 7),
#  ('brownies', 6),
#  ('golden', 6),
#  ('almonds', 6),
#  ('chocolate,', 6),
#  ('jam', 6),
#  ('muffins', 6),
#  ('brandy', 6),
#  ('triple', 6),
#  ('roll', 6),
#  ('fudge', 6),
#  ('poppy', 6),
#  ('jelly', 6),
#  ('crown', 6),
#  ('olive', 6),
#  ('prawns', 6),
#  ('venison', 6),
#  ('brioche', 6),
#  ('brie', 6),
#  ('jewelled', 6),
#  ('berry', 6),
#  ('slow', 6),
#  ('dippers', 6),
#  ('roulade', 6),
#  ('relish', 6),
#  ('shallot', 6),
#  ('yogurt', 6),
#  ('pine', 6),
#  ('nuts', 6),
#  ('cucumber', 6),
#  ('parcels', 6),
#  ('toasts', 6),
#  ('spring', 6),
#  ('bean', 6),
#  ('buns', 5),
#  ('citrus', 5),
#  ('saffron', 5),
#  ('glaze', 5),
#  ('gammon', 5),
#  ('yule', 5),
#  ('chunky', 5),
#  ('vegetable', 5),
#  ('snowball', 5),
#  ('cheeseboard', 5),
#  ('peanut', 5),
#  ('candy', 5),
#  ('whisky', 5),
#  ('toasted', 5),
#  ('really', 5),
#  ('shortbread', 5),
#  ('creamed', 5),
#  ('homemade', 5),
#  ('reindeer', 5),
#  ('poached', 5),
#  ('crunch', 5),
#  ('eggs', 5),
#  ('martini', 5),
#  ('tomato', 5),
#  ('sour', 5),
#  ('thai', 5),
#  ('turkey,', 5),
#  ('fraîche', 5),
#  ('salmon,', 5),
#  ('dill', 5),
#  ('crisp', 5),
#  ('quick', 5),
#  ('kale', 5),
#  ('polenta', 5),
#  ('make-ahead', 5),
#  ('parfait', 5),
#  ('mont', 5),
#  ('tarts', 5),
#  ('fizz', 5),
#  ('risotto', 5),
#  ('treacle', 5),
#  ('leeks', 5),
#  ('hash', 5),
#  ('candied', 5),
#  ('sorbet', 5),
#  ('pepper', 5),
#  ('roots', 5),
#  ('punch', 5),
#  ('pots', 5),
#  ('juniper', 5),
#  ('platter', 5),
#  ('and', 5),
#  ('herb', 5),
#  ('slaw', 4),
#  ('sparkling', 4),
#  ('pops', 4),
#  ('rudolph', 4),
#  ('traybake', 4),
#  ('veg', 4),
#  ('brownie', 4),
#  ('bay', 4),
#  ('ultimate', 4),
#  ('ham,', 4),
#  ('melting', 4),
#  ('balls', 4),
#  ('compote', 4),
#  ('avocado', 4),
#  ('buttery', 4),
#  ('pigs', 4),
#  ('pastry', 4),
#  ('blankets', 4),
#  ('chestnut,', 4),
#  ('sugar-dusted', 4),
#  ('snowflake', 4),
#  ('pavlova', 4),
#  ('fritters', 4),
#  ('wings', 4),
#  ('potted', 4),
#  ('cookie', 4),
#  ('sugar', 4),
#  ('ricotta', 4),
#  ('chipolatas', 4),
#  ('eccles', 4),
#  ('truffled', 4),
#  ('vodka', 4),
#  ('recipe', 4),
#  ('bramley', 4),
#  ('parsley', 4),
#  ('double', 4),
#  ('caraway', 4),
#  ('tarragon', 4),
#  ('cranberry,', 4),
#  ('curry', 4),
#  ('mushrooms', 4),
#  ('blinis', 4),
#  ('greens', 4),
#  ('cooker', 4),
#  ('bark', 4),
#  ('turkish', 4),
#  ('tea', 4),
#  ('charred', 4),
#  ('party', 4),
#  ('choc', 4),
#  ('squares', 4),
#  ('anise', 4),
#  ('celery', 4),
#  ('salt', 4),
#  ('raisin', 4),
#  ('brown', 4),
#  ('sharing', 4),
#  ('plum', 4),
#  ('lentil', 4),
#  ('artichoke', 4),
#  ('madeira', 4),
#  ('scallops', 4),
#  ('coriander', 4),
#  ('savoy', 4),
#  ('fish', 4),
#  ('beans', 4),
#  ('twists', 4),
#  ('cheesy', 4),
#  ('rye', 4),
#  ('loin', 4),
#  ('grilled', 4),
#  ('mary', 3),
#  ('mix', 3),
#  ('strudel', 3),
#  ('mousse', 3),
#  ('amaretti', 3),
#  ('trees', 3),
#  ('soufflés', 3),
#  ('the', 3),
#  ('nutmeg', 3),
#  ('a', 3),
#  ('crostini', 3),
#  ('ho,', 3),
#  ('clotted', 3),
#  ('semifreddo', 3),
#  ('breast', 3),
#  ('wrapped', 3),
#  ('bauble', 3),
#  ('chip', 3),
#  ('eggnog', 3),
#  ('de', 3),
#  ('milk', 3),
#  ('sausage,', 3),
#  ('persian', 3),
#  ('fondue', 3),
#  ('pot', 3),
#  ('st', 3),
#  ('bundt', 3),
#  ('lobster', 3),
#  ('remoulade', 3),
#  ('stacks', 3),
#  ('biscuit', 3),
#  ('cardamom', 3),
#  ('stem', 3),
#  ('thins', 3),
#  ('french', 3),
#  ('banana', 3),
#  ('soufflé', 3),
#  ('fillet', 3),
#  ('baileys', 3),
#  ('limoncello', 3),
#  ('cranberries', 3),
#  ('tatin', 3),
#  ('slow-cooked', 3),
#  ('dauphinoise', 3),
#  ('pilaf', 3),
#  ('tagine', 3),
#  ('prosecco', 3),
#  ('english', 3),
#  ('healthy', 3),
#  ('sourdough', 3),
#  ('celeriac,', 3),
#  ('gravadlax', 3),
#  ('filled', 3),
#  ('creams', 3),
#  ('partridge', 3),
#  ('sloe', 3),
#  ('mayo', 3),
#  ('boxing', 3),
#  ('day', 3),
#  ('scones', 3),
#  ('oatcakes', 3),
#  ('ripple', 3),
#  ('gin', 3),
#  ('purée', 3),
#  ('honey-roasted', 3),
#  ('raisins', 3),
#  ('parmesan', 3),
#  ('bruschetta', 3),
#  ('delight', 3),
#  ('carbonara', 3),
#  ('stars', 3),
#  ('on', 3),
#  ('decoration', 3),
#  ('mashed', 3),
#  ('leaf', 3),
#  ('hasselback', 3),
#  ('pumpkin', 3),
#  ('slices', 3),
#  ('cointreau', 3),
#  ('pear,', 3),
#  ('stir-fried', 3),
#  ('prunes', 3),
#  ('giant', 3),
#  ('palmiers', 3),
#  ('confit', 3),
#  ('tartlets', 3),
#  ('yorkies', 3),
#  ('rose', 3),
#  ('irish', 3),
#  ('pheasant', 3),
#  ('sticks', 3),
#  ('chips', 3),
#  ('croutons', 3),
#  ('elderflower', 3),
#  ('artichokes', 3),
#  ('quince', 3),
#  ('beetroot,', 3),
#  ('jaffa', 3),
#  ('layer', 3),
#  ('broccoli', 3),
#  ('filo', 3),
#  ('egg', 3),
#  ('shoulder', 3),
#  ('redcurrant', 3),
#  ('muffin', 2),
#  ('gingery', 2),
#  ('granny', 2),
#  ('light', 2),
#  ('frosty', 2),
#  ('friands', 2),
#  ('cupcake', 2),
#  ('morning', 2),
#  ("mum's", 2),
#  ('for', 2),
#  ('fool', 2),
#  ('penguins', 2),
#  ('last-minute', 2),
#  ('tortilla', 2),
#  ('lollipops', 2),
#  ('membrillo', 2),
#  ('tiramisu', 2),
#  ('match', 2),
#  ('biscotti', 2),
#  ('malt', 2),
#  ('ciabatta', 2),
#  ('moroccan', 2),
#  ('house', 2),
#  ('man', 2),
#  ('holly', 2),
#  ('glam', 2),
#  ('fancies', 2),
#  ('shooting', 2),
#  ('mexican', 2),
#  ('cane', 2),
#  ('slow-roasted', 2),
#  ('rib', 2),
#  ('perfect', 2),
#  ('dough', 2),
#  ('toddy', 2),
#  ('crumbs', 2),
#  ('rocky', 2),
#  ('puff', 2),
#  ('bûche', 2),
#  ('noël', 2),
#  ('burnt', 2),
#  ('spritzer', 2),
#  ('fragrant', 2),
#  ('en', 2),
#  ('croûte', 2),
#  ('zesty', 2),
#  ('snow', 2),
#  ('macadamia', 2),
#  ('american', 2),
#  ('parsnip,', 2),
#  ('prawns,', 2),
#  ('chillies', 2),
#  ('chelsea', 2),
#  ('satay', 2),
#  ('rich', 2),
#  ('butter-basted', 2),
#  ('hollandaise', 2),
#  ('watercress', 2),
#  ('people', 2),
#  ('doughnuts', 2),
#  ('croquettes', 2),
#  ('juice', 2),
#  ('bellini', 2),
#  ('halloumi', 2),
#  ('deep-fried', 2),
#  ('guinea', 2),
#  ('fowl', 2),
#  ('icing', 2),
#  ('spirals', 2),
#  ('mincemeat,', 2),
#  ('whiskey', 2),
#  ('croque', 2),
#  ('maple-roasted', 2),
#  ('bacon,', 2),
#  ('comté', 2),
#  ('sherried', 2),
#  ('beer', 2),
#  ('tangerine', 2),
#  ('florentines', 2),
#  ('pea', 2),
#  ('food', 2),
#  ('pistachios', 2),
#  ('squash,', 2),
#  ('barley', 2),
#  ('traditional', 2),
#  ('squidgy', 2),
#  ('tarte', 2),
#  ('legs', 2),
#  ('straws', 2),
#  ('wellingtons', 2),
#  ('pesto', 2),
#  ('marsala', 2),
#  ('deep-filled', 2),
#  ('nougat', 2),
#  ('profiteroles', 2),
#  ('ivy', 2),
#  ('sparkle', 2),
#  ('full', 2),
#  ('twist', 2),
#  ('hock', 2),
#  ('peppered', 2),
#  ('mackerel', 2),
#  ('pink', 2),
#  ('leftover', 2),
#  ('casserole', 2),
#  ('cauliflower,', 2),
#  ('honey-roast', 2),
#  ('smashed', 2),
#  ('grapefruit', 2),
#  ('fruit,', 2),
#  ('flatbread', 2),
#  ('marshmallow', 2),
#  ('perky', 2),
#  ('blanc', 2),
#  ('faux', 2),
#  ('salsa', 2),
#  ('peppercorn', 2),
#  ('rillettes', 2),
#  ('savoury', 2),
#  ('mushroom,', 2),
#  ('dates', 2),
#  ('cottage', 2),
#  ('damson', 2),
#  ('orange,', 2),
#  ('garlicky', 2),
#  ('belly', 2),
#  ('chunks', 2),
#  ('mojito', 2),
#  ('buttermilk', 2),
#  ('freeze-ahead', 2),
#  ('rösti', 2),
#  ('swede', 2),
#  ('aubergine', 2),
#  ('hotpot', 2),
#  ('whipped', 2),
#  ('frosted', 2),
#  ('prune', 2),
#  ('all-the-trimmings', 2),
#  ('carrot,', 2),
#  ('potato,', 2),
#  ('dhal', 2),
#  ('stirrers', 2),
#  ('fridge', 2),
#  ('clementine,', 2),
#  ('bitter', 2),
#  ('chinese', 2),
#  ('rice,', 2),
#  ('ice-cream', 2),
#  ('seared', 2),
#  ('falafel', 2),
#  ('silky', 2),
#  ("santa's", 2),
#  ('samosas', 2),
#  ('alaska', 2),
#  ('haddock', 2),
#  ('kedgeree', 2),
#  ('breeze', 2),
#  ('sponge', 2),
#  ('spuds', 2),
#  ('paprika', 2),
#  ('sea', 2),
#  ('tangy', 2),
#  ('from-the-freezer', 2),
#  ('squashed', 2),
#  ('bourbon', 2),
#  ('courgette', 2),
#  ('minty', 2),
#  ('rainbow', 2),
#  ('crackers', 2),
#  ('microwave', 2),
#  ('butternut,', 2),
#  ('’n’', 2),
#  ('steamed', 2),
#  ('vinaigrette', 2),
#  ('bloody', 2),
#  ('cheddar', 2),
#  ('toastie', 2),
#  ('courgettes', 2),
#  ('fondant', 2),
#  ('rudolph’s', 2),
#  ('dark', 2),
#  ('honeyed', 2),
#  ('beetroot-cured', 2),
#  ('sandwiches', 2),
#  ('apricots', 2),
#  ('mocktail', 2),
#  ('oysters', 2),
#  ('meringues', 2),
#  ('bresaola', 2),
#  ('pecans', 2),
#  ('leaves', 2),
#  ('maple-glazed', 2),
#  ('griddled', 2),
#  ('hazelnuts', 2),
#  ('jerusalem', 2),
#  ('celebration', 2),
#  ('sautéed', 2),
#  ('tropical', 2),
#  ('blancs', 2),
#  ('korean', 2),
#  ('shots', 2),
#  ('sliders', 2),
#  ('sirloin', 2),
#  ('pasta', 2),
#  ('brie,', 2),
#  ('quiche', 2),
#  ('crust', 2),
#  ('next', 2),
#  ('level', 2),
#  ('cured', 2),
#  ('crackling', 2),
#  ('burgers', 2),
#  ('cocktails', 2),
#  ('porridge', 2),
#  ('nutty', 2),
#  ('rhubarb', 2),
#  ('tatins', 2),
#  ('piña', 2),
#  ('colada', 2),
#  ('vinegar', 2),
#  ('browns', 2),
#  ('asian', 2),
#  ('tzatziki', 2),
#  ('tomatoes', 2),
#  ('au', 2),
#  ('flavoured', 2),
#  ('butters', 2),
#  ('simmer-&-stir', 1),
#  ('mess', 1),
#  ('cosmopolitan', 1),
#  ('pizza', 1),
#  ('poussin', 1),
#  ("berry's", 1),
#  ('make', 1),
#  ('mature', 1),
#  ('angela', 1),
#  ("nilsen's", 1),
#  ("gordon's", 1),
#  ('sherry', 1),
#  ('liqueur', 1),
#  ("martin's", 1),
#  ('individual', 1),
#  ('christmas-pudding', 1),
#  ('figgy', 1),
#  ("chocoholic's", 1),
#  ('spices', 1),
#  ('suits-all', 1),
#  ("cook's", 1),
#  ('nancy’s', 1),
#  ('orange-stuffed', 1),
#  ('puds', 1),
#  ('enchanted', 1),
#  ('latte', 1),
#  ('buttercream', 1),
#  ('lunch', 1),
#  ('jar', 1),
#  ('isaac', 1),
#  ("scout's", 1),
#  ('lightly', 1),
#  ('tutti', 1),
#  ('frutti', 1),
#  ('ceviche', 1),
#  ('guacamole', 1),
#  ('rockies', 1),
#  ('unbelievably', 1),
#  ('krispie', 1),
#  ('snowy', 1),
#  ('owl', 1),
#  ('orlando', 1),
#  ("murrin's", 1),
#  ('deluxe', 1),
#  ('let-it-glow', 1),
#  ('pure', 1),
#  ('gold', 1),
#  ('drip', 1),
#  ('sundaes', 1),
#  ('as-you-like-it', 1),
#  ('blitz-&-bake', 1),
#  ('mandarin-in-the-middle', 1),
#  ('merry', 1),
#  ('veg,', 1),
#  ('bramble', 1),
#  ('cola', 1),
#  ('biryani', 1),
#  ('parmesan-roasted', 1),
#  ('middle', 1),
#  ('glitz', 1),
#  ('plait', 1),
#  ('orange-glazed', 1),
#  ('bacon-wrapped', 1),
#  ('breadsticks', 1),
#  ('bonbons', 1),
#  ('koftas', 1),
#  ('pressed', 1),
#  ('mississippi', 1),
#  ('mud', 1),
#  ('alaskan', 1),
#  ('herb-scented', 1),
#  ('shallot-stuffed', 1),
#  ('terrines', 1),
#  ('robin', 1),
#  ('bottle', 1),
#  ('sours', 1),
#  ('scallop', 1),
#  ('baubles', 1),
#  ('lebkuchen', 1),
#  ('globe', 1),
#  ('velvet', 1),
#  ('melty', 1),
#  ('mulling', 1),
#  ('lucia', 1),
#  ('croquetas', 1),
#  ('corn', 1),
#  ('marzipan-in-the-middle', 1),
#  ('fajitas', 1),
#  ('crumpets', 1),
#  ('magical', 1),
#  ('three-bird', 1),
#  ('oatmeal', 1),
#  ('rillette', 1),
#  ('slashed', 1),
#  ('egg,', 1),
#  ('caviar,', 1),
#  ('cashew', 1),
#  ('caramels', 1),
#  ('ramen', 1),
#  ('sunday', 1),
#  ('elf', 1),
#  ('panforte', 1),
#  ('yummy', 1),
#  ('naan,', 1),
#  ('reverse', 1),
#  ('espresso', 1),
#  ('olives', 1),
#  ('gnocchi,', 1),
#  ('sundried', 1),
#  ('arancello', 1),
#  ('set', 1),
#  ('favourite', 1),
#  ('tapenade', 1),
#  ('lattice', 1),
#  ('charms', 1),
#  ('monsieurs', 1),
#  ('coulibiac', 1),
#  ('raymond’s', 1),
#  ('spanish', 1),
#  ('blueberry', 1),
#  ('dogs', 1),
#  ('sage-wrapped', 1),
#  ('pineapple,', 1),
#  ('benedict', 1),
#  ('chives', 1),
#  ('mango,', 1),
#  ('coconut,', 1),
#  ('ponche', 1),
#  ('stained', 1),
#  ('glass', 1),
#  ('meatloaf', 1),
#  ('trifles', 1),
#  ('semi-freddo', 1),
#  ('snow-topped', 1),
#  ('devil’s', 1),
#  ('millionaire’s', 1),
#  ('layered', 1),
#  ('potage', 1),
#  ('dubarry', 1),
#  ('(creamy', 1),
#  ('soup)', 1),
#  ('oil-baked', 1),
#  ('cranachan', 1),
#  ('jalousie', 1),
#  ('cobbler', 1),
#  ('marbled', 1),
#  ('bacon-basted', 1),
#  ('sparkly', 1),
#  ('midwinter', 1),
#  ('candle', 1),
#  ('decadent', 1),
#  ('snowfetti', 1),
#  ('bunting', 1),
#  ('sandham', 1),
#  ('family', 1),
#  ('smoothie', 1),
#  ('sage,', 1),
#  ('open', 1),
#  ('ravioli', 1),
#  ('porcini', 1),
#  ('shukhi', 1),
#  ('–', 1),
#  ('jellies', 1),
#  ('very', 1),
#  ('cacciatore', 1),
#  ('whirls', 1),
#  ('florentine', 1),
#  ('chestnuts,', 1),
#  ('lemon,', 1),
#  ('margarita', 1),
#  ('topping', 1),
#  ('starter', 1),
#  ('mixed', 1),
#  ('houses', 1),
#  ('breasts', 1),
#  ('75', 1),
#  ('jamaican', 1),
#  ('frozen', 1),
#  ('unicorn', 1),
#  ('blanc-tini', 1),
#  ('crisp-topped', 1),
#  ("nick's", 1),
#  ('flip', 1),
#  ('wonderland', 1),
#  ('hedgerow', 1),
#  ('royale', 1),
#  ('sherry,', 1),
#  ('pandoro', 1),
#  ('spritz', 1),
#  ('prosciutto-wrapped', 1),
#  ('babka', 1),
#  ('bun', 1),
#  ('bespoke', 1),
#  ('centrepiece', 1),
#  ('super-simple', 1),
#  ('vegetarian', 1),
#  ('posh', 1),
#  ('cranberry-topped', 1),
#  ('raised', 1),
#  ('jolly', 1),
#  ('snowmen', 1),
#  ('mint-choc', 1),
#  ('gras', 1),
#  ('pickles', 1),
#  ('one-pot', 1),
#  ('drunken', 1),
#  ('royales', 1),
#  ('icy', 1),
#  ('kir', 1),
#  ('roquefort', 1),
#  ('coco', 1),
#  ('mead', 1),
#  ('jackfruit', 1),
#  ('tacos', 1),
#  ('sweetcorn', 1),
#  ('gochujang', 1),
#  ('madame', 1),
#  ('treacle-glazed', 1),
#  ('almond-topped', 1),
#  ('10-minute', 1),
#  ("barney's", 1),
#  ('roly-poly', 1),
#  ('gooey', 1),
#  ('noodle', 1),
#  ('pecan-stuffed', 1),
#  ('cheese-cupcakes', 1),
#  ('bourbon-glazed', 1),
#  ('zimtsterne', 1),
#  ('(cinnamon', 1),
#  ('stars)', 1),
#  ('clements', 1),
#  ('old', 1),
#  ('fashioned', 1),
#  ('bananas', 1),
#  ('brazils', 1),
#  ('sablés', 1),
#  ('oven-baked', 1),
#  ('garland', 1),
#  ('praline', 1),
#  ('nigella', 1),
#  ('appleberry', 1),
#  ('aïoli', 1),
#  ('pancetta-wrapped', 1),
#  ('two', 1),
#  ('ways', 1),
#  ('timbales', 1),
#  ('couscous', 1),
#  ('glossy', 1),
#  ('four', 1),
#  ('twenty', 1),
#  ('polar', 1),
#  ('bear', 1),
#  ('spinach,', 1),
#  ('guinness,', 1),
#  ('gingered', 1),
#  ('makeover:', 1),
#  ('sultanas', 1),
#  ('snowballs', 1),
#  ('flapjack', 1),
#  ('gremolata', 1),
#  ('garden', 1),
#  ('rosemary-spiked', 1),
#  ('pithivier', 1),
#  ('nibbles', 1),
#  ('choc-cherry', 1),
#  ('pepper-crusted', 1),
#  ('chickpeas', 1),
#  ('espresso,', 1),
#  ('decorative', 1),
#  ('bombes', 1),
#  ('chilli-charred', 1),
#  ('golden-glazed', 1),
#  ('serrano-wrapped', 1),
#  ('tassies', 1),
#  ('all-in-one', 1),
#  ('friends', 1),
#  ('colcannon', 1),
#  ('vodka-baked', 1),
#  ('peppers', 1),
#  ('corn,', 1),
#  ('after-dinner', 1),
#  ('tiffin', 1),
#  ('herb-roast', 1),
#  ('martinis', 1),
#  ('butter-roasted', 1),
#  ('supreme', 1),
#  ('gnocchi', 1),
#  ('fondants', 1),
#  ('rotolo', 1),
#  ('jumpers', 1),
#  ("lover's", 1),
#  ('cracker', 1),
#  ('angel', 1),
#  ('frosting', 1),
#  ('pernod', 1),
#  ...]

# %% [markdown]
# **Pudding Ingredients:**
# flour, butter, egg, muscovado sugar, breadcrumb

# %%
baked_other_ratios = Counter()
# Calculate the ratios of positive and negative uses of the most common words
# Consider words to be "common" if they've been used at least 100 times
for term, cnt in list(total_method.most_common()):
    if(cnt > 200):
        baked_other_ratio = baked_method[term] / float(other_method[term]+1)
        baked_other_ratios[term] = baked_other_ratio

# %%
print("Pos-to-neg ratio for 'the' = {}".format(baked_other_ratios["the"]))
# Out:
# Pos-to-neg ratio for 'the' = 1.3834515366427953

# %%
for word,ratio in baked_other_ratios.most_common():
    baked_other_ratios[word] = np.log(ratio)

# %%
print("Pos-to-neg ratio for 'the' = {}".format(baked_other_ratios["the"]))
# Out:
# Pos-to-neg ratio for 'the' = 0.32458149009952453

# %%
baked_other_ratios.most_common()
# Out:
# [('pie', 3.906004933102584),
#  ('cake.', 2.7739766475146315),
#  ('cake', 2.2491567380481965),
#  ('icing', 1.9585953085826202),
#  ('biscuits', 1.9389897062107406),
#  ('pudding', 1.8935843300535757),
#  ('comes', 1.852300649933008),
#  ('flour,', 1.7968745698948279),
#  ('20cm', 1.7783364488959155),
#  ('cake,', 1.77001948259165),
#  ('pastry', 1.7348879582734427),
#  ('eggs,', 1.707018240772965),
#  ('skewer', 1.6644976896171295),
#  ('decorate', 1.6439857198879897),
#  ('electric', 1.5930887744325717),
#  ('round', 1.5686159179138466),
#  ('marzipan', 1.5270220206150094),
#  ('knead', 1.414465238086588),
#  ('wire', 1.3958638121360427),
#  ('floured', 1.368835139748123),
#  ('beat', 1.3506671834767412),
#  ('stick', 1.3229672271686188),
#  ('dust', 1.282815313561771),
#  ('centre', 1.258153817130246),
#  ('eggs', 1.258153817130246),
#  ('line', 1.2539051730741448),
#  ('out', 1.2380206867581542),
#  ('press', 1.2379164603783757),
#  ('base', 1.2321436812926345),
#  ('trim', 1.2274451605110794),
#  ('flour', 1.2042359276007104),
#  ('surface', 1.1874264082115293),
#  ('vanilla', 1.163150809805682),
#  ('wrap', 1.1513163521586798),
#  ('sides', 1.1349799328389867),
#  ('bake', 1.1298462963192333),
#  ('smooth', 1.129702875738143),
#  ('work', 1.1219927373121743),
#  ('dough', 1.1181728145226062),
#  ('grease', 1.1141768052092225),
#  ('edges', 1.0784095813505918),
#  ('roll', 1.0704414117014098),
#  ('melted', 1.065551426407223),
#  ('4.', 1.0399822042167066),
#  ('smooth.', 1.0296194171811592),
#  ('parchment.', 0.9846680293188935),
#  ('an', 0.9737909676282169),
#  ('use', 0.9726780407810172),
#  ('tin.', 0.9666064493524265),
#  ('sugar.', 0.9624801143435309),
#  ('brush', 0.9574231259766716),
#  ('cool', 0.9563472160748264),
#  ('sugar,', 0.9432913336926633),
#  ('syrup', 0.9204201252161676),
#  ('shape', 0.911836381524775),
#  ('sugar', 0.9101793803171379),
#  ('middle', 0.9012382505329526),
#  ('fruit', 0.8944446388129068),
#  ('butter,', 0.8852249122992666),
#  ('make', 0.871285304060397),
#  ('excess', 0.8679780656247427),
#  ('together', 0.8575675270246569),
#  ('using', 0.855628086521146),
#  ('180c/160c', 0.8492377252050318),
#  ('onto', 0.8480043245635291),
#  ('baking', 0.8408253458815775),
#  ('sheet', 0.8332461069315552),
#  ('food', 0.7996029865791885),
#  ('little', 0.785815350901427),
#  ('time,', 0.7837844546648782),
#  ('two', 0.7793248768009997),
#  ('white', 0.7756311905158515),
#  ('fold', 0.7753852787969195),
#  ('around', 0.7677452286852525),
#  ('lightly', 0.7658048261360233),
#  ('enough', 0.7649268629540779),
#  ('fill', 0.7645116667679166),
#  ('hr', 0.7639162514481536),
#  ('chocolate', 0.7597582412994915),
#  ('tin,', 0.7543908058006658),
#  ('like', 0.750906014712138),
#  ('butter', 0.7500345549619898),
#  ('top', 0.708926600663904),
#  ('need', 0.6910172543021212),
#  ('egg', 0.681652801134213),
#  ('x', 0.669004875238347),
#  ('orange', 0.6632570350867386),
#  ('parchment', 0.6598723916750744),
#  ('your', 0.6410833711734382),
#  ('one', 0.6319364495150516),
#  ('together.', 0.6300194285253923),
#  ('mix', 0.6257896324137169),
#  ('milk', 0.6241543090729956),
#  ('mixture', 0.6179776371812614),
#  ('down', 0.6167742017753738),
#  ('tin', 0.6143020126299775),
#  ('tsp', 0.5982748610851748),
#  ('dry', 0.5869753058312415),
#  ('processor', 0.5864139810901468),
#  ('get', 0.5833323145527384),
#  ('paper', 0.5815946946541989),
#  ('spoon', 0.5715105755875713),
#  ('bottom', 0.5682738506785376),
#  ('it.', 0.5647308886021929),
#  ('small', 0.5620225279659882),
#  ('lift', 0.5613534078339646),
#  ('whisk', 0.5596157879354252),
#  ('knife', 0.5561008458279793),
#  ('cut', 0.5475618635916069),
#  ('sit', 0.5453734312198801),
#  ('remaining', 0.5416332853849881),
#  ('chill', 0.5398472026130025),
#  ('black', 0.2455004584154855),
#  ('more', 0.2449571277854418),
#  ('like.', 0.24338181355520028),
#  ('gently', 0.242946178610392),
#  ('over', 0.24191365399618978),
#  ('up', 0.23897387213632956),
#  ('can', 0.2337467686013945),
#  ('soft', 0.23025002336590594),
#  ('very', 0.22825865198098122),
#  ('aside', 0.22399425319452337),
#  ('end', 0.2186892009648295),
#  ('transfer', 0.21458241901217742),
#  ('everything', 0.20799391184808205),
#  ('ingredients', 0.19788607333506744),
#  ('side', 0.19735943415849594),
#  ('turn', 0.19129022677671748),
#  ('water.', 0.18455619459537162),
#  ('cream', 0.18330726411871637),
#  ('for', 0.18241750306414434),
#  ('water', 0.1780018956494396),
#  ('1', 0.17488657830643328),
#  ('allow', 0.17095779814363932),
#  ('boiling', 0.16848050538208267),
#  ('be', 0.16039619616499168),
#  ('is', 0.16014128396441094),
#  ('some', 0.1567788022335301),
#  ('along', 0.1507550908261198),
#  ('piece', 0.14926069453306645),
#  ('has', 0.14585187701256505),
#  ('carefully', 0.1431008436406746),
#  ('mins,', 0.13955188040610833),
#  ('put', 0.13891643525540326),
#  ('6', 0.1376213778760475),
#  ('sprinkle', 0.13742623688606515),
#  ('tip', 0.1328732813799732),
#  ('back', 0.12640076687435722),
#  ('cheese', 0.125163142954006),
#  ('10', 0.12499062505484862),
#  ('remove', 0.12281560423875795),
#  ('mins', 0.12209565588613464),
#  ('place', 0.119559235057642),
#  ('from', 0.11920913348389361),
#  ('take', 0.11631822415537012),
#  ('5', 0.10719369673948959),
#  ('20', 0.10427884978708686),
#  ('cream,', 0.09249459840416067),
#  ('all', 0.08390168457257961),
#  ('tray', 0.08363689549960135),
#  ('medium', 0.07789824832750329),
#  ('before', 0.05942342047080311),
#  ('heat', 0.05720536109470675),
#  ('not', 0.05688737440205205),
#  ('fridge', 0.05310982531395001),
#  ('200c/180c', 0.05270406349056903),
#  ('away', 0.03922071315328069),
#  ('mins.', 0.03167232065246616),
#  ('golden.', 0.026855087303176976),
#  ('peel', 0.014388737452099452),
#  ('that', 0.013483350337288522),
#  ('but', 0.004827040748317491),
#  ('add', -0.0028895161158522817),
#  ('rest', -0.006861090379943787),
#  ('large', -0.01428243928564704),
#  ('meanwhile,', -0.015968403178729985),
#  ('ready', -0.029772158333670144),
#  ('low', -0.04232462440479073),
#  ('leaves', -0.04837358428421606),
#  ('dish', -0.05218575317057089),
#  ('cold', -0.05406722127027641),
#  ('ice', -0.06018224180479722),
#  ('serve', -0.06407885668451992),
#  ('they', -0.08661447283676972),
#  ('slice', -0.09211528890780539),
#  ('serve,', -0.09884583463663321),
#  ('saucepan', -0.10244080555449188),
#  ('should', -0.10312587785641035),
#  ('pour', -0.11944867677001117),
#  ('hot', -0.12306009275722637),
#  ('heat.', -0.12456272264176274),
#  ('are', -0.13200583931568327),
#  ('bay', -0.13536794043182465),
#  ('cooked', -0.1659851374742617),
#  ('now', -0.16663134105086808),
#  ('scatter', -0.19574457712609414),
#  ('well.', -0.21981576122153582),
#  ('sauce', -0.22583534297992117),
#  ('through', -0.2308358969373642),
#  ('slices', -0.24334625863172987),
#  ('stirring', -0.25131442828090533),
#  ('pan.', -0.2657031657330062),
#  ('lemon', -0.27871340246902004),
#  ('serve.', -0.2799411497073436),
#  ('bring', -0.2921364228011591),
#  ('drizzle', -0.3053816495511821),
#  ('serving', -0.3090468949494784),
#  ('onion', -0.3807724955177935),
#  ('chopped', -0.38407391812684744),
#  ('pan,', -0.4226329117305295),
#  ('juice', -0.461554574759208),
#  ('salt', -0.46676563397195975),
#  ('cook', -0.46933632947505816),
#  ('boil', -0.4938760654522175),
#  ('return', -0.5143038881423161),
#  ('pan', -0.5358423066824558),
#  ('oil', -0.6443570163905116),
#  ('heat,', -0.7049816382069486),
#  ('season', -0.7243997240640491),
#  ('boil,', -0.7419373447293777),
#  ('simmer', -0.7866596692212159),
#  ('frying', -0.8525241135151663),
#  ('fry', -1.0307010830519),
#  ('roasting', -1.0894669558459187),
#  ('toss', -1.1127969236600666),
#  ('garlic', -1.124355176361245),
#  ('drain', -1.2239580967061934),
#  ('potatoes', -1.2449918237704818),
#  ('roast', -1.910762761289668),
#  ('turkey', -2.6484879399508667)]

# %%
list(reversed(baked_other_ratios.most_common()))[0:50]
# Out:
# [('turkey', -2.6484879399508667),
#  ('roast', -1.910762761289668),
#  ('potatoes', -1.2449918237704818),
#  ('drain', -1.2239580967061934),
#  ('garlic', -1.124355176361245),
#  ('toss', -1.1127969236600666),
#  ('roasting', -1.0894669558459187),
#  ('fry', -1.0307010830519),
#  ('frying', -0.8525241135151663),
#  ('simmer', -0.7866596692212159),
#  ('boil,', -0.7419373447293777),
#  ('season', -0.7243997240640491),
#  ('heat,', -0.7049816382069486),
#  ('oil', -0.6443570163905116),
#  ('pan', -0.5358423066824558),
#  ('return', -0.5143038881423161),
#  ('boil', -0.4938760654522175),
#  ('cook', -0.46933632947505816),
#  ('salt', -0.46676563397195975),
#  ('juice', -0.461554574759208),
#  ('pan,', -0.4226329117305295),
#  ('chopped', -0.38407391812684744),
#  ('onion', -0.3807724955177935),
#  ('serving', -0.3090468949494784),
#  ('drizzle', -0.3053816495511821),
#  ('bring', -0.2921364228011591),
#  ('serve.', -0.2799411497073436),
#  ('lemon', -0.27871340246902004),
#  ('pan.', -0.2657031657330062),
#  ('stirring', -0.25131442828090533),
#  ('slices', -0.24334625863172987),
#  ('through', -0.2308358969373642),
#  ('sauce', -0.22583534297992117),
#  ('well.', -0.21981576122153582),
#  ('scatter', -0.19574457712609414),
#  ('now', -0.16663134105086808),
#  ('cooked', -0.1659851374742617),
#  ('bay', -0.13536794043182465),
#  ('are', -0.13200583931568327),
#  ('heat.', -0.12456272264176274),
#  ('hot', -0.12306009275722637),
#  ('pour', -0.11944867677001117),
#  ('should', -0.10312587785641035),
#  ('saucepan', -0.10244080555449188),
#  ('serve,', -0.09884583463663321),
#  ('slice', -0.09211528890780539),
#  ('they', -0.08661447283676972),
#  ('serve', -0.06407885668451992),
#  ('ice', -0.06018224180479722),
#  ('cold', -0.05406722127027641)]

# %%
vocab = set(total_method.keys())

# %%
vocab_size = len(vocab)
print(vocab_size)
# Out:
# 10234

# %%
layer_0 = np.zeros((1,vocab_size))
layer_0.shape
# Out:
# (1, 10234)

# %%
# Create a dictionary of words in the vocabulary mapped to index positions 
# (to be used in layer_0)
word2index = {}
for i,word in enumerate(vocab):
    word2index[word] = i
word2index
# Out:
# {'': 0,
#  'chestnuts': 1,
#  'florets.': 2,
#  'raisins': 3,
#  'indent': 4,
#  'twist.': 5,
#  'juices;': 6,
#  'white.': 7,
#  'blades': 8,
#  'bakes,': 9,
#  'ends': 10,
#  'pretzel': 11,
#  '–\xa0if': 12,
#  '36': 13,
#  '3-4.': 14,
#  'brushing': 15,
#  'puddle.': 16,
#  'alongside,': 17,
#  'shrinking': 18,
#  'machine,': 19,
#  'upside-down,': 20,
#  'shallots.': 21,
#  'tip,': 22,
#  'golden': 23,
#  'combine,': 24,
#  'rough': 25,
#  'curdles,': 26,
#  '15-30': 27,
#  'salting': 28,
#  'hats': 29,
#  'include': 30,
#  'caramelises.': 31,
#  'appropriate': 32,
#  '(less': 33,
#  'movement,': 34,
#  'twist,': 35,
#  '230c/fan': 36,
#  'florets': 37,
#  'casserole.': 38,
#  'oil;': 39,
#  'pizza': 40,
#  'prunes,': 41,
#  'grater': 42,
#  'broth': 43,
#  'partridges': 44,
#  'damage': 45,
#  'zest\xa0and': 46,
#  'temperature),': 47,
#  'shallower': 48,
#  'mortar,': 49,
#  'mousses': 50,
#  'rich.': 51,
#  'spreadable.': 52,
#  'electric': 53,
#  'slices),': 54,
#  'plateful': 55,
#  'feeling': 56,
#  'carried': 57,
#  'cornichons,': 58,
#  'blender).': 59,
#  'standing': 60,
#  'side.': 61,
#  'leftovers,': 62,
#  'matches': 63,
#  'obviously': 64,
#  'parsnips': 65,
#  'baked': 66,
#  'wait': 67,
#  'scarf,': 68,
#  'roughly\xa0doubled': 69,
#  'anise,\xa0cloves,': 70,
#  'fennel,': 71,
#  'knock': 72,
#  'beforehand).': 73,
#  'toasts,': 74,
#  'falling': 75,
#  'syrups': 76,
#  'underneath.': 77,
#  'crispiness)': 78,
#  'constantly,': 79,
#  'crisp': 80,
#  '4.5-6.5kg': 81,
#  'ready': 82,
#  'amount': 83,
#  'desired': 84,
#  'quicker.': 85,
#  '55-60': 86,
#  'noses.': 87,
#  'cold': 88,
#  'l': 89,
#  'pasta.': 90,
#  'theturkey': 91,
#  'combined.': 92,
#  'found': 93,
#  'style).': 94,
#  'bones.': 95,
#  'dragees,': 96,
#  'fashionable)': 97,
#  'neater).': 98,
#  'cup)': 99,
#  'tumbler.': 100,
#  'lengths': 101,
#  'night': 102,
#  'pulpy,': 103,
#  'salads': 104,
#  'of\xa0butter': 105,
#  '/2': 106,
#  '500ml/18fl': 107,
#  'gently,': 108,
#  'guide.': 109,
#  'link,': 110,
#  'come': 111,
#  'mature': 112,
#  'well,': 113,
#  '17cm.': 114,
#  'pie.\xa0cover': 115,
#  'mediumhigh': 116,
#  '4kg': 117,
#  'places': 118,
#  'crown\xa0on': 119,
#  '31': 120,
#  'dill.': 121,
#  'started': 122,
#  'accidents).': 123,
#  '200/gas': 124,
#  'onion': 125,
#  'up,': 126,
#  'means': 127,
#  'stone,': 128,
#  'meringue.\xa0it’s': 129,
#  'partially': 130,
#  '70%': 131,
#  'cluster': 132,
#  'wait.': 133,
#  '100g/4oz': 134,
#  'nibbles.': 135,
#  'catching,': 136,
#  'saucepan\xa0along': 137,
#  'coconut,': 138,
#  'slighter': 139,
#  'korma': 140,
#  'cauliflower.': 141,
#  'date,': 142,
#  'sprouts,': 143,
#  'body,': 144,
#  '10-12': 145,
#  'scoops,': 146,
#  'mushroom': 147,
#  'suet.': 148,
#  '(cover': 149,
#  '9.': 150,
#  'does': 151,
#  'family': 152,
#  'soups).': 153,
#  'remains.': 154,
#  '15': 155,
#  'chop': 156,
#  'shaving': 157,
#  '),': 158,
#  'breadcrumbs': 159,
#  '400ml': 160,
#  'pot.\xa0beat': 161,
#  'apples.': 162,
#  'bulbs.': 163,
#  'pittas': 164,
#  'stem.': 165,
#  'marzipan:': 166,
#  'sell-by': 167,
#  'drink,': 168,
#  '(see': 169,
#  'breadcrumbs\xa0and': 170,
#  'guarantee': 171,
#  'pairs,': 172,
#  'ganoush': 173,
#  'next': 174,
#  '‘berries’.': 175,
#  'formed.': 176,
#  'dampen': 177,
#  'powdery,': 178,
#  'spin': 179,
#  'charred.': 180,
#  'sandwich': 181,
#  'bubble,': 182,
#  'under-cook': 183,
#  '2.4': 184,
#  'nestled': 185,
#  'places,': 186,
#  'trivet': 187,
#  'worktop,': 188,
#  'reduced': 189,
#  '170c/gas': 190,
#  'ladle,': 191,
#  'turkey).': 192,
#  'reassemble': 193,
#  'smoky': 194,
#  'including': 195,
#  'wobbly)': 196,
#  'dough': 197,
#  '(known': 198,
#  'chocolate-covered': 199,
#  'milk': 200,
#  'covered': 201,
#  'attach': 202,
#  'direction': 203,
#  'rows.': 204,
#  'that’s': 205,
#  'salad.': 206,
#  'measurements.': 207,
#  'fluffy,': 208,
#  'egg).': 209,
#  'cinammon)': 210,
#  'lifting.': 211,
#  '(longer': 212,
#  'wedge-shaped': 213,
#  'blast.': 214,
#  'complete': 215,
#  'left),': 216,
#  '62)': 217,
#  'days.': 218,
#  'overlapping': 219,
#  'steaming': 220,
#  'pat': 221,
#  'fish.\xa0season': 222,
#  'candle': 223,
#  'saucepans,': 224,
#  "there's": 225,
#  'actually': 226,
#  'cutter': 227,
#  '(except': 228,
#  'warm),': 229,
#  'discs': 230,
#  'angles': 231,
#  'shiny': 232,
#  'clementines': 233,
#  '11⁄4': 234,
#  'tipping': 235,
#  'moulded': 236,
#  'cherries,': 237,
#  '‘bauble’,': 238,
#  '‘wash’': 239,
#  'raita': 240,
#  'marmalade.': 241,
#  'tight,': 242,
#  '6.roll': 243,
#  'croustade': 244,
#  'attached.': 245,
#  'mess': 246,
#  '45cm': 247,
#  'dressing;': 248,
#  '1tbsp': 249,
#  'chicory,': 250,
#  'temperature,': 251,
#  'tall,': 252,
#  'runny-ish': 253,
#  'danger': 254,
#  'cheese.': 255,
#  'pies': 256,
#  'curdle,': 257,
#  'gifts,': 258,
#  'floats': 259,
#  'smiles,': 260,
#  '180/160c': 261,
#  'cigar.': 262,
#  'amber-orange': 263,
#  'length': 264,
#  'flutes)': 265,
#  'conserve': 266,
#  'buttered': 267,
#  'nozzles': 268,
#  'boat.': 269,
#  'instructed': 270,
#  'blender,': 271,
#  'additions': 272,
#  'reserve.': 273,
#  'hazelnut': 274,
#  'rows': 275,
#  'boxes': 276,
#  'bags': 277,
#  'differently': 278,
#  'neat).': 279,
#  'harden.': 280,
#  '(ruth': 281,
#  're-check': 282,
#  'fruits,': 283,
#  'digital': 284,
#  'desiccated': 285,
#  'petit': 286,
#  'write': 287,
#  '25-35': 288,
#  '600ml': 289,
#  'melon': 290,
#  'gradually': 291,
#  'thewhitesintothedryingredients,thenfold': 292,
#  'down,': 293,
#  'orange': 294,
#  'elastic.': 295,
#  'toppings,': 296,
#  'pocket.': 297,
#  '170c/150c': 298,
#  'layers,': 299,
#  '45-50': 300,
#  'such': 301,
#  'kg': 302,
#  'lights,': 303,
#  'potted': 304,
#  'braise': 305,
#  'marshmallows': 306,
#  'and\xa0lime': 307,
#  'dijon,': 308,
#  'slivers': 309,
#  'recipes,': 310,
#  'entirely': 311,
#  'widthways.': 312,
#  'suet,': 313,
#  'thick)': 314,
#  'buffet,': 315,
#  'stack,': 316,
#  'pack': 317,
#  'layering': 318,
#  '22': 319,
#  'stalks.': 320,
#  '70c': 321,
#  'parsnip,': 322,
#  'stick,': 323,
#  'hr-1hr': 324,
#  'overlap': 325,
#  'gel': 326,
#  'click': 327,
#  'conker': 328,
#  'breasts': 329,
#  'mango.': 330,
#  'there,': 331,
#  'follow': 332,
#  'ahead.)': 333,
#  'until\xa0soft.': 334,
#  '90c/gas': 335,
#  'ears': 336,
#  'poppadum': 337,
#  'coupé': 338,
#  'using\xa0only': 339,
#  '(heated': 340,
#  'upsidedown': 341,
#  'bowl),': 342,
#  'air': 343,
#  'insides': 344,
#  'deglaze,': 345,
#  'mashing': 346,
#  'cm).': 347,
#  '9cm': 348,
#  'walnuts': 349,
#  'cooking),': 350,
#  'crosses': 351,
#  'cyclinder,': 352,
#  'bind': 353,
#  'half-filled': 354,
#  'browning.': 355,
#  'drippy': 356,
#  're-apply': 357,
#  'glitters.': 358,
#  'candies': 359,
#  'bubble.': 360,
#  'boxes.': 361,
#  'diameter.': 362,
#  'it': 363,
#  'lever': 364,
#  'edge.': 365,
#  'fill,': 366,
#  'drinks': 367,
#  'streak-free.': 368,
#  '(on': 369,
#  'crunchy,': 370,
#  'prod': 371,
#  'cover': 372,
#  'rewrap': 373,
#  '2': 374,
#  '1.2-litre': 375,
#  'lights': 376,
#  'white).': 377,
#  'muffins,': 378,
#  'out)': 379,
#  'pud': 380,
#  'another.': 381,
#  'messy!': 382,
#  'peel.': 383,
#  'colour).': 384,
#  'square.': 385,
#  'intothe': 386,
#  'rings': 387,
#  'tomato,': 388,
#  'will': 389,
#  'pesto.': 390,
#  'ours,': 391,
#  'unfrozen': 392,
#  'do),': 393,
#  'nutmeg.': 394,
#  'distributed,': 395,
#  'fridge)': 396,
#  'non-stick)': 397,
#  'worry': 398,
#  'anise.': 399,
#  'watercress.': 400,
#  'wok': 401,
#  'reserve,': 402,
#  'the': 403,
#  'tip.': 404,
#  '35cm': 405,
#  'months': 406,
#  'the\xa0cucumber.': 407,
#  'here)': 408,
#  'to\xa0come\xa0together': 409,
#  '45': 410,
#  'rosé': 411,
#  'ribcage,': 412,
#  'fine,': 413,
#  'got': 414,
#  'stir-fried': 415,
#  'scrambled': 416,
#  'parcel.': 417,
#  'ganache,': 418,
#  'griddle': 419,
#  'lined.': 420,
#  'adds': 421,
#  'fan': 422,
#  'acid': 423,
#  'doesn’t': 424,
#  'edges\xa0to': 425,
#  'foam': 426,
#  'like': 427,
#  '50cm.': 428,
#  'left.': 429,
#  'loose.': 430,
#  'the\xa0pastry': 431,
#  'foamy,': 432,
#  'neaten,': 433,
#  'cleaned-out': 434,
#  'gone': 435,
#  'tent': 436,
#  'overbeat': 437,
#  'even-textured': 438,
#  'flavourful': 439,
#  'looking': 440,
#  'uncover,': 441,
#  'springs': 442,
#  'charred': 443,
#  'remaining': 444,
#  'day).': 445,
#  'soften.': 446,
#  'initially,': 447,
#  'lobster.': 448,
#  '24-72': 449,
#  '142ml': 450,
#  'tabasco': 451,
#  'lack': 452,
#  '5cm,': 453,
#  're-roll': 454,
#  'jostle': 455,
#  'improve': 456,
#  'calvados,': 457,
#  'pulp,': 458,
#  'freezer-proof': 459,
#  'be).': 460,
#  'squash,': 461,
#  'sizzle': 462,
#  'themselves': 463,
#  'snacks.': 464,
#  'bay.': 465,
#  'ribs': 466,
#  'ganache.': 467,
#  'bacon.': 468,
#  'evaporated': 469,
#  'shards,': 470,
#  'days),': 471,
#  'dish,': 472,
#  'caramelise.': 473,
#  'warm': 474,
#  'biscuits.': 475,
#  'through.': 476,
#  'stop': 477,
#  'step': 478,
#  'icing': 479,
#  '(be': 480,
#  '10.': 481,
#  'shots': 482,
#  'dry': 483,
#  'dusty': 484,
#  'tic': 485,
#  'half;': 486,
#  'thickly': 487,
#  'brown': 488,
#  'setting': 489,
#  'patches.': 490,
#  'same': 491,
#  'serve': 492,
#  'cm': 493,
#  'capacity)': 494,
#  'tangy': 495,
#  'from': 496,
#  'what’s': 497,
#  'sprouts.': 498,
#  'kipper': 499,
#  'minute,': 500,
#  'carrots,': 501,
#  'temp,': 502,
#  'essence\xa0and': 503,
#  'gloopy,': 504,
#  'backwards': 505,
#  'moderate': 506,
#  'behind,': 507,
#  '½.': 508,
#  'lids.': 509,
#  'chopping': 510,
#  'fork,': 511,
#  'glove),': 512,
#  'finger),': 513,
#  'marjoram.': 514,
#  'curl': 515,
#  'parsnips.': 516,
#  'fruit-flavoured': 517,
#  'celery\xa0and': 518,
#  'can': 519,
#  'flavourings,': 520,
#  '200c.': 521,
#  'knocking': 522,
#  'sinew.': 523,
#  'hat;': 524,
#  'spreads': 525,
#  'need),': 526,
#  'potato.': 527,
#  'strips.': 528,
#  '120ml/1': 529,
#  'index': 530,
#  'mandarin': 531,
#  'starting': 532,
#  'walnut-size': 533,
#  '(ensure': 534,
#  'wellingtons': 535,
#  'connecting': 536,
#  'curls': 537,
#  'small).': 538,
#  'dente,': 539,
#  'balls.': 540,
#  'juice': 541,
#  'melts': 542,
#  '150c.': 543,
#  'marshmallows.': 544,
#  'anchovies.': 545,
#  'guest': 546,
#  'indents': 547,
#  'pomegranates': 548,
#  'carefully': 549,
#  'wrapping.': 550,
#  'breads.': 551,
#  'gum.': 552,
#  'chelsea': 553,
#  'vermouth': 554,
#  '225ml/8fl': 555,
#  '\xa0out': 556,
#  'width,': 557,
#  'brandy)': 558,
#  '60': 559,
#  'molasses': 560,
#  'peak.': 561,
#  "know-how',": 562,
#  '(bread': 563,
#  'drizzle,': 564,
#  'preparing': 565,
#  '200c/gas': 566,
#  '10-min': 567,
#  'chunks.': 568,
#  'gathering': 569,
#  'equator': 570,
#  'burst.': 571,
#  'cracks;': 572,
#  'turntable': 573,
#  '120c/': 574,
#  'reins.': 575,
#  'piles.': 576,
#  '‘open’': 577,
#  'biscuit-brown.': 578,
#  'drained': 579,
#  'bay,': 580,
#  'linseed': 581,
#  'through,': 582,
#  '‘tip': 583,
#  'contain': 584,
#  'wraps,': 585,
#  'happen': 586,
#  'reduce,': 587,
#  'using,': 588,
#  'criss-cross': 589,
#  'tip),': 590,
#  'hat,': 591,
#  'shred.': 592,
#  'fragrance.': 593,
#  'stripe': 594,
#  'corkscrew.': 595,
#  'fluff': 596,
#  'tomato': 597,
#  'shiitake': 598,
#  'them)': 599,
#  'crumbly': 600,
#  'raisins.': 601,
#  'trickles': 602,
#  '1–11/2': 603,
#  '3cm.': 604,
#  'short,': 605,
#  'sandy': 606,
#  'expansion': 607,
#  'tart.': 608,
#  'boneless\xa0gammon': 609,
#  'successful': 610,
#  '1-3': 611,
#  'sorbet,': 612,
#  'shaohsing': 613,
#  'each\xa0interval.': 614,
#  'blast.\xa0once': 615,
#  '3⁄4': 616,
#  'little': 617,
#  'casserole,': 618,
#  'overbeat.': 619,
#  'form.': 620,
#  'dislodge': 621,
#  'stands': 622,
#  '(about': 623,
#  'polystyrene': 624,
#  'flambé.': 625,
#  'wheel.': 626,
#  'onions.': 627,
#  'microwave': 628,
#  'lifted': 629,
#  'gelatine,': 630,
#  'stack': 631,
#  'cake,': 632,
#  'slice': 633,
#  'sauce-like,': 634,
#  'tartlet,': 635,
#  'nicely': 636,
#  'combined).': 637,
#  'slashes': 638,
#  'overwork.': 639,
#  'pastry\xa0level': 640,
#  'fallen': 641,
#  'disintegrate': 642,
#  'soaks': 643,
#  'batter,': 644,
#  'moist.)': 645,
#  '2-2½': 646,
#  'keep,': 647,
#  'fresh.': 648,
#  'walls.': 649,
#  "'flooding'": 650,
#  "'tip',": 651,
#  'unti': 652,
#  'like,': 653,
#  'butter:': 654,
#  'wreath.': 655,
#  'pan': 656,
#  'thickness.': 657,
#  'loin,': 658,
#  'covers': 659,
#  'neither': 660,
#  '8': 661,
#  'paprika': 662,
#  'lava.': 663,
#  'well.': 664,
#  'haphazardly': 665,
#  'trying': 666,
#  'persillade.': 667,
#  'film': 668,
#  'bodies': 669,
#  'cool': 670,
#  'width': 671,
#  'temp.)': 672,
#  'kitchen': 673,
#  'least': 674,
#  'simmer,': 675,
#  '5': 676,
#  'left)': 677,
#  'lift': 678,
#  'paprika,': 679,
#  'rectangles,': 680,
#  'dry)': 681,
#  'blender.': 682,
#  'collar,': 683,
#  'circulate': 684,
#  'cup,': 685,
#  'blunt': 686,
#  'up).': 687,
#  'baklava,': 688,
#  'virgin': 689,
#  'orange,': 690,
#  'an': 691,
#  'spice,': 692,
#  'trout': 693,
#  'alongside.': 694,
#  'fruit.': 695,
#  'mould,': 696,
#  'incorporates': 697,
#  'mins,': 698,
#  'steam': 699,
#  'carry': 700,
#  'churned,': 701,
#  'loosen': 702,
#  '200g': 703,
#  '1½-2': 704,
#  '3).': 705,
#  'spaces.': 706,
#  'cutters,': 707,
#  'wellington,': 708,
#  'ideal).': 709,
#  'pies.\xa0place': 710,
#  'curried': 711,
#  'tender.': 712,
#  'chives.': 713,
#  'lighty': 714,
#  'spoonful,': 715,
#  'pop,': 716,
#  'flatbread': 717,
#  'develop,': 718,
#  'scrollshaped': 719,
#  'two-thirds.': 720,
#  "'foundation'.": 721,
#  '(otherwise': 722,
#  '20-23cm': 723,
#  'lumpy.': 724,
#  'cases,': 725,
#  'snap': 726,
#  'cane': 727,
#  'deepest': 728,
#  'teaspoonfuls': 729,
#  'juiced': 730,
#  'see': 731,
#  'open.': 732,
#  'closed,': 733,
#  'both': 734,
#  'fat.': 735,
#  'imagine': 736,
#  'jasmine': 737,
#  'tough': 738,
#  'dispose': 739,
#  'toddy': 740,
#  'glutinous': 741,
#  'onion\xa0until': 742,
#  'defrosted.': 743,
#  'garnished': 744,
#  'to': 745,
#  "say's:": 746,
#  'powder': 747,
#  'shallot,': 748,
#  'apricots': 749,
#  'diagonally.': 750,
#  'branches': 751,
#  'briskly': 752,
#  '(discard': 753,
#  'aside;': 754,
#  'marjoram,': 755,
#  'bar': 756,
#  'cupboard': 757,
#  'slowly,': 758,
#  'delicious.': 759,
#  'mascarpone,': 760,
#  'ladle': 761,
#  '2⁄2½hours.': 762,
#  'sheets).': 763,
#  'pestle': 764,
#  'undisturbed': 765,
#  'chives': 766,
#  'theboil,': 767,
#  'egg-side': 768,
#  'substitute': 769,
#  '90': 770,
#  'leg': 771,
#  'stars.': 772,
#  'fans': 773,
#  'join.': 774,
#  '15-25': 775,
#  'radishes': 776,
#  'gritty': 777,
#  'starters),': 778,
#  'protect': 779,
#  'boil': 780,
#  'of': 781,
#  'ropes': 782,
#  'narrow': 783,
#  '1.5cm.': 784,
#  'has': 785,
#  'oli': 786,
#  'cloves': 787,
#  'dotted': 788,
#  'mignonette': 789,
#  'ladder,': 790,
#  'tins)': 791,
#  '1-2': 792,
#  'fabric': 793,
#  'areas,': 794,
#  'darkened': 795,
#  'provide': 796,
#  'together.repeat': 797,
#  'clinging': 798,
#  'marron': 799,
#  'vanilla': 800,
#  'cure,': 801,
#  'muscle': 802,
#  'enough.': 803,
#  'game,': 804,
#  'bottom.': 805,
#  'water),': 806,
#  'selection': 807,
#  'stroke': 808,
#  'topping,': 809,
#  'trimmings.': 810,
#  'agave': 811,
#  'cake-decorating': 812,
#  'barrel': 813,
#  'toast,': 814,
#  'puck,': 815,
#  'turkey),': 816,
#  'edged': 817,
#  'polish': 818,
#  'thigh': 819,
#  'shaken.': 820,
#  '60c,': 821,
#  'marked.': 822,
#  'growing': 823,
#  'croutes': 824,
#  'internal': 825,
#  'bitterness': 826,
#  'low.': 827,
#  'facing': 828,
#  'rolls,': 829,
#  'maldon': 830,
#  'polar': 831,
#  'three-quarters.': 832,
#  'nibble': 833,
#  'teapot.': 834,
#  'truly': 835,
#  '140c/conventional': 836,
#  '‘h’': 837,
#  'sizzling': 838,
#  'start,': 839,
#  'cheddar': 840,
#  'delight,': 841,
#  'essential': 842,
#  '31cm': 843,
#  '(process': 844,
#  'mature.': 845,
#  'seeds.': 846,
#  'burns': 847,
#  'tops).': 848,
#  'well-done': 849,
#  'someone': 850,
#  'thoroughly,': 851,
#  'shelled': 852,
#  'pappardelle,': 853,
#  'persimmons': 854,
#  'eyebrows': 855,
#  'candied': 856,
#  'steps': 857,
#  'label.': 858,
#  'tongs.': 859,
#  'even-sized': 860,
#  'poured': 861,
#  'curly': 862,
#  'melons,': 863,
#  'bombe.': 864,
#  'grapefruit.': 865,
#  '240c/fan': 866,
#  'table,': 867,
#  'strength': 868,
#  'children': 869,
#  'horizontal.': 870,
#  'twice': 871,
#  'owls': 872,
#  'microwave,': 873,
#  '15g': 874,
#  '(they': 875,
#  'paper,': 876,
#  'croquetas,': 877,
#  'get': 878,
#  'foil-wrapped': 879,
#  'stilton.': 880,
#  'spit)': 881,
#  'parson’s': 882,
#  'left).': 883,
#  '170c/': 884,
#  'tin\xa0and': 885,
#  'fifth': 886,
#  'el': 887,
#  'amount,': 888,
#  'not': 889,
#  '4kg,': 890,
#  'score': 891,
#  'many': 892,
#  '22-24cm': 893,
#  'longest': 894,
#  'fudgy.': 895,
#  'scoop.': 896,
#  'malleable,': 897,
#  'rotate': 898,
#  'off.': 899,
#  'mugs.': 900,
#  'firm.': 901,
#  '1.5': 902,
#  'ample': 903,
#  'outlines.': 904,
#  'rocket': 905,
#  'canes': 906,
#  'meringues': 907,
#  'hrs).': 908,
#  '(up': 909,
#  'pudding.': 910,
#  'fringe.': 911,
#  'circles).': 912,
#  'corner,': 913,
#  'grissini.': 914,
#  'warmed': 915,
#  'ribbons,': 916,
#  'upright': 917,
#  'perfect': 918,
#  'pesto,': 919,
#  'pastry;': 920,
#  'mango': 921,
#  '.\xa0': 922,
#  'oregano': 923,
#  'bottoms.': 924,
#  'paintbrush': 925,
#  'above),': 926,
#  'forming': 927,
#  'rounded,': 928,
#  'o’clock': 929,
#  'golden.': 930,
#  'transparent.': 931,
#  '3-leaf': 932,
#  'tofu': 933,
#  'the\xa0chicken': 934,
#  'strands),': 935,
#  'resealable': 936,
#  'membranes': 937,
#  'top.\u2028': 938,
#  'bases.': 939,
#  'sift': 940,
#  '0.5-1cm': 941,
#  'rice': 942,
#  'lime': 943,
#  'any': 944,
#  'convenient).': 945,
#  'delight.': 946,
#  'ferrero': 947,
#  'paprika.': 948,
#  'whirls': 949,
#  'figurines,': 950,
#  'cobbler': 951,
#  'panic.': 952,
#  'oyster': 953,
#  'mins.': 954,
#  'required.': 955,
#  'birds': 956,
#  'earthenware': 957,
#  '38cm.': 958,
#  'marinate': 959,
#  'wilts,': 960,
#  'palm': 961,
#  'cornflour,': 962,
#  'processer': 963,
#  'garni,': 964,
#  'stone': 965,
#  'meal),': 966,
#  'cling-filmed': 967,
#  'mortar': 968,
#  'they': 969,
#  'each': 970,
#  'number.': 971,
#  'kirsch.': 972,
#  'imbued': 973,
#  'salmon': 974,
#  '6cm': 975,
#  '300ml/⁄½': 976,
#  '-40': 977,
#  'millimetres': 978,
#  'cherry': 979,
#  'suitably,': 980,
#  'aubergine': 981,
#  'tagliatelle': 982,
#  'nutmeg': 983,
#  'shredder': 984,
#  'accumulates': 985,
#  'dries': 986,
#  'butterscotch': 987,
#  '400g': 988,
#  'semi-salted': 989,
#  'beans': 990,
#  'ease': 991,
#  'pass\xa0through': 992,
#  'gubbins': 993,
#  'kahlúa.': 994,
#  'returning': 995,
#  'sort': 996,
#  'translucent': 997,
#  '-side': 998,
#  'overhangs': 999,
#  ...}

# %%
def update_input_layer(review):
    """ Modify the global layer_0 to represent the vector form of review.
    The element at a given index of layer_0 should represent
    how many times the given word occurs in the review.
    Args:
        review(string) - the string of the review
    Returns:
        None
    """
     
    global layer_0
    
    # clear out previous state, reset the layer to be all 0s
    layer_0 *= 0
    
    # count how many times each word is used in the given review and store the results in layer_0 
    for word in review.split(" "):
        layer_0[0][word2index[word]] += 1

# %%
for i in range(len(data)):
    for j in range(len(data[i]['Method'])):
        data[i]['Method'][j] += " "
for i in range(len(data)):   
    data[i]['Method'][0:len(data[i]['Method'])] = [' '.join(data[i]['Method'][0:len(data[i]['Method'])])] 

method_description = []
print(data[0]['Method'])

for i in range(len(data)):
    method_description.append(data[i]['Method'][0])
    
update_input_layer(method_description[0])
layer_0
# Out:
# ['heat oven to 190c/fan 170c/gas 5. heat 1 tbsp oil and the butter in a frying pan, then add the onion and fry for 5 mins until softened. cool slightly. tip the sausagemeat, lemon zest, breadcrumbs, apricots, chestnuts and thyme into a bowl. add the onion and cranberries, and mix everything together with your hands, adding plenty of pepper and a little salt.  cut each chicken breast into three fillets lengthwise and season all over with salt and pepper. heat the remaining oil in the frying pan, and fry the chicken fillets quickly until browned, about 6-8 mins.  roll out two-thirds of the pastry to line a 20-23cm springform or deep loose-based tart tin. press in half the sausage mix and spread to level. then add the chicken pieces in one layer and cover with the rest of the sausage. press down lightly.  roll out the remaining pastry. brush the edges of the pastry with beaten egg and cover with the pastry lid. pinch the edges to seal, then trim. brush the top of the pie with egg, then roll out the trimmings to make holly leaf shapes and berries. decorate the pie and brush again with egg.  set the tin on a baking sheet and bake for 50-60 mins, then cool in the tin for 15 mins. remove and leave to cool completely. serve with a winter salad and pickles.   ']
# array([[7., 1., 0., ..., 0., 0., 0.]])

# %%
def get_target_for_label(label):
    """Convert a label to `0` or `1`.
    Args:
        label(string) - Either "POSITIVE" or "NEGATIVE".
    Returns:
        `0` or `1`.
    """
    if(label == 'Baked Good'):
        return 1
    else:
        return 0

# %%
expected_data[0]
# Out:
# 'Baked Good'

# %%
get_target_for_label(expected_data[0])
# Out:
# 1

# %%
expected_data[3]
# Out:
# 'Other'

# %%
get_target_for_label(expected_data[3])
# Out:
# 0

# %%
import time
import sys
import numpy as np

# Encapsulate our neural network in a class
class SentimentNetwork:
    def __init__(self, reviews,labels,hidden_nodes = 10, learning_rate = 0.1):
        """Create a SentimenNetwork with the given settings
        Args:
            reviews(list) - List of reviews used for training
            labels(list) - List of POSITIVE/NEGATIVE labels associated with the given reviews
            hidden_nodes(int) - Number of nodes to create in the hidden layer
            learning_rate(float) - Learning rate to use while training
        
        """
        # Assign a seed to our random number generator to ensure we get
        # reproducable results during development 
        np.random.seed(1)

        # process the reviews and their associated labels so that everything
        # is ready for training
        self.pre_process_data(reviews, labels)
        
        # Build the network to have the number of hidden nodes and the learning rate that
        # were passed into this initializer. Make the same number of input nodes as
        # there are vocabulary words and create a single output node.
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)

    def pre_process_data(self, reviews, labels):
        
        # populate review_vocab with all of the words in the given reviews
        review_vocab = set()
        for review in reviews:
            for word in review.split(" "):
                review_vocab.add(word)

        # Convert the vocabulary set to a list so we can access words via indices
        self.review_vocab = list(review_vocab)
        
        # populate label_vocab with all of the words in the given labels.
        label_vocab = set()
        for label in labels:
            label_vocab.add(label)
        
        # Convert the label vocabulary set to a list so we can access labels via indices
        self.label_vocab = list(label_vocab)
        
        # Store the sizes of the review and label vocabularies.
        self.review_vocab_size = len(self.review_vocab)
        self.label_vocab_size = len(self.label_vocab)
        
        # Create a dictionary of words in the vocabulary mapped to index positions
        self.word2index = {}
        for i, word in enumerate(self.review_vocab):
            self.word2index[word] = i
        
        # Create a dictionary of labels mapped to index positions
        self.label2index = {}
        for i, label in enumerate(self.label_vocab):
            self.label2index[label] = i
        
    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        # Set number of nodes in input, hidden and output layers.
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        # Store the learning rate
        self.learning_rate = learning_rate

        # Initialize weights

        # These are the weights between the input layer and the hidden layer.
        self.weights_0_1 = np.zeros((self.input_nodes,self.hidden_nodes))
    
        # These are the weights between the hidden layer and the output layer.
        self.weights_1_2 = np.random.normal(0.0, self.output_nodes**-0.5, 
                                                (self.hidden_nodes, self.output_nodes))
        
        # The input layer, a two-dimensional matrix with shape 1 x input_nodes
        self.layer_0 = np.zeros((1,input_nodes))
    
    def update_input_layer(self,review):

        # clear out previous state, reset the layer to be all 0s
        self.layer_0 *= 0
        
        for word in review.split(" "):
            # NOTE: This if-check was not in the version of this method created in Project 2,
            #       and it appears in Andrew's Project 3 solution without explanation. 
            #       It simply ensures the word is actually a key in word2index before
            #       accessing it, which is important because accessing an invalid key
            #       with raise an exception in Python. This allows us to ignore unknown
            #       words encountered in new reviews.
            if(word in self.word2index.keys()):
                self.layer_0[0][self.word2index[word]] += 1
                
    def get_target_for_label(self,label):
        if(label == 'Baked Good'):
            return 1
        else:
            return 0
        
    def sigmoid(self,x):
        return 1 / (1 + np.exp(-x))
    
    def sigmoid_output_2_derivative(self,output):
        return output * (1 - output)
    
    def train(self, training_reviews, training_labels):
        
        # make sure out we have a matching number of reviews and labels
        assert(len(training_reviews) == len(training_labels))
        
        # Keep track of correct predictions to display accuracy during training 
        correct_so_far = 0

        # Remember when we started for printing time statistics
        start = time.time()
        
        # loop through all the given reviews and run a forward and backward pass,
        # updating weights for every item
        for i in range(len(training_reviews)):
            
            # Get the next review and its correct label
            review = training_reviews[i]
            label = training_labels[i]
            
            #### Implement the forward pass here ####
            ### Forward pass ###

            # Input Layer
            self.update_input_layer(review)

            # Hidden layer
            layer_1 = self.layer_0.dot(self.weights_0_1)

            # Output layer
            layer_2 = self.sigmoid(layer_1.dot(self.weights_1_2))
            
            #### Implement the backward pass here ####
            ### Backward pass ###

            # Output error
            layer_2_error = layer_2 - self.get_target_for_label(label) # Output layer error is the difference between desired target and actual output.
            layer_2_delta = layer_2_error * self.sigmoid_output_2_derivative(layer_2)

            # Backpropagated error
            layer_1_error = layer_2_delta.dot(self.weights_1_2.T) # errors propagated to the hidden layer
            layer_1_delta = layer_1_error # hidden layer gradients - no nonlinearity so it's the same as the error

            # Update the weights
            self.weights_1_2 -= layer_1.T.dot(layer_2_delta) * self.learning_rate # update hidden-to-output weights with gradient descent step
            self.weights_0_1 -= self.layer_0.T.dot(layer_1_delta) * self.learning_rate # update input-to-hidden weights with gradient descent step

            # Keep track of correct predictions.
            if(layer_2 >= 0.5 and label == 'Baked Good'):
                correct_so_far += 1
            elif(layer_2 < 0.5 and label == 'Other'):
                correct_so_far += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the training process. 
            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) \
                             + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%")
            if(i % 2500 == 0):
                print("")
    
    def test(self, testing_reviews, testing_labels):
        """
        Attempts to predict the labels for the given testing_reviews,
        and uses the test_labels to calculate the accuracy of those predictions.
        """
        
        # keep track of how many correct predictions we make
        correct = 0

        # we'll time how many predictions per second we make
        start = time.time()

        # Loop through each of the given reviews and call run to predict
        # its label. 
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the prediction process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct) + " #Tested:" + str(i+1) \
                             + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
    
    def run(self, review):
        """
        Returns a Baked Good or Other prediction for the given review.
        """
        # Run a forward pass through the network, like in the "train" function.
        
        # Input Layer
        self.update_input_layer(review.lower())

        # Hidden layer
        layer_1 = self.layer_0.dot(self.weights_0_1)

        # Output layer
        layer_2 = self.sigmoid(layer_1.dot(self.weights_1_2))
        
        # Return POSITIVE for values above greater-than-or-equal-to 0.5 in the output layer;
        # return NEGATIVE for other values
        if(layer_2[0] >= 0.5):
            return "Baked Good"
        else:
            return "Other"

# %%
mlp = SentimentNetwork(expected_data[:-1000],expected_data[:-1000], learning_rate=0.1)

# %%
mlp.test(method_description[-1000:],expected_data[-1000:])
# Out:
# Progress:99.9% Speed(reviews/sec):7085. #Correct:205 #Tested:1000 Testing Accuracy:20.5%

# %%
mlp.train(method_description[-1000:],expected_data[-1000:])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:0 #Trained:1 Training Accuracy:0.0%
# Progress:23.9% Speed(reviews/sec):3634. #Correct:59 #Trained:240 Training Accuracy:24.5%
# Progress:41.8% Speed(reviews/sec):4062. #Correct:87 #Trained:419 Training Accuracy:20.7%
# Progress:83.2% Speed(reviews/sec):5024. #Correct:173 #Trained:833 Training Accuracy:20.7%
# Progress:99.9% Speed(reviews/sec):5114. #Correct:205 #Trained:1000 Training Accuracy:20.5%

# %%
mlp = SentimentNetwork(method_description[:-1000],expected_data[:-1000], learning_rate=0.01)
mlp.train(method_description[:-1000],expected_data[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:99.8% Speed(reviews/sec):1457. #Correct:377 #Trained:617 Training Accuracy:61.1%

# %%
mlp = SentimentNetwork(method_description[:-1000],expected_data[:-1000], learning_rate=0.001)
mlp.train(method_description[:-1000],expected_data[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:99.8% Speed(reviews/sec):1572. #Correct:394 #Trained:617 Training Accuracy:63.8%

# %%
mlp = SentimentNetwork(method_description[:-1000],expected_data[:-1000], learning_rate=0.00001)
mlp.train(method_description[:-1000],expected_data[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:99.8% Speed(reviews/sec):1300. #Correct:405 #Trained:617 Training Accuracy:65.6%

# %% [markdown]
# With a learning rate of 0.00001, the network should finally have started to improve during training. It's still not very good, but it shows that this solution has potential. We will improve it in the next lesson.

# %% [markdown]
# **Understanding Nueral Noise**

# %%
def update_input_layer(review):
    
    global layer_0
    
    # clear out previous state, reset the layer to be all 0s
    layer_0 *= 0
    for word in review.split(" "):
        layer_0[0][word2index[word]] += 1

update_input_layer(method_description[0])

# %%
layer_0
# Out:
# array([[5., 1., 0., ..., 0., 0., 0.]])

# %%
description_counter = Counter()
for word in method_description[0].split(" "):
    description_counter[word] += 1
description_counter.most_common()
# Out:
# [('the', 23),
#  ('and', 17),
#  ('with', 8),
#  ('to', 6),
#  ('a', 6),
#  ('in', 5),
#  ('then', 5),
#  ('of', 5),
#  ('', 5),
#  ('heat', 3),
#  ('add', 3),
#  ('for', 3),
#  ('cool', 3),
#  ('chicken', 3),
#  ('roll', 3),
#  ('out', 3),
#  ('pastry', 3),
#  ('brush', 3),
#  ('oil', 2),
#  ('frying', 2),
#  ('pan,', 2),
#  ('onion', 2),
#  ('fry', 2),
#  ('until', 2),
#  ('into', 2),
#  ('mix', 2),
#  ('fillets', 2),
#  ('remaining', 2),
#  ('mins.', 2),
#  ('press', 2),
#  ('cover', 2),
#  ('edges', 2),
#  ('pie', 2),
#  ('tin', 2),
#  ('oven', 1),
#  ('190c/fan', 1),
#  ('170c/gas', 1),
#  ('5.', 1),
#  ('1', 1),
#  ('tbsp', 1),
#  ('butter', 1),
#  ('5', 1),
#  ('mins', 1),
#  ('softened.', 1),
#  ('slightly.', 1),
#  ('tip', 1),
#  ('sausagemeat,', 1),
#  ('lemon', 1),
#  ('zest,', 1),
#  ('breadcrumbs,', 1),
#  ('apricots,', 1),
#  ('chestnuts', 1),
#  ('thyme', 1),
#  ('bowl.', 1),
#  ('cranberries,', 1),
#  ('everything', 1),
#  ('together', 1),
#  ('your', 1),
#  ('hands,', 1),
#  ('adding', 1),
#  ('plenty', 1),
#  ('pepper', 1),
#  ('little', 1),
#  ('salt.', 1),
#  ('cut', 1),
#  ('each', 1),
#  ('breast', 1),
#  ('three', 1),
#  ('lengthwise', 1),
#  ('season', 1),
#  ('all', 1),
#  ('over', 1),
#  ('salt', 1),
#  ('pepper.', 1),
#  ('quickly', 1),
#  ('browned,', 1),
#  ('about', 1),
#  ('6-8', 1),
#  ('two-thirds', 1),
#  ('line', 1),
#  ('20-23cm', 1),
#  ('springform', 1),
#  ('or', 1),
#  ('deep', 1),
#  ('loose-based', 1),
#  ('tart', 1),
#  ('tin.', 1),
#  ('half', 1),
#  ('sausage', 1),
#  ('spread', 1),
#  ('level.', 1),
#  ('pieces', 1),
#  ('one', 1),
#  ('layer', 1),
#  ('rest', 1),
#  ('sausage.', 1),
#  ('down', 1),
#  ('lightly.', 1),
#  ('pastry.', 1),
#  ('beaten', 1),
#  ('egg', 1),
#  ('lid.', 1),
#  ('pinch', 1),
#  ('seal,', 1),
#  ('trim.', 1),
#  ('top', 1),
#  ('egg,', 1),
#  ('trimmings', 1),
#  ('make', 1),
#  ('holly', 1),
#  ('leaf', 1),
#  ('shapes', 1),
#  ('berries.', 1),
#  ('decorate', 1),
#  ('again', 1),
#  ('egg.', 1),
#  ('set', 1),
#  ('on', 1),
#  ('baking', 1),
#  ('sheet', 1),
#  ('bake', 1),
#  ('50-60', 1),
#  ('mins,', 1),
#  ('15', 1),
#  ('remove', 1),
#  ('leave', 1),
#  ('completely.', 1),
#  ('serve', 1),
#  ('winter', 1),
#  ('salad', 1),
#  ('pickles.', 1)]

# %% [markdown]
# # Making the Network More Efficient<a id='project_5'></a>
# **TODO:** Make the `SentimentNetwork` class more efficient by eliminating unnecessary multiplications and additions that occur during forward and backward propagation. To do that, you can do the following:
# * Copy the `SentimentNetwork` class from the previous project into the following cell.
# * Remove the `update_input_layer` function - you will not need it in this version.
# * Modify `init_network`:
# >* You no longer need a separate input layer, so remove any mention of `self.layer_0`
# >* You will be dealing with the old hidden layer more directly, so create `self.layer_1`, a two-dimensional matrix with shape 1 x hidden_nodes, with all values initialized to zero
# * Modify `train`:
# >* Change the name of the input parameter `training_reviews` to `training_reviews_raw`. This will help with the next step.
# >* At the beginning of the function, you'll want to preprocess your reviews to convert them to a list of indices (from `word2index`) that are actually used in the review. This is equivalent to what you saw in the video when Andrew set specific indices to 1. Your code should create a local `list` variable named `training_reviews` that should contain a `list` for each review in `training_reviews_raw`. Those lists should contain the indices for words found in the review.
# >* Remove call to `update_input_layer`
# >* Use `self`'s  `layer_1` instead of a local `layer_1` object.
# >* In the forward pass, replace the code that updates `layer_1` with new logic that only adds the weights for the indices used in the review.
# >* When updating `weights_0_1`, only update the individual weights that were used in the forward pass.
# * Modify `run`:
# >* Remove call to `update_input_layer`
# >* Use `self`'s  `layer_1` instead of a local `layer_1` object.
# >* Much like you did in `train`, you will need to pre-process the `review` so you can work with word indices, then update `layer_1` by adding weights for the indices used in the review.

# %%
import time
import sys
import numpy as np

# Encapsulate our neural network in a class
class SentimentNetwork:
    def __init__(self, reviews,labels,hidden_nodes = 10, learning_rate = 0.1):
        """Create a SentimenNetwork with the given settings
        Args:
            reviews(list) - List of reviews used for training
            labels(list) - List of POSITIVE/NEGATIVE labels associated with the given reviews
            hidden_nodes(int) - Number of nodes to create in the hidden layer
            learning_rate(float) - Learning rate to use while training
        
        """
        # Assign a seed to our random number generator to ensure we get
        # reproducable results during development 
        np.random.seed(1)

        # process the reviews and their associated labels so that everything
        # is ready for training
        self.pre_process_data(reviews, labels)
        
        # Build the network to have the number of hidden nodes and the learning rate that
        # were passed into this initializer. Make the same number of input nodes as
        # there are vocabulary words and create a single output node.
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)

    def pre_process_data(self, reviews, labels):
        
        # populate review_vocab with all of the words in the given reviews
        review_vocab = set()
        for review in reviews:
            for word in review.split(" "):
                review_vocab.add(word)

        # Convert the vocabulary set to a list so we can access words via indices
        self.review_vocab = list(review_vocab)
        
        # populate label_vocab with all of the words in the given labels.
        label_vocab = set()
        for label in labels:
            label_vocab.add(label)
        
        # Convert the label vocabulary set to a list so we can access labels via indices
        self.label_vocab = list(label_vocab)
        
        # Store the sizes of the review and label vocabularies.
        self.review_vocab_size = len(self.review_vocab)
        self.label_vocab_size = len(self.label_vocab)
        
        # Create a dictionary of words in the vocabulary mapped to index positions
        self.word2index = {}
        for i, word in enumerate(self.review_vocab):
            self.word2index[word] = i
        
        # Create a dictionary of labels mapped to index positions
        self.label2index = {}
        for i, label in enumerate(self.label_vocab):
            self.label2index[label] = i

    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        # Set number of nodes in input, hidden and output layers.
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        # Store the learning rate
        self.learning_rate = learning_rate

        # Initialize weights

        # These are the weights between the input layer and the hidden layer.
        self.weights_0_1 = np.zeros((self.input_nodes,self.hidden_nodes))

        # These are the weights between the hidden layer and the output layer.
        self.weights_1_2 = np.random.normal(0.0, self.output_nodes**-0.5, 
                                                (self.hidden_nodes, self.output_nodes))
        
        ## New for Project 5: Removed self.layer_0; added self.layer_1
        # The input layer, a two-dimensional matrix with shape 1 x hidden_nodes
        self.layer_1 = np.zeros((1,hidden_nodes))
    
    ## New for Project 5: Removed update_input_layer function
    
    def get_target_for_label(self,label):
        if(label == 'Baked Good'):
            return 1
        else:
            return 0
        
    def sigmoid(self,x):
        return 1 / (1 + np.exp(-x))
    
    def sigmoid_output_2_derivative(self,output):
        return output * (1 - output)
    
    ## New for Project 5: changed name of first parameter form 'training_reviews' 
    #                     to 'training_reviews_raw'
    def train(self, training_reviews_raw, training_labels):

        ## New for Project 5: pre-process training reviews so we can deal 
        #                     directly with the indices of non-zero inputs
        training_reviews = list()
        for review in training_reviews_raw:
            indices = set()
            for word in review.split(" "):
                if(word in self.word2index.keys()):
                    indices.add(self.word2index[word])
            training_reviews.append(list(indices))

        # make sure out we have a matching number of reviews and labels
        assert(len(training_reviews) == len(training_labels))
        
        # Keep track of correct predictions to display accuracy during training 
        correct_so_far = 0

        # Remember when we started for printing time statistics
        start = time.time()
        
        # loop through all the given reviews and run a forward and backward pass,
        # updating weights for every item
        for i in range(len(training_reviews)):
            
            # Get the next review and its correct label
            review = training_reviews[i]
            label = training_labels[i]
            
            #### Implement the forward pass here ####
            ### Forward pass ###

            ## New for Project 5: Removed call to 'update_input_layer' function
            #                     because 'layer_0' is no longer used

            # Hidden layer
            ## New for Project 5: Add in only the weights for non-zero items
            self.layer_1 *= 0
            for index in review:
                self.layer_1 += self.weights_0_1[index]

            # Output layer
            ## New for Project 5: changed to use 'self.layer_1' instead of 'local layer_1'
            layer_2 = self.sigmoid(self.layer_1.dot(self.weights_1_2))            
            
            #### Implement the backward pass here ####
            ### Backward pass ###

            # Output error
            layer_2_error = layer_2 - self.get_target_for_label(label) # Output layer error is the difference between desired target and actual output.
            layer_2_delta = layer_2_error * self.sigmoid_output_2_derivative(layer_2)

            # Backpropagated error
            layer_1_error = layer_2_delta.dot(self.weights_1_2.T) # errors propagated to the hidden layer
            layer_1_delta = layer_1_error # hidden layer gradients - no nonlinearity so it's the same as the error

            # Update the weights
            ## New for Project 5: changed to use 'self.layer_1' instead of local 'layer_1'
            self.weights_1_2 -= self.layer_1.T.dot(layer_2_delta) * self.learning_rate # update hidden-to-output weights with gradient descent step
            
            ## New for Project 5: Only update the weights that were used in the forward pass
            for index in review:
                self.weights_0_1[index] -= layer_1_delta[0] * self.learning_rate # update input-to-hidden weights with gradient descent step

            # Keep track of correct predictions.
            if(layer_2 >= 0.5 and label == 'Baked Good'):
                correct_so_far += 1
            elif(layer_2 < 0.5 and label == 'Other'):
                correct_so_far += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the training process. 
            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) \
                             + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%")
            if(i % 2500 == 0):
                print("")
    
    def test(self, testing_reviews, testing_labels):
        """
        Attempts to predict the labels for the given testing_reviews,
        and uses the test_labels to calculate the accuracy of those predictions.
        """
        
        # keep track of how many correct predictions we make
        correct = 0

        # we'll time how many predictions per second we make
        start = time.time()

        # Loop through each of the given reviews and call run to predict
        # its label. 
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the prediction process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct) + " #Tested:" + str(i+1) \
                             + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
    
    def run(self, review):
        """
        Returns a POSITIVE or NEGATIVE prediction for the given review.
        """
        # Run a forward pass through the network, like in the "train" function.
        
        ## New for Project 5: Removed call to update_input_layer function
        #                     because layer_0 is no longer used

        # Hidden layer
        ## New for Project 5: Identify the indices used in the review and then add
        #                     just those weights to layer_1 
        self.layer_1 *= 0
        unique_indices = set()
        for word in review.lower().split(" "):
            if word in self.word2index.keys():
                unique_indices.add(self.word2index[word])
        for index in unique_indices:
            self.layer_1 += self.weights_0_1[index]
        
        # Output layer
        ## New for Project 5: changed to use self.layer_1 instead of local layer_1
        layer_2 = self.sigmoid(self.layer_1.dot(self.weights_1_2))
        
        # Return POSITIVE for values above greater-than-or-equal-to 0.5 in the output layer;
        # return NEGATIVE for other values
        if(layer_2[0] >= 0.5):
            return "Baked Good"
        else:
            return "Other"

# %%
mlp = SentimentNetwork(method_description[:-1000],expected_data[:-1000], learning_rate=0.001)
mlp.train(method_description[:-1000],expected_data[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:76.6% Speed(reviews/sec):1157. #Correct:333 #Trained:474 Training Accuracy:70.2%
# Progress:99.8% Speed(reviews/sec):1226. #Correct:451 #Trained:617 Training Accuracy:73.0%

# %%
from bokeh.models import ColumnDataSource, LabelSet
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
hist, edges = np.histogram(list(map(lambda x:x[1],baked_other_ratios.most_common())), density=True, bins=100, normed=True)

p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="Baked Good/Other Affinity Distribution")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)
# Out:
# /Users/hazel/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: The normed argument is ignored when density is provided. In future passing both will result in an error.
#   """Entry point for launching an IPython kernel.
#   <div class="bk-root" id="5a105000-a443-4da8-999f-c5cb31628c15" data-root-id="1003"></div>

# %% [markdown]
# **Reducing Noise by Strategically Reducing the Vocabulary** : Improve the SentimentNetwork's performance by reducing more noise in the vocabulary. Specifically, do the following.

# %%
import time
import sys
import numpy as np

# Encapsulate our neural network in a class
class SentimentNetwork:
    ## New for Project 6: added min_count and polarity_cutoff parameters
    def __init__(self, reviews,labels,min_count = 10,polarity_cutoff = 0.1,hidden_nodes = 10, learning_rate = 0.1):
        """Create a SentimenNetwork with the given settings
        Args:
            reviews(list) - List of reviews used for training
            labels(list) - List of POSITIVE/NEGATIVE labels associated with the given reviews
            min_count(int) - Words should only be added to the vocabulary 
                             if they occur more than this many times
            polarity_cutoff(float) - The absolute value of a word's positive-to-negative
                                     ratio must be at least this big to be considered.
            hidden_nodes(int) - Number of nodes to create in the hidden layer
            learning_rate(float) - Learning rate to use while training
        
        """
        # Assign a seed to our random number generator to ensure we get
        # reproducable results during development 
        np.random.seed(1)

        # process the reviews and their associated labels so that everything
        # is ready for training
        ## New for Project 6: added min_count and polarity_cutoff arguments to pre_process_data call
        self.pre_process_data(reviews, labels, polarity_cutoff, min_count)
        
        # Build the network to have the number of hidden nodes and the learning rate that
        # were passed into this initializer. Make the same number of input nodes as
        # there are vocabulary words and create a single output node.
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)

    ## New for Project 6: added min_count and polarity_cutoff parameters
    def pre_process_data(self, reviews, labels, polarity_cutoff, min_count):
        
        ## ----------------------------------------
        ## New for Project 6: Calculate positive-to-negative ratios for words before
        #                     building vocabulary
        #
        positive_counts = Counter()
        negative_counts = Counter()
        total_counts = Counter()

        for i in range(len(reviews)):
            if(labels[i] == 'Baked Good'):
                for word in reviews[i].split(" "):
                    positive_counts[word] += 1
                    total_counts[word] += 1
            else:
                for word in reviews[i].split(" "):
                    negative_counts[word] += 1
                    total_counts[word] += 1

        pos_neg_ratios = Counter()

        for term,cnt in list(total_counts.most_common()):
            if(cnt >= 50):
                pos_neg_ratio = positive_counts[term] / float(negative_counts[term]+1)
                pos_neg_ratios[term] = pos_neg_ratio

        for word,ratio in pos_neg_ratios.most_common():
            if(ratio > 1):
                pos_neg_ratios[word] = np.log(ratio)
            else:
                pos_neg_ratios[word] = -np.log((1 / (ratio + 0.01)))
        #
        ## end New for Project 6
        ## ----------------------------------------

        # populate review_vocab with all of the words in the given reviews
        review_vocab = set()
        for review in reviews:
            for word in review.split(" "):
                ## New for Project 6: only add words that occur at least min_count times
                #                     and for words with pos/neg ratios, only add words
                #                     that meet the polarity_cutoff
                if(total_counts[word] > min_count):
                    if(word in pos_neg_ratios.keys()):
                        if((pos_neg_ratios[word] >= polarity_cutoff) or (pos_neg_ratios[word] <= -polarity_cutoff)):
                            review_vocab.add(word)
                    else:
                        review_vocab.add(word)

        # Convert the vocabulary set to a list so we can access words via indices
        self.review_vocab = list(review_vocab)
        
        # populate label_vocab with all of the words in the given labels.
        label_vocab = set()
        for label in labels:
            label_vocab.add(label)
        
        # Convert the label vocabulary set to a list so we can access labels via indices
        self.label_vocab = list(label_vocab)
        
        # Store the sizes of the review and label vocabularies.
        self.review_vocab_size = len(self.review_vocab)
        self.label_vocab_size = len(self.label_vocab)
        
        # Create a dictionary of words in the vocabulary mapped to index positions
        self.word2index = {}
        for i, word in enumerate(self.review_vocab):
            self.word2index[word] = i
        
        # Create a dictionary of labels mapped to index positions
        self.label2index = {}
        for i, label in enumerate(self.label_vocab):
            self.label2index[label] = i

    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        # Set number of nodes in input, hidden and output layers.
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        # Store the learning rate
        self.learning_rate = learning_rate

        # Initialize weights

        # These are the weights between the input layer and the hidden layer.
        self.weights_0_1 = np.zeros((self.input_nodes,self.hidden_nodes))

        # These are the weights between the hidden layer and the output layer.
        self.weights_1_2 = np.random.normal(0.0, self.output_nodes**-0.5, 
                                                (self.hidden_nodes, self.output_nodes))
        
        ## New for Project 5: Removed self.layer_0; added self.layer_1
        # The input layer, a two-dimensional matrix with shape 1 x hidden_nodes
        self.layer_1 = np.zeros((1,hidden_nodes))
    
    ## New for Project 5: Removed update_input_layer function
    
    def get_target_for_label(self,label):
        if(label == 'Baked Good'):
            return 1
        else:
            return 0
        
    def sigmoid(self,x):
        return 1 / (1 + np.exp(-x))
    
    def sigmoid_output_2_derivative(self,output):
        return output * (1 - output)
    
    ## New for Project 5: changed name of first parameter form 'training_reviews' 
    #                     to 'training_reviews_raw'
    def train(self, training_reviews_raw, training_labels):

        ## New for Project 5: pre-process training reviews so we can deal 
        #                     directly with the indices of non-zero inputs
        training_reviews = list()
        for review in training_reviews_raw:
            indices = set()
            for word in review.split(" "):
                if(word in self.word2index.keys()):
                    indices.add(self.word2index[word])
            training_reviews.append(list(indices))

        # make sure out we have a matching number of reviews and labels
        assert(len(training_reviews) == len(training_labels))
        
        # Keep track of correct predictions to display accuracy during training 
        correct_so_far = 0

        # Remember when we started for printing time statistics
        start = time.time()
        
        # loop through all the given reviews and run a forward and backward pass,
        # updating weights for every item
        for i in range(len(training_reviews)):
            
            # Get the next review and its correct label
            review = training_reviews[i]
            label = training_labels[i]
            
            #### Implement the forward pass here ####
            ### Forward pass ###

            ## New for Project 5: Removed call to 'update_input_layer' function
            #                     because 'layer_0' is no longer used

            # Hidden layer
            ## New for Project 5: Add in only the weights for non-zero items
            self.layer_1 *= 0
            for index in review:
                self.layer_1 += self.weights_0_1[index]

            # Output layer
            ## New for Project 5: changed to use 'self.layer_1' instead of 'local layer_1'
            layer_2 = self.sigmoid(self.layer_1.dot(self.weights_1_2))            
            
            #### Implement the backward pass here ####
            ### Backward pass ###

            # Output error
            layer_2_error = layer_2 - self.get_target_for_label(label) # Output layer error is the difference between desired target and actual output.
            layer_2_delta = layer_2_error * self.sigmoid_output_2_derivative(layer_2)

            # Backpropagated error
            layer_1_error = layer_2_delta.dot(self.weights_1_2.T) # errors propagated to the hidden layer
            layer_1_delta = layer_1_error # hidden layer gradients - no nonlinearity so it's the same as the error

            # Update the weights
            ## New for Project 5: changed to use 'self.layer_1' instead of local 'layer_1'
            self.weights_1_2 -= self.layer_1.T.dot(layer_2_delta) * self.learning_rate # update hidden-to-output weights with gradient descent step
            
            ## New for Project 5: Only update the weights that were used in the forward pass
            for index in review:
                self.weights_0_1[index] -= layer_1_delta[0] * self.learning_rate # update input-to-hidden weights with gradient descent step

            # Keep track of correct predictions.
            if(layer_2 >= 0.5 and label == 'Baked Good'):
                correct_so_far += 1
            elif(layer_2 < 0.5 and label == 'Other'):
                correct_so_far += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the training process. 
            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) \
                             + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%")
            if(i % 2500 == 0):
                print("")
    
    def test(self, testing_reviews, testing_labels):
        """
        Attempts to predict the labels for the given testing_reviews,
        and uses the test_labels to calculate the accuracy of those predictions.
        """
        
        # keep track of how many correct predictions we make
        correct = 0

        # we'll time how many predictions per second we make
        start = time.time()

        # Loop through each of the given reviews and call run to predict
        # its label. 
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the prediction process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct) + " #Tested:" + str(i+1) \
                             + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
    
    def run(self, review):
        """
        Returns a Baked Good or Other prediction for the given review.
        """
        # Run a forward pass through the network, like in the "train" function.
        
        ## New for Project 5: Removed call to update_input_layer function
        #                     because layer_0 is no longer used

        # Hidden layer
        ## New for Project 5: Identify the indices used in the review and then add
        #                     just those weights to layer_1 
        self.layer_1 *= 0
        unique_indices = set()
        for word in review.lower().split(" "):
            if word in self.word2index.keys():
                unique_indices.add(self.word2index[word])
        for index in unique_indices:
            self.layer_1 += self.weights_0_1[index]
        
        # Output layer
        ## New for Project 5: changed to use self.layer_1 instead of local layer_1
        layer_2 = self.sigmoid(self.layer_1.dot(self.weights_1_2))
         
        # Return POSITIVE for values above greater-than-or-equal-to 0.5 in the output layer;
        # return NEGATIVE for other values
        if(layer_2[0] >= 0.5):
            return "Baked Good"
        else:
            return "Other"

# %% [markdown]
# **1. Run the following cell to train the network with a small polarity cutoff.**

# %%
mlp = SentimentNetwork(method_description[:-1000],expected_data[:-1000],min_count=20,polarity_cutoff=0.05,learning_rate=0.01)
mlp.train(method_description[:-1000],expected_data[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:99.8% Speed(reviews/sec):1813. #Correct:479 #Trained:617 Training Accuracy:77.6%

# %% [markdown]
# **1.1 Run the following cell to test its performance.**

# %%
mlp.test(method_description[-1000:],expected_data[-1000:])
# Out:
# Progress:15.5% Speed(reviews/sec):2613. #Correct:120 #Tested:156 Testing Accuracy:76.9%
# Progress:52.9% Speed(reviews/sec):2609. #Correct:445 #Tested:530 Testing Accuracy:83.9%
# Progress:69.2% Speed(reviews/sec):2612. #Correct:588 #Tested:693 Testing Accuracy:84.8%
# Progress:99.9% Speed(reviews/sec):2778. #Correct:848 #Tested:1000 Testing Accuracy:84.8%

# %% [markdown]
# **2. Run the following cell to train your network with a much larger polarity cutoff.**

# %%
mlp = SentimentNetwork(method_description[:-1000],expected_data[:-1000],min_count=20,polarity_cutoff=0.8,learning_rate=0.01)
mlp.train(method_description[:-1000],expected_data[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:99.8% Speed(reviews/sec):4378. #Correct:483 #Trained:617 Training Accuracy:78.2%

# %% [markdown]
# **2.1 And Run the following cell to test its performance**

# %%
mlp.test(method_description[-1000:], expected_data[-1000:])
# Out:
# Progress:32.8% Speed(reviews/sec):5858. #Correct:269 #Tested:329 Testing Accuracy:81.7%
# Progress:99.9% Speed(reviews/sec):5980. #Correct:837 #Tested:1000 Testing Accuracy:83.7%

# %% [markdown]
# **Analysis: about Weights**

# %%
mlp_full = SentimentNetwork(method_description[:-1000],expected_data[:-1000],min_count=0,polarity_cutoff=0,learning_rate=0.01)
mlp_full.train(method_description[:-1000],expected_data[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:88.4% Speed(reviews/sec):1343. #Correct:419 #Trained:547 Training Accuracy:76.5%
# Progress:99.8% Speed(reviews/sec):1265. #Correct:481 #Trained:617 Training Accuracy:77.9%

# %%
def get_most_similar_words(focus = "horrible"):
    most_similar = Counter()

    for word in mlp_full.word2index.keys():
        most_similar[word] = np.dot(mlp_full.weights_0_1[mlp_full.word2index[word]],mlp_full.weights_0_1[mlp_full.word2index[focus]])
    
    return most_similar.most_common()

# %%
get_most_similar_words
#  ('like,', 0.001957415324449246),
#  ('on', 0.0019558749020011103),
#  ('cloves,', 0.0019524882750603502),
#  ('£1', 0.0019401688899707836),
#  ('green.', 0.001933781578571661),
#  ('cutter,', 0.0019329584949079953),
#  ('mixed', 0.0019319565039369925),
#  ('10', 0.0019295921044032583),
#  ('30', 0.0019230546056621968),
#  ('biscuits', 0.0019224887794501056),
#  ('method', 0.0019201253408348135),
#  ('skewer,', 0.0019176889895218124),
#  ('gingerbread', 0.0019146912398912788),
#  ('green', 0.0019083513895743428),
#  ('dough.', 0.0019032623185788488),
#  ('fluffy', 0.0018924165036623606),
#  ('milk', 0.0018906845759824804),
#  ('puddings', 0.0018878198151368588),
#  ('salt.', 0.0018792524875554876),
#  ('smaller', 0.0018754801901811218),
#  ('tops', 0.0018703417886493565),
#  ('egg.', 0.001856983640003195),
#  ('firmly', 0.0018569081887958119),
#  ('bag', 0.0018505856608970548),
#  ('edges', 0.0018395530836714164),
#  ('spices.', 0.0018349588005995776),
#  ('batter.', 0.0018279220887416898),
#  ('ensuring', 0.0018273430799101713),
#  ('tins.', 0.0018235002610376043),
#  ('mincemeat.', 0.001818098007169848),
#  ('touch', 0.0018159310169442967),
#  ('you', 0.0018095596176943337),
#  ('fruit,', 0.0018017513987392123),
#  ('apricot', 0.0017951249864442535),
#  ('looks', 0.0017878190397061927),
#  ('slight', 0.0017835519874817487),
#  ('star', 0.0017683581768263299),
#  ('slightly', 0.0017641820212982895),
#  ('parchment.', 0.001764012843046275),
#  ('trees', 0.0017631424317380807),
#  ('halves', 0.001752003047922801),
#  ('in.', 0.00172631828138212),
#  ('pieces', 0.0017233112496113992),
#  ('two-thirds', 0.0017232375833820777),
#  ('ribbon.', 0.0017217998098432654),
#  ('larger', 0.0017183490929856275),
#  ('potato', 0.001718345167441368),
#  ('melted', 0.0017069403599306156),
#  ('light', 0.0016932160133247874),
#  ('jam.', 0.0016847005962144803),
#  ('centre.', 0.0016806409727965826),
#  ('take', 0.001670829552168985),
#  ('bottom.', 0.0016692120710282796),
#  ('case', 0.0016685133933884507),
#  ('up.', 0.0016644377587782962),
#  ('spices', 0.001663541933886853),
#  ('ball,', 0.0016611531638777478),
#  ('dry', 0.00165830478731583),
#  ('corners', 0.0016492858206092105),
#  ('knead', 0.0016486801375948878),
#  ('lots', 0.0016441686603341312),
#  ('jar', 0.001643279500525871),
#  ('squeeze', 0.0016393985863460496),
#  ('any', 0.001638992638732723),
#  ('syrup', 0.0016387436238787141),
#  ('milk.', 0.0016336605401000087),
#  ('rounds,', 0.0016310080900880449),
#  ('15-20', 0.0016308680887604878),
#  ('evenly', 0.0016228173794346683),
#  ('white', 0.0016120384244175281),
#  ('ribbon', 0.001611925905999377),
#  ('months,', 0.0016044182208409538),
#  ('chestnuts', 0.0016040865219813475),
#  ('200ml', 0.001599995624731062),
#  ('paper,', 0.001594579089777193),
#  ('tops.', 0.0015941647536698424),
#  ('decorate', 0.0015917709837086483),
#  ('cooked.', 0.001582926726672267),
#  ('lids', 0.0015759937143321207),
#  ('parchment,', 0.0015747783401540573),
#  ('arrange', 0.001572824212188882),
#  ('strips', 0.0015721509615919617),
#  ('vanilla,', 0.0015703826048015955),
#  ('beans.', 0.0015645348773669293),
#  ('drops', 0.0015632327898260903),
#  ('cakes', 0.0015593179259055054),
#  ('ball.', 0.0015574132845405952),
#  ('loose', 0.0015566450447343496),
#  ('help', 0.0015445681174297286),
#  ('onto', 0.0015412752554635255),
#  ('serve', 0.0015338171718278797),
#  ('gradually', 0.0015284064105574337),
#  ('trimming', 0.0015265844551985077),
#  ('more,', 0.0015261198093733486),
#  ('foil.', 0.0015073294770836085),
#  ('sit', 0.0015046367785523308),
#  ('rectangular', 0.0015034227540914927),
#  ('5', 0.001501121975567384),
#  ('crumb', 0.0014993128788110426),
#  ('base,', 0.001498637737632045),
#  ('holly', 0.001496836726890982),
#  ('trimmings.', 0.0014931152998741257),
#  ('steam', 0.0014891347970426023),
#  ('pipe', 0.0014857752616931016),
#  ('white,', 0.001484445204583515),
#  ('baking', 0.0014836434373072939),
#  ('than', 0.0014824159711466975),
#  ('10cm', 0.001481990910280289),
#  ('treacle', 0.0014801328086037025),
#  ('pastry,', 0.0014748508711664705),
#  ('check', 0.0014663330908425095),
#  ('spray', 0.00146061455302584),
#  ('again,', 0.0014605602323143096),
#  ('cases', 0.0014590903149401323),
#  ('bases', 0.0014571108122684523),
#  ('darken', 0.0014561711595739758),
#  ('kitchen', 0.0014465109434485261),
#  ('microwave', 0.001444708283961141),
#  ('mixture.', 0.0014442625962414978),
#  ('saucer', 0.0014441224523613079),
#  ('little.', 0.0014434947684341228),
#  ('brownie', 0.0014391630150067188),
#  ('well,', 0.0014348040687110924),
#  ('circles', 0.0014332755714229438),
#  ('creamy.', 0.0014298151937966),
#  ('kettle', 0.0014289525392994923),
#  ('thickened.', 0.0014273443748998643),
#  ('cools', 0.0014236451096719875),
#  ('processor,', 0.001421324646571594),
#  ('final', 0.001416760449205799),
#  ('small', 0.0014152138060602852),
#  ('edges.', 0.001415121593722018),
#  ('pockets', 0.0014146867184121992),
#  ('lower', 0.0014091049869744418),
#  ('gelatine', 0.001404548954272462),
#  ('sealed', 0.0014032791389494749),
#  ('create', 0.0014026258306945607),
#  ('stand', 0.0013963588174574469),
#  ('covered.', 0.0013938767276036154),
#  ('extract,', 0.0013935921698787087),
#  ('temperature', 0.001390506139519269),
#  ('creamy,', 0.0013890848304659075),
#  ('spices,', 0.001381288185268663),
#  ('mixture,', 0.0013750820453480909),
#  ('thickly', 0.001374722090137312),
#  ('briefly.', 0.001369454441151007),
#  ('stage', 0.0013681294066376984),
#  ('rather', 0.0013676590847553182),
#  ('do', 0.0013672081895643963),
#  ('cheese', 0.0013664700468221144),
#  ('largest', 0.0013636567105397121),
#  ('cinnamon,', 0.0013619064533073124),
#  ('glue', 0.001359407307739224),
#  ('35', 0.0013593890288425),
#  ('sift', 0.0013551285256742504),
#  ('prepared', 0.001347831467147305),
#  ('180c/fan', 0.0013426175336302712),
#  ('250g', 0.0013411019488669454),
#  ('3', 0.0013366978120183093),
#  ('tree,', 0.0013359471975875033),
#  ('fitted', 0.0013339121874176027),
#  ('flours', 0.0013312928590471663),
#  ('overhanging.', 0.001331185834982613),
#  ('stretch', 0.001330131225988753),
#  ('deep,', 0.0013300853849514836),
#  ('down,', 0.0013228924193773354),
#  ('170c/gas', 0.0013220411975313237),
#  ('halve', 0.0013163475050337978),
#  ('rise.', 0.0013130708710853089),
#  ('salt,', 0.0013101610583913252),
#  ('shallots', 0.0013073149033084538),
#  ('swirl', 0.0013062058258577044),
#  ('spice', 0.0013058393661307234),
#  ('ginger', 0.001303992733131149),
#  ('rough', 0.001300851555100962),
#  ('removing', 0.0012849039308691795),
#  ('across.', 0.0012824935703306547),
#  ('processor', 0.0012812604696273784),
#  ('decorations.', 0.0012772244845842301),
#  ('bottom,', 0.0012766459015876993),
#  ('150ml', 0.0012765400210974856),
#  ('edge', 0.0012752684877234452),
#  ('buttered', 0.001273828018233632),
#  ('processor.', 0.0012675650206349547),
#  ('figs', 0.0012671113929771086),
#  ('zests,', 0.001266220815668106),
#  ('hot', 0.001264508147808722),
#  ('necessary.', 0.0012616029747108447),
#  ('forms', 0.0012587530637527549),
#  ('coin.', 0.001258630832024338),
#  ('breadcrumbs.', 0.001249240339063243),
#  ('it’s', 0.001248361051716042),
#  ('stir', 0.00124687104983363),
#  ('140g', 0.0012467494764053862),
#  ('cream.', 0.001244690502958665),
#  ('hours.', 0.0012412030723359486),
#  ('inside.', 0.001239520256823887),
#  ('ring', 0.001234993519990182),
#  ('buttons', 0.0012323753946770876),
#  ('peaks', 0.001232029430693409),
#  ('week,', 0.0012308966897728883),
#  ('if', 0.0012272440814768484),
#  ('effect.', 0.0012182588323264632),
#  ('bow', 0.001214951825544011),
#  ('tins,', 0.0012148856949209996),
#  ('18', 0.0012090827289433607),
#  ('8cm', 0.0012051384910939551),
#  ('double-line', 0.001203961646823114),
#  ('beans,', 0.0012038207164849562),
#  ('flour.', 0.0012010124450214758),
#  ('layer.', 0.0012002370194512274),
#  ('away,', 0.001196566712687917),
#  ('eyes', 0.0011904772983136157),
#  ('crush', 0.0011901738141321108),
#  ('newspaper', 0.0011801616018926563),
#  ('well.', 0.0011766917579441741),
#  ('overnight,', 0.0011718271007714026),
#  ('parsley.', 0.0011717816878333695),
#  ('build', 0.0011711474304307416),
#  ('from', 0.001171093267139617),
#  ('slits', 0.0011659380919668274),
#  ('dark', 0.001162583445042454),
#  ('sides.', 0.001162355919709823),
#  ('escape,', 0.0011586886921476735),
#  ('nose', 0.0011530498206334372),
#  ('fingers,', 0.0011517823222122097),
#  ('soda,', 0.001150937779078498),
#  ('runny', 0.0011491590733006376),
#  ('trim.', 0.0011489293973133447),
#  ('ready-to-roll', 0.0011479676556966673),
#  ('chosen', 0.0011427958952655744),
#  ('golden', 0.0011351032224521701),
#  ('soured', 0.0011342560327707116),
#  ('hard', 0.0011326983621044004),
#  ('like', 0.0011321286308222823),
#  ('have', 0.0011321270936659731),
#  ('plate', 0.001131341734612859),
#  ('feed', 0.001129126824571214),
#  ('patch', 0.0008902498713778935),
#  ('bicarb,', 0.0008848396580372588),
#  ('firm,', 0.0008805838981229072),
#  ('using.', 0.0008797773884179109),
#  ('gather', 0.0008796540863736525),
#  ('fluted', 0.0008779444589115221),
#  ('blob', 0.0008766645012789759),
#  ('nozzle,', 0.0008755522592668642),
#  ('months.', 0.0008748702401906215),
#  ('next', 0.0008745792740979652),
#  ('edible', 0.0008739883369590409),
#  ('fill', 0.0008725478965884931),
#  ('branches', 0.0008685873106439968),
#  ('1/', 0.0008635961974241991),
#  ('glacé', 0.0008589867011569458),
#  ('halfway', 0.0008581405820465785),
#  ('hand,', 0.0008565056269276082),
#  ('dark,', 0.0008518787261849938),
#  ('continuing', 0.0008502337484715158),
#  ('full.', 0.000849919383680808),
#  ('blind', 0.0008496926174476752),
#  ('immediately,', 0.0008495084793487917),
#  ('giving', 0.0008490140043686029),
#  ('punch', 0.0008484290241102691),
#  ('slide', 0.0008471123897070341),
#  ('nozzle.', 0.000846114247037105),
#  ('antlers,', 0.0008433001020170575),
#  ('forms.', 0.0008392711655709939),
#  ('let', 0.0008341648470895899),
#  ('year.', 0.0008333920326546149),
#  ('chicken', 0.0008305266935008972),
#  ('thinner', 0.0008304474681021282),
#  ('sheets', 0.0008301359034199572),
#  ('puffed', 0.0008293838967083564),
#  ('¼', 0.0008292276396519484),
#  ('people', 0.0008285855838464838),
#  ('yourself,', 0.0008272796210783034),
#  ('consistency,', 0.0008270040621053057),
#  ('brown,', 0.0008247760942965382),
#  ('fluffy.', 0.0008225880223416872),
#  ('jam', 0.0008199922690614733),
#  ('together,', 0.000819175800902893),
#  ('apple,', 0.0008191378244884188),
#  ('table.', 0.0008181863865464273),
#  ('slightly,', 0.0008136437081686241),
#  ('slightly.', 0.0008135642373027062),
#  ('ricotta', 0.0008121334405523039),
#  ('spot', 0.0008116752411734258),
#  ('worry', 0.0008075063178181602),
#  ('rum,', 0.000807296760067913),
#  ('pickles.', 0.0008071327485303753),
#  ('7cm', 0.0008067276193736183),
#  ('cheesecake,', 0.0008032150170759931),
#  ('several', 0.0007978515389246617),
#  ('bubble', 0.0007959750903020844),
#  ('burn', 0.0007959556578016959),
#  ('dishes.', 0.0007944125417221272),
#  ('enjoy', 0.0007918699637676293),
#  ('lot', 0.0007916222348158931),
#  ('fondant', 0.0007913114822848821),
#  ('\xa0the', 0.0007888230151279613),
#  ('one-third', 0.0007885287880087369),
#  ('liberally', 0.0007883510644733009),
#  ('spoon', 0.0007871786619187854),
#  ('ready,', 0.0007869581439170143),
#  ('375g', 0.000785931242439845),
#  ('recipe', 0.0007845124313297072),
#  ('balls', 0.0007842510504003599),
#  ('blender', 0.0007836903260804252),
#  ('additional', 0.000782949244330038),
#  ('tart.', 0.0007823448642760091),
#  ('apples', 0.0007794695597511009),
#  ('off.', 0.0007777094542790968),
#  ('25-30', 0.0007759663608032838),
#  ('it.', 0.0007754001779568304),
#  ('demerara', 0.000774786880136712),
#  ('chia', 0.0007747728841419887),
#  ('perfectly', 0.000773864146882183),
#  ('come', 0.000772306825267991),
#  ('18cm', 0.0007720762053734437),
#  ('fix', 0.0007714338476462982),
#  ('kettle.', 0.0007703401105288536),
#  ('pudding,', 0.0007703317785936798),
#  ('12-15', 0.0007667446432168054),
#  ('smartie', 0.0007660004986630576),
#  ('figs,', 0.0007658661056705143),
#  ('cakes,', 0.0007640729870825612),
#  ('down.', 0.0007639957865975785),
#  ('bottom', 0.0007631769975578317),
#  ('paste', 0.0007631621450013108),
#  ('horizontal', 0.0007622207706208454),
#  ('hole,', 0.0007611971586170968),
#  ('shrunk', 0.0007610660219396351),
#  ('layers.', 0.0007606810077804119),
#  ('lard', 0.0007590190518031516),
#  ('funnel,', 0.0007590190518031516),
#  ('size', 0.0007566284663517878),
#  ('stock,', 0.0007551102638263074),
#  ('up,', 0.0007526516319119492),
#  ('powdery', 0.0007525035225458398),
#  ('become', 0.000748960895425401),
#  ('basins', 0.000746929280341643),
#  ('speed,', 0.0007469261823658801),
#  ('mins.\xa0', 0.0007464744953190891),
#  ('side,', 0.0007450041549492396),
#  ('heated', 0.0007446827940807095),
#  ('bursts', 0.0007444168633955527),
#  ('pliable.', 0.0007431902063398349),
#  ('scoop,', 0.0007423881008179725),
#  ('extract', 0.0007422912028444482),
#  ('cases,', 0.0007408332961873952),
#  ('softly', 0.0007394858413935278),
#  ('thickness.', 0.0007391811833929692),
#  ('leftover', 0.0007390157627549908),
#  ('chance', 0.0007387467892561153),
#  ('blasts', 0.0007377708686721848),
#  ('discs', 0.0007366754132123656),
#  ('slicing.', 0.0007364890997677107),
#  ('3/4', 0.0007359559633319977),
#  ('hook,', 0.0007350694027551259),
#  ('pale,', 0.0007325545504666363),
#  ('teaspoon', 0.0007304087384336869),
#  ('fortnight,', 0.0007303704114599402),
#  ('running', 0.0007286291630488762),
#  ('herbs', 0.0007284786161171415),
#  ('1/4', 0.0007274836685224017),
#  ('buttercream', 0.0007264009525581739),
#  ('trees.', 0.0007261617023260282),
#  ('easing', 0.000724621573577785),
#  ('addition.', 0.000723522671713823),
#  ('2cm', 0.0007234152910004855),
#  ('gently', 0.0007232598395230114),
#  ('oil,', 0.0007196053780093163),
#  ('criss-crossing', 0.0007187608437812919),
#  ('eyes.', 0.00071658353379464),
#  ('600ml', 0.0007153189609460714),
#  ('ovenproof', 0.0007147382886803549),
#  ('85g', 0.0007127412470528478),
#  ('write', 0.0007125378079849591),
#  ('ground', 0.0007123879928258318),
#  ('natural', 0.0007116912830232036),
#  ('brandy', 0.0007070247784750223),
#  ('100ml', 0.000706434690642629),
#  ('combined', 0.0007054347397626424),
#  ('basin', 0.0007051673720399579),
#  ('ribbon,', 0.0007046120780396768),
#  ('powder.', 0.000697285832511411),
#  ('one.', 0.0006968671098606073),
#  ('150c/gas', 0.0006964857664435858),
#  ('sandy.', 0.0006960465007056363),
#  ('leaf,', 0.0006959077409263443),
#  ('steps', 0.0006953786744628289),
#  ('tie', 0.0006930666844307321),
#  ('form,', 0.0006928690401552648),
#  ('kneading', 0.0006912144630429765),
#  ('100g', 0.0002987129184863934),
#  ('plain', 0.0002952315111866161),
#  ('of', 0.00029349334919941177),
#  ('flat', 0.0002917062080608711),
#  ('level', 0.00029123052940511796),
#  ('lid.', 0.0002903715496766727),
#  ('15', 0.0002899381939484759),
#  ('fingers', 0.00028901042523196365),
#  ('an', 0.00028835683333348704),
#  ('there', 0.00028780590945452566),
#  ('pies', 0.0002877912033573874),
#  ('mins', 0.000287277207461346),
#  ('bicarbonate', 0.000285866625940278),
#  ('shapes', 0.0002831539852318495),
#  ('pressing', 0.0002795622050484071),
#  ('muffin', 0.0002785867435074126),
#  ('string', 0.0002773078455353786),
#  ('insert', 0.0002771589618351943),
#  ('day,', 0.00027582590240593714),
#  ('re-roll', 0.0002750122674431673),
#  ('surface,', 0.0002744979118986741),
#  ('stamp', 0.0002720165524423792),
#  ('attach', 0.00027127793417128015),
#  ('mixing', 0.0002707789542411864),
#  ('gaps', 0.00026931189810379635),
#  ('roughly', 0.00026893254915347263),
#  ('grease', 0.0002681401395114384),
#  ('ingredients,', 0.00026646530008498536),
#  ('enough', 0.0002651457219877317),
#  ('nuts', 0.0002643742667003978),
#  ('pale', 0.0002632110200390487),
#  ('case,', 0.0002626403585467592),
#  ('pastry.', 0.0002624038486878287),
#  ('either', 0.00026221696230076345),
#  ('inserted', 0.000258267312775367),
#  (',', 0.0002580513555686027),
#  ('cheesecake', 0.0002579414570680093),
#  ('pie,', 0.0002576674041220629),
#  ('side', 0.0002565125559289359),
#  ('lay', 0.00025626648285985074),
#  ('sheet', 0.0002546063159784644),
#  ('stiff', 0.0002532053932961222),
#  ('get', 0.00025281057202374045),
#  ('water.', 0.0002525795673043547),
#  ('spice,', 0.0002525540130167966),
#  ('occasionally.', 0.00025143561941261006),
#  ('mix', 0.0002498690997983425),
#  ('excess.', 0.00024897629771102416),
#  ('look', 0.0002452993087028213),
#  ('chocolate,', 0.0002444796097720124),
#  ('using,', 0.00024308070547879537),
#  ('silver', 0.00024043414759282932),
#  ('sure', 0.00023803510150824465),
#  ('0.5cm', 0.00023761581334726925),
#  ('softened', 0.00023400308544563992),
#  ('dusted', 0.00023383006069349738),
#  ('colour', 0.00023177447950039156),
#  ('base.', 0.00023146085400155294),
#  ('cranberries', 0.0002277762117773613),
#  ('23cm', 0.000227678313679464),
#  ('upturned', 0.0002264990661603147),
#  ('need', 0.0002262505606037166),
#  ('top.', 0.00022489180625293232),
#  ('powder,', 0.0002241620075218422),
#  ('fridge,', 0.0002241476892295313),
#  ('at', 0.0002223784456026788),
#  ('like,', 0.00022223247422819775),
#  ('on', 0.00022205758447039835),
#  ('cloves,', 0.00022167308840820223),
#  ('£1', 0.00022027442385539733),
#  ('green.', 0.00021954924918338823),
#  ('cutter,', 0.00021945580150430427),
#  ('mixed', 0.0002193420418285426),
#  ('10', 0.0002190736029582208),
#  ('30', 0.00021833137697156225),
#  ('biscuits', 0.00021826713666572346),
#  ('method', 0.00021799880689196395),
#  ('skewer,', 0.00021772219907469876),
#  ('gingerbread', 0.0002173818536665532),
#  ('gradually', 0.00017352553339184009),
#  ('trimming', 0.00017331868017970363),
#  ('more,', 0.0001732659272508412),
#  ('foil.', 0.00017113259254963577),
#  ('sit', 0.0001708268807012191),
#  ('rectangular', 0.00017068904809291378),
#  ('5', 0.0001704278323469874),
#  ('crumb', 0.00017022243901872522),
#  ('base,', 0.00017014578778748788),
#  ('holly', 0.00016994131249392148),
#  ('trimmings.', 0.00016951880536256026),
#  ('steam', 0.0001690668844125847),
#  ('pipe', 0.00016868546415718403),
#  ('white,', 0.00016853445794065132),
#  ('baking', 0.0001684434303884889),
#  ('than', 0.00016830407169516842),
#  ('10cm', 0.00016825581299050843),
#  ('treacle', 0.0001680448559555871),
#  ('pastry,', 0.00016744517840594654),
#  ('check', 0.00016647812385565136),
#  ('spray', 0.00016582887747850676),
#  ('again,', 0.00016582271025074758),
#  ('cases', 0.00016565582519018112),
#  ('bases', 0.00016543108505916545),
#  ('darken', 0.00016532440287444952),
#  ('kitchen', 0.0001642276434364688),
#  ('microwave', 0.0001640229809547416),
#  ('mixture.', 0.0001639723804084844),
#  ('saucer', 0.00016395646936454114),
#  ('little.', 0.00016388520612754215),
#  ('brownie', 0.00016339340642111588),
#  ('well,', 0.00016289851940955256),
#  ('circles', 0.0001627249835584976),
#  ('creamy.', 0.0001623321143129875),
#  ('kettle', 0.00016223417401339867),
#  ('thickened.', 0.00016205159326569983),
#  ('cools', 0.0001616316022427683),
#  ('processor,', 0.0001613681516353706),
#  ('final', 0.00016084996172401294),
#  ('small', 0.0001606743657078367),
#  ('edges.', 0.00016066389650601148),
#  ('pockets', 0.00016061452353192946),
#  ('lower', 0.00015998080928008093),
#  ('gelatine', 0.00015946354633267326),
#  ('sealed', 0.0001593193795850671),
#  ('create', 0.0001592452071250328),
#  ('stand', 0.00015853369034047072),
#  ('covered.', 0.00015825188966046995),
#  ('extract,', 0.00015821958278799538),
#  ('temperature', 0.00015786921454792114),
#  ('creamy,', 0.0001577078481666396),
#  ('spices,', 0.0001568226667075895),
#  ('mixture,', 0.00015611806109184302),
#  ('thickly', 0.00015607719406883388),
#  ('briefly.', 0.00015547913873894541),
#  ('stage', 0.0001553287027560182),
#  ('rather', 0.00015527530540375499),
#  ('do', 0.00015522411363436166),
#  ('cheese', 0.00015514030960672276),
#  ('largest', 0.00015482090131607292),
#  ('cinnamon,', 0.00015462218825276254),
#  ('glue', 0.00015433845117554873),
#  ('35', 0.00015433637590598565),
#  ('sift', 0.00015385266550037535),
#  ('prepared', 0.0001530242039312971),
#  ('180c/fan', 0.00015243224711381496),
#  ('250g', 0.0001522601772686219),
#  ('3', 0.0001517601596093715),
#  ('tree,', 0.0001516749396256175),
#  ('fitted', 0.0001514438975266374),
#  ('flours', 0.00015114651565917807),
#  ('overhanging.', 0.00015113436482824783),
#  ('stretch', 0.0001510146312371589),
#  ('deep,', 0.00015100942673763022),
#  ('down,', 0.00015019278321971407),
#  ('170c/gas', 0.00015009614091054572),
#  ('halve', 0.00014944971531276118),
#  ('rise.', 0.00014907770715464702),
#  ('processer', 0.00012473892356559322),
#  ('40-45', 0.00012470288596353802),
#  ('frozen.', 0.0001240768618914532),
#  ('week.', 0.00012383968493196378),
#  ('christmas', 0.00012381963785332515),
#  ('salad.', 0.0001236293522052077),
#  ('cauliflower', 0.00012251203007362894),
#  ('left.', 0.00012238968153042954),
#  ('fairly', 0.00012236070858318357),
#  ('50g', 0.00012205772530582883),
#  ('ball', 0.00012183548464283799),
#  ('throw', 0.0001217368399481982),
#  ('a\xa0', 0.00012168483484150723),
#  ('pie.', 0.00012147744202494733),
#  ('somewhere', 0.0001214702733726772),
#  ('creamy', 0.00012081723395124296),
#  ('boil', 0.00012042170948155747),
#  ('crimp', 0.00011970144472113531),
#  ('lumps', 0.00011955984096498906),
#  ('edge,', 0.00011939886210835673),
#  ('melted,', 0.00011935817848915209),
#  ('ginger,', 0.00011925987484663625),
#  ('pushing', 0.00011886788132660219),
#  ('treacle,', 0.0001188526013492999),
#  ('dissolves,', 0.00011858213666207873),
#  ('preferably', 0.0001185233023227654),
#  ('hr', 0.00011823111021052314),
#  ('pear.', 0.00011822923240999351),
#  ('whatever', 0.00011822334170887288),
#  ('seven', 0.00011811623859533441),
#  ('log', 0.0001179361809150321),
#  ('them.', 0.00011775731428455515),
#  ('black', 0.00011767608824480891),
#  ('cutter', 0.00011760945443890626),
#  ('2-litre', 0.00011757475440643348),
#  ('soft,', 0.0001174856087749799),
#  ('empty', 0.00011731053810076574),
#  ('mouth.', 0.00011730524315745888),
#  ('clean', 0.00011720209511286877),
#  ('stars', 0.00011717040885831799),
#  ('beets', 0.00011688666503197214),
#  ('store,', 0.0001167256719272852),
#  ('box', 0.00011653635495401899),
#  ('soda', 0.00011630069188348495),
#  ('gold', 0.00011599247974418792),
#  ('rounds', 0.00011592319324314598),
#  ('crisp,', 0.000115909870524337),
#  ('circles,', 0.00011572969498163871),
#  ('wiggle', 0.00011555595006122326),
#  ('overhang.', 0.0001154828330813795),
#  ('snowy', 0.00011531846342907595),
#  ('granulated', 0.00011515309532533061),
#  ('teasing', 0.00011469666243072362),
#  ('paste.', 0.00011442716313460799),
#  ('amaretti', 0.00011428509024995244),
#  ('fully.', 0.00011405219909073184),
#  ('they’re', 0.00011403233255278705),
#  ('plates,', 0.00011393775761170218),
#  ('hang', 0.00011357918684749529),
#  ('defrost', 0.000113148958068346),
#  ('dough', 0.00011265165366534808),
#  ('other.', 0.0001125841949401309),
#  ('discarding', 0.00011235091180327852),
#  ('28cm', 0.00011203945576027878),
#  ('(keep', 0.00011198700680840426),
#  ('case.', 0.00011193073029138775),
#  ('central', 0.00011173606852388045),
#  ('leeks.', 0.00011170627052599424),
#  ('100g/4oz', 0.00011158892298482362),
#  ('cake,', 0.00011154747921820792),
#  ('secure', 0.00011154173539803001),
#  ('flaked', 0.00011148897270597139),
#  ('zests', 0.0001114670951746435),
#  ('20cm-deep', 0.00011139757938618309),
#  ('blitz', 0.00011129192721891631),
#  ('rack.', 0.00011119361422593202),
#  ('logs', 0.00011076775962667315),
