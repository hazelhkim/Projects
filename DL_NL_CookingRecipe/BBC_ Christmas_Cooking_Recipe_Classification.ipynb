# %% [markdown]
# **Importing the recipe data:**
#  the recipes.json data might be a JSON file dumped from MongoDB. It got an error "JSONDecoder error: Extra data: line 2 column 1" when I used normal json.loads method. The MongoDB JSON dump has one object per line. So the code below worked.

# %%
import json
data = [json.loads(line) for line in open('recipes.json', 'r')]

count = 0
count1 = 0
count2 = 0
expected_data =[]
for i in range(len(data)):
    if "cake" in data[i]['Name']:
        expected_data.append("Baked Good")
        count1 += 1
    elif "Cake" in data[i]['Name']:
        expected_data.append("Baked Good")
        count1 += 1
    elif "cookie" in data[i]['Name']:
        expected_data.append("Baked Good")
        count1 += 1
    elif "Cookie" in data[i]['Name']:
        expected_data.append("Baked Good")
        count1 += 1
    elif "pie" in data[i]['Name']:
        expected_data.append("Baked Good")
        count1 += 1
    elif "Pie" in data[i]['Name']:
        expected_data.append("Baked Good")
        count1 += 1
    elif "pudding" in data[i]['Name']:
        expected_data.append("Baked Good")
        count1 += 1
    elif "Pudding" in data[i]['Name']:
        expected_data.append("Baked Good")
        count1 += 1
    elif "brownie" in data[i]['Name']:
        expected_data.append("Baked Good")
        count1 += 1
    elif "biscuit" in data[i]['Name']:
        expected_data.append("Baked Good")
        count1 += 1
    elif "scone" in data[i]['Name']:
        expected_data.append("Baked Good")
        count1 += 1
    elif "muffin" in data[i]['Name']:
        expected_data.append("Baked Good")
        count1 += 1
    elif "tart" in data[i]['Name']:
        expected_data.append("Baked Good")
        count1 += 1
    elif "bread" in data[i]['Name']:
        expected_data.append("Baked Good")
        count1 += 1
    elif "Bread" in data[i]['Name']:
        expected_data.append("Baked Good")
        count1 += 1
    elif "roll" in data[i]['Name']:
        expected_data.append("Baked Good")
        count1 += 1
    else:
        expected_data.append("Other")
        count += 1
        print(data[i]['Name'])

print(count)
print(count1)
# Out:
# Christmas buns
# Christmas slaw
# Christmas mess
# Christmas cosmopolitan
# Christmas pizza
# Christmas poussin
# Mary Berry's Christmas chutney
# Gordon's Christmas roast goose
# Christmas spiced red cabbage
# Christmas cream liqueur
# Christmas pud ice cream
# Light & fruity Christmas pud
# Lamb with Christmas spices
# Christmas spiced friands
# Spiced & iced Christmas trees
# Granny Cook's Christmas pud
# Orange-stuffed Christmas duck
# Vegan Christmas wreath
# Christmas tree pops
# Little iced Christmas puds
# Christmas crumble friands
# Gravy for the Christmas turkey
# Christmas stollen with almonds & marzipan
# Black Forest Christmas fool
# Christmas white chocolate traybake
# Christmas spice latte
# Christmas spice buttercream
# Christmas lunch loaf
# Nutmeg & orange Christmas coffee
# Boozy Christmas bombe
# Lightly spiced Christmas stuffing
# Christmas tree crispy pops
# Easy Christmas turkey
# Christmas salad with goat's cheese
# Christmas sausage & veg tortilla
# Christmas ceviche with guacamole
# Cranberry Christmas rockies
# Fruity Christmas stuffing
# Crunchy Christmas crostini
# Christmas ham with sticky ginger glaze
# Spiced Christmas gammon with membrillo glaze
# Christmas pear & chocolate tiramisu trifle
# Christmas turkey with clementine & bay butter
# Chocolate sundaes with pear & Christmas pud
# Christmas salted caramel yule log
# Blitz-&-bake sticky toffee Christmas pud
# Mandarin-in-the-middle Christmas pud
# Christmas goose with root veg, sticky pears & bramble gravy
# Sweet chilli jam
# Beef Wellington
# Fruity biscotti
# Ultimate roast potatoes
# Salted caramel chocolate torte
# Apple & cranberry chutney
# Coffee semifreddo
# Nut roast
# Cola ham with maple & mustard glaze
# Spiced vegetable biryani
# Snowball cocktail
# Spiced beetroot & orange chutney
# Maple & mustard glazed ham
# Parmesan-roasted potatoes
# Melting middle truffles
# Roast turkey breast wrapped in bacon
# Easy cheese & onion slice
# Brandy syrup cream
# Glitz & glam bauble fancies
# Triple nut & apple stuffing balls
# Cranberry & marmalade sauce
# Spiced stollen plait
# Chocolate orange cocktail
# Ginger & orange-glazed baby carrots
# Crunchy peanut & toffee bonbons
# Mexican pork koftas
# Candy cane lollipops
# Whisky cream
# Toasted malt loaf with pressed ham terrine & spiced apple compote
# Alaskan yule log
# Roast turkey with lemon & garlic
# Really simple cranberry sauce
# Herb-scented slow-roasted rib of beef
# Perfect pancetta & roast shallot-stuffed turkey
# Singapore sling
# Classic nougat
# Pear & rose punch
# Gin-free G&T
# Perfect roast potatoes
# Sweet potato & parsnip bake
# Poached pears in spiced tea
# Raspberry ripple pavlova
# Venison sausage & chestnut casserole
# Beetroot shots with tarragon yogurt ice cubes
# Goat's cheese & onion pastries
# Home-churned butter
# Healthy gravy
# Clementine & Cointreau marmalade
# Hot chocolate milkshakes
# Chilli potato stack with squash & garlic butter sauce
# Microwave boozy fudge
# Spicy squash & apple chutney
# Winter slaw with warm celery seed dressing
# Right-every-time roasties
# Rosti-filled onions
# Spiced prawns with coriander mayo
# Aubergines filled with spinach & mushrooms
# Full English frittata
# Cranberry sunrise
# Winter leaf & parsnip salad with walnuts
# Poached pears in spiced red wine
# Roasted winter vegetables with smoked mayo
# Stuffed mushroom bruschettas
# Mustard-buttered chicken with tarragon, peas & carrots
# Exotic avocado salad
# Honey-roast carrots
# Rare beef with mustard Yorkshires
# Easy coq au vin
# Partridge with wine & cinnamon
# Bresaola with rocket & artichokes
# Blanquette of veal
# Pecan toffee meringue with mulled pears
# Potato, parsnip & horseradish baked rosti
# Grilled duck breast with minted peas
# One-pan English breakfast
# Warm stuffed avocados
# Lemony potato gratin
# Mulled wine kit
# Truffle-stuffed guinea fowl
# Butter bean pâté with melba toast
# Mushroom & olive tatins
# Moreish mocha profiteroles
# Melon granita
# Roast chicken with savoury sauce
# Hot spiced buttered rum
# Poule au pot with stuffing balls & garlic cream
# Chocolate & coffee truffle pots
# Low-fat roasties
# Roast pheasant with ricotta & Parma ham
# Boozy berry & elderflower trifle
# Mushroom & tarragon pâté
# Spicy prawn cocktail with tomato & coriander dressing
# Classic prawn cocktail
# Squash with rice, sage & goat's cheese
# Rustic chestnut stuffing
# Hash browns with mustard & smoked salmon
# Lemon meringue ice cream
# Salted almond brittle
# Bay & potato sticks
# Bloody Mary recipe
# Charred tomatoes
# Purple sprouting broccoli with garlic & sesame
# Tomato & pepper dip
# Flavoured butters
# Apricot stilton pots
# Classic vinaigrette
# Flavoured butters
# Crispy Roast Duck
# Smoked salmon kedgeree
# Spicy potted crab
# Sage and Onion Sauce
# 1193
# 424

# %%
count = Counter()
for i in range(len(data)):       
    if data[i]['Name'] != None:
        for word in data[i]['Name'].split(" "):
            count[word] += 1
count.most_common()
# Out:
# [('&', 616),
#  ('with', 321),
#  ('Christmas', 114),
#  ('cake', 101),
#  ('sauce', 64),
#  ('salad', 55),
#  ('cheese', 53),
#  ('turkey', 50),
#  ('roast', 49),
#  ('chocolate', 48),
#  ('cranberry', 47),
#  ('pudding', 43),
#  ('cream', 40),
#  ('stuffing', 39),
#  ('Chocolate', 36),
#  ('potato', 36),
#  ('salmon', 36),
#  ('cabbage', 35),
#  ('pie', 33),
#  ('pies', 33),
#  ('Cranberry', 32),
#  ('red', 31),
#  ('potatoes', 31),
#  ('apple', 31),
#  ('Spiced', 28),
#  ('ham', 28),
#  ('mince', 27),
#  ('wine', 27),
#  ('butter', 26),
#  ('orange', 25),
#  ('Sticky', 25),
#  ('sprouts', 25),
#  ('Mini', 24),
#  ('tart', 24),
#  ('Roast', 24),
#  ('spiced', 23),
#  ('ginger', 23),
#  ('bacon', 23),
#  ('onion', 23),
#  ('gravy', 22),
#  ('Smoked', 22),
#  ('in', 21),
#  ('Creamy', 21),
#  ('soup', 21),
#  ('pork', 20),
#  ('chestnut', 20),
#  ('bread', 19),
#  ('mushroom', 18),
#  ('cakes', 17),
#  ('mustard', 17),
#  ('carrots', 17),
#  ('ice', 16),
#  ('pancetta', 16),
#  ('parsnip', 16),
#  ('dressing', 16),
#  ('gratin', 16),
#  ('chutney', 15),
#  ('trifle', 15),
#  ('pear', 15),
#  ('fruit', 15),
#  ('cocktail', 15),
#  ('Gingerbread', 15),
#  ('of', 15),
#  ('squash', 15),
#  ('sage', 15),
#  ('Festive', 15),
#  ('smoked', 15),
#  ('mincemeat', 15),
#  ('Easy', 14),
#  ('biscuits', 14),
#  ('clementine', 14),
#  ('beef', 14),
#  ('Winter', 14),
#  ('chicken', 14),
#  ('Mulled', 14),
#  ('Red', 14),
#  ('Brussels', 14),
#  ('wreath', 13),
#  ('nut', 13),
#  ('chilli', 13),
#  ('syrup', 13),
#  ('Baked', 13),
#  ('cheesecake', 12),
#  ('Classic', 12),
#  ('pud', 12),
#  ('garlic', 12),
#  ('pecan', 12),
#  ('Vegan', 12),
#  ('crumble', 12),
#  ('sausage', 12),
#  ('Crunchy', 12),
#  ('hazelnut', 12),
#  ('coconut', 12),
#  ('roasties', 12),
#  ('Turkey', 12),
#  ('meringue', 12),
#  ('rice', 12),
#  ('almond', 11),
#  ('loaf', 11),
#  ('Sweet', 11),
#  ('beetroot', 11),
#  ('lemon', 11),
#  ('bake', 11),
#  ('seed', 11),
#  ('kit', 11),
#  ('onions', 11),
#  ('dip', 11),
#  ('cupcakes', 10),
#  ('spice', 10),
#  ('puddings', 10),
#  ('tree', 10),
#  ('duck', 10),
#  ('sticky', 10),
#  ('caramel', 10),
#  ('pears', 10),
#  ('truffles', 10),
#  ('star', 10),
#  ('spinach', 10),
#  ('celeriac', 10),
#  ('apples', 10),
#  ('truffle', 10),
#  ('honey', 9),
#  ('Hot', 9),
#  ('leek', 9),
#  ('terrine', 9),
#  ('pancakes', 9),
#  ('blue', 9),
#  ('wild', 9),
#  ('baked', 9),
#  ('sprout', 9),
#  ('Orange', 9),
#  ('cookies', 8),
#  ('goose', 8),
#  ('marzipan', 8),
#  ('log', 8),
#  ('White', 8),
#  ('root', 8),
#  ('Stollen', 8),
#  ('slice', 8),
#  ('pomegranate', 8),
#  ('rosemary', 8),
#  ('rolls', 8),
#  ('Ham', 8),
#  ('Spicy', 8),
#  ('Clementine', 8),
#  ('bites', 8),
#  ('Roasted', 8),
#  ('skewers', 8),
#  ('mulled', 8),
#  ('crème', 8),
#  ('custard', 8),
#  ('vegetables', 8),
#  ('Lemon', 8),
#  ('Beetroot', 8),
#  ('walnuts', 8),
#  ('walnut', 8),
#  ('horseradish', 8),
#  ('shallots', 8),
#  ('bombe', 7),
#  ("goat's", 7),
#  ('toffee', 7),
#  ('Ginger', 7),
#  ('Wellington', 7),
#  ('Salted', 7),
#  ('torte', 7),
#  ('toast', 7),
#  ('camembert', 7),
#  ('Chestnut', 7),
#  ('mash', 7),
#  ('Port', 7),
#  ('mango', 7),
#  ('cups', 7),
#  ('Crispy', 7),
#  ('stuffed', 7),
#  ('parsnips', 7),
#  ('lime', 7),
#  ('thyme', 7),
#  ('Duck', 7),
#  ('chorizo', 7),
#  ('feta', 7),
#  ('Apricot', 7),
#  ('fennel', 7),
#  ('liver', 7),
#  ('squeak', 7),
#  ('carrot', 7),
#  ('roasted', 7),
#  ('pâté', 7),
#  ('cinnamon', 7),
#  ('brownies', 6),
#  ('vanilla', 6),
#  ('Buttered', 6),
#  ('Little', 6),
#  ('cherry', 6),
#  ('almonds', 6),
#  ('Black', 6),
#  ('white', 6),
#  ('gingerbread', 6),
#  ('coffee', 6),
#  ('crispy', 6),
#  ('easy', 6),
#  ('jam', 6),
#  ('Mince', 6),
#  ('Apple', 6),
#  ('Simple', 6),
#  ('maple', 6),
#  ('muffins', 6),
#  ('Triple', 6),
#  ('marmalade', 6),
#  ('baby', 6),
#  ('roll', 6),
#  ('fruitcake', 6),
#  ('fudge', 6),
#  ('chestnuts', 6),
#  ('Coconut', 6),
#  ('sesame', 6),
#  ('mint', 6),
#  ('poppy', 6),
#  ('jelly', 6),
#  ('crown', 6),
#  ('Herby', 6),
#  ('apricot', 6),
#  ('prawns', 6),
#  ('cider', 6),
#  ('raspberry', 6),
#  ('cauliflower', 6),
#  ('Chicken', 6),
#  ('Slow', 6),
#  ('dippers', 6),
#  ('roulade', 6),
#  ('relish', 6),
#  ('Peppermint', 6),
#  ('shallot', 6),
#  ('stilton', 6),
#  ('Cauliflower', 6),
#  ('Caramelised', 6),
#  ('nuts', 6),
#  ('herby', 6),
#  ('parcels', 6),
#  ('peas', 6),
#  ('date', 6),
#  ('toasts', 6),
#  ('bean', 6),
#  ('buns', 5),
#  ('Iced', 5),
#  ('rum', 5),
#  ('Golden', 5),
#  ('Fruity', 5),
#  ('Chocolate,', 5),
#  ('glaze', 5),
#  ('gammon', 5),
#  ('Beef', 5),
#  ('vegetable', 5),
#  ('glazed', 5),
#  ('Cheeseboard', 5),
#  ('Brandy', 5),
#  ('peanut', 5),
#  ('Really', 5),
#  ('prosciutto', 5),
#  ('Pecan', 5),
#  ('braised', 5),
#  ('Mincemeat', 5),
#  ('crunch', 5),
#  ('olive', 5),
#  ('sweet', 5),
#  ('goat’s', 5),
#  ('Braised', 5),
#  ('Thai', 5),
#  ('brioche', 5),
#  ('fraîche', 5),
#  ('dill', 5),
#  ('winter', 5),
#  ('Quick', 5),
#  ('kale', 5),
#  ('Glazed', 5),
#  ('Jewelled', 5),
#  ('panettone', 5),
#  ('berry', 5),
#  ('pickled', 5),
#  ('Sausage', 5),
#  ('parfait', 5),
#  ('Mont', 5),
#  ('Passion', 5),
#  ('tarts', 5),
#  ('fizz', 5),
#  ('risotto', 5),
#  ('green', 5),
#  ('treacle', 5),
#  ('pine', 5),
#  ('cucumber', 5),
#  ('Spinach', 5),
#  ('Prawn', 5),
#  ('sorbet', 5),
#  ('Mushroom', 5),
#  ('roots', 5),
#  ('Stuffed', 5),
#  ('punch', 5),
#  ('pots', 5),
#  ('spring', 5),
#  ('platter', 5),
#  ('and', 5),
#  ('slaw', 4),
#  ('Sparkling', 4),
#  ('citrus', 4),
#  ('Fig', 4),
#  ('saffron', 4),
#  ('pops', 4),
#  ('Lamb', 4),
#  ('Cherry', 4),
#  ('Rudolph', 4),
#  ('forest', 4),
#  ('traybake', 4),
#  ('Boozy', 4),
#  ('veg', 4),
#  ('brownie', 4),
#  ('Chunky', 4),
#  ('Coffee', 4),
#  ('Maple', 4),
#  ('balls', 4),
#  ('Whisky', 4),
#  ('compote', 4),
#  ('Sprouts', 4),
#  ('shortbread', 4),
#  ('avocado', 4),
#  ('pastry', 4),
#  ('blankets', 4),
#  ('Creamed', 4),
#  ('Sugar-dusted', 4),
#  ('hot', 4),
#  ('Chorizo', 4),
#  ('Pineapple', 4),
#  ('Caramel', 4),
#  ('Homemade', 4),
#  ('Bread', 4),
#  ('fritters', 4),
#  ('wings', 4),
#  ('Mustard', 4),
#  ('Hazelnut', 4),
#  ('eggs', 4),
#  ('Parsnip', 4),
#  ('martini', 4),
#  ('cookie', 4),
#  ('tomato', 4),
#  ('Celeriac', 4),
#  ('sour', 4),
#  ('Eccles', 4),
#  ('Truffled', 4),
#  ('vodka', 4),
#  ('recipe', 4),
#  ('Bramley', 4),
#  ('Raspberry', 4),
#  ('Pork', 4),
#  ('parsley', 4),
#  ('Double', 4),
#  ('Butternut', 4),
#  ('brie', 4),
#  ('tarragon', 4),
#  ('Cranberry,', 4),
#  ('curry', 4),
#  ('mushrooms', 4),
#  ('pistachio', 4),
#  ('Reindeer', 4),
#  ('greens', 4),
#  ('cooker', 4),
#  ('pineapple', 4),
#  ('bark', 4),
#  ('Turkish', 4),
#  ('tea', 4),
#  ('party', 4),
#  ('squares', 4),
#  ('anise', 4),
#  ('yogurt', 4),
#  ('port', 4),
#  ('Pickled', 4),
#  ('Squash', 4),
#  ('Wild', 4),
#  ('Salmon', 4),
#  ('caramelised', 4),
#  ('leeks', 4),
#  ('hash', 4),
#  ('Sprout', 4),
#  ('Snowman', 4),
#  ('candied', 4),
#  ('pepper', 4),
#  ('raisin', 4),
#  ('lentil', 4),
#  ('candy', 4),
#  ('Bubble', 4),
#  ('scallops', 4),
#  ('coriander', 4),
#  ('juniper', 4),
#  ('Savoy', 4),
#  ('passion', 4),
#  ('crab', 4),
#  ('prawn', 4),
#  ('fresh', 4),
#  ('fish', 4),
#  ('boozy', 4),
#  ('toasted', 4),
#  ('Cheese', 4),
#  ('chicory', 4),
#  ('beans', 4),
#  ('twists', 4),
#  ('Warm', 4),
#  ('loin', 4),
#  ('Grilled', 4),
#  ('Mary', 3),
#  ('strudel', 3),
#  ('mousse', 3),
#  ('amaretti', 3),
#  ('iced', 3),
#  ('trees', 3),
#  ('soufflés', 3),
#  ('stollen', 3),
#  ('Forest', 3),
#  ('a', 3),
#  ('crostini', 3),
#  ('yule', 3),
#  ('Ho,', 3),
#  ('Ultimate', 3),
#  ('Pistachio', 3),
#  ('semifreddo', 3),
#  ('Snowball', 3),
#  ('Ham,', 3),
#  ('Panettone', 3),
#  ('Melting', 3),
#  ('breast', 3),
#  ('wrapped', 3),
#  ('bauble', 3),
#  ('de', 3),
#  ('milk', 3),
#  ('Pomegranate', 3),
#  ('Chestnut,', 3),
#  ('snowflake', 3),
#  ('Persian', 3),
#  ('fondue', 3),
#  ('pot', 3),
#  ('St', 3),
#  ('butternut', 3),
#  ('bundt', 3),
#  ('Lobster', 3),
#  ('remoulade', 3),
#  ('stacks', 3),
#  ('biscuit', 3),
#  ('Chicory', 3),
#  ('ricotta', 3),
#  ('thins', 3),
#  ('venison', 3),
#  ('chipolatas', 3),
#  ('French', 3),
#  ('soufflé', 3),
#  ('fig', 3),
#  ('Turkey,', 3),
#  ('fillet', 3),
#  ('Baileys', 3),
#  ('Salmon,', 3),
#  ('cranberries', 3),
#  ('crisp', 3),
#  ('tatin', 3),
#  ('Slow-cooked', 3),
#  ('Dauphinoise', 3),
#  ('Buttery', 3),
#  ('caraway', 3),
#  ('Polenta', 3),
#  ('pilaf', 3),
#  ('tagine', 3),
#  ('warm', 3),
#  ('Make-ahead', 3),
#  ('English', 3),
#  ('blinis', 3),
#  ('Healthy', 3),
#  ('pigs', 3),
#  ('lamb', 3),
#  ('filled', 3),
#  ('creams', 3),
#  ('Sloe', 3),
#  ('Fresh', 3),
#  ('mayo', 3),
#  ('Boxing', 3),
#  ('Day', 3),
#  ('scones', 3),
#  ('oatcakes', 3),
#  ('ripple', 3),
#  ('gin', 3),
#  ('Carrot', 3),
#  ('purée', 3),
#  ('celery', 3),
#  ('Venison', 3),
#  ('spicy', 3),
#  ('Chilli', 3),
#  ('raisins', 3),
#  ('Parmesan', 3),
#  ('bruschetta', 3),
#  ('delight', 3),
#  ('stars', 3),
#  ('on', 3),
#  ('sugar', 3),
#  ('sharing', 3),
#  ('bubble', 3),
#  ('decoration', 3),
#  ('Mashed', 3),
#  ('leaf', 3),
#  ('snowman', 3),
#  ('slices', 3),
#  ('Bay', 3),
#  ('Cointreau', 3),
#  ('Stir-fried', 3),
#  ('Poached', 3),
#  ('Pear', 3),
#  ('prunes', 3),
#  ('Giant', 3),
#  ('palmiers', 3),
#  ('confit', 3),
#  ('tartlets', 3),
#  ('Yorkies', 3),
#  ('rose', 3),
#  ('Irish', 3),
#  ('Brown', 3),
#  ('black', 3),
#  ('herb', 3),
#  ('madeira', 3),
#  ('pheasant', 3),
#  ('sticks', 3),
#  ('Cheesy', 3),
#  ('chips', 3),
#  ('rye', 3),
#  ('croutons', 3),
#  ('artichokes', 3),
#  ('Charred', 3),
#  ('Crab', 3),
#  ('Gratin', 3),
#  ('layer', 3),
#  ('plum', 3),
#  ('egg', 3),
#  ('shoulder', 3),
#  ('muffin', 2),
#  ('mix', 2),
#  ('Gingery', 2),
#  ('Honey', 2),
#  ('Granny', 2),
#  ('fruity', 2),
#  ('friands', 2),
#  ('morning', 2),
#  ("Mum's", 2),
#  ('for', 2),
#  ('the', 2),
#  ('fool', 2),
#  ('penguins', 2),
#  ('Last-minute', 2),
#  ('tortilla', 2),
#  ('lollipops', 2),
#  ('Cake', 2),
#  ('membrillo', 2),
#  ('tiramisu', 2),
#  ('match', 2),
#  ('mini', 2),
#  ('salted', 2),
#  ('biscotti', 2),
#  ('ciabatta', 2),
#  ('Moroccan', 2),
#  ('man', 2),
#  ('holly', 2),
#  ('fancies', 2),
#  ('peppermint', 2),
#  ('Mexican', 2),
#  ('cane', 2),
#  ('simple', 2),
#  ('rib', 2),
#  ('Perfect', 2),
#  ('Vanilla', 2),
#  ('dough', 2),
#  ('toddy', 2),
#  ('crumbs', 2),
#  ('chip', 2),
#  ('Eggnog', 2),
#  ('Rocky', 2),
#  ('Bûche', 2),
#  ('Noël', 2),
#  ('spritzer', 2),
#  ('Stuffing', 2),
#  ('Fragrant', 2),
#  ('Sausage,', 2),
#  ('en', 2),
#  ('croûte', 2),
#  ('Zesty', 2),
#  ('American', 2),
#  ('Parsnip,', 2),
#  ('Pavlova', 2),
#  ('prawns,', 2),
#  ('chillies', 2),
#  ('Chelsea', 2),
#  ('satay', 2),
#  ('Potted', 2),
#  ('nutmeg', 2),
#  ('poached', 2),
#  ('hollandaise', 2),
#  ('people', 2),
#  ('doughnuts', 2),
#  ('croquettes', 2),
#  ('juice', 2),
#  ('Bellini', 2),
#  ('Deep-fried', 2),
#  ('guinea', 2),
#  ('fowl', 2),
#  ('Fruitcake', 2),
#  ('icing', 2),
#  ('Goat’s', 2),
#  ('spirals', 2),
#  ('Mincemeat,', 2),
#  ('cardamom', 2),
#  ('stem', 2),
#  ('banana', 2),
#  ('Sherried', 2),
#  ('beer', 2),
#  ('Limoncello', 2),
#  ('food', 2),
#  ('pistachios', 2),
#  ('barley', 2),
#  ('Traditional', 2),
#  ('Squidgy', 2),
#  ('legs', 2),
#  ('straws', 2),
#  ('Wellingtons', 2),
#  ('pesto', 2),
#  ('Deep-filled', 2),
#  ('nougat', 2),
#  ('profiteroles', 2),
#  ('Star', 2),
#  ('sparkle', 2),
#  ('Full', 2),
#  ('twist', 2),
#  ('hock', 2),
#  ('mackerel', 2),
#  ('pink', 2),
#  ('Leftover', 2),
#  ('casserole', 2),
#  ('Sourdough', 2),
#  ('Cauliflower,', 2),
#  ('Honey-roast', 2),
#  ('Smashed', 2),
#  ('fruit,', 2),
#  ('flatbread', 2),
#  ('Gravadlax', 2),
#  ('marshmallow', 2),
#  ('Perky', 2),
#  ('Blanc', 2),
#  ('Faux', 2),
#  ('salsa', 2),
#  ('peppercorn', 2),
#  ('rillettes', 2),
#  ('dates', 2),
#  ('Brie', 2),
#  ('cottage', 2),
#  ('choc', 2),
#  ('Orange,', 2),
#  ('belly', 2),
#  ('chunks', 2),
#  ('Baby', 2),
#  ('Freeze-ahead', 2),
#  ('Stilton', 2),
#  ('rösti', 2),
#  ('Yule', 2),
#  ('Aubergine', 2),
#  ('hotpot', 2),
#  ('Honey-roasted', 2),
#  ('carbonara', 2),
#  ('Salt', 2),
#  ('Rum', 2),
#  ('prune', 2),
#  ('All-the-trimmings', 2),
#  ('turkey,', 2),
#  ('Lime', 2),
#  ('dhal', 2),
#  ('stirrers', 2),
#  ('fridge', 2),
#  ('Artichoke', 2),
#  ('Clementine,', 2),
#  ('Hasselback', 2),
#  ('Bitter', 2),
#  ('Chinese', 2),
#  ('Fennel', 2),
#  ('pumpkin', 2),
#  ('Cinnamon', 2),
#  ('Bacon', 2),
#  ('rice,', 2),
#  ('ice-cream', 2),
#  ('make-ahead', 2),
#  ('Marzipan', 2),
#  ('Seared', 2),
#  ('Pear,', 2),
#  ('falafel', 2),
#  ('Silky', 2),
#  ("Santa's", 2),
#  ('samosas', 2),
#  ('Alaska', 2),
#  ('haddock', 2),
#  ('kedgeree', 2),
#  ('breeze', 2),
#  ('sponge', 2),
#  ('festive', 2),
#  ('spuds', 2),
#  ('paprika', 2),
#  ('sea', 2),
#  ('Walnut', 2),
#  ('Marmalade', 2),
#  ('From-the-freezer', 2),
#  ('Chestnuts', 2),
#  ('minty', 2),
#  ('crackers', 2),
#  ('Microwave', 2),
#  ('Butternut,', 2),
#  ('pavlova', 2),
#  ('’n’', 2),
#  ('vinaigrette', 2),
#  ('Bloody', 2),
#  ('cheddar', 2),
#  ('toastie', 2),
#  ('courgettes', 2),
#  ('fondant', 2),
#  ('Rudolph’s', 2),
#  ('Prosecco', 2),
#  ('Dark', 2),
#  ('Honeyed', 2),
#  ('sandwiches', 2),
#  ('Partridge', 2),
#  ('Root', 2),
#  ('apricots', 2),
#  ('mocktail', 2),
#  ('snowball', 2),
#  ('Oysters', 2),
#  ('meringues', 2),
#  ('Green', 2),
#  ('potted', 2),
#  ('pecans', 2),
#  ('Potato', 2),
#  ('leaves', 2),
#  ('maple-glazed', 2),
#  ('Clotted', 2),
#  ('Prosciutto', 2),
#  ('Griddled', 2),
#  ('hazelnuts', 2),
#  ('elderflower', 2),
#  ('Jerusalem', 2),
#  ('artichoke', 2),
#  ('polenta', 2),
#  ('quince', 2),
#  ('Sautéed', 2),
#  ('Tropical', 2),
#  ('Blancs', 2),
#  ('Korean', 2),
#  ('shots', 2),
#  ('salt', 2),
#  ('sliders', 2),
#  ('pasta', 2),
#  ('Crisp', 2),
#  ('Brie,', 2),
#  ('quiche', 2),
#  ('crust', 2),
#  ('Next', 2),
#  ('level', 2),
#  ('salmon,', 2),
#  ('beetroot,', 2),
#  ('cured', 2),
#  ('crackling', 2),
#  ('burgers', 2),
#  ('cocktails', 2),
#  ('Nutty', 2),
#  ('Rhubarb', 2),
#  ('tatins', 2),
#  ('Jaffa', 2),
#  ('Choc', 2),
#  ('colada', 2),
#  ('filo', 2),
#  ('celeriac,', 2),
#  ('Yogurt', 2),
#  ('vinegar', 2),
#  ('Herb', 2),
#  ("Goat's", 2),
#  ('browns', 2),
#  ('Sesame', 2),
#  ('broccoli', 2),
#  ('creamy', 2),
#  ('Asian', 2),
#  ('tzatziki', 2),
#  ('Redcurrant', 2),
#  ('au', 2),
#  ('Flavoured', 2),
#  ('butters', 2),
#  ('Simmer-&-stir', 1),
#  ('mess', 1),
#  ('cosmopolitan', 1),
#  ('pizza', 1),
#  ('poussin', 1),
#  ("Berry's", 1),
#  ('Make', 1),
#  ('mature', 1),
#  ('Angela', 1),
#  ("Nilsen's", 1),
#  ("Gordon's", 1),
#  ('Sherry', 1),
#  ('liqueur', 1),
#  ("Martin's", 1),
#  ('Individual', 1),
#  ('little', 1),
#  ('Light', 1),
#  ('Christmas-pudding', 1),
#  ('Figgy', 1),
#  ("Chocoholic's", 1),
#  ('spices', 1),
#  ('frosty', 1),
#  ('Suits-all', 1),
#  ('Cupcake', 1),
#  ("Cook's", 1),
#  ('Nancy’s', 1),
#  ('Orange-stuffed', 1),
#  ('puds', 1),
#  ('Gravy', 1),
#  ('Enchanted', 1),
#  ('latte', 1),
#  ('buttercream', 1),
#  ('lunch', 1),
#  ('Nutmeg', 1),
#  ('jar', 1),
#  ('Isaac', 1),
#  ("Scout's", 1),
#  ('Lightly', 1),
#  ('Tutti', 1),
#  ('frutti', 1),
#  ('ceviche', 1),
#  ('guacamole', 1),
#  ('rockies', 1),
#  ('Unbelievably', 1),
#  ('Fruit', 1),
#  ('Rice', 1),
#  ('Krispie', 1),
#  ('Snowy', 1),
#  ('owl', 1),
#  ('Orlando', 1),
#  ("Murrin's", 1),
#  ('Deluxe', 1),
#  ('Let-it-glow', 1),
#  ('bay', 1),
#  ('Pure', 1),
#  ('gold', 1),
#  ('drip', 1),
#  ('sundaes', 1),
#  ('Mix', 1),
#  ('As-you-like-it', 1),
#  ('Blitz-&-bake', 1),
#  ('Mandarin-in-the-middle', 1),
#  ('chocolate,', 1),
#  ('Merry', 1),
#  ('veg,', 1),
#  ('bramble', 1),
#  ('Malt', 1),
#  ('clotted', 1),
#  ('house', 1),
#  ('Nut', 1),
#  ('Cola', 1),
#  ('biryani', 1),
#  ('Parmesan-roasted', 1),
#  ('middle', 1),
#  ('Glitz', 1),
#  ('glam', 1),
#  ('plait', 1),
#  ('shooting', 1),
#  ('orange-glazed', 1),
#  ('bacon-wrapped', 1),
#  ('breadsticks', 1),
#  ('bonbons', 1),
#  ('koftas', 1),
#  ('Candy', 1),
#  ('Toasted', 1),
#  ('malt', 1),
#  ('pressed', 1),
#  ('Mississippi', 1),
#  ('mud', 1),
#  ('Alaskan', 1),
#  ('Herb-scented', 1),
#  ('slow-roasted', 1),
#  ('shallot-stuffed', 1),
#  ('terrines', 1),
#  ('buttery', 1),
#  ('robin', 1),
#  ('Pigs', 1),
#  ('puff', 1),
#  ('bottle', 1),
#  ('Burnt', 1),
#  ('sours', 1),
#  ('Scallop', 1),
#  ('baubles', 1),
#  ('Lebkuchen', 1),
#  ('Snow', 1),
#  ('globe', 1),
#  ('Macadamia', 1),
#  ('velvet', 1),
#  ('Melty', 1),
#  ('Mulling', 1),
#  ('Lucia', 1),
#  ('croquetas', 1),
#  ('Corn', 1),
#  ('Marzipan-in-the-middle', 1),
#  ('fajitas', 1),
#  ('crumpets', 1),
#  ('burnt', 1),
#  ('Magical', 1),
#  ('reindeer', 1),
#  ('three-bird', 1),
#  ('oatmeal', 1),
#  ('rillette', 1),
#  ('Rich', 1),
#  ('slashed', 1),
#  ('butter-basted', 1),
#  ('egg,', 1),
#  ('caviar,', 1),
#  ('watercress', 1),
#  ('Cashew', 1),
#  ('caramels', 1),
#  ('ramen', 1),
#  ('Sunday', 1),
#  ('elf', 1),
#  ('Panforte', 1),
#  ('Yummy', 1),
#  ('Naan,', 1),
#  ('halloumi', 1),
#  ('Reverse', 1),
#  ('espresso', 1),
#  ('olives', 1),
#  ('chestnut,', 1),
#  ('gnocchi,', 1),
#  ('sundried', 1),
#  ('arancello', 1),
#  ('set', 1),
#  ('Favourite', 1),
#  ('tapenade', 1),
#  ('lattice', 1),
#  ('Sugar', 1),
#  ('charms', 1),
#  ('whiskey', 1),
#  ('croque', 1),
#  ('monsieurs', 1),
#  ('coulibiac', 1),
#  ('Raymond’s', 1),
#  ('Spanish', 1),
#  ('blueberry', 1),
#  ('dogs', 1),
#  ('Pancetta', 1),
#  ('sage-wrapped', 1),
#  ('maple-roasted', 1),
#  ('Brioche', 1),
#  ('bacon,', 1),
#  ('Comté', 1),
#  ('tangerine', 1),
#  ('Florentines', 1),
#  ('Pineapple,', 1),
#  ('Eggs', 1),
#  ('Benedict', 1),
#  ('chives', 1),
#  ('mango,', 1),
#  ('Coconut,', 1),
#  ('Ponche', 1),
#  ('stained', 1),
#  ('glass', 1),
#  ('meatloaf', 1),
#  ('Pea', 1),
#  ('Shortbread', 1),
#  ('trifles', 1),
#  ('semi-freddo', 1),
#  ('Snow-topped', 1),
#  ('Devil’s', 1),
#  ('Date', 1),
#  ('Millionaire’s', 1),
#  ('Layered', 1),
#  ('squash,', 1),
#  ('Potage', 1),
#  ('Dubarry', 1),
#  ('(Creamy', 1),
#  ('soup)', 1),
#  ('Olive', 1),
#  ('oil-baked', 1),
#  ('cranachan', 1),
#  ('jalousie', 1),
#  ('cobbler', 1),
#  ('marbled', 1),
#  ('tarte', 1),
#  ('Mint', 1),
#  ('bacon-basted', 1),
#  ('Trifle', 1),
#  ('Sparkly', 1),
#  ('Midwinter', 1),
#  ('candle', 1),
#  ('Decadent', 1),
#  ('snowfetti', 1),
#  ('marsala', 1),
#  ('bunting', 1),
#  ('Sandham', 1),
#  ('family', 1),
#  ('smoothie', 1),
#  ('ivy', 1),
#  ('Sage,', 1),
#  ('Open', 1),
#  ...]

# %% [markdown]
# The recipes are categorized into: pie, cake/cupcake/pancake, cookies, biscuits, rolls, scones, (possibly) brownies and tarts.

# %%
from collections import Counter
import numpy as np

baked_ingredients = Counter()
total_ingredients = Counter()
for i in range(len(data)):
    if expected_data[i] == "Baked Good":
        for j in range(len(data[i]['Ingredients'])):       
            if data[i]['Ingredients'] != None:
                for word in data[i]['Ingredients'][j].split(" "):
                    baked_ingredients[word] += 1
                    total_ingredients[word] += 1
                
baked_ingredients.most_common()
# Out:
# [('1', 832),
#  ('tbsp', 527),
#  ('tsp', 517),
#  ('2', 476),
#  ('sugar', 400),
#  ('100g', 353),
#  ('for', 331),
#  ('chopped', 282),
#  ('and', 281),
#  ('plus', 279),
#  ('200g', 239),
#  ('50g', 236),
#  ('butter,', 225),
#  ('extra', 225),
#  ('flour', 221),
#  ('icing', 219),
#  ('ground', 211),
#  ('3', 200),
#  ('plain', 195),
#  ('caster', 182),
#  ('or', 180),
#  ('to', 176),
#  ('of', 169),
#  ('4', 169),
#  ('large', 166),
#  ('white', 158),
#  ('½', 155),
#  ('mixed', 152),
#  ('golden', 151),
#  ('a', 147),
#  ('140g', 137),
#  ('finely', 135),
#  ('beaten', 127),
#  ('butter', 126),
#  ('dark', 126),
#  ('zest', 124),
#  ('small', 124),
#  ('cream', 123),
#  ('dusting', 122),
#  ('85g', 118),
#  ('dried', 118),
#  ('250g', 117),
#  ('sugar,', 116),
#  ('grated', 115),
#  ('pack', 115),
#  ('into', 113),
#  ('milk', 110),
#  ('orange', 108),
#  ('175g', 103),
#  ('greasing', 97),
#  ('the', 97),
#  ('muscovado', 96),
#  ('juice', 95),
#  ('eggs', 95),
#  ('egg', 95),
#  ('500g', 90),
#  ('powder', 90),
#  ('vanilla', 90),
#  ('300g', 87),
#  ('light', 87),
#  ('cinnamon', 86),
#  ('25g', 85),
#  ('double', 83),
#  ('flour,', 82),
#  ('self-raising', 80),
#  ('eggs,', 79),
#  ('soft', 72),
#  ('baking', 70),
#  ('ginger', 70),
#  ('roughly', 70),
#  ('extract', 70),
#  ('serve', 70),
#  ('chocolate', 69),
#  ('spice', 67),
#  ('unsalted', 66),
#  ('cut', 66),
#  ('fresh', 64),
#  ('softened', 64),
#  ('brown', 64),
#  ('225g', 63),
#  ('syrup', 63),
#  ('sliced', 60),
#  ('lemon', 59),
#  ('egg,', 59),
#  ('almond', 58),
#  ('6', 58),
#  ('whole', 58),
#  ('used', 56),
#  ('oil', 54),
#  ('x', 54),
#  ('little', 54),
#  ('leaves', 54),
#  ('400g', 53),
#  ('pastry', 51),
#  ('100ml', 49),
#  ('(optional)', 49),
#  ('olive', 48),
#  ('red', 48),
#  ('150g', 47),
#  ('chocolate,', 47),
#  ('oil,', 47),
#  ('black', 43),
#  ('5', 43),
#  ('medium', 42),
#  ('glacé', 41),
#  ('with', 41),
#  ('almonds', 40),
#  ('cocoa', 40),
#  ('150ml', 40),
#  ('75g', 40),
#  ('brandy', 39),
#  ('¼', 39),
#  ('bicarbonate', 39),
#  ('pinch', 39),
#  ('pot', 38),
#  ('cloves', 38),
#  ('soda', 38),
#  ('melted', 38),
#  ('pieces', 37),
#  ('nutmeg', 36),
#  ('decorate', 36),
#  ('from', 36),
#  ('apricot', 36),
#  ('diced', 36),
#  ('green', 35),
#  ('onion,', 34),
#  ('edible', 34),
#  ('in', 34),
#  ('halved', 34),
#  ('chunks', 34),
#  ('350g', 32),
#  ('peeled', 31),
#  ('1½', 31),
#  ('few', 30),
#  ('375g', 30),
#  ('handful', 30),
#  ('full-fat', 30),
#  ('cake', 30),
#  ('ready-to-roll', 30),
#  ('fondant', 29),
#  ('silver', 29),
#  ('food', 29),
#  ('if', 29),
#  ('about', 29),
#  ('marzipan', 29),
#  ('garlic', 29),
#  ('mincemeat', 29),
#  ('fruit', 28),
#  ('peel', 28),
#  ('sifted', 28),
#  ('softened,', 28),
#  ('cheese', 28),
#  ('cranberries', 28),
#  ('bay', 28),
#  ('broken', 27),
#  ('200ml', 27),
#  ('jar', 27),
#  ('thyme', 26),
#  ('125g', 26),
#  ('salted', 26),
#  ('300ml', 26),
#  ('puff', 26),
#  ('crushed', 25),
#  ('flaked', 25),
#  ('jam', 25),
#  ('frozen', 24),
#  ('you', 24),
#  ('(we', 24),
#  ('seeds', 24),
#  ('toasted', 24),
#  ('can', 24),
#  ('stem', 24),
#  ('(see', 24),
#  ('750g', 23),
#  ('very', 23),
#  ('natural', 23),
#  ('Christmas', 23),
#  ('each', 23),
#  ('8', 23),
#  ('shortcrust', 22),
#  ('maple', 22),
#  ('rum', 22),
#  ('coconut', 22),
#  ('gold', 21),
#  ('blanched', 21),
#  ('well', 21),
#  ('room', 21),
#  ('orange,', 21),
#  ('12', 21),
#  ('50ml', 21),
#  ('cold', 21),
#  ('sunflower', 21),
#  ('breadcrumbs', 20),
#  ('lightly', 20),
#  ('ready-rolled', 20),
#  ('colouring', 20),
#  ('tin', 20),
#  ('use', 20),
#  ('bunch', 20),
#  ('water', 20),
#  ('wine', 20),
#  ('cranberry', 20),
#  ('balls', 19),
#  ('raisins', 19),
#  ('salt', 19),
#  ('tub', 19),
#  ('rolling', 19),
#  ('at', 18),
#  ('cubes', 18),
#  ('ribbon', 18),
#  ('sultanas', 18),
#  ('zested', 18),
#  ('450g', 18),
#  ('mini', 18),
#  ('whites', 18),
#  ('good-quality', 18),
#  ('vegetable', 18),
#  ('glaze', 17),
#  ('as', 17),
#  ('cherry,', 17),
#  ('honey', 17),
#  ('sweet', 17),
#  ('raisin', 17),
#  ('yolks', 17),
#  ('thinly', 17),
#  ('cooked', 17),
#  ('cored', 17),
#  ('below)', 17),
#  ('round', 17),
#  ('chopped,', 17),
#  ('mustard', 17),
#  ('onions,', 17),
#  ('ready-made', 16),
#  ('freshly', 16),
#  ('slices', 16),
#  ('bag', 16),
#  ('half', 16),
#  ('ginger,', 16),
#  ('out', 16),
#  ('peeled,', 16),
#  ('jam,', 16),
#  ('(or', 16),
#  ('cubed', 16),
#  ('smoked', 16),
#  ('280g', 15),
#  ('yogurt', 15),
#  ('yolk', 15),
#  ('thin', 15),
#  ('treacle', 15),
#  ('temperature', 15),
#  ('30g', 15),
#  ('drained', 15),
#  ('cream,', 15),
#  ('vinegar', 15),
#  ('crème', 15),
#  ('chicken', 14),
#  ('cherries', 14),
#  ('sprigs', 14),
#  ('sieved', 14),
#  ('clear', 14),
#  ('(about', 14),
#  ('leftover', 14),
#  ('284ml', 14),
#  ('leaves,', 14),
#  ('apple', 14),
#  ('cloves,', 14),
#  ('paste', 14),
#  ('1kg', 13),
#  ('cherries,', 13),
#  ('candied', 13),
#  ('sultana', 13),
#  ('soured', 13),
#  ('20cm', 13),
#  ('leaf', 13),
#  ('stock', 13),
#  ('streaky', 13),
#  ('gluten-free', 13),
#  ('cherry', 12),
#  ('700g', 12),
#  ('breadcrumb', 12),
#  ('mascarpone', 12),
#  ('crumbled', 12),
#  ('eating', 12),
#  ('strong', 12),
#  ('parsley,', 12),
#  ('120g', 12),
#  ('600g', 12),
#  ('warmed', 12),
#  ('pork', 12),
#  ('lemon,', 12),
#  ('knob', 11),
#  ('mix', 11),
#  ('such', 11),
#  ('currant', 11),
#  ('thick', 11),
#  ('good', 11),
#  ('142ml', 11),
#  ('splash', 11),
#  ('fine', 11),
#  ('shelled', 11),
#  ('dust', 11),
#  ("'Goes", 11),
#  ('buttermilk', 11),
#  ('frying', 11),
#  ('500ml', 11),
#  ('fraîche', 11),
#  ('sauce', 11),
#  ('pepper', 11),
#  ('apricots,', 10),
#  ('allspice', 10),
#  ('pecan', 10),
#  ('quartered', 10),
#  ('clementines', 10),
#  ('600ml', 10),
#  ('carton', 10),
#  ('writing', 10),
#  ('packs', 10),
#  ('2-3', 10),
#  ('40g', 10),
#  ('nuts', 10),
#  ('cumin', 10),
#  ('rashers', 10),
#  ('bacon', 10),
#  ('biscuit', 10),
#  ('block', 10),
#  ('picked', 10),
#  ('deseeded', 10),
#  ('raisins,', 9),
#  ('approx', 9),
#  ('oranges', 9),
#  ('custard', 9),
#  ('apples,', 9),
#  ('vegetarian', 9),
#  ('ice', 9),
#  ('sheets', 9),
#  ('melted,', 9),
#  ('bar', 9),
#  ('bread', 9),
#  ('yeast', 9),
#  ('like', 9),
#  ('pitted', 9),
#  ('sprinkles,', 9),
#  ('225ml', 9),
#  ('shallots,', 9),
#  ('wholegrain', 9),
#  ('star', 9),
#  ('stoned', 9),
#  ('rice', 9),
#  ('milk,', 9),
#  ('desiccated', 9),
#  ('sage', 9),
#  ('see', 9),
#  ('10', 9),
#  ('cranberries,', 8),
#  ('luxury', 8),
#  ('more', 8),
#  ('biscuits,', 8),
#  ('almond,', 8),
#  ('cup', 8),
#  ('almonds,', 8),
#  ('tubs', 8),
#  ('sprinkling', 8),
#  ('shredded', 8),
#  ('suet', 8),
#  ('jelly', 8),
#  ('separated', 8),
#  ('then', 8),
#  ('royal', 8),
#  ('liqueur', 8),
#  ('wholemeal', 8),
#  ('date,', 8),
#  ('cooled', 8),
#  ('cake(see', 8),
#  ('make', 8),
#  ('granulated', 8),
#  ('80g', 8),
#  ('slightly', 8),
#  ("with'", 8),
#  ('juiced', 8),
#  ('peppercorns', 8),
#  ('your', 8),
#  ('ham,', 8),
#  ('grating', 8),
#  ('hot', 8),
#  ('butternut', 8),
#  ('cheese,', 8),
#  ('shallot,', 8),
#  ('320g', 8),
#  ('chilli', 8),
#  ('digestive', 8),
#  ('lime', 8),
#  ('ripe', 8),
#  ('9', 7),
#  ('peel,', 7),
#  ('walnut', 7),
#  ('scraped', 7),
#  ('demerara', 7),
#  ('split', 7),
#  ('packet', 7),
#  ('mace', 7),
#  ('potato,', 7),
#  ('filo', 7),
#  ('walnuts,', 7),
#  ('800g', 7),
#  ('left', 7),
#  ('biscuits', 7),
#  ('rest', 7),
#  ('clove,', 7),
#  ('nutmeg,', 7),
#  ('sifted,', 7),
#  ('ribbon,', 7),
#  ('pistachio', 7),
#  ('liquid', 7),
#  ('75ml', 7),
#  ('apple,', 7),
#  ('bean', 7),
#  ('hazelnuts,', 7),
#  ('crystallised', 7),
#  ('250ml', 7),
#  ('square', 7),
#  ('glitter', 7),
#  ('cutter', 7),
#  ('sage,', 7),
#  ('syrup,', 7),
#  ('180g', 7),
#  ('is', 7),
#  ('gelatine', 7),
#  ('all-butter', 7),
#  ('strips', 7),
#  ('65cm', 7),
#  ('pineapple', 7),
#  ('pine', 7),
#  ('parsley', 7),
#  ('ready-to-eat', 6),
#  ('chestnut,', 6),
#  ('skinless', 6),
#  ('root', 6),
#  ('sprinkles', 6),
#  ('sweets,', 6),
#  ('amaretti', 6),
#  ('1-2', 6),
#  ('brandy,', 6),
#  ('currants', 6),
#  ('Grand', 6),
#  ('rinsed', 6),
#  ('sea', 6),
#  ('Bramley', 6),
#  ('it', 6),
#  ('beaten,', 6),
#  ('sprigs,', 6),
#  ('Waitrose', 6),
#  ('temperature,', 6),
#  ('cocktail', 6),
#  ('sticks', 6),
#  ('sprig', 6),
#  ('rolled', 6),
#  ('heaped', 6),
#  ('<a', 6),
#  ('apricot,', 6),
#  ('pecan,', 6),
#  ('pears,', 6),
#  ('juice,', 6),
#  ('glazing', 6),
#  ('coriander', 6),
#  ('125ml', 6),
#  ('chilled', 6),
#  ('chestnut', 6),
#  ('meat', 6),
#  ('–', 6),
#  ('fork', 6),
#  ('coloured', 6),
#  ('other', 6),
#  ('kg', 6),
#  ('tomato', 6),
#  ('seed', 6),
#  ('185g', 6),
#  ('chilli,', 6),
#  ('sesame', 6),
#  ('cornflour', 6),
#  ('bread,', 6),
#  ('that', 5),
#  ('includes', 5),
#  ('cherries)', 5),
#  ('oz', 5),
#  ('nut', 5),
#  ('rum,', 5),
#  ('lustre', 5),
#  ('buttons', 5),
#  ('sultanas,', 5),
#  ('feeding', 5),
#  ('carrot,', 5),
#  ('Marnier', 5),
#  ('fig,', 5),
#  ('have', 5),
#  ('nuts,', 5),
#  ('pudding', 5),
#  ('an', 5),
#  ('pod,', 5),
#  ('pudding,', 5),
#  ('custard,', 5),
#  ('sour', 5),
#  ('powder,', 5),
#  ('Cointreau', 5),
#  ('holly', 5),
#  ('figs', 5),
#  ('solids)', 5),
#  ('quantity', 5),
#  ('link', 5),
#  ('16', 5),
#  ('rosemary,', 5),
#  ('lemons,', 5),
#  ('7g', 5),
#  ('sachet', 5),
#  ('fast-action', 5),
#  ('smooth', 5),
#  ('drops', 5),
#  ('glucose', 5),
#  ('wide', 5),
#  ('20g', 5),
#  ('oats', 5),
#  ('coarsely', 5),
#  ('Granny', 5),
#  ("'goes", 5),
#  ('icing,', 5),
#  ('single', 5),
#  ('1cm', 5),
#  ('semi-dried', 5),
#  ('figs,', 5),
#  ('walnut,', 5),
#  ('recipe)', 5),
#  ('piece', 5),
#  ('per', 5),
#  ('fat', 5),
#  ('not', 5),
#  ('wedges', 5),
#  ('175ml', 5),
#  ('marzipan,', 5),
#  ('English', 5),
#  ('tea', 5),
#  ('semi-skimmed', 5),
#  ('white,', 5),
#  ('nut,', 5),
#  ('hazelnut', 5),
#  ('squash', 5),
#  ('onion', 5),
#  ('red,', 5),
#  ('polenta', 5),
#  ('hazelnuts', 5),
#  ('creamor', 5),
#  ('Doves', 5),
#  ('raspberry', 5),
#  ('boiled', 5),
#  ('brushing', 5),
#  ('anise', 5),
#  ('vegan', 5),
#  ('piping', 5),
#  ('removed', 5),
#  ('400ml', 5),
#  ('spring', 5),
#  ('stick', 5),
#  ('trimmed', 5),
#  ('flat-leaf', 5),
#  ('removed,', 5),
#  ('mince', 5),
#  ('board', 5),
#  ('Maris', 5),
#  ('tube', 5),
#  ('tip)', 5),
#  ('chives,', 5),
#  ('salmon', 5),
#  ('macadamia', 4),
#  ('warm', 4),
#  ('snowflake', 4),
#  ('spray', 4),
#  ('currants,', 4),
#  ('prunes', 4),
#  ('optional', 4),
#  ('sherry,', 4),
#  ('rosewater', 4),
#  ('hazelnut,', 4),
#  ('(from', 4),
#  ('one', 4),
#  ('240g', 4),
#  ('30ml', 4),
#  ('stout', 4),
#  ('box', 4),
#  ('fridge', 4),
#  ('sticks,', 4),
#  ('leek,', 4),
#  ('mushroom,', 4),
#  ('pinches', 4),
#  ('madeira', 4),
#  ('paper', 4),
#  ('fruits', 4),
#  ('cocoa,', 4),
#  ('espresso', 4),
#  ('(70%', 4),
#  ('pecansor', 4),
#  ('toasted,', 4),
#  ('cloudy', 4),
#  ('fruit(the', 4),
#  ('kind', 4),
#  ('peel)', 4),
#  ('balls,', 4),
#  ('drizzle', 4),
#  ('¾', 4),
#  ('yolk,', 4),
#  ('brown,', 4),
#  ('tie', 4),
#  ('sauce,', 4),
#  ('molasses', 4),
#  ('170g', 4),
#  ('Kilner', 4),
#  ('410g', 4),
#  ("with')", 4),
#  ('thawed', 4),
#  ('425g', 4),
#  ('pear,', 4),
#  ('chip', 4),
#  ('glitter(optional)', 4),
#  ('dates,', 4),
#  ('pud)', 4),
#  ('oranges,', 4),
#  ('jar,', 4),
#  ('Greek', 4),
#  ('generous', 4),
#  ('dates', 4),
#  ('pistachios,', 4),
#  ('rings', 4),
#  ('cayenne', 4),
#  ('peppermintextract', 4),
#  ('on', 4),
#  ('2½', 4),
#  ('vacuum-packed', 4),
#  ('24', 4),
#  ('clove', 4),
#  ('15g', 4),
#  ('yolks,', 4),
#  ('together', 4),
#  ('Smarties', 4),
#  ('turkey', 4),
#  ('mature', 4),
#  ('flakes', 4),
#  ('gingerbread', 4),
#  ('colours', 4),
#  ('411g', 4),
#  ('thickly', 4),
#  ('sweets', 4),
#  ('dill,', 4),
#  ('Brazil', 4),
#  ('wateror', 4),
#  ('plastic', 4),
#  ('lengthways', 4),
#  ('purée', 4),
#  ('drizzling', 4),
#  ('cider', 4),
#  ('rapeseed', 4),
#  ('icingcoloured', 4),
#  ('beef', 4),
#  ('blue', 4),
#  ('preferably', 4),
#  ('leaf,', 4),
#  ('sherry', 4),
#  ('cranberrysauce', 4),
#  ('prunes,', 4),
#  ('shop-bought', 4),
#  ('homemade', 4),
#  ('cheddar,', 4),
#  ('fruit,', 4),
#  ('chutney', 4),
#  ('cm', 4),
#  ('only', 4),
#  ('are', 4),
#  ('need', 4),
#  ('salad', 4),
#  ('bought', 4),
#  ('snipped', 4),
#  ('fruitcake', 4),
#  ('sausagemeat', 3),
#  ('skinned', 3),
#  ('sausages', 3),
#  ('1tsp', 3),
#  ('boneless,', 3),
#  ('fl', 3),
#  ('pecannuts,', 3),
#  ('marmalade', 3),
#  ('available', 3),
#  ('whisky', 3),
#  ('walnuts', 3),
#  ('raisin,', 3),
#  ('natural-coloured', 3),
#  ('around', 3),
#  ('pod', 3),
#  ('pods,', 3),
#  ('find', 3),
#  ('quarters', 3),
#  ('caraway', 3),
#  ('cranberry,', 3),
#  ('20', 3),
#  ('honey,', 3),
#  ('250g/9oz', 3),
#  ('satsumas,', 3),
#  ('decorations', 3),
#  ('coffee', 3),
#  ('Tia', 3),
#  ('curls', 3),
#  ('cake,', 3),
#  ('clementines,', 3),
#  ('blossom', 3),
#  ('mango,', 3),
#  ('balls)', 3),
#  ('cans', 3),
#  ('tomatoes', 3),
#  ('like)', 3),
#  ('cases', 3),
#  ('segments', 3),
#  ('pieces,', 3),
#  ('1.2kg', 3),
#  ('pretzels,', 3),
#  ('string', 3),
#  ('brandyor', 3),
#  ('fruitcake,', 3),
#  ('spice,', 3),
#  ('Cointreauor', 3),
#  ('chia', 3),
#  ('sticking', 3),
#  ('icingor', 3),
#  ('1l', 3),
#  ('gift', 3),
#  ('bars', 3),
#  ('20cm-wide', 3),
#  ('runny', 3),
#  ('stand', 3),
#  ('sheet', 3),
#  ('dice', 3),
#  ('grated,', 3),
#  ('giant', 3),
#  ('hanging', 3),
#  ('pineapple,', 3),
#  ('(including', 3),
#  ('tubes', 3),
#  ('different', 3),
#  ('60g', 3),
#  ('pistachios', 3),
#  ('900g', 3),
#  ('mixture', 3),
#  ('pecans,', 3),
#  ('lemons', 3),
#  ('(use', 3),
#  ('any', 3),
#  ('ball', 3),
#  ('gingerfrom', 3),
#  ('regal', 3),
#  ('malt', 3),
#  ('270g', 3),
#  ('loaf', 3),
#  ('clotted', 3),
#  ('squash,', 3),
#  ('mint,', 3),
#  ('harissa', 3),
#  ('7', 3),
#  ('own', 3),
#  ('roll', 3),
#  ('leeks,', 3),
#  ('potatoes,', 3),
#  ('ham', 3),
#  ('boiling', 3),
#  ('whipped', 3),
#  ('crustless', 3),
#  ('l', 3),
#  ('pancetta', 3),
#  ('200g/7oz', 3),
#  ('18cm', 3),
#  ("with',", 3),
#  ('milkor', 3),
#  ('pearl', 3),
#  ('preserving', 3),
#  ('cutters', 3),
#  ('15', 3),
#  ('sageleaves,', 3),
#  ('cinnamon,', 3),
#  ('tip,', 3),
#  ('baby', 3),
#  ('tarragon', 3),
#  ('taste', 3),
#  ('buttons,', 3),
#  ('cellophane', 3),
#  ('squares', 3),
#  ('celery', 3),
#  ('whipping', 3),
#  ('Dijon', 3),
#  ('Brussels', 3),
#  ('long', 3),
#  ("goat's", 3),
#  ('salad,', 3),
#  ('ricotta', 3),
#  ('350ml', 3),
#  ('prosecco', 3),
#  ('scattering', 3),
#  ('new', 3),
#  ('torn', 3),
#  ('curd', 3),
#  ('chocolate(70%', 3),
#  ('colourless', 3),
#  ('alcohol', 3),
#  ('sugarpaste(fondant)', 3),
#  ('lid', 3),
#  ('bags', 3),
#  ('length', 3),
#  ('firm', 3),
#  ('plum', 3),
#  ('carrots,', 3),
#  ('goes', 3),
#  ('rye', 3),
#  ('wooden', 3),
#  ('weight),', 3),
#  ('parmesan(or', 3),
#  ('alternative),', 3),
#  ('cookie', 3),
#  ('juice(from', 3),
#  ('above)', 3),
#  ('colouringpaste', 3),
#  ('breast', 3),
#  ('lean', 3),
#  ('poppy', 3),
#  ('skin', 3),
#  ('2cm/¾', 3),
#  ('300g/11oz', 3),
#  ('bones', 3),
#  ('650g', 3),
#  ('(save', 3),
#  ('dry', 3),
#  ('seedless', 3),
#  ('2x', 3),
#  ('marshmallows', 3),
#  ('low-fat', 3),
#  ('squeezed', 3),
#  ('dessert', 3),
#  ('apricots', 3),
#  ('paprika', 3),
#  ('below', 3),
#  ('roasted', 3),
#  ('garnish', 3),
#  ('potatoes', 3),
#  ('paste)', 3),
#  ('tins', 3),
#  ('mint', 3),
#  ('topping', 3),
#  ('18-23cm', 3),
#  ('drained,', 3),
#  ('(you', 3),
#  ('sparkles,', 3),
#  ('pistachio,', 3),
#  ('crusts', 3),
#  ('minced', 3),
#  ('cheese)', 3),
#  ('160g', 3),
#  ('Savoy', 3),
#  ('coconut,', 3),
#  ('100ml/3½', 2),
#  ('4tbsp', 2),
#  ('85g/3oz', 2),
#  ('Dr', 2),
#  ('pens,', 2),
#  ('cubes,', 2),
#  ('rosemary', 2),
#  ('Lindt', 2),
#  ('fruit(use', 2),
#  ('figs)', 2),
#  ('tropical', 2),
#  ('10cm', 2),
#  ('hollysprig,', 2),
#  ('feed', 2),
#  ('Sundora)', 2),
#  ('big', 2),
#  ('wine,', 2),
#  ('bread)', 2),
#  ('flaky', 2),
#  ('110g', 2),
#  ('cooking', 2),
#  ('pieces)', 2),
#  ('all', 2),
#  ('three', 2),
#  ('lumpy', 2),
#  ('taken', 2),
#  ('straight', 2),
#  ('bowl', 2),
#  ('can,', 2),
#  ('berries', 2),
#  ('Baileys', 2),
#  ('solids,', 2),
#  ('Maria', 2),
#  ('beans', 2),
#  ('uncooked', 2),
#  ('fronds', 2),
#  ('1m', 2),
#  ('whole,', 2),
#  ('pear', 2),
#  ('120ml', 2),
#  ('brandy(optional)', 2),
#  ('cranberriesor', 2),
#  ('crisp', 2),
#  ('Christmassy', 2),
#  ('cornmeal', 2),
#  ('muffin', 2),
#  ('48', 2),
#  ('across', 2),
#  ('top)', 2),
#  ('12cm', 2),
#  ('Disaronno', 2),
#  ('easy-blend', 2),
#  ('below),', 2),
#  ('base', 2),
#  ('fig', 2),
#  ('flower', 2),
#  ('dairy-free', 2),
#  ('yellow', 2),
#  ('colour', 2),
#  ('shred', 2),
#  ('enough', 2),
#  ('boardor', 2),
#  ('pastry,', 2),
#  ('sheets)', 2),
#  ("Sainsbury's", 2),
#  ('button', 2),
#  ('string,', 2),
#  ('100g/4oz', 2),
#  ('colourful', 2),
#  ('ones', 2),
#  ('slices,', 2),
#  ('pineapple)', 2),
#  ('Suits-all', 2),
#  ('sizes', 2),
#  ('colours,', 2),
#  ('115g', 2),
#  ('we', 2),
#  ('our', 2),
#  ('recipe</a>', 2),
#  ('carrot', 2),
#  ('currant,', 2),
#  ('light,', 2),
#  ('flavourless', 2),
#  ("don't", 2),
#  ('rich', 2),
#  ('malted', 2),
#  ('full', 2),
#  ('cheese(we', 2),
#  ('mincemeat(about', 2),
#  ('ciabatta', 2),
#  ('spinach', 2),
#  ('medjool', 2),
#  ('slices)', 2),
#  ('stilton,', 2),
#  ('brie', 2),
#  ('undyed)', 2),
#  ('1¼kg', 2),
#  ('plenty', 2),
#  ('bundt', 2),
#  ('camembertin', 2),
#  ('325g', 2),
#  ('chestnuts,', 2),
#  ('thyme,', 2),
#  ('stripped', 2),
#  ('raspberryor', 2),
#  ('1.3kg', 2),
#  ('fraîche,', 2),
#  ('frothed', 2),
#  ('made', 2),
#  ('sugaror', 2),
#  ('glitter,', 2),
#  ('sausagemeator', 2),
#  ('Regal-Ice', 2),
#  ('Ready', 2),
#  ('Roll', 2),
#  ('reserving', 2),
#  ('black,', 2),
#  ('top', 2),
#  ('right)', 2),
#  ('spinach,', 2),
#  ('washed', 2),
#  ('semolina,', 2),
#  ('pepper,', 2),
#  ('cardboard', 2),
#  ('gravy', 2),
#  ('sprinkle', 2),
#  ('sprouts,', 2),
#  ('mashed', 2),
#  ('gin', 2),
#  ('vermouth', 2),
#  ('20ml', 2),
#  ('cupcake', 2),
#  ('using', 2),
#  ('25ml', 2),
#  ('275g', 2),
#  ('cardamom', 2),
#  ('pods', 2),
#  ('tip', 2),
#  ('ribbonor', 2),
#  ('chocolatecurls', 2),
#  ('should', 2),
#  ...]

# %%
total_method = Counter()
baked_method = Counter()

for i in range(len(data)):
    if expected_data[i] == "Baked Good":
        for j in range(len(data[i]['Method'])):       
            if data[i]['Method'] != None:
                for word in data[i]['Method'][j].split(" "):
                    baked_method[word] += 1
                    total_method[word] += 1
                
baked_method.most_common()
# Out:
# [('the', 9515),
#  ('and', 4312),
#  ('a', 4142),
#  ('to', 2789),
#  ('in', 1986),
#  ('with', 1955),
#  ('of', 1834),
#  ('then', 1462),
#  ('for', 1430),
#  ('until', 1203),
#  ('into', 1085),
#  ('on', 748),
#  ('out', 606),
#  ('over', 603),
#  ('or', 590),
#  ('it', 531),
#  ('mins', 525),
#  ('cake', 517),
#  ('oven', 483),
#  ('icing', 475),
#  ('baking', 461),
#  ('you', 455),
#  ('sugar', 400),
#  ('make', 383),
#  ('top', 341),
#  ('Heat', 337),
#  ('up', 331),
#  ('pastry', 328),
#  ('each', 324),
#  ('butter', 323),
#  ('from', 306),
#  ('tin', 303),
#  ('little', 297),
#  ('is', 291),
#  ('large', 287),
#  ('your', 271),
#  ('mixture', 269),
#  ('1', 267),
#  ('together', 261),
#  ('2', 257),
#  ('mix', 255),
#  ('remaining', 248),
#  ('cool', 246),
#  ('bowl', 242),
#  ('Put', 239),
#  ('add', 238),
#  ('fan/gas', 235),
#  ('onto', 235),
#  ('as', 233),
#  ('at', 230),
#  ('Add', 229),
#  ('To', 220),
#  ('all', 218),
#  ('an', 209),
#  ('small', 208),
#  ('leave', 203),
#  ('heat', 198),
#  ('if', 198),
#  ('–', 198),
#  ('water', 198),
#  ('about', 193),
#  ('', 193),
#  ('bake', 186),
#  ('chocolate', 184),
#  ('mins.', 181),
#  ('half', 179),
#  ('flour', 179),
#  ('Bake', 179),
#  ('dough', 177),
#  ('cover', 175),
#  ('egg', 173),
#  ('will', 173),
#  ('be', 173),
#  ('stir', 172),
#  ('pan', 171),
#  ('Leave', 170),
#  ('cut', 170),
#  ('mins,', 169),
#  ('one', 167),
#  ('them', 162),
#  ('around', 155),
#  ('line', 154),
#  ('roll', 153),
#  ('Mix', 153),
#  ('30', 152),
#  ('Stir', 150),
#  ('set', 146),
#  ('so', 146),
#  ('off', 145),
#  ('using', 145),
#  ('any', 142),
#  ('flour,', 140),
#  ('put', 140),
#  ('10', 138),
#  ('use', 138),
#  ('cream', 138),
#  ('tbsp', 137),
#  ('Tip', 136),
#  ('surface', 136),
#  ('down', 134),
#  ('Spoon', 132),
#  ('cook', 132),
#  ('cling', 132),
#  ('5', 130),
#  ('just', 130),
#  ('Remove', 129),
#  ('well', 129),
#  ('few', 129),
#  ('have', 128),
#  ('golden', 128),
#  ('before', 127),
#  ('gently', 126),
#  ('some', 126),
#  ('lightly', 124),
#  ('tin.', 123),
#  ('sugar,', 122),
#  ('are', 122),
#  ('this', 122),
#  ('bowl,', 122),
#  ('Roll', 121),
#  ('pudding', 121),
#  ('base', 120),
#  ('sides', 120),
#  ('more', 120),
#  ('whisk', 118),
#  ('Use', 118),
#  ('can', 116),
#  ('food', 116),
#  ('smooth', 114),
#  ('by', 113),
#  ('orange', 112),
#  ('pour', 112),
#  ('keep', 110),
#  ('two', 109),
#  ('comes', 107),
#  ('Pour', 107),
#  ('beat', 107),
#  ('3', 106),
#  ('sheet', 105),
#  ('Brush', 104),
#  ('butter,', 103),
#  ('remove', 103),
#  ('cake.', 103),
#  ('tin,', 101),
#  ('If', 101),
#  ('has', 100),
#  ('turn', 100),
#  ('skewer', 99),
#  ('milk', 98),
#  ('enough', 98),
#  ('Cut', 97),
#  ('When', 97),
#  ('chill', 97),
#  ('4.', 96),
#  ('place', 96),
#  ('stick', 96),
#  ('Cool', 95),
#  ('oil', 94),
#  ('centre', 93),
#  ('eggs', 93),
#  ('film', 91),
#  ('another', 91),
#  ('spoon', 90),
#  ('4', 90),
#  ('tsp', 89),
#  ('but', 88),
#  ('20', 88),
#  ('15', 87),
#  ('fridge', 87),
#  ('parchment.', 87),
#  ('bowl.', 86),
#  ('dry', 86),
#  ('cool.', 86),
#  ('between', 86),
#  ('Beat', 86),
#  ('180C/160C', 85),
#  ('melted', 84),
#  ('edges', 83),
#  ('round', 83),
#  ('white', 83),
#  ('6.', 83),
#  ('rest', 82),
#  ('brush', 82),
#  ('foil', 82),
#  ('press', 82),
#  ('Cover', 81),
#  ('tip', 81),
#  ('that', 79),
#  ('bring', 78),
#  ('back', 77),
#  ('syrup', 77),
#  ('layer', 76),
#  ('parchment', 76),
#  ('x', 76),
#  ('fruit', 75),
#  ('warm', 75),
#  ('wire', 75),
#  ('Using', 75),
#  ('top.', 75),
#  ('marzipan', 74),
#  ('ingredients', 74),
#  ('through', 74),
#  ('tray', 73),
#  ('20cm', 72),
#  ('they', 72),
#  ('sugar.', 72),
#  ('floured', 72),
#  ('middle', 72),
#  ('pie', 71),
#  ('Meanwhile,', 71),
#  ('vanilla', 71),
#  ('biscuits', 71),
#  ('fold', 71),
#  ('The', 70),
#  ('knife', 70),
#  ('smooth.', 69),
#  ('Once', 69),
#  ('paper', 69),
#  ('serve', 69),
#  ('hr', 68),
#  ('In', 68),
#  ('need', 67),
#  ('very', 67),
#  ('Serve', 66),
#  ('work', 66),
#  ('least', 66),
#  ('spread', 65),
#  ('stirring', 65),
#  ('electric', 65),
#  ('Line', 65),
#  ('cake,', 65),
#  ('water.', 64),
#  ('hot', 64),
#  ('200C/180C', 64),
#  ('eggs,', 63),
#  ('aside', 63),
#  ('Place', 63),
#  ('side', 63),
#  ('everything', 62),
#  ('golden.', 62),
#  ('thick', 62),
#  ('aside.', 62),
#  ('not', 62),
#  ('zest', 61),
#  ('clean.', 61),
#  ('time,', 61),
#  ('lemon', 60),
#  ('salt', 58),
#  ('Make', 58),
#  ('bottom', 58),
#  ('soft', 58),
#  ('excess', 57),
#  ('together.', 57),
#  ('water,', 56),
#  ('like', 56),
#  ('brown', 56),
#  ('icing.', 56),
#  ('pan,', 55),
#  ('tart', 55),
#  ('Set', 55),
#  ('wrap', 55),
#  ('For', 55),
#  ('completely', 55),
#  ('Melt', 55),
#  ('Can', 55),
#  ('rack', 54),
#  ('icing,', 54),
#  ('medium', 53),
#  ('dough.', 53),
#  ('together,', 53),
#  ('sauce', 53),
#  ('processor', 52),
#  ('ready', 52),
#  ('circle', 52),
#  ('days', 52),
#  ('juice', 51),
#  ('thickness', 51),
#  ('cheese', 51),
#  ('tins', 51),
#  ('piece', 51),
#  ('muffin', 50),
#  ('cakes', 50),
#  ('mixing', 50),
#  ('6', 50),
#  ('pinch', 50),
#  ('leaving', 50),
#  ('ground', 49),
#  ('it.', 49),
#  ('along', 49),
#  ('Butter', 49),
#  ('saucepan', 49),
#  ('leaves', 49),
#  ('deep', 48),
#  ('cool,', 48),
#  ('firm', 48),
#  ('12', 48),
#  ('should', 48),
#  ('decorate', 48),
#  ('while', 48),
#  ('circles', 48),
#  ('end', 48),
#  ('completely.', 47),
#  ('evenly', 47),
#  ('melt', 47),
#  ('Grease', 47),
#  ('Chill', 47),
#  ('trim', 47),
#  ('mincemeat', 47),
#  ('pan.', 46),
#  ('other', 46),
#  ('help', 46),
#  ('knead', 46),
#  ('plate', 46),
#  ('fine', 45),
#  ('batter', 45),
#  ('inserted', 45),
#  ('cold', 45),
#  ('Spread', 45),
#  ('balls', 45),
#  ('when', 45),
#  ('greaseproof', 45),
#  ('sprinkle', 45),
#  ('pieces', 44),
#  ('almonds', 44),
#  ('holes', 44),
#  ('butter.', 44),
#  ('Divide', 44),
#  ('cutter', 44),
#  ('same', 44),
#  ('airtight', 44),
#  ('serve.', 44),
#  ('star', 44),
#  ('serve,', 44),
#  ('made', 44),
#  ('well.', 43),
#  ('Fold', 43),
#  ('dust', 43),
#  ('Turn', 43),
#  ('spoon.', 43),
#  ('bag', 43),
#  ('egg,', 42),
#  ('again', 42),
#  ('Bring', 42),
#  ('powder', 42),
#  ('come', 42),
#  ('pale', 42),
#  ('serving', 42),
#  ('(see', 42),
#  ('don’t', 42),
#  ('slice', 42),
#  ('get', 42),
#  ('clean', 42),
#  ('filling', 42),
#  ('edge', 42),
#  ('Transfer', 42),
#  ('piping', 42),
#  ('slices', 42),
#  ('black', 42),
#  ('onion', 41),
#  ('boiling', 41),
#  ('microwave', 41),
#  ('biscuit', 41),
#  ('flat', 41),
#  ('non-stick', 41),
#  ('like.', 41),
#  ('overnight.', 41),
#  ('hand', 41),
#  ('Cook', 41),
#  ('Repeat', 41),
#  ('shape', 41),
#  ('lift', 41),
#  ('season', 40),
#  ('brandy', 40),
#  ('whole', 40),
#  ('set.', 40),
#  ('prepared', 40),
#  ('give', 40),
#  ('paper.', 40),
#  ('Wrap', 40),
#  ('pies', 40),
#  ('rack.', 39),
#  ('Will', 39),
#  ('mixed', 39),
#  ('wooden', 39),
#  ('away', 39),
#  ('Sprinkle', 39),
#  ('boil', 39),
#  ('transfer', 39),
#  ('rolling', 39),
#  ('Take', 39),
#  ('simmering', 38),
#  ('it’s', 38),
#  ('simmer', 38),
#  ('(or', 38),
#  ('sheets', 38),
#  ('ginger', 38),
#  ('frozen', 38),
#  ('sharp', 38),
#  ('scatter', 38),
#  ('cream,', 38),
#  ('big', 38),
#  ('low', 38),
#  ('carefully', 38),
#  ('surface.', 38),
#  ('thin', 38),
#  ('beaten', 37),
#  ('dried', 37),
#  ('top,', 37),
#  ('create', 37),
#  ('making', 37),
#  ('still', 37),
#  ('mixture.', 37),
#  ('slightly', 37),
#  ('Carefully', 37),
#  ('frying', 36),
#  ('dark', 36),
#  ('too', 36),
#  ('pipe', 36),
#  ('mixture,', 36),
#  ('time', 36),
#  ('up.', 36),
#  ('its', 36),
#  ('temperature', 36),
#  ('chopped', 36),
#  ('cranberries', 36),
#  ('dish', 36),
#  ('180C/gas', 36),
#  ('cooked', 36),
#  ('Scatter', 36),
#  ('peel', 35),
#  ('double', 35),
#  ('light', 35),
#  ('pastry,', 35),
#  ('surface,', 35),
#  ('fluffy.', 35),
#  ('three', 34),
#  ('Press', 34),
#  ('nuts', 34),
#  ('juice,', 34),
#  ('risen', 34),
#  ('green', 34),
#  ('heat.', 34),
#  ('1-2', 34),
#  ('ice', 34),
#  ('hole', 34),
#  ('basin', 34),
#  ('fill', 34),
#  ('roasting', 34),
#  ('3.', 34),
#  ('bay', 34),
#  ('stamp', 34),
#  ('oil,', 34),
#  ('salt.', 33),
#  ('spices', 33),
#  ('further', 33),
#  ('extra', 33),
#  ('sure', 33),
#  ('level', 33),
#  ('Dust', 33),
#  ('pulse', 33),
#  ('£1', 33),
#  ('steam', 33),
#  ('room', 33),
#  ('drizzle', 33),
#  ('Lightly', 33),
#  ('stars', 33),
#  ('Lay', 33),
#  ('want', 33),
#  ('brown.', 33),
#  ('bread', 33),
#  ('trimmings', 32),
#  ('parchment,', 32),
#  ('hrs', 32),
#  ('Keep', 32),
#  ('You', 32),
#  ('Whisk', 32),
#  ('bit', 32),
#  ('200C/fan', 32),
#  ('23cm', 32),
#  ('shapes', 31),
#  ('fruit,', 31),
#  ('minutes', 31),
#  ('foil.', 31),
#  ('every', 31),
#  ('almonds,', 31),
#  ('Lift', 31),
#  ('hrs,', 31),
#  ('sit', 31),
#  ('day', 31),
#  ('Trim', 31),
#  ('8', 31),
#  ('salt,', 31),
#  ('case', 31),
#  ('Sift', 30),
#  ('combined.', 30),
#  ('caster', 30),
#  ('While', 30),
#  ('hrs.', 30),
#  ('cooled', 30),
#  ('strip', 30),
#  ('once', 30),
#  ('edges.', 30),
#  ('Sit', 30),
#  ('pastry.', 29),
#  ('freeze', 29),
#  ('dusted', 29),
#  ('look', 29),
#  ('string', 29),
#  ('ribbon', 29),
#  ('halfway', 29),
#  ('allow', 29),
#  ('cream.', 29),
#  ('crumbs', 29),
#  ('whizz', 29),
#  ('Arrange', 29),
#  ('jam', 29),
#  ('hands', 29),
#  ('ball', 29),
#  ('smaller', 29),
#  ('trays', 29),
#  ('potatoes', 29),
#  ('fry', 28),
#  ('20-25', 28),
#  ('kitchen', 28),
#  ('may', 28),
#  ('custard', 28),
#  ('take', 28),
#  ('than', 28),
#  ('covered', 28),
#  ('sauce,', 28),
#  ('smooth,', 28),
#  ('tray.', 28),
#  ('mix.', 28),
#  ('lid', 28),
#  ('160C/gas', 28),
#  ('there', 27),
#  ('fondant', 27),
#  ('12-hole', 27),
#  ('powder,', 27),
#  ('liquid', 27),
#  ('form', 27),
#  ('days.', 27),
#  ('little.', 27),
#  ('180C/fan', 27),
#  ('grease', 27),
#  ('cinnamon', 27),
#  ('cookie', 27),
#  ('pressing', 27),
#  ('5.', 26),
#  ('adding', 26),
#  ('45', 26),
#  ('starts', 26),
#  ('cases', 26),
#  ('tops', 26),
#  ('cocoa', 26),
#  ('jar', 26),
#  ('soak', 26),
#  ('plate.', 26),
#  ('syrup,', 26),
#  ('Gently', 26),
#  ('long', 26),
#  ('160C/140C', 26),
#  ('knife.', 26),
#  ('soft.', 26),
#  ('thick.', 26),
#  ('Knead', 26),
#  ('return', 26),
#  ('thyme', 25),
#  ('boil,', 25),
#  ('first', 25),
#  ('lay', 25),
#  ('gold', 25),
#  ('final', 25),
#  ('runny', 25),
#  ('bicarbonate', 25),
#  ('again.', 25),
#  ('beating', 25),
#  ('mix,', 25),
#  ('container', 25),
#  ('knife,', 25),
#  ('warm.', 25),
#  ('cocktail', 25),
#  ('rub', 25),
#  ('month.', 25),
#  ('squash', 25),
#  ('coconut', 25),
#  ('cutter,', 25),
#  ('crisp', 25),
#  ('zest,', 24),
#  ('no', 24),
#  ('paper,', 24),
#  ('nuts,', 24),
#  ('after', 24),
#  ('edible', 24),
#  ('tie', 24),
#  ('dry.', 24),
#  ('way', 24),
#  ('buttered', 24),
#  ('foil,', 24),
#  ('let', 24),
#  ('arrange', 24),
#  ('followed', 24),
#  ('sieve', 24),
#  ('sheet.', 24),
#  ('shape.', 24),
#  ('squeeze', 24),
#  ('board', 24),
#  ('red', 24),
#  ('gingerbread', 24),
#  ('slowly', 23),
#  ('now', 23),
#  ('apricot', 23),
#  ('well,', 23),
#  ('turning', 23),
#  ('inside', 23),
#  ('even', 23),
#  ('.', 23),
#  ('boil.', 23),
#  ('straight', 23),
#  ('Top', 23),
#  ('roughly', 23),
#  ('lined', 23),
#  ('heat,', 23),
#  ('Season', 23),
#  ('sausage', 22),
#  ('doesn’t', 22),
#  ('both', 22),
#  ('topping', 22),
#  ('dip', 22),
#  ('tightly', 22),
#  ('fit', 22),
#  ('2-3', 22),
#  ('puddings', 22),
#  ('yolks', 22),
#  ('cherries', 22),
#  ('(if', 22),
#  ('milk,', 22),
#  ('chocolate,', 22),
#  ('Pipe', 22),
#  ('whites', 22),
#  ('rum', 22),
#  ('square', 22),
#  ('you’re', 22),
#  ('ahead', 22),
#  ('loaf', 22),
#  ('Stick', 22),
#  ('12-15', 22),
#  ('15-20', 22),
#  ('syrup.', 22),
#  ('serving.', 22),
#  ('quickly', 21),
#  ('egg.', 21),
#  ('chop', 21),
#  ('soaked', 21),
#  ('colour', 21),
#  ('colouring', 21),
#  ('oven,', 21),
#  ('yolk', 21),
#  ('through.', 21),
#  ('overnight', 21),
#  ('cooling', 21),
#  ('processor,', 21),
#  ('potato', 21),
#  ('crumbs.', 21),
#  ('under', 21),
#  ('Fill', 21),
#  ('1cm', 21),
#  ('these', 21),
#  ('palette', 21),
#  ('garlic', 21),
#  ('base.', 21),
#  ('breadcrumbs.', 21),
#  ('good', 21),
#  ('40', 21),
#  ('onions', 21),
#  ('bacon', 21),
#  ('springform', 20),
#  ('cases.', 20),
#  ('second', 20),
#  ('looks', 20),
#  ('flour.', 20),
#  ('On', 20),
#  ('day,', 20),
#  ('separate', 20),
#  ('cheesecake', 20),
#  ('stand', 20),
#  ('fingers', 20),
#  ('kept', 20),
#  ('gradually', 20),
#  ('maple', 20),
#  ('saucepan,', 20),
#  ('start', 20),
#  ('really', 20),
#  ('freezer', 20),
#  ('their', 20),
#  ('stiff', 20),
#  ('sides.', 20),
#  ('25-30', 20),
#  ('fridge.', 20),
#  ('two-thirds', 19),
#  ('bubble', 19),
#  ('-', 19),
#  ('gas', 19),
#  ('25', 19),
#  ('chocolate.', 19),
#  ('chilled', 19),
#  ('softened', 19),
#  ('plain', 19),
#  ('it,', 19),
#  ('slight', 19),
#  ('strips', 19),
#  ('Allow', 19),
#  ('seeds', 19),
#  ('third', 19),
#  ('seal', 19),
#  ('hold', 19),
#  ('10cm', 19),
#  ('golden,', 19),
#  ('mini', 19),
#  ('worry', 19),
#  ('push', 19),
#  ('couple', 19),
#  ('milk.', 19),
#  ('hr.', 19),
#  ('sandwich', 19),
#  ('bun', 19),
#  ('ahead.', 19),
#  ('breadcrumbs,', 18),
#  ('pepper', 18),
#  ('Stamp', 18),
#  ('silver', 18),
#  ('outside', 18),
#  ('film.', 18),
#  ('honey', 18),
#  ('left', 18),
#  ('loosely', 18),
#  ('film,', 18),
#  ('divide', 18),
#  ('ends', 18),
#  ('7.', 18),
#  ('decorate,', 18),
#  ('blitz', 18),
#  ('kettle', 18),
#  ('overhanging', 18),
#  ('apple', 18),
#  ('basin.', 18),
#  ('size', 18),
#  ('soft,', 18),
#  ('almond', 18),
#  ('trees', 18),
#  ('8cm', 18),
#  ('finish', 18),
#  ('starting', 18),
#  ('shelf', 18),
#  ('shallow', 18),
#  ('olive', 18),
#  ('Reduce', 17),
#  ('Christmas', 17),
#  ('brownie', 17),
#  ('either', 17),
#  ('poke', 17),
#  ('100g', 17),
#  ('next', 17),
#  ('round,', 17),
#  ('mixer', 17),
#  ('loose-bottomed', 17),
#  ('edges,', 17),
#  ('This', 17),
#  ('1½', 17),
#  ('rounds', 17),
#  ('Drain', 17),
#  ('larger', 17),
#  ('time.', 17),
#  ('ingredients,', 17),
#  ('tins.', 17),
#  ('Drizzle', 17),
#  ('tea', 17),
#  ('beans', 17),
#  ('wet', 17),
#  ('5cm', 17),
#  ('shape,', 17),
#  ('sauce.', 17),
#  ('sticky', 17),
#  ('jam.', 17),
#  ('and,', 17),
#  ('190C/170C', 17),
#  ('Combine', 17),
#  ('best', 17),
#  ('snip', 17),
#  ('leaves,', 17),
#  ('sage', 17),
#  ('rectangle', 17),
#  ('minutes.', 16),
#  ('metal', 16),
#  ('swirl', 16),
#  ('spice', 16),
#  ('150ml', 16),
#  ('week', 16),
#  ('centre.', 16),
#  ('string.', 16),
#  ('2cm', 16),
#  ('layers', 16),
#  ('warm,', 16),
#  ('secure', 16),
#  ('do', 16),
#  ('Now', 16),
#  ('out.', 16),
#  ('them.', 16),
#  ('more,', 16),
#  ('crisp.', 16),
#  ('Scrape', 16),
#  ('lumps', 16),
#  ('more.', 16),
#  ('fitted', 16),
#  ('whisking', 16),
#  ('reserved', 16),
#  ('rough', 16),
#  ('cranberry', 16),
#  ('edge.', 16),
#  ('Re-roll', 16),
#  ('crème', 16),
#  ('dates', 16),
#  ('gelatine', 16),
#  ('generously', 16),
#  ('slightly.', 15),
#  ('holly', 15),
#  ('melted.', 15),
#  ('140C/gas', 15),
#  ('in.', 15),
#  ('cherries,', 15),
#  ('thick,', 15),
#  ('upturned', 15),
#  ('saucer', 15),
#  ('160C/fan', 15),
#  ('Check', 15),
#  ('peel,', 15),
#  ('spoonful', 15),
#  ('quarter', 15),
#  ('caramel', 15),
#  ('Peel', 15),
#  ('Slice', 15),
#  ('disc', 15),
#  ('220C/200C', 15),
#  ('jelly', 15),
#  ('border', 15),
#  ('filling,', 15),
#  ('splash', 15),
#  ('Return', 15),
#  ('keeping', 15),
#  ('sponge', 15),
#  ('reduce', 15),
#  ('high', 15),
#  ('drop', 15),
#  ('doubled', 15),
#  ('marzipan,', 15),
#  ('eyes', 15),
#  ('coat', 15),
#  ('resembles', 15),
#  ('cookies', 15),
#  ('pushing', 15),
#  ('firmly', 15),
#  ('juice.', 15),
#  ('briefly', 15),
#  ('coin.', 15),
#  ('beans,', 15),
#  ('meat', 15),
#  ('10-15', 15),
#  ('overlapping', 15),
#  ('190C/fan', 14),
#  ('ginger,', 14),
#  ('sift', 14),
#  ('lower', 14),
#  ('glass', 14),
#  ('batter.', 14),
#  ('within', 14),
#  ('Shape', 14),
#  ('store', 14),
#  ('soda', 14),
#  ('fresh', 14),
#  ('almonds.', 14),
#  ('middle.', 14),
#  ('pudding,', 14),
#  ('deep,', 14),
#  ('custard.', 14),
#  ('grated', 14),
#  ('like,', 14),
#  ('done', 14),
#  ('Whizz', 14),
#  ('see', 14),
#  ('used', 14),
#  ('up,', 14),
#  ('largest', 14),
#  ('most', 14),
#  ('cooled,', 14),
#  ('effect.', 14),
#  ('Break', 14),
#  ('across', 14),
#  ('oiled', 14),
#  ('pin', 14),
#  ('continue', 14),
#  ('firm.', 14),
#  ('simmer,', 14),
#  ('clementine', 14),
#  ('min', 14),
#  ('filling.', 14),
#  ('careful', 14),
#  ('toss', 14),
#  ('dry,', 14),
#  ('one-third', 14),
#  ('rolls', 14),
#  ('gentle', 14),
#  ('jug.', 14),
#  ('fluted', 14),
#  ('cutter.', 14),
#  ('tender.', 14),
#  ('wedges', 14),
#  ('170C/gas', 13),
#  ('pepper.', 13),
#  ('Decorate', 13),
#  ('(about', 13),
#  ('cold,', 13),
#  ('months.', 13),
#  ('ready.', 13),
#  ('extract', 13),
#  ('creamy', 13),
#  (',', 13),
#  ('cloves,', 13),
#  ('flaked', 13),
#  ('Don’t', 13),
#  ('10-12', 13),
#  ('drops', 13),
#  ('oven.', 13),
#  ('raisins,', 13),
#  ('bottom.', 13),
#  ('Tie', 13),
#  ('spices,', 13),
#  ('pleat', 13),
#  ('eggs.', 13),
#  ('handle,', 13),
#  ('thinly', 13),
#  ('5-10', 13),
#  ('almost', 13),
#  ('24', 13),
#  ('needed.', 13),
#  ('soured', 13),
#  ('Dip', 13),
#  ('one,', 13),
#  ('oil.', 13),
#  ('later.', 13),
#  ('dollop', 13),
#  ('one.', 13),
#  ('rise', 13),
#  ('seal.', 13),
#  ('down,', 13),
#  ('Push', 13),
#  ('dish.', 13),
#  ('Warm', 13),
#  ('tins,', 13),
#  ('0.5cm', 13),
#  ('18', 13),
#  ('ready-to-roll', 13),
#  ('pretty', 13),
#  ('30cm', 13),
#  ('slices,', 13),
#  ('Preheat', 13),
#  ('saucepan.', 13),
#  ('cutting', 13),
#  ('7cm', 13),
#  ('re-roll', 13),
#  ('topping.', 13),
#  ('stock', 13),
#  ('occasionally.', 12),
#  ('been', 12),
#  ('hours', 12),
#  ('check', 12),
#  ('jam,', 12),
#  ('fluffy', 12),
#  ('balls.', 12),
#  ('½', 12),
#  ('spice,', 12),
#  ('coloured', 12),
#  ('out,', 12),
#  ('zest.', 12),
#  ('hours.', 12),
#  ('creamy.', 12),
#  ('leftover', 12),
#  ('mascarpone', 12),
#  ('(this', 12),
#  ('Boil', 12),
#  ('fork', 12),
#  ('Smooth', 12),
#  ('Let', 12),
#  ('individual', 12),
#  ('fan/', 12),
#  ('puffed', 12),
#  ('little,', 12),
#  ('pop', 12),
#  ('scrape', 12),
#  ('excess.', 12),
#  ('week.', 12),
#  ...]

# %%
other_ingredients = Counter()

for i in range(len(data)):
    if expected_data[i] == "Other":
        for j in range(len(data[i]['Ingredients'])):       
            if data[i]['Ingredients'] != None:
                for word in data[i]['Ingredients'][j].split(" "):
                    other_ingredients[word] += 1
                    total_ingredients[word] += 1
                
other_ingredients.most_common()
# Out:
# [('1', 2063),
#  ('tbsp', 1678),
#  ('2', 1519),
#  ('chopped', 970),
#  ('and', 834),
#  ('tsp', 794),
#  ('or', 503),
#  ('3', 490),
#  ('finely', 463),
#  ('sugar', 454),
#  ('of', 454),
#  ('100g', 452),
#  ('to', 448),
#  ('oil', 444),
#  ('4', 440),
#  ('large', 412),
#  ('50g', 390),
#  ('into', 386),
#  ('small', 376),
#  ('for', 362),
#  ('sliced', 359),
#  ('olive', 316),
#  ('½', 310),
#  ('plus', 306),
#  ('red', 300),
#  ('a', 300),
#  ('butter', 287),
#  ('cut', 282),
#  ('200g', 260),
#  ('grated', 255),
#  ('serve', 252),
#  ('extra', 251),
#  ('juice', 251),
#  ('white', 246),
#  ('leaves', 246),
#  ('caster', 243),
#  ('cream', 241),
#  ('garlic', 241),
#  ('fresh', 236),
#  ('ground', 230),
#  ('peeled', 230),
#  ('the', 210),
#  ('25g', 197),
#  ('pack', 193),
#  ('6', 192),
#  ('wine', 190),
#  ('dried', 188),
#  ('roughly', 187),
#  ('double', 186),
#  ('butter,', 184),
#  ('zest', 183),
#  ('vinegar', 173),
#  ('halved', 171),
#  ('golden', 163),
#  ('handful', 161),
#  ('flour', 158),
#  ('plain', 156),
#  ('onion,', 154),
#  ('vegetable', 153),
#  ('500g', 152),
#  ('lemon', 151),
#  ('250g', 151),
#  ('milk', 149),
#  ('crushed', 147),
#  ('stock', 143),
#  ('cinnamon', 137),
#  ('onions,', 137),
#  ('cloves,', 131),
#  ('chicken', 130),
#  ('icing', 129),
#  ('85g', 129),
#  ('140g', 129),
#  ('orange', 127),
#  ('thyme', 124),
#  ('300g', 123),
#  ('mustard', 119),
#  ('bay', 118),
#  ('x', 114),
#  ('100ml', 114),
#  ('5', 109),
#  ('oil,', 107),
#  ('in', 107),
#  ('thinly', 107),
#  ('egg', 106),
#  ('used', 105),
#  ('smoked', 105),
#  ('sunflower', 102),
#  ('8', 100),
#  ('400g', 100),
#  ('whole', 100),
#  ('light', 99),
#  ('mixed', 98),
#  ('seeds', 98),
#  ('bunch', 95),
#  ('dark', 95),
#  ('if', 92),
#  ('diced', 91),
#  ('from', 89),
#  ('200ml', 89),
#  ('pinch', 88),
#  ('chunks', 88),
#  ('slices', 88),
#  ('cooked', 87),
#  ('150ml', 87),
#  ('(optional)', 87),
#  ('brown', 86),
#  ('toasted', 86),
#  ('shredded', 85),
#  ('sauce', 85),
#  ('beaten', 85),
#  ('pieces', 85),
#  ('cloves', 84),
#  ('few', 84),
#  ('black', 84),
#  ('300ml', 83),
#  ('honey', 83),
#  ('with', 83),
#  ('greasing', 82),
#  ('dusting', 81),
#  ('medium', 81),
#  ('vanilla', 79),
#  ('sugar,', 79),
#  ('1kg', 78),
#  ('frozen', 77),
#  ('leaves,', 77),
#  ('1½', 74),
#  ('about', 73),
#  ('powder', 72),
#  ('chocolate,', 72),
#  ('softened', 71),
#  ('soft', 71),
#  ('clove,', 71),
#  ('salt', 70),
#  ('¼', 70),
#  ('150g', 70),
#  ('500ml', 68),
#  ('175g', 68),
#  ('nutmeg', 68),
#  ('removed', 68),
#  ('parsley,', 68),
#  ('carrots,', 67),
#  ('unsalted', 66),
#  ('trimmed', 66),
#  ('cored', 65),
#  ('sprigs', 64),
#  ('crème', 64),
#  ('you', 63),
#  ('syrup', 61),
#  ('eggs', 61),
#  ('coriander', 60),
#  ('parsley', 60),
#  ('good', 58),
#  ('can', 58),
#  ('pot', 57),
#  ('12', 57),
#  ('75g', 56),
#  ('streaky', 56),
#  ('deseeded', 55),
#  ('muscovado', 55),
#  ('egg,', 55),
#  ('as', 55),
#  ('potatoes,', 55),
#  ('little', 54),
#  ('ginger', 53),
#  ('quartered', 53),
#  ('sea', 53),
#  ('50ml', 53),
#  ('green', 52),
#  ('brandy', 52),
#  ('eggs,', 52),
#  ('ginger,', 52),
#  ('fraîche', 52),
#  ('cranberries', 50),
#  ('clear', 50),
#  ('freshly', 50),
#  ('Brussels', 50),
#  ('on', 50),
#  ('peeled,', 50),
#  ('450g', 49),
#  ('broken', 49),
#  ('250ml', 49),
#  ('flour,', 48),
#  ('cider', 48),
#  ('leftover', 48),
#  ('fat', 48),
#  ('star', 48),
#  ('600ml', 47),
#  ('cranberry', 47),
#  ('rashers', 47),
#  ('350g', 47),
#  ('kg', 47),
#  ('sage', 47),
#  ('lemon,', 47),
#  ('piece', 47),
#  ('chocolate', 47),
#  ('chilli', 47),
#  ('each', 45),
#  ('good-quality', 45),
#  ('shallots,', 45),
#  ('wedges', 45),
#  ('cheese', 45),
#  ('400ml', 45),
#  ('wholegrain', 45),
#  ('water', 44),
#  ('bacon', 44),
#  ('half', 44),
#  ('vegetarian', 44),
#  ('thin', 44),
#  ('tub', 43),
#  ('turkey', 43),
#  ('decorate', 43),
#  ('knob', 43),
#  ('225g', 42),
#  ('leaf', 42),
#  ('(about', 41),
#  ('zested', 41),
#  ('bag', 40),
#  ('stick', 40),
#  ('extract', 40),
#  ('dry', 40),
#  ('baby', 40),
#  ('jar', 40),
#  ('cumin', 40),
#  ('rice', 40),
#  ('lime', 40),
#  ('anise', 40),
#  ('breadcrumbs', 39),
#  ('pork', 39),
#  ('rosemary', 39),
#  ('coconut', 39),
#  ('spring', 38),
#  ('picked', 38),
#  ('sesame', 38),
#  ('1l', 37),
#  ('chopped,', 37),
#  ('cocoa', 37),
#  ('drizzle', 37),
#  ('drained', 37),
#  ('such', 37),
#  ('(we', 36),
#  ('very', 36),
#  ('juiced', 36),
#  ('separated', 36),
#  ('peppercorns', 36),
#  ('chilli,', 36),
#  ('cabbage,', 35),
#  ('Dijon', 35),
#  ('pastry', 35),
#  ('left', 35),
#  ('cheese,', 34),
#  ('maple', 33),
#  ('tomato', 33),
#  ('apples,', 33),
#  ('orange,', 33),
#  ('potato,', 33),
#  ('apple,', 33),
#  ('ice', 33),
#  ('puff', 33),
#  ('seed', 33),
#  ('soy', 33),
#  ('salmon', 33),
#  ('port', 32),
#  ('sticks', 32),
#  ('cubes', 32),
#  ('10', 32),
#  ('Bramley', 32),
#  ('rapeseed', 32),
#  ('melted', 31),
#  ('pepper', 31),
#  ('goose', 31),
#  ('whites', 31),
#  ('(or', 31),
#  ('spice', 31),
#  ('strips', 31),
#  ('sweet', 31),
#  ('chestnut', 31),
#  ('garnish', 30),
#  ('almond', 30),
#  ('carton', 30),
#  ('apple', 30),
#  ('your', 30),
#  ('hot', 30),
#  ('600g', 30),
#  ('grating', 29),
#  ('bread', 29),
#  ('bread,', 29),
#  ('thickly', 29),
#  ('sherry', 29),
#  ('Maris', 29),
#  ('&', 29),
#  ('taste', 29),
#  ('shallot,', 29),
#  ('turkey,', 28),
#  ('bacon,', 28),
#  ('thick', 28),
#  ('almonds', 28),
#  ('beef', 28),
#  ('yogurt', 28),
#  ('use', 28),
#  ('24', 28),
#  ('fennel', 28),
#  ('bottle', 28),
#  ('paprika', 27),
#  ('cardamom', 27),
#  ('duck', 27),
#  ('balsamic', 27),
#  ('cornflour', 27),
#  ('mini', 27),
#  ('sticks,', 27),
#  ('ripe', 27),
#  ('coriander,', 27),
#  ('breadcrumb', 27),
#  ('parsnips,', 27),
#  ('cherry', 27),
#  ('packs', 27),
#  ('jelly', 27),
#  ('well', 26),
#  ('root', 26),
#  ('carrot,', 26),
#  ('flaked', 26),
#  ('baking', 26),
#  ('yolks', 26),
#  ('heaped', 26),
#  ('pepper,', 26),
#  ('other', 26),
#  ('pomegranate', 26),
#  ('horseradish', 26),
#  ('potatoes', 26),
#  ('strong', 25),
#  ('crumbled', 25),
#  ('allspice', 25),
#  ('walnut', 25),
#  ('lightly', 25),
#  ('flat-leaf', 25),
#  ('sprouts,', 25),
#  ('vodka', 24),
#  ('cayenne', 24),
#  ('virgin', 24),
#  ('cold', 24),
#  ('284ml', 24),
#  ('celery', 24),
#  ('leeks,', 24),
#  ('but', 24),
#  ('raw', 24),
#  ('onion', 24),
#  ('mayonnaise', 24),
#  ('stalks', 24),
#  ('yeast', 23),
#  ('coffee', 23),
#  ('dill,', 23),
#  ('lengthways', 23),
#  ('1-2', 23),
#  ('like', 23),
#  ('2½', 23),
#  ('any', 23),
#  ('splash', 23),
#  ('is', 23),
#  ('English', 23),
#  ('butternut', 23),
#  ('long', 23),
#  ('skin', 23),
#  ('800g', 23),
#  ('food', 22),
#  ('sprigs,', 22),
#  ('sprig', 22),
#  ('sprinkling', 22),
#  ('mint', 22),
#  ('cubed', 22),
#  ('full-fat', 22),
#  ('(see', 21),
#  ('granulated', 21),
#  ('16', 21),
#  ('peel', 21),
#  ('oven-ready', 21),
#  ('spinach', 21),
#  ('rum', 21),
#  ('salted', 21),
#  ('purée', 21),
#  ('jam', 21),
#  ('flakes', 21),
#  ('oz', 20),
#  ('ready-to-eat', 20),
#  ('self-raising', 20),
#  ('pine', 20),
#  ('eating', 20),
#  ('blanched', 20),
#  ('tin', 20),
#  ('giblets', 20),
#  ('quartered,', 20),
#  ('mushroom,', 20),
#  ('wild', 20),
#  ('paste', 20),
#  ('floury', 20),
#  ('-', 20),
#  ('pancetta', 20),
#  ('125g', 20),
#  ('juniper', 20),
#  ('redcurrant', 20),
#  ('7g', 19),
#  ('Greek', 19),
#  ("goat's", 19),
#  ('blue', 19),
#  ('Piper', 19),
#  ('cooking', 19),
#  ('nutmeg,', 19),
#  ('unpeeled', 19),
#  ('squash,', 19),
#  ('all', 19),
#  ('sage,', 18),
#  ('cream,', 18),
#  ('demerara', 18),
#  ('clementines,', 18),
#  ('salad', 18),
#  ('mascarpone', 18),
#  ('torn', 18),
#  ('shelled', 18),
#  ('cheddar,', 18),
#  ('washed', 18),
#  ('thyme,', 18),
#  ('snipped', 18),
#  ('parmesan,', 18),
#  ('then', 18),
#  ('natural', 18),
#  ('75ml', 18),
#  ('stem', 17),
#  ('lemons', 17),
#  ('stoned', 17),
#  ('30g', 17),
#  ('chestnuts,', 17),
#  ('pared', 17),
#  ('curry', 17),
#  ('out', 17),
#  ('coarsely', 17),
#  ('edible', 17),
#  ('have', 17),
#  ('frying', 17),
#  ('madeira', 17),
#  ('watercress', 17),
#  ('below)', 17),
#  ('pitted', 16),
#  ('sprout,', 16),
#  ('ham', 16),
#  ('it', 16),
#  ('bar', 16),
#  ('pears,', 16),
#  ('coarse', 16),
#  ('tomatoes', 16),
#  ('2kg', 16),
#  ('fine', 16),
#  ('turmeric', 16),
#  ('defrosted', 16),
#  ('2-3', 16),
#  ('extra-virgin', 16),
#  ('125ml', 16),
#  ('375g', 16),
#  ('sliced,', 16),
#  ('25ml', 16),
#  ('King', 16),
#  ('new', 16),
#  ('at', 15),
#  ('seeds,', 15),
#  ('single', 15),
#  ('oranges', 15),
#  ('vegan', 15),
#  ('raisin', 15),
#  ('20', 15),
#  ('halved,', 15),
#  ('nuts', 15),
#  ('parmesan(or', 15),
#  ('are', 15),
#  ('stock,', 15),
#  ('bulb,', 15),
#  ('parsnip,', 15),
#  ('oranges,', 15),
#  ('sheets', 15),
#  ('nut', 15),
#  ('rinsed', 15),
#  ('20g', 15),
#  ('more', 15),
#  ('celeriac,', 15),
#  ('Worcestershire', 14),
#  ('Christmas', 14),
#  ('fruit', 14),
#  ('sultanas', 14),
#  ('drizzling', 14),
#  ('80g', 14),
#  ('sauce,', 14),
#  ('soaked', 14),
#  ('split', 14),
#  ('almonds,', 14),
#  ('chillies,', 14),
#  ('prosciutto', 14),
#  ('potato', 14),
#  ('15g', 14),
#  ('mushrooms,', 14),
#  ('basmati', 14),
#  ('yellow', 14),
#  ('cocktail', 14),
#  ('gelatine', 14),
#  ('berries', 14),
#  ('soured', 14),
#  ('their', 14),
#  ('removed,', 14),
#  ('alternative)', 14),
#  ('bone', 14),
#  ('basil', 14),
#  ('pod', 14),
#  ('4½', 14),
#  ('120g', 14),
#  ('fast-action', 13),
#  ('room', 13),
#  ('pecans,', 13),
#  ('pods', 13),
#  ('cake', 13),
#  ('mix', 13),
#  ('pods,', 13),
#  ('see', 13),
#  ('custard', 13),
#  ('boneless', 13),
#  ('pod,', 13),
#  ('only', 13),
#  ('walnuts,', 13),
#  ('ones', 13),
#  ('beetroot,', 13),
#  ('skins', 13),
#  ('gold', 13),
#  ('ham,', 13),
#  ('chilled', 13),
#  ('dill', 13),
#  ('apricots,', 13),
#  ('hazelnuts,', 13),
#  ('flaky', 13),
#  ('chives,', 13),
#  ('dice', 13),
#  ('carrots', 13),
#  ('parmesan', 13),
#  ('drops', 13),
#  ('60g', 13),
#  ('rocket', 13),
#  ('temperature', 12),
#  ('apricot', 12),
#  ('700g', 12),
#  ('de', 12),
#  ('soda', 12),
#  ('raisins', 12),
#  ('suet', 12),
#  ('generous', 12),
#  ('cranberries,', 12),
#  ('banana', 12),
#  ('roast', 12),
#  ('firm', 12),
#  ('beetroot', 12),
#  ('clove', 12),
#  ('neck', 12),
#  ('liqueur', 12),
#  ('all-butter', 12),
#  ('bags', 12),
#  ('bashed', 12),
#  ('chives', 12),
#  ('cube', 12),
#  ('candied', 12),
#  ('skinless', 12),
#  ('cucumber,', 12),
#  ('stick,', 12),
#  ('pistachios', 12),
#  ('oilor', 12),
#  ('Edward', 12),
#  ('175ml', 12),
#  ('hard', 12),
#  ('made', 12),
#  ('berries,', 12),
#  ('squeeze', 12),
#  ('chunky', 12),
#  ('40g', 11),
#  ('instant', 11),
#  ('Cointreau', 11),
#  ('nuts,', 11),
#  ('lemons,', 11),
#  ('vacuum-packed', 11),
#  ('boiled', 11),
#  ('beans,', 11),
#  ('oregano', 11),
#  ('roasted', 11),
#  ('up', 11),
#  ('alternative),', 11),
#  ('60ml', 11),
#  ('peppermint', 11),
#  ('gruyère,', 11),
#  ('will', 11),
#  ('onions', 11),
#  ('thumb-sized', 11),
#  ('rind', 11),
#  ('clementines', 11),
#  ('oats', 11),
#  ('desiccated', 11),
#  ('an', 11),
#  ('1¼kg', 11),
#  ('2cm', 11),
#  ('thymesprigs', 11),
#  ('handfuls', 11),
#  ('truffle', 11),
#  ('cleaned', 11),
#  ('need', 11),
#  ('heads', 11),
#  ('diagonal', 11),
#  ('1cm', 11),
#  ('3-4', 11),
#  ('sachet', 10),
#  ('limes,', 10),
#  ('optional', 10),
#  ('packet', 10),
#  ('passion', 10),
#  ('sifted', 10),
#  ('brushing', 10),
#  ('reserved', 10),
#  ('142ml', 10),
#  ('head', 10),
#  ('butcher', 10),
#  ('whipping', 10),
#  ('750g', 10),
#  ('celery,', 10),
#  ('florets', 10),
#  ('quarters', 10),
#  ('squeezed', 10),
#  ('not', 10),
#  ('whisky', 10),
#  ('mild', 10),
#  ('rounded', 10),
#  ('ready-rolled', 10),
#  ('chutney', 10),
#  ('pineapple,', 10),
#  ('chestnuts', 10),
#  ('apricot,', 10),
#  ('350ml', 10),
#  ('mango', 10),
#  ('7', 10),
#  ('sprouts', 10),
#  ('Savoy', 10),
#  ('feta', 10),
#  ('gluten-free', 10),
#  ('18', 10),
#  ('preferably', 10),
#  ('gin', 10),
#  ('pink', 10),
#  ('polenta', 10),
#  ('filo', 10),
#  ('pumpkin', 10),
#  ('900g', 9),
#  ('Grand', 9),
#  ('bicarbonate', 9),
#  ('clementine', 9),
#  ('4-5', 9),
#  ('cm', 9),
#  ('peppercorn', 9),
#  ('walnuts', 9),
#  ('170g', 9),
#  ('mature', 9),
#  ('unsmoked', 9),
#  ('top', 9),
#  ('glass', 9),
#  ('trimmed,', 9),
#  ('buy', 9),
#  ('make', 9),
#  ('1.2l', 9),
#  ('prosecco', 9),
#  ('rosemarysprigs', 9),
#  ('seed,', 9),
#  ('yolk', 9),
#  ('marshmallows', 9),
#  ('one', 9),
#  ('poppy', 9),
#  ('salmon,', 9),
#  ('chestnut,', 9),
#  ('mixture', 9),
#  ('creamed', 9),
#  ('280g', 9),
#  ('mushrooms', 9),
#  ('mint,', 9),
#  ('walnut,', 9),
#  ('sausages', 9),
#  ('wine,', 9),
#  ('pea', 9),
#  ('shallots', 9),
#  ('rosemary,', 9),
#  ('rose', 9),
#  ('rounds', 9),
#  ('wedges,', 9),
#  ('this', 9),
#  ('pistachios,', 9),
#  ('70%', 9),
#  ('flatleaf', 9),
#  ('Gem', 9),
#  ('peppers,', 8),
#  ('garlic,', 8),
#  ('Chinese', 8),
#  ('fl', 8),
#  ('pecans', 8),
#  ('rye', 8),
#  ('strip', 8),
#  ('sultana', 8),
#  ('quality', 8),
#  ('bulb', 8),
#  ('prawns,', 8),
#  ('middle', 8),
#  ('celerysticks,', 8),
#  ('powder,', 8),
#  ('meat', 8),
#  ("'Goes", 8),
#  ('marzipan', 8),
#  ('marmalade', 8),
#  ('scrubbed', 8),
#  ('kept', 8),
#  ('(from', 8),
#  ('juice,', 8),
#  ('size', 8),
#  ('chipolatas', 8),
#  ('big', 8),
#  ('button', 8),
#  ('we', 8),
#  ('mace', 8),
#  ('tomatoes,', 8),
#  ('ready-made', 8),
#  ('breasts,', 8),
#  ('rolled', 8),
#  ('yogurt,', 8),
#  ('sourdough', 8),
#  ('warm', 8),
#  ('nut,', 8),
#  ('3kg', 8),
#  ('fillet', 8),
#  ('raspberry', 8),
#  ('raspberries', 8),
#  ('batons', 8),
#  ('750ml', 8),
#  ('l', 8),
#  ('15', 8),
#  ('pineapple', 8),
#  ('core', 8),
#  ('chicory,', 8),
#  ('halves', 8),
#  ('sparkling', 8),
#  ("'goes", 7),
#  ("with')", 7),
#  ('cabbage', 7),
#  ('1kg/2lb', 7),
#  ('slightly', 7),
#  ('Marnier', 7),
#  ('pecan', 7),
#  ('5cm', 7),
#  ('850ml', 7),
#  ('apricots', 7),
#  ('watercress,', 7),
#  ('fronds', 7),
#  ('cherries', 7),
#  ('rolling', 7),
#  ('milk,', 7),
#  ('red-skinned', 7),
#  ('marzipan,', 7),
#  ('mince', 7),
#  ('skinned', 7),
#  ('marsala', 7),
#  ('tubs', 7),
#  ('5-5½', 7),
#  ('4oz', 7),
#  ('hazelnuts', 7),
#  ('glacé', 7),
#  ('roasting', 7),
#  ('turnips,', 7),
#  ('some', 7),
#  ('lentils', 7),
#  ('700ml', 7),
#  ('fondant', 7),
#  ('ready-to-roll', 7),
#  ('glaze', 7),
#  ('peanut', 7),
#  ('shop-bought', 7),
#  ('apples', 7),
#  ('over', 7),
#  ('stripped', 7),
#  ('squash', 7),
#  ('parsnips', 7),
#  ('–', 7),
#  ('condensed', 7),
#  ('molasses', 7),
#  ('sausages,', 7),
#  ('back', 7),
#  ('550g', 7),
#  ('prawns', 7),
#  ('Thai', 7),
#  ('saltflakes', 7),
#  ('matchsticks', 7),
#  ('lime,', 7),
#  ('tarragon,', 7),
#  ('celeriac', 7),
#  ('serving', 7),
#  ('chorizo', 7),
#  ('using', 7),
#  ('livers,', 7),
#  ('jumbo', 7),
#  ('leek,', 7),
#  ('70g', 7),
#  ('biscuits,', 7),
#  ('rings', 7),
#  ('cans', 7),
#  ('approx', 7),
#  ('get', 7),
#  ('chicory', 7),
#  ('lardons', 7),
#  ('ends', 7),
#  ('400g/14oz', 7),
#  ('depending', 7),
#  ('(you', 7),
#  ('slice', 7),
#  ('unwaxed', 7),
#  ('cooled', 7),
#  ('harissa', 7),
#  ('another', 7),
#  ('groundnut', 7),
#  ('cornichons,', 7),
#  ('stuffing', 6),
#  ('weight', 6),
#  ('boiling', 6),
#  ('fruits', 6),
#  ('fillets,', 6),
#  ('saffron', 6),
#  ('currants', 6),
#  ('block', 6),
#  ('colouring', 6),
#  ('wineor', 6),
#  ('100g/4oz', 6),
#  ('rosemarysprigs,', 6),
#  ('cabbage(about', 6),
#  ('pear', 6),
#  ('loaf', 6),
#  ('stilton,', 6),
#  ('leaf,', 6),
#  ('syrup,', 6),
#  ('caramel', 6),
#  ('give', 6),
#  ('goose,', 6),
#  ('find', 6),
#  ('around', 6),
#  ('500g/1lb', 6),
#  ('pastry,', 6),
#  ('thawed', 6),
#  ('pistachio', 6),
#  ('salt,', 6),
#  ('biscuits', 6),
#  ('397g', 6),
#  ('cauliflower,', 6),
#  ('bean,', 6),
#  ('Disaronno', 6),
#  ('5oz', 6),
#  ('beaten,', 6),
#  ('minced', 6),
#  ('tarragon', 6),
#  ('treacle', 6),
#  ('parsnip', 6),
#  ('650g', 6),
#  ('swede,', 6),
#  ('too', 6),
#  ('wings', 6),
#  ('sheet', 6),
#  ('ice,', 6),
#  ('240g', 6),
#  ('450ml', 6),
#  ('brie,', 6),
#  ('rest', 6),
#  ('jars', 6),
#  ('porcinimushrooms', 6),
#  ('toast,', 6),
#  ('Piper,', 6),
#  ('sachets', 6),
#  ('peel,', 6),
#  ('Tabasco', 6),
#  ('squares', 6),
#  ('olives', 6),
#  ('prepared', 6),
#  ('320g', 6),
#  ('excess', 6),
#  ('legs', 6),
#  ('gammon', 6),
#  ('peeler', 6),
#  ('Granny', 6),
#  ('bottles', 6),
#  ('quantity', 6),
#  ('pancetta,', 6),
#  ('8oz', 6),
#  ('6-8', 6),
#  ('porridge', 6),
#  ('Puy', 6),
#  ('thymesprigs,', 6),
#  ('amaretti', 6),
#  ('parmesan-style', 6),
#  ('(available', 6),
#  ('peas', 6),
#  ('do', 6),
#  ('120ml', 6),
#  ('rosemarysprig,', 6),
#  ('ketchup', 6),
#  ('only,', 6),
#  ('Little', 6),
#  ('shallot', 6),
#  ('lengthways,', 6),
#  ('90g', 6),
#  ('rosewater', 6),
#  ('larger', 6),
#  ('fingers', 6),
#  ('peppercorns,', 6),
#  ('wholemeal', 6),
#  ('plump', 6),
#  ('hazelnut', 6),
#  ('sweetened', 6),
#  ('want', 6),
#  ('crabmeat', 6),
#  ('olives,', 6),
#  ('tiger', 6),
#  ('limes', 5),
#  ('five-spice', 5),
#  ('dulce', 5),
#  ('Merchant', 5),
#  ('Gourmet)', 5),
#  ('litre', 5),
#  ('100ml/3½', 5),
#  ('lolly', 5),
#  ('writing', 5),
#  ('shortcrust', 5),
#  ('sifted,', 5),
#  ('dust', 5),
#  ('liquid', 5),
#  ('dates', 5),
#  ('frozen)', 5),
#  ('crusts', 5),
#  ('sausagemeat', 5),
#  ('1⁄2', 5),
#  ('crusty', 5),
#  ('scooped', 5),
#  ('on,', 5),
#  ('wedge', 5),
#  ('tied', 5),
#  ('paste)', 5),
#  ('scattering', 5),
#  ('softened,', 5),
#  ('2oz', 5),
#  ('2l', 5),
#  ('good)', 5),
#  ('seeded', 5),
#  ('5kg', 5),
#  ('200g/7oz', 5),
#  ('breast', 5),
#  ('grated,', 5),
#  ('assorted', 5),
#  ('choice', 5),
#  ('water,', 5),
#  ('brandy,', 5),
#  ('bouillon', 5),
#  ('outer', 5),
#  ('same', 5),
#  ('don’t', 5),
#  ('essence', 5),
#  ('Cumberland', 5),
#  ('topping', 5),
#  ('gift', 5),
#  ('long,', 5),
#  ('balls', 5),
#  ("don't", 5),
#  ('kirsch', 5),
#  ('8-10', 5),
#  ('cooked,', 5),
#  ('avocado,', 5),
#  ('36', 5),
#  ('label', 5),
#  ('five', 5),
#  ('mincemeat', 5),
#  ('cherry,', 5),
#  ('bruised', 5),
#  ('tip', 5),
#  ('dry-cured', 5),
#  ('noodles', 5),
#  ('flavourless', 5),
#  ('small,', 5),
#  ('naan', 5),
#  ('160g', 5),
#  ('vegetables,', 5),
#  ('fork', 5),
#  ('40', 5),
#  ('sundried', 5),
#  ('king', 5),
#  ('free-range', 5),
#  ('2cm/¾', 5),
#  ('scraped', 5),
#  ('garlicbulb,', 5),
#  ('cranberry,', 5),
#  ('elderflower', 5),
#  ('cordial', 5),
#  ('32', 5),
#  ('Desirée', 5),
#  ('almond,', 5),
#  ('French', 5),
#  ('porcini', 5),
#  ...]

# %%
other_method = Counter()

for i in range(len(data)):
    if expected_data[i] == "Other":
        for j in range(len(data[i]['Method'])):       
            if data[i]['Method'] != None:
                for word in data[i]['Method'][j].split(" "):
                    other_method[word] += 1
                    total_method[word] += 1
                
other_method.most_common()
# Out:
# [('the', 19332),
#  ('and', 9461),
#  ('a', 7425),
#  ('to', 5442),
#  ('in', 4193),
#  ('with', 3574),
#  ('for', 3378),
#  ('of', 3150),
#  ('then', 2816),
#  ('until', 2548),
#  ('into', 2042),
#  ('over', 1331),
#  ('on', 1311),
#  ('mins', 1307),
#  ('or', 1188),
#  ('it', 978),
#  ('oven', 920),
#  ('pan', 823),
#  ('large', 818),
#  ('from', 759),
#  ('you', 758),
#  ('Heat', 756),
#  ('add', 727),
#  ('up', 719),
#  ('is', 700),
#  ('heat', 665),
#  ('1', 630),
#  ('cook', 611),
#  ('Put', 604),
#  ('Add', 589),
#  ('each', 579),
#  ('all', 568),
#  ('baking', 558),
#  ('2', 549),
#  ('oil', 503),
#  ('out', 491),
#  ('mins.', 490),
#  ('butter', 463),
#  ('water', 463),
#  ('tin', 458),
#  ('sugar', 454),
#  ('as', 453),
#  ('if', 450),
#  ('bowl', 439),
#  ('make', 438),
#  ('top', 433),
#  ('fan/gas', 428),
#  ('leave', 418),
#  ('mins,', 414),
#  ('stir', 410),
#  ('your', 408),
#  ('be', 407),
#  ('mixture', 405),
#  ('remaining', 403),
#  ('about', 400),
#  ('are', 393),
#  ('little', 378),
#  ('at', 378),
#  ('–', 374),
#  ('Pour', 369),
#  ('mix', 367),
#  ('', 355),
#  ('cover', 351),
#  ('Remove', 345),
#  ('them', 343),
#  ('10', 340),
#  ('cream', 336),
#  ('small', 331),
#  ('To', 331),
#  ('before', 328),
#  ('5', 326),
#  ('put', 322),
#  ('pour', 321),
#  ('cool', 312),
#  ('together', 309),
#  ('will', 307),
#  ('some', 303),
#  ('so', 302),
#  ('Tip', 300),
#  ('set', 298),
#  ('tbsp', 296),
#  ('off', 295),
#  ('half', 292),
#  ('Stir', 290),
#  ('onto', 283),
#  ('roasting', 282),
#  ('potatoes', 281),
#  ('few', 276),
#  ('turkey', 276),
#  ('30', 274),
#  ('gently', 269),
#  ('more', 262),
#  ('just', 262),
#  ('bring', 261),
#  ('through', 260),
#  ('can', 260),
#  ('salt', 258),
#  ('cut', 254),
#  ('Leave', 252),
#  ('one', 249),
#  ('well', 248),
#  ('but', 247),
#  ('any', 246),
#  ('egg', 244),
#  ('Mix', 243),
#  ('frying', 243),
#  ('has', 241),
#  ('golden', 240),
#  ('have', 239),
#  ('chocolate', 238),
#  ('pan,', 234),
#  ('stirring', 232),
#  ('remove', 232),
#  ('tip', 231),
#  ('fridge', 230),
#  ('juice', 230),
#  ('simmer', 229),
#  ('rest', 225),
#  ('this', 224),
#  ('cling', 223),
#  ('keep', 223),
#  ('Serve', 223),
#  ('3', 222),
#  ('lemon', 221),
#  ('that', 221),
#  ('20', 221),
#  ('they', 219),
#  ('an', 216),
#  ('turn', 215),
#  ('bowl,', 215),
#  ('spoon', 210),
#  ('season', 208),
#  ('hot', 208),
#  ('by', 207),
#  ('down', 204),
#  ('around', 204),
#  ('Place', 201),
#  ('Meanwhile,', 200),
#  ('Cover', 200),
#  ('place', 200),
#  ('When', 194),
#  ('fry', 193),
#  ('back', 188),
#  ('Bring', 188),
#  ('icing', 187),
#  ('tray', 187),
#  ('sauce', 185),
#  ('serve', 183),
#  ('Cut', 180),
#  ('garlic', 179),
#  ('6.', 179),
#  ('bake', 178),
#  ('fat', 177),
#  ('If', 176),
#  ('4', 174),
#  ('warm', 172),
#  ('boil', 172),
#  ('roll', 171),
#  ('15', 170),
#  ('ingredients', 169),
#  ('200C/180C', 169),
#  ('golden.', 168),
#  ('Cook', 168),
#  ('lightly', 167),
#  ('using', 167),
#  ('pan.', 167),
#  ('pastry', 167),
#  ('onion', 167),
#  ('another', 165),
#  ('serving', 164),
#  ('use', 163),
#  ('not', 163),
#  ('orange', 162),
#  ('dough', 161),
#  ('serve.', 161),
#  ('bowl.', 159),
#  ('chill', 159),
#  ('stock', 159),
#  ('cooking', 158),
#  ('whisk', 157),
#  ('film', 156),
#  ('Bake', 155),
#  ('Season', 155),
#  ('medium', 154),
#  ('skin', 154),
#  ('very', 154),
#  ('side', 153),
#  ('foil', 152),
#  ('flour', 151),
#  ('saucepan', 151),
#  ('cake', 151),
#  ('slices', 149),
#  ('well.', 149),
#  ('ready', 149),
#  ('cool.', 149),
#  ('water.', 148),
#  ('should', 148),
#  ('chopped', 147),
#  ('milk', 146),
#  ('The', 146),
#  ('boil,', 146),
#  ('food', 144),
#  ('juices', 144),
#  ('between', 144),
#  ('roast', 144),
#  ('leaves', 143),
#  ('aside', 140),
#  ('Spoon', 140),
#  ('everything', 140),
#  ('scatter', 139),
#  ('two', 137),
#  ('tsp', 136),
#  ('serve,', 135),
#  ('heat,', 134),
#  ('thick', 134),
#  ('slice', 133),
#  ('sugar,', 132),
#  ('tin,', 132),
#  ('cold', 132),
#  ('dry', 132),
#  ('tin.', 130),
#  ('sheet', 129),
#  ('enough', 129),
#  ('soft', 128),
#  ('toss', 128),
#  ('Once', 127),
#  ('drizzle', 126),
#  ('zest', 125),
#  ('cheese', 125),
#  ('layer', 125),
#  ('aside.', 124),
#  ('tender.', 123),
#  ('top.', 123),
#  ('onions', 122),
#  ('In', 121),
#  ('6', 121),
#  ('piece', 121),
#  ('dish', 121),
#  ('bacon', 119),
#  ('Drain', 119),
#  ('boil.', 118),
#  ('Turn', 118),
#  ('Can', 118),
#  ('return', 118),
#  ('cooked', 118),
#  ('butter,', 117),
#  ('least', 117),
#  ('along', 117),
#  ('surface', 117),
#  ('end', 116),
#  ('knife', 114),
#  ('completely', 113),
#  ('Scatter', 112),
#  ('ice', 112),
#  ('heat.', 111),
#  ('water,', 110),
#  ('liquid', 109),
#  ('brown', 109),
#  ('parchment', 109),
#  ('meat', 109),
#  ('x', 108),
#  ('Set', 108),
#  ('olive', 108),
#  ('low', 108),
#  ('bay', 108),
#  ('sprinkle', 107),
#  ('paper', 107),
#  ('Use', 107),
#  ('sides', 107),
#  ('smooth', 107),
#  ('brush', 107),
#  ('under', 106),
#  ('white', 106),
#  ('thyme', 105),
#  ('carefully', 105),
#  ('further', 105),
#  ('chicken', 105),
#  ('away', 104),
#  ('180C/160C', 103),
#  ('while', 101),
#  ('Roast', 101),
#  ('hrs', 101),
#  ('salmon', 101),
#  ('ham', 101),
#  ('when', 100),
#  ('spread', 100),
#  ('For', 99),
#  ('drain', 99),
#  ('minutes', 99),
#  ('oil.', 98),
#  ('stuffing', 98),
#  ('Melt', 98),
#  ('wine', 97),
#  ('base', 97),
#  ('Sprinkle', 97),
#  ('cream,', 96),
#  ('oil,', 96),
#  ('boiling', 96),
#  ('Using', 96),
#  ('turning', 96),
#  ('4.', 96),
#  ('pepper', 96),
#  ('its', 95),
#  ('crisp', 95),
#  ('line', 95),
#  ('made', 95),
#  ('don’t', 95),
#  ('pinch', 95),
#  ('good', 95),
#  ('Brush', 94),
#  ('need', 93),
#  ('Roll', 93),
#  ('other', 93),
#  ('transfer', 92),
#  ('bottom', 91),
#  ('duck', 91),
#  ('really', 91),
#  ('seasoning.', 91),
#  ('black', 91),
#  ('hr', 90),
#  ('day', 90),
#  ('Transfer', 90),
#  ('parchment.', 90),
#  ('seeds', 90),
#  ('covered', 89),
#  ('like.', 89),
#  ('butter.', 89),
#  ('take', 89),
#  ('sprouts', 89),
#  ('starting', 88),
#  ('Spread', 88),
#  ('pieces', 88),
#  ('fruit', 87),
#  ('fold', 87),
#  ('syrup', 87),
#  ('garlic,', 87),
#  ('too', 85),
#  ('days', 85),
#  ('cool,', 84),
#  ('Toss', 84),
#  ('now', 84),
#  ('together.', 84),
#  ('plate', 83),
#  ('melted', 82),
#  ('leaving', 82),
#  ('goose', 82),
#  ('beat', 82),
#  ('paper.', 82),
#  ('Whisk', 82),
#  ('slightly', 82),
#  ('middle', 82),
#  ('peel', 82),
#  ('making', 82),
#  ('finely', 82),
#  ('220C/200C', 81),
#  ('sauce.', 81),
#  ('stick', 81),
#  ('allow', 81),
#  ('Make', 80),
#  ('processor', 80),
#  ('edges', 80),
#  ('salted', 80),
#  ('time', 79),
#  ('Line', 79),
#  ('pork', 79),
#  ('through.', 78),
#  ('room', 78),
#  ('it.', 77),
#  ('Take', 77),
#  ('give', 77),
#  ('time,', 77),
#  ('foil,', 77),
#  ('salt.', 77),
#  ('2-3', 77),
#  ('pepper.', 77),
#  ('kitchen', 77),
#  ('7.', 76),
#  ('still', 76),
#  ('couple', 76),
#  ('sugar.', 76),
#  ('Carefully', 76),
#  ('seasoning', 76),
#  ('extra', 75),
#  ('sharp', 75),
#  ('clean', 75),
#  ('Chill', 75),
#  ('serving.', 75),
#  ('brown.', 74),
#  ('centre', 73),
#  ('You', 73),
#  ('eggs', 73),
#  ('freeze', 73),
#  ('shallots', 73),
#  ('Return', 73),
#  ('vinegar', 73),
#  ('carrots', 72),
#  ('like', 72),
#  ('every', 72),
#  ('non-stick', 72),
#  ('Arrange', 72),
#  ('crème', 72),
#  ('melt', 71),
#  ('gravy', 71),
#  ('both', 71),
#  ('their', 71),
#  ('do', 71),
#  ('whites', 70),
#  ('(see', 70),
#  ('Top', 70),
#  ('8', 69),
#  ('inside', 69),
#  ('40', 69),
#  ('reduce', 69),
#  ('breast', 69),
#  ('press', 69),
#  ('sieve', 69),
#  ('long', 69),
#  ('nuts', 69),
#  ('thin', 69),
#  ('hrs.', 69),
#  ('vegetables', 69),
#  ('rice', 69),
#  ('lime', 68),
#  ('(or', 68),
#  ('red', 68),
#  ('cabbage', 68),
#  ('smooth.', 68),
#  ('get', 68),
#  ('shallow', 68),
#  ('potato', 68),
#  ('pack', 67),
#  ('chop', 67),
#  ('continue', 67),
#  ('Gently', 67),
#  ('sure', 67),
#  ('3-4', 67),
#  ('frozen', 66),
#  ('ginger', 66),
#  ('min', 66),
#  ('45', 66),
#  ('dish.', 66),
#  ('excess', 66),
#  ('salt,', 65),
#  ('Fry', 65),
#  ('well,', 65),
#  ('parsley', 65),
#  ('cranberries', 64),
#  ('flour,', 64),
#  ('push', 64),
#  ('let', 64),
#  ('adding', 63),
#  ('5.', 63),
#  ('dressing', 63),
#  ('juice,', 63),
#  ('Drizzle', 63),
#  ('vanilla', 63),
#  ('start', 63),
#  ('sauce,', 63),
#  ('meringue', 62),
#  ('veg', 62),
#  ('leaves.', 62),
#  ('freezer', 62),
#  ('ground', 62),
#  ('again', 62),
#  ('mixture.', 62),
#  ('Divide', 62),
#  ('high', 62),
#  ('beef', 62),
#  ('Repeat', 61),
#  ('honey', 61),
#  ('reserved', 61),
#  ('apple', 61),
#  ('roughly', 61),
#  ('grill', 61),
#  ('strain', 61),
#  ('ahead', 61),
#  ('mushrooms', 61),
#  ('Boil', 61),
#  ('cinnamon', 60),
#  ('lift', 60),
#  ('evenly', 60),
#  ('squash', 60),
#  ('it’s', 59),
#  ('taste.', 59),
#  ('saucepan,', 59),
#  ('Fold', 59),
#  ('Simmer', 59),
#  ('board', 59),
#  ('temperature', 59),
#  ('bread', 59),
#  ('whole', 59),
#  ('dark', 58),
#  ('Will', 58),
#  ('wooden', 58),
#  ('Lay', 58),
#  ('cocktail', 58),
#  ('splash', 57),
#  ('Beat', 57),
#  ('hrs,', 57),
#  ('squeeze', 57),
#  ('work', 57),
#  ('loaf', 57),
#  ('mustard', 57),
#  ('sage', 56),
#  ('dried', 56),
#  ('Cool', 56),
#  ('lined', 56),
#  ('fridge.', 56),
#  ('up.', 56),
#  ('dish,', 56),
#  ('way', 56),
#  ('piping', 56),
#  ('Peel', 55),
#  ('crisp.', 55),
#  ('sit', 55),
#  ('bubble', 55),
#  ('wrap', 55),
#  ('over.', 55),
#  ('While', 55),
#  ('oven,', 55),
#  ('tender', 55),
#  ('tray.', 55),
#  ('cranberry', 54),
#  ('onions,', 54),
#  ('big', 54),
#  ('overnight.', 54),
#  ('chilled', 54),
#  ('Lift', 54),
#  ('salad', 53),
#  ('vinegar,', 53),
#  ('1-2', 53),
#  ('floured', 52),
#  ('more.', 52),
#  ('minutes,', 52),
#  ('once', 52),
#  ('Keep', 52),
#  ('24', 52),
#  ('bag', 52),
#  ('no', 51),
#  ('wire', 51),
#  ('lid', 51),
#  ('together,', 51),
#  ('softened.', 51),
#  ('onion,', 51),
#  ('mash', 51),
#  ('parsnips', 51),
#  ('mixture,', 51),
#  ('chilli', 51),
#  ('bird', 50),
#  ('sea', 50),
#  ('want', 50),
#  ('pudding', 50),
#  ('overnight', 50),
#  ('discard', 50),
#  ('coat', 50),
#  ('caster', 50),
#  ('soft.', 50),
#  ('seasoning,', 49),
#  ('This', 49),
#  ('round', 49),
#  ('cream.', 49),
#  ('container', 49),
#  ('mixing', 49),
#  ('deep', 49),
#  ('10-15', 49),
#  ('slowly', 49),
#  ('coriander', 49),
#  ('minutes.', 49),
#  ('leaves,', 49),
#  ('simmering', 49),
#  ('days.', 48),
#  ('turkey,', 48),
#  ('legs', 48),
#  ('help', 48),
#  ('skewer', 48),
#  ('bit', 48),
#  ('stock,', 48),
#  ('most', 48),
#  ('plenty', 48),
#  ('juice.', 48),
#  ('rosemary', 48),
#  ('Strain', 48),
#  ('come', 47),
#  ('smooth,', 47),
#  ('pepper,', 47),
#  ('.', 47),
#  ('bits', 47),
#  ('cooked,', 47),
#  ('sticky', 47),
#  ('shape', 47),
#  ('hand', 47),
#  ('divide', 47),
#  ('180C/gas', 47),
#  ('than', 47),
#  ('tray,', 47),
#  ('balls', 47),
#  ('needed.', 47),
#  ('hot.', 46),
#  ('fine', 46),
#  ('loosely', 46),
#  ('comes', 46),
#  ('top,', 46),
#  ('rack', 46),
#  ('gas', 46),
#  ('8-10', 46),
#  ('ends', 46),
#  ('run', 46),
#  ('side.', 46),
#  ('and,', 46),
#  ('milk,', 46),
#  ('ovenproof', 46),
#  ('almost', 46),
#  ('up,', 46),
#  ('coconut', 46),
#  ('zest,', 45),
#  ('knife,', 45),
#  ('per', 45),
#  ('halfway', 45),
#  ('filling', 45),
#  ('star', 45),
#  ('firm', 45),
#  ('break', 45),
#  ('final', 45),
#  ('apples', 45),
#  ('beaten', 45),
#  ('tightly', 45),
#  ('prepared', 44),
#  ('much', 44),
#  ('ahead.', 44),
#  ('reheat', 44),
#  ('set.', 44),
#  ('fill', 44),
#  ('spinach', 44),
#  ('shape.', 44),
#  ('film.', 44),
#  ('flesh', 44),
#  ('Now', 44),
#  ('rolling', 44),
#  ('marzipan', 44),
#  ('Sit', 43),
#  ('may', 43),
#  ('heatproof', 43),
#  ('glasses', 43),
#  ('month.', 43),
#  ('starts', 43),
#  ('thick.', 43),
#  ('edge', 43),
#  ('separate', 43),
#  ('arrange', 43),
#  ('season.', 43),
#  ('serving,', 43),
#  ('large,', 43),
#  ('again.', 43),
#  ('platter', 43),
#  ('fish', 43),
#  ('tea', 42),
#  ('sliced', 42),
#  ('tie', 42),
#  ('cook,', 42),
#  ('fan/', 42),
#  ('same', 42),
#  ('sausage', 42),
#  ('clementine', 42),
#  ('straight', 42),
#  ('plate.', 42),
#  ('third', 42),
#  ('hours', 42),
#  ('jug', 42),
#  ('Lightly', 41),
#  ('you’re', 41),
#  ('completely.', 41),
#  ('gravy.', 41),
#  ('scoop', 41),
#  ('Grease', 41),
#  ('saucepan.', 41),
#  ('over,', 41),
#  ('metal', 41),
#  ('slices.', 41),
#  ('25', 41),
#  ('first', 41),
#  ('15-20', 41),
#  ('hands', 41),
#  ('wedges', 41),
#  ('Slice', 41),
#  ('fresh', 41),
#  ('herbs', 41),
#  ('sheets', 41),
#  ('190C/170C', 40),
#  ('double', 40),
#  ('spices', 40),
#  ('½', 40),
#  ('grate', 40),
#  ('oven.', 40),
#  ('grated', 40),
#  ('mustard,', 40),
#  ('fraîche', 40),
#  ('jars', 39),
#  ('generously', 39),
#  ('bowls', 39),
#  ('reduced', 39),
#  ('hr.', 39),
#  ('spoon.', 39),
#  ('neck', 39),
#  ('soften', 39),
#  ('casserole', 39),
#  ('yolks', 39),
#  ('tender,', 39),
#  ('seal', 39),
#  ('dip', 39),
#  ('shake', 38),
#  ('glass', 38),
#  ('rub', 38),
#  ('go', 38),
#  ('simmer,', 38),
#  ('airtight', 38),
#  ('(if', 38),
#  ('hold', 38),
#  ('spring', 38),
#  ('200C/fan', 38),
#  ('beetroot', 38),
#  ('pat', 38),
#  ('softened', 38),
#  ('Allow', 38),
#  ('risen', 37),
#  ('jam', 37),
#  ('after', 37),
#  ('foil.', 37),
#  ('3.', 37),
#  ('outside', 37),
#  ('cloves', 37),
#  ('custard', 37),
#  ('soften.', 37),
#  ('joint', 37),
#  ('even', 37),
#  ('lay', 37),
#  ('surface.', 36),
#  ('quickly', 36),
#  ('months.', 36),
#  ('used', 36),
#  ('20cm', 36),
#  ('length', 36),
#  ('form', 36),
#  ('25-30', 36),
#  ('chocolate.', 36),
#  ('electric', 36),
#  ('thigh', 36),
#  ('spoonful', 36),
#  ('last', 36),
#  ('slotted', 36),
#  ('microwave', 36),
#  ('jelly', 36),
#  ('cheese,', 36),
#  ('sterilised', 35),
#  ('almonds', 35),
#  ('dough.', 35),
#  ('mix.', 35),
#  ('On', 35),
#  ('mixed', 35),
#  ('syrup,', 35),
#  ('breadcrumbs', 35),
#  ('sausages', 35),
#  ('pears', 35),
#  ('cooking,', 35),
#  ('little.', 35),
#  ('whisking', 35),
#  ('down,', 35),
#  ('glaze', 34),
#  ('strips', 34),
#  ('jug.', 34),
#  ('occasionally,', 34),
#  ('toast', 34),
#  ('spoon,', 34),
#  ('5-10', 34),
#  (',', 34),
#  ('half.', 34),
#  ('Preheat', 34),
#  ('prawns', 34),
#  ('three', 34),
#  ('time.', 34),
#  ('hot,', 34),
#  ('paste.', 34),
#  ('sponge', 34),
#  ('Trim', 34),
#  ('smoked', 34),
#  ('nutmeg', 34),
#  ('gelatine', 34),
#  ('second', 34),
#  ('day,', 34),
#  ('yogurt', 33),
#  ('melted.', 33),
#  ('brandy', 33),
#  ('160C/140C', 33),
#  ('7', 33),
#  ('12', 33),
#  ('knead', 33),
#  ('warm.', 33),
#  ('doesn’t', 33),
#  ('sprigs', 33),
#  ('next', 33),
#  ('finish', 33),
#  ('fillet', 33),
#  ('single', 33),
#  ('oiled', 33),
#  ('pancetta', 33),
#  ('doubled', 32),
#  ('size', 32),
#  ('stock.', 32),
#  ('taste', 32),
#  ('plus', 32),
#  ('string', 32),
#  ('handful', 32),
#  ('cooled', 32),
#  ('melted,', 32),
#  ('dill', 32),
#  ('point', 32),
#  ('kept', 32),
#  ('mini', 32),
#  ('light', 32),
#  ('soak', 32),
#  ('whizz', 32),
#  ('except', 32),
#  ('golden,', 32),
#  ('slices,', 32),
#  ('potatoes,', 32),
#  ('gradually', 32),
#  ('there', 32),
#  ('parchment,', 32),
#  ('dry.', 32),
#  ('rectangle', 32),
#  ('paste', 32),
#  ('thickened.', 32),
#  ('4-5', 32),
#  ('Continue', 31),
#  ('chutney', 31),
#  ('cavity', 31),
#  ('(you', 31),
#  ('scrape', 31),
#  ('strip', 31),
#  ('Dust', 31),
#  ('eggs,', 31),
#  ('circle', 31),
#  ('Rub', 31),
#  ('chill.', 31),
#  ('With', 31),
#  ('mix,', 31),
#  ('been', 31),
#  ('purée', 31),
#  ('rashers', 31),
#  ('browned', 31),
#  ('chestnuts', 31),
#  ('pomegranate', 31),
#  ('stirring,', 30),
#  ('skin,', 30),
#  ('greaseproof', 30),
#  ('breadcrumbs,', 30),
#  ('pile', 30),
#  ('Halve', 30),
#  ('Scrape', 30),
#  ('knife.', 30),
#  ('create', 30),
#  ('cake,', 30),
#  ('Wrap', 30),
#  ('fat,', 30),
#  ('ahead,', 30),
#  ('lengthways', 30),
#  ('caramel', 30),
#  ('mint', 30),
#  ('more,', 30),
#  ('sides.', 30),
#  ('chunks', 30),
#  ('wine,', 30),
#  ('potatoes.', 30),
#  ('leaf', 30),
#  ('dressing.', 30),
#  ('powder', 29),
#  ('them.', 29),
#  ('cranberries,', 29),
#  ('Fill', 29),
#  ('100ml', 29),
#  ('nuts,', 29),
#  ('nutmeg,', 29),
#  ('stop', 29),
#  ('it,', 29),
#  ('become', 29),
#  ('coffee', 29),
#  ('freshly', 29),
#  ('green', 29),
#  ('gentle', 29),
#  ('trim', 29),
#  ('done', 29),
#  ('uncovered,', 29),
#  ('check', 29),
#  ('shelf', 29),
#  ('leeks', 29),
#  ('celeriac', 29),
#  ('cheese.', 29),
#  ('test', 29),
#  ('rise', 28),
#  ('20-25', 28),
#  ('syrupy.', 28),
#  ('four', 28),
#  ('without', 28),
#  ('best', 28),
#  ('cocoa', 28),
#  ('film,', 28),
#  ('Butter', 28),
#  ('hr,', 28),
#  ('colour.', 28),
#  ('biscuits', 28),
#  ('stiff', 28),
#  ('min.', 28),
#  ('thyme,', 28),
#  ('sweet', 28),
#  ('sesame', 28),
#  ('seeds,', 28),
#  ('jar', 28),
#  ('blitz', 28),
#  ('breasts', 27),
#  ('smaller', 27),
#  ('store', 27),
#  ('dust', 27),
#  ('little,', 27),
#  ('through,', 27),
#  ('hour', 27),
#  ('dressing,', 27),
#  ('simmer.', 27),
#  ('sizzle', 27),
#  ('min,', 27),
#  ('edges.', 27),
#  ('prosciutto', 27),
#  ('truffle', 27),
#  ('slightly.', 27),
#  ('skin.', 27),
#  ('colander', 27),
#  ('cauliflower', 27),
#  ('longer', 26),
#  ('grease', 26),
#  ('Whip', 26),
#  ('following', 26),
#  ('190C/fan', 26),
#  ('thinly', 26),
#  ('out.', 26),
#  ('week', 26),
#  ('firm.', 26),
#  ('flat', 26),
#  ('pieces.', 26),
#  ('pulse', 26),
#  ('Pack', 26),
#  ('trays', 26),
#  ('layers', 26),
#  ('liquid.', 26),
#  ('rinse', 26),
#  ('pastry.', 26),
#  ('pressing', 26),
#  ('then,', 26),
#  ('Press', 26),
#  ('blend', 26),
#  ('terrine', 26),
#  ('egg,', 26),
#  ('vegetable', 25),
#  ('glasses.', 25),
#  ('immediately.', 25),
#  ('pasta', 25),
#  ('heavy-based', 25),
#  ('170C/gas', 25),
#  ('softened,', 25),
#  ('occasionally', 25),
#  ('Cool,', 25),
#  ('(about', 25),
#  ('crispy', 25),
#  ('dissolve', 25),
#  ('vinegar.', 25),
#  ('zest.', 25),
#  ('pastry,', 25),
#  ('short', 25),
#  ('across', 25),
#  ('pop', 25),
#  ('fit', 25),
#  ('thick,', 25),
#  ('followed', 25),
#  ('alongside', 25),
#  ('colour', 25),
#  ('fingers', 25),
#  ('ingredients,', 25),
#  ('celery', 25),
#  ('ginger,', 25),
#  ('peppercorns', 25),
#  ('worry', 25),
#  ('times', 25),
#  ('mushroom', 25),
#  ('stand', 25),
#  ('syrup.', 25),
#  ('repeat', 25),
#  ('hands.', 25),
#  ('herbs,', 25),
#  ('left', 25),
#  ('drop', 25),
#  ('Reduce', 25),
#  ('peas', 25),
#  ('soup', 25),
#  ...]

# %%
total_method.most_common()
# Out:
# [('the', 28847),
#  ('and', 13773),
#  ('a', 11567),
#  ('to', 8231),
#  ('in', 6179),
#  ('with', 5529),
#  ('of', 4984),
#  ('for', 4808),
#  ('then', 4278),
#  ('until', 3751),
#  ('into', 3127),
#  ('on', 2059),
#  ('over', 1934),
#  ('mins', 1832),
#  ('or', 1778),
#  ('it', 1509),
#  ('oven', 1403),
#  ('you', 1213),
#  ('large', 1105),
#  ('out', 1097),
#  ('Heat', 1093),
#  ('from', 1065),
#  ('up', 1050),
#  ('baking', 1019),
#  ('pan', 994),
#  ('is', 991),
#  ('add', 965),
#  ('each', 903),
#  ('1', 897),
#  ('heat', 863),
#  ('sugar', 854),
#  ('Put', 843),
#  ('make', 821),
#  ('Add', 818),
#  ('2', 806),
#  ('butter', 786),
#  ('all', 786),
#  ('top', 774),
#  ('tin', 761),
#  ('cook', 743),
#  ('as', 686),
#  ('bowl', 681),
#  ('your', 679),
#  ('little', 675),
#  ('mixture', 674),
#  ('mins.', 671),
#  ('cake', 668),
#  ('fan/gas', 663),
#  ('icing', 662),
#  ('water', 661),
#  ('remaining', 651),
#  ('if', 648),
#  ('mix', 622),
#  ('leave', 621),
#  ('at', 608),
#  ('oil', 597),
#  ('about', 593),
#  ('mins,', 583),
#  ('stir', 582),
#  ('be', 580),
#  ('–', 572),
#  ('together', 570),
#  ('cool', 558),
#  ('To', 551),
#  ('', 548),
#  ('small', 539),
#  ('cover', 526),
#  ('onto', 518),
#  ('are', 515),
#  ('them', 505),
#  ('pastry', 495),
#  ('will', 480),
#  ('10', 478),
#  ('Pour', 476),
#  ('Remove', 474),
#  ('cream', 474),
#  ('half', 471),
#  ('put', 462),
#  ('5', 456),
#  ('before', 455),
#  ('so', 448),
#  ('set', 444),
#  ('Stir', 440),
#  ('off', 440),
#  ('Tip', 436),
#  ('tbsp', 433),
#  ('pour', 433),
#  ('some', 429),
#  ('30', 426),
#  ('an', 425),
#  ('cut', 424),
#  ('Leave', 422),
#  ('chocolate', 422),
#  ('egg', 417),
#  ('one', 416),
#  ('few', 405),
#  ('Mix', 396),
#  ('gently', 395),
#  ('just', 392),
#  ('any', 388),
#  ('more', 382),
#  ('well', 377),
#  ('can', 376),
#  ('golden', 368),
#  ('have', 367),
#  ('bake', 364),
#  ('around', 359),
#  ('cling', 355),
#  ('this', 346),
#  ('has', 341),
#  ('bring', 339),
#  ('down', 338),
#  ('dough', 338),
#  ('bowl,', 337),
#  ('remove', 335),
#  ('but', 335),
#  ('Bake', 334),
#  ('through', 334),
#  ('keep', 333),
#  ('flour', 330),
#  ('3', 328),
#  ('roll', 324),
#  ('by', 320),
#  ('fridge', 317),
#  ('salt', 316),
#  ('roasting', 316),
#  ('turn', 315),
#  ('using', 312),
#  ('tip', 312),
#  ('potatoes', 310),
#  ('20', 309),
#  ('rest', 307),
#  ('use', 301),
#  ('spoon', 300),
#  ('that', 300),
#  ('stirring', 297),
#  ('place', 296),
#  ('they', 291),
#  ('When', 291),
#  ('lightly', 291),
#  ('pan,', 289),
#  ('Serve', 289),
#  ('turkey', 283),
#  ('lemon', 281),
#  ('juice', 281),
#  ('Cover', 281),
#  ('frying', 279),
#  ('Cut', 277),
#  ('If', 277),
#  ('whisk', 275),
#  ('orange', 274),
#  ('Spoon', 272),
#  ('hot', 272),
#  ('Meanwhile,', 271),
#  ('simmer', 267),
#  ('back', 265),
#  ('4', 264),
#  ('Place', 264),
#  ('6.', 262),
#  ('food', 260),
#  ('tray', 260),
#  ('15', 257),
#  ('chill', 256),
#  ('another', 256),
#  ('sugar,', 254),
#  ('tin.', 253),
#  ('surface', 253),
#  ('serve', 252),
#  ('line', 249),
#  ('season', 248),
#  ('warm', 247),
#  ('film', 247),
#  ('two', 246),
#  ('bowl.', 245),
#  ('milk', 244),
#  ('ingredients', 243),
#  ('sauce', 238),
#  ('cool.', 235),
#  ('sheet', 234),
#  ('foil', 234),
#  ('tin,', 233),
#  ('200C/180C', 233),
#  ('Bring', 230),
#  ('between', 230),
#  ('golden.', 230),
#  ('sides', 227),
#  ('enough', 227),
#  ('tsp', 225),
#  ('Use', 225),
#  ('not', 225),
#  ('fry', 221),
#  ('smooth', 221),
#  ('very', 221),
#  ('butter,', 220),
#  ('dry', 218),
#  ('base', 217),
#  ('The', 216),
#  ('side', 216),
#  ('Roll', 214),
#  ('pan.', 213),
#  ('water.', 212),
#  ('boil', 211),
#  ('Cook', 209),
#  ('onion', 208),
#  ('medium', 207),
#  ('serving', 206),
#  ('serve.', 205),
#  ('flour,', 204),
#  ('aside', 203),
#  ('everything', 202),
#  ('layer', 201),
#  ('ready', 201),
#  ('saucepan', 200),
#  ('garlic', 200),
#  ('Brush', 198),
#  ('top.', 198),
#  ('should', 196),
#  ('Once', 196),
#  ('thick', 196),
#  ('well.', 192),
#  ('4.', 192),
#  ('leaves', 192),
#  ('slices', 191),
#  ('brush', 189),
#  ('beat', 189),
#  ('white', 189),
#  ('In', 189),
#  ('180C/160C', 188),
#  ('zest', 186),
#  ('soft', 186),
#  ('aside.', 186),
#  ('parchment', 185),
#  ('x', 184),
#  ('knife', 184),
#  ('least', 183),
#  ('chopped', 183),
#  ('serve,', 179),
#  ('Season', 178),
#  ('fat', 178),
#  ('cold', 177),
#  ('parchment.', 177),
#  ('scatter', 177),
#  ('stick', 177),
#  ('paper', 176),
#  ('cheese', 176),
#  ('slice', 175),
#  ('Can', 173),
#  ('piece', 172),
#  ('stock', 172),
#  ('boil,', 171),
#  ('Using', 171),
#  ('pudding', 171),
#  ('6', 171),
#  ('completely', 168),
#  ('cooking', 167),
#  ('centre', 166),
#  ('eggs', 166),
#  ('water,', 166),
#  ('melted', 166),
#  ('along', 166),
#  ('spread', 165),
#  ('brown', 165),
#  ('syrup', 164),
#  ('end', 164),
#  ('edges', 163),
#  ('Set', 163),
#  ('fruit', 162),
#  ('Turn', 161),
#  ('need', 160),
#  ('drizzle', 159),
#  ('hr', 158),
#  ('fold', 158),
#  ('dish', 157),
#  ('heat,', 157),
#  ('roast', 156),
#  ('For', 154),
#  ('middle', 154),
#  ('cooked', 154),
#  ('skin', 154),
#  ('comes', 153),
#  ('Melt', 153),
#  ('sprinkle', 152),
#  ('Cool', 151),
#  ('press', 151),
#  ('bottom', 149),
#  ('while', 149),
#  ('sugar.', 148),
#  ('juices', 148),
#  ('Scatter', 148),
#  ('skewer', 147),
#  ('ice', 146),
#  ('low', 146),
#  ('heat.', 145),
#  ('when', 145),
#  ('pinch', 145),
#  ('Line', 144),
#  ('return', 144),
#  ('Beat', 143),
#  ('away', 143),
#  ('carefully', 143),
#  ('onions', 143),
#  ('bay', 142),
#  ('toss', 142),
#  ('boil.', 141),
#  ('together.', 141),
#  ('bacon', 140),
#  ('other', 139),
#  ('made', 139),
#  ('further', 138),
#  ('Make', 138),
#  ('time,', 138),
#  ('boiling', 137),
#  ('smooth.', 137),
#  ('don’t', 137),
#  ('days', 137),
#  ('tender.', 137),
#  ('liquid', 136),
#  ('Sprinkle', 136),
#  ('Drain', 136),
#  ('vanilla', 134),
#  ('cream,', 134),
#  ('butter.', 133),
#  ('Spread', 133),
#  ('hrs', 133),
#  ('black', 133),
#  ('pieces', 132),
#  ('round', 132),
#  ('cool,', 132),
#  ('processor', 132),
#  ('Transfer', 132),
#  ('leaving', 132),
#  ('its', 131),
#  ('transfer', 131),
#  ('thyme', 130),
#  ('minutes', 130),
#  ('like.', 130),
#  ('oil,', 130),
#  ('plate', 129),
#  ('like', 128),
#  ('under', 127),
#  ('wire', 126),
#  ('it.', 126),
#  ('olive', 126),
#  ('floured', 124),
#  ('meat', 124),
#  ('work', 123),
#  ('excess', 123),
#  ('Chill', 122),
#  ('paper.', 122),
#  ('too', 121),
#  ('day', 121),
#  ('cake.', 120),
#  ('crisp', 120),
#  ('making', 119),
#  ('turning', 119),
#  ('slightly', 119),
#  ('melt', 118),
#  ('marzipan', 118),
#  ('peel', 117),
#  ('give', 117),
#  ('take', 117),
#  ('covered', 117),
#  ('clean', 117),
#  ('good', 116),
#  ('Take', 116),
#  ('time', 115),
#  ('pepper', 114),
#  ('Whisk', 114),
#  ('non-stick', 113),
#  ('still', 113),
#  ('sharp', 113),
#  ('Carefully', 113),
#  ('chicken', 112),
#  ('(see', 112),
#  ('ground', 111),
#  ('room', 111),
#  ('oil.', 111),
#  ('really', 111),
#  ('ham', 111),
#  ('salt.', 110),
#  ('wrap', 110),
#  ('allow', 110),
#  ('get', 110),
#  ('salmon', 110),
#  ('seeds', 109),
#  ('20cm', 108),
#  ('extra', 108),
#  ('stuffing', 108),
#  ('evenly', 107),
#  ('now', 107),
#  ('brown.', 107),
#  ('thin', 107),
#  ('Divide', 106),
#  ('(or', 106),
#  ('starting', 106),
#  ('wine', 106),
#  ('kitchen', 105),
#  ('You', 105),
#  ('drain', 105),
#  ('again', 104),
#  ('together,', 104),
#  ('ginger', 104),
#  ('frozen', 104),
#  ('nuts', 103),
#  ('every', 103),
#  ('freeze', 102),
#  ('Fold', 102),
#  ('Repeat', 102),
#  ('Roast', 102),
#  ('electric', 101),
#  ('foil,', 101),
#  ('Arrange', 101),
#  ('lift', 101),
#  ('sure', 100),
#  ('rack', 100),
#  ('8', 100),
#  ('cranberries', 100),
#  ('whole', 99),
#  ('hrs.', 99),
#  ('mixing', 99),
#  ('biscuits', 99),
#  ('mixture.', 99),
#  ('through.', 99),
#  ('2-3', 99),
#  ('seasoning.', 99),
#  ('garlic,', 99),
#  ('sauce.', 98),
#  ('piping', 98),
#  ('deep', 97),
#  ('juice,', 97),
#  ('Will', 97),
#  ('it’s', 97),
#  ('wooden', 97),
#  ('serving.', 97),
#  ('220C/200C', 96),
#  ('salt,', 96),
#  ('overnight.', 95),
#  ('temperature', 95),
#  ('long', 95),
#  ('cake,', 95),
#  ('bag', 95),
#  ('couple', 95),
#  ('Toss', 95),
#  ('eggs,', 94),
#  ('dark', 94),
#  ('help', 94),
#  ('7.', 94),
#  ('finely', 94),
#  ('firm', 93),
#  ('dried', 93),
#  ('both', 93),
#  ('sieve', 93),
#  ('Gently', 93),
#  ('Top', 93),
#  ('sprouts', 93),
#  ('45', 92),
#  ('balls', 92),
#  ('up.', 92),
#  ('inside', 92),
#  ('big', 92),
#  ('whites', 92),
#  ('bread', 92),
#  ('red', 92),
#  ('fine', 91),
#  ('sauce,', 91),
#  ('Lay', 91),
#  ('their', 91),
#  ('duck', 91),
#  ('pepper.', 90),
#  ('40', 90),
#  ('5.', 89),
#  ('adding', 89),
#  ('come', 89),
#  ('potato', 89),
#  ('star', 89),
#  ('completely.', 88),
#  ('chop', 88),
#  ('Grease', 88),
#  ('well,', 88),
#  ('dough.', 88),
#  ('hrs,', 88),
#  ('hand', 88),
#  ('let', 88),
#  ('Return', 88),
#  ('shape', 88),
#  ('seasoning', 88),
#  ('crème', 88),
#  ('salted', 88),
#  ('simmering', 87),
#  ('1-2', 87),
#  ('mixture,', 87),
#  ('do', 87),
#  ('filling', 87),
#  ('cinnamon', 87),
#  ('pork', 87),
#  ('same', 86),
#  ('sit', 86),
#  ('shallow', 86),
#  ('While', 85),
#  ('Lift', 85),
#  ('edge', 85),
#  ('squash', 85),
#  ('shallots', 85),
#  ('set.', 84),
#  ('prepared', 84),
#  ('Keep', 84),
#  ('reduce', 84),
#  ('roughly', 84),
#  ('top,', 83),
#  ('circle', 83),
#  ('tray.', 83),
#  ('want', 83),
#  ('180C/gas', 83),
#  ('cocktail', 83),
#  ('rolling', 83),
#  ('ahead', 83),
#  ('board', 83),
#  ('start', 83),
#  ('push', 83),
#  ('vinegar', 83),
#  ('beaten', 82),
#  ('spoon.', 82),
#  ('airtight', 82),
#  ('once', 82),
#  ('freezer', 82),
#  ('goose', 82),
#  ('12', 81),
#  ('squeeze', 81),
#  ('continue', 81),
#  ('caster', 80),
#  ('icing.', 80),
#  ('way', 80),
#  ('bit', 80),
#  ('Drizzle', 80),
#  ('min', 80),
#  ('lime', 80),
#  ('almonds', 79),
#  ('sheets', 79),
#  ('honey', 79),
#  ('lid', 79),
#  ('apple', 79),
#  ('knead', 79),
#  ('saucepan,', 79),
#  ('loaf', 79),
#  ('dish.', 79),
#  ('lined', 79),
#  ('fill', 78),
#  ('cream.', 78),
#  ('microwave', 77),
#  ('Butter', 77),
#  ('3-4', 77),
#  ('high', 77),
#  ('reserved', 77),
#  ('rice', 77),
#  ('cabbage', 77),
#  ('oven,', 76),
#  ('trim', 76),
#  ('soft.', 76),
#  ('parsley', 76),
#  ('fridge.', 76),
#  ('carrots', 76),
#  ('no', 75),
#  ('double', 75),
#  ('greaseproof', 75),
#  ('than', 75),
#  ('smooth,', 75),
#  ('days.', 75),
#  ('pie', 74),
#  ('bubble', 74),
#  ('mixed', 74),
#  ('halfway', 74),
#  ('container', 74),
#  ('Lightly', 74),
#  ('tins', 74),
#  ('surface.', 74),
#  ('leaves.', 74),
#  ('pack', 74),
#  ('brandy', 73),
#  ('spices', 73),
#  ('cakes', 73),
#  ('chilled', 73),
#  ('Boil', 73),
#  ('Sit', 73),
#  ('sage', 73),
#  ('meringue', 73),
#  ('slowly', 72),
#  ('splash', 72),
#  ('breast', 71),
#  ('powder', 71),
#  ('risen', 71),
#  ('3.', 71),
#  ('may', 71),
#  ('overnight', 71),
#  ('mushrooms', 71),
#  ('crisp.', 71),
#  ('coconut', 71),
#  ('gravy', 71),
#  ('clean.', 70),
#  ('dust', 70),
#  ('final', 70),
#  ('circles', 70),
#  ('Wrap', 70),
#  ('Peel', 70),
#  ('knife,', 70),
#  ('.', 70),
#  ('200C/fan', 70),
#  ('hands', 70),
#  ('cranberry', 70),
#  ('Fry', 70),
#  ('vegetables', 70),
#  ('zest,', 69),
#  ('starts', 69),
#  ('thick.', 69),
#  ('veg', 69),
#  ('grill', 69),
#  ('three', 68),
#  ('egg,', 68),
#  ('foil.', 68),
#  ('again.', 68),
#  ('plate.', 68),
#  ('milk,', 68),
#  ('shape.', 68),
#  ('month.', 68),
#  ('more.', 68),
#  ('Simmer', 68),
#  ('taste.', 68),
#  ('create', 67),
#  ('flat', 67),
#  ('tightly', 67),
#  ('arrange', 67),
#  ('light', 67),
#  ('mustard', 67),
#  ('strain', 67),
#  ('dressing', 67),
#  ('first', 66),
#  ('batter', 66),
#  ('tie', 66),
#  ('This', 66),
#  ('jam', 66),
#  ('leaves,', 66),
#  ('minutes.', 65),
#  ('gas', 65),
#  ('muffin', 65),
#  ('decorate', 65),
#  ('custard', 65),
#  ('Trim', 65),
#  ('divide', 65),
#  ('straight', 65),
#  ('dish,', 65),
#  ('24', 65),
#  ('over.', 65),
#  ('coat', 65),
#  ('beef', 65),
#  ('sausage', 64),
#  ('holes', 64),
#  ('Dust', 64),
#  ('parchment,', 64),
#  ('thickness', 64),
#  ('loosely', 64),
#  ('ends', 64),
#  ('icing,', 64),
#  ('sticky', 64),
#  ('10-15', 64),
#  ('minutes,', 63),
#  ('pale', 63),
#  ('green', 63),
#  ('separate', 63),
#  ('form', 63),
#  ('mix.', 63),
#  ('rub', 63),
#  ('you’re', 63),
#  ('and,', 63),
#  ('15-20', 63),
#  ('juice.', 63),
#  ('ahead.', 63),
#  ('softened.', 62),
#  ('lay', 62),
#  ('film.', 62),
#  ('cooled', 62),
#  ('little.', 62),
#  ('most', 62),
#  ('onions,', 62),
#  ('rack.', 61),
#  ('after', 61),
#  ('string', 61),
#  ('dip', 61),
#  ('strip', 61),
#  ('whizz', 61),
#  ('yolks', 61),
#  ('syrup,', 61),
#  ('third', 61),
#  ('mincemeat', 61),
#  ('onion,', 61),
#  ('tender', 61),
#  ('Press', 60),
#  ('25', 60),
#  ('even', 60),
#  ('Now', 60),
#  ('(if', 60),
#  ('pastry,', 60),
#  ('needed.', 60),
#  ('up,', 60),
#  ('vinegar,', 60),
#  ('mash', 60),
#  ('tart', 59),
#  ('there', 59),
#  ('pulse', 59),
#  ('almost', 59),
#  ('tea', 59),
#  ('160C/140C', 59),
#  ('cooked,', 59),
#  ('salad', 58),
#  ('soak', 58),
#  ('seal', 58),
#  ('warm.', 58),
#  ('hr.', 58),
#  ('chilli', 58),
#  ('quickly', 57),
#  ('metal', 57),
#  ('rosemary', 57),
#  ('softened', 57),
#  ('steam', 57),
#  ('Allow', 57),
#  ('discard', 57),
#  ('edges.', 57),
#  ('bits', 57),
#  ('hold', 57),
#  ('190C/170C', 57),
#  ('Strain', 57),
#  ('side.', 57),
#  ('hot.', 57),
#  ('8-10', 56),
#  ('20-25', 56),
#  ('biscuit', 56),
#  ('dry.', 56),
#  ('mix,', 56),
#  ('Slice', 56),
#  ('knife.', 56),
#  ('smaller', 56),
#  ('25-30', 56),
#  ('clementine', 56),
#  ('plenty', 55),
#  ('pastry.', 55),
#  ('doesn’t', 55),
#  ('chocolate.', 55),
#  ('outside', 55),
#  ('cutter', 55),
#  ('On', 55),
#  ('fresh', 55),
#  ('tray,', 55),
#  ('break', 55),
#  ('trays', 55),
#  ('sea', 55),
#  ('reheat', 55),
#  ('stock,', 55),
#  ('large,', 55),
#  ('pepper,', 55),
#  ('generously', 55),
#  ('wedges', 55),
#  ('hours', 54),
#  ('inserted', 54),
#  ('combined.', 54),
#  ('second', 54),
#  ('cocoa', 54),
#  ('jar', 54),
#  ('day,', 54),
#  ('grated', 54),
#  ('fan/', 54),
#  ('heatproof', 54),
#  ('ovenproof', 54),
#  ('saucepan.', 54),
#  ('spinach', 54),
#  ('much', 54),
#  ('turkey,', 54),
#  ('fish', 54),
#  ('Sift', 53),
#  ('nuts,', 53),
#  ('pipe', 53),
#  ('oven.', 53),
#  ('strips', 53),
#  ('apples', 53),
#  ('surface,', 53),
#  ('grease', 53),
#  ('pressing', 53),
#  ('seasoning,', 53),
#  ('scoop', 52),
#  ('½', 52),
#  ('glass', 52),
#  ('basin', 52),
#  ('jug', 52),
#  ('kept', 52),
#  ('serving,', 52),
#  ('gradually', 52),
#  ('simmer,', 52),
#  ('parsnips', 52),
#  ('coriander', 52),
#  ('trimmings', 51),
#  ('spoonful', 51),
#  ('time.', 51),
#  ('jelly', 51),
#  ('run', 51),
#  ('golden,', 51),
#  ('mini', 51),
#  ('whisking', 51),
#  ('finish', 51),
#  ('per', 51),
#  ('season.', 51),
#  ('sliced', 51),
#  ('bird', 51),
#  ('next', 50),
#  ('grate', 50),
#  ('used', 50),
#  ('Fill', 50),
#  ('size', 50),
#  ('sides.', 50),
#  ('pat', 50),
#  ('gelatine', 50),
#  ('legs', 50),
#  ('months.', 49),
#  ('over,', 49),
#  ('followed', 49),
#  ('sponge', 49),
#  ('cloves', 49),
#  ('rectangle', 49),
#  ('breadcrumbs,', 48),
#  ('melted.', 48),
#  ('hole', 48),
#  ('it,', 48),
#  ('down,', 48),
#  ('stiff', 48),
#  ('cook,', 48),
#  ('jug.', 48),
#  ('tender,', 48),
#  ('flesh', 48),
#  (',', 47),
#  ('powder,', 47),
#  ('length', 47),
#  ('fit', 47),
#  ('5-10', 47),
#  ('soften', 47),
#  ('chocolate,', 47),
#  ('oiled', 47),
#  ('doubled', 47),
#  ('ball', 47),
#  ('syrup.', 47),
#  ('Preheat', 47),
#  ('shelf', 47),
#  ('herbs', 47),
#  ('fraîche', 47),
#  ('go', 47),
#  ('shapes', 46),
#  ('level', 46),
#  ('colour', 46),
#  ('film,', 46),
#  ('more,', 46),
#  ('sheet.', 46),
#  ('blitz', 46),
#  ('reduced', 46),
#  ('Scrape', 46),
#  ('cheese,', 46),
#  ('last', 46),
#  ('slices.', 46),
#  ('spring', 46),
#  ('platter', 46),
#  ('look', 45),
#  ('topping', 45),
#  ('caramel', 45),
#  ('stand', 45),
#  ('fingers', 45),
#  ('spoon,', 45),
#  ('them.', 45),
#  ('shake', 45),
#  ('paste.', 45),
#  ('square', 45),
#  ('slices,', 45),
#  ('best', 45),
#  ('paper,', 44),
#  ('tops', 44),
#  ('almonds,', 44),
#  ('buttered', 44),
#  ('processor,', 44),
#  ('bowls', 44),
#  ('stars', 44),
#  ('half.', 44),
#  ('these', 44),
#  ('worry', 44),
#  ('yogurt', 44),
#  ('glasses', 44),
#  ('mustard,', 44),
#  ('been', 43),
#  ('looks', 43),
#  ('left', 43),
#  ('crumbs', 43),
#  ('done', 43),
#  ('nutmeg', 43),
#  ('hot,', 43),
#  ('scrape', 43),
#  ('fluffy.', 43),
#  ('maple', 43),
#  ('glaze', 43),
#  ('stamp', 43),
#  ('gentle', 43),
#  ('slightly.', 42),
#  ('egg.', 42),
#  ('Reduce', 42),
#  ('week', 42),
#  ('layers', 42),
#  ('cooking,', 42),
#  ('out.', 42),
#  ('ingredients,', 42),
#  ('(you', 42),
#  ('neck', 42),
#  ('melted,', 42),
#  ('slotted', 42),
#  ('breadcrumbs', 42),
#  ('pears', 42),
#  ('beetroot', 42),
#  ('two-thirds', 41),
#  ('fruit,', 41),
#  ('-', 41),
#  ('check', 41),
#  ('soaked', 41),
#  ('flour.', 41),
#  ('ribbon', 41),
#  ('store', 41),
#  ('except', 41),
#  ('beans', 41),
#  ('rise', 41),
#  ('Continue', 41),
#  ('Knead', 41),
#  ('toast', 41),
#  ('plus', 41),
#  ('nutmeg,', 41),
#  ('With', 41),
#  ('casserole', 41),
#  ('gravy.', 41),
#  ('190C/fan', 40),
#  ('colouring', 40),
#  ('150ml', 40),
#  ('100g', 40),
#  ('£1', 40),
#  ('thick,', 40),
#  ('ahead,', 40),
#  ('thickened.', 40),
#  ('larger', 40),
#  ('pies', 40),
#  ('160C/gas', 40),
#  ('1cm', 40),
#  ('four', 40),
#  ('drop', 40),
#  ('palette', 40),
#  ('cheese.', 40),
#  ('firm.', 40),
#  ('paste', 40),
#  ('point', 40),
#  ('cranberries,', 39),
#  ('ginger,', 39),
#  ('spice', 39),
#  ('stop', 39),
#  ('stirring,', 39),
#  ('thinly', 39),
#  ('little,', 39),
#  ('occasionally,', 39),
#  ('7', 39),
#  ('across', 39),
#  ('without', 39),
#  ('23cm', 39),
#  ('colour.', 39),
#  ('min,', 39),
#  ('Halve', 39),
#  ('chill.', 39),
#  ('100ml', 39),
#  ('pancetta', 39),
#  ('case', 39),
#  ('sausages', 39),
#  ('overlapping', 39),
#  ('soften.', 39),
#  ('jars', 39),
#  ('170C/gas', 38),
#  ('(about', 38),
#  ('in.', 38),
#  ('sprigs', 38),
#  ('simmer.', 38),
#  ('shape,', 38),
#  ('breadcrumbs.', 38),
#  ('purée', 38),
#  ('Rub', 38),
#  ('browned', 38),
#  ('chestnuts', 37),
#  ('leaf', 37),
#  ('dusted', 37),
#  ('zest.', 37),
#  ('beating', 37),
#  ('filling,', 37),
#  ('pop', 37),
#  ('liquid.', 37),
#  ('180C/fan', 37),
#  ('soft,', 37),
#  ('12-15', 37),
#  ('become', 37),
#  ...]

# %% [markdown]
# **Cake Ingredients:**
#  : sugar, flour, butter, milk, vanilla extract, egg, baking powder, zest

# %%
name_count = Counter()
for i in range(len(data)):     
    if data[i]['Name'] != None:
        for word in data[i]['Name'].split(" "):
            name_count[word] += 1
name_count.most_common()
# Out:
# [('&', 616),
#  ('with', 321),
#  ('Christmas', 114),
#  ('cake', 101),
#  ('sauce', 64),
#  ('salad', 55),
#  ('cheese', 53),
#  ('turkey', 50),
#  ('roast', 49),
#  ('chocolate', 48),
#  ('cranberry', 47),
#  ('pudding', 43),
#  ('cream', 40),
#  ('stuffing', 39),
#  ('Chocolate', 36),
#  ('potato', 36),
#  ('salmon', 36),
#  ('cabbage', 35),
#  ('pie', 33),
#  ('pies', 33),
#  ('Cranberry', 32),
#  ('red', 31),
#  ('potatoes', 31),
#  ('apple', 31),
#  ('Spiced', 28),
#  ('ham', 28),
#  ('mince', 27),
#  ('wine', 27),
#  ('butter', 26),
#  ('orange', 25),
#  ('Sticky', 25),
#  ('sprouts', 25),
#  ('Mini', 24),
#  ('tart', 24),
#  ('Roast', 24),
#  ('spiced', 23),
#  ('ginger', 23),
#  ('bacon', 23),
#  ('onion', 23),
#  ('gravy', 22),
#  ('Smoked', 22),
#  ('in', 21),
#  ('Creamy', 21),
#  ('soup', 21),
#  ('pork', 20),
#  ('chestnut', 20),
#  ('bread', 19),
#  ('mushroom', 18),
#  ('cakes', 17),
#  ('mustard', 17),
#  ('carrots', 17),
#  ('ice', 16),
#  ('pancetta', 16),
#  ('parsnip', 16),
#  ('dressing', 16),
#  ('gratin', 16),
#  ('chutney', 15),
#  ('trifle', 15),
#  ('pear', 15),
#  ('fruit', 15),
#  ('cocktail', 15),
#  ('Gingerbread', 15),
#  ('of', 15),
#  ('squash', 15),
#  ('sage', 15),
#  ('Festive', 15),
#  ('smoked', 15),
#  ('mincemeat', 15),
#  ('Easy', 14),
#  ('biscuits', 14),
#  ('clementine', 14),
#  ('beef', 14),
#  ('Winter', 14),
#  ('chicken', 14),
#  ('Mulled', 14),
#  ('Red', 14),
#  ('Brussels', 14),
#  ('wreath', 13),
#  ('nut', 13),
#  ('chilli', 13),
#  ('syrup', 13),
#  ('Baked', 13),
#  ('cheesecake', 12),
#  ('Classic', 12),
#  ('pud', 12),
#  ('garlic', 12),
#  ('pecan', 12),
#  ('Vegan', 12),
#  ('crumble', 12),
#  ('sausage', 12),
#  ('Crunchy', 12),
#  ('hazelnut', 12),
#  ('coconut', 12),
#  ('roasties', 12),
#  ('Turkey', 12),
#  ('meringue', 12),
#  ('rice', 12),
#  ('almond', 11),
#  ('loaf', 11),
#  ('Sweet', 11),
#  ('beetroot', 11),
#  ('lemon', 11),
#  ('bake', 11),
#  ('seed', 11),
#  ('kit', 11),
#  ('onions', 11),
#  ('dip', 11),
#  ('cupcakes', 10),
#  ('spice', 10),
#  ('puddings', 10),
#  ('tree', 10),
#  ('duck', 10),
#  ('sticky', 10),
#  ('caramel', 10),
#  ('pears', 10),
#  ('truffles', 10),
#  ('star', 10),
#  ('spinach', 10),
#  ('celeriac', 10),
#  ('apples', 10),
#  ('truffle', 10),
#  ('honey', 9),
#  ('Hot', 9),
#  ('leek', 9),
#  ('terrine', 9),
#  ('pancakes', 9),
#  ('blue', 9),
#  ('wild', 9),
#  ('baked', 9),
#  ('sprout', 9),
#  ('Orange', 9),
#  ('cookies', 8),
#  ('goose', 8),
#  ('marzipan', 8),
#  ('log', 8),
#  ('White', 8),
#  ('root', 8),
#  ('Stollen', 8),
#  ('slice', 8),
#  ('pomegranate', 8),
#  ('rosemary', 8),
#  ('rolls', 8),
#  ('Ham', 8),
#  ('Spicy', 8),
#  ('Clementine', 8),
#  ('bites', 8),
#  ('Roasted', 8),
#  ('skewers', 8),
#  ('mulled', 8),
#  ('crème', 8),
#  ('custard', 8),
#  ('vegetables', 8),
#  ('Lemon', 8),
#  ('Beetroot', 8),
#  ('walnuts', 8),
#  ('walnut', 8),
#  ('horseradish', 8),
#  ('shallots', 8),
#  ('bombe', 7),
#  ("goat's", 7),
#  ('toffee', 7),
#  ('Ginger', 7),
#  ('Wellington', 7),
#  ('Salted', 7),
#  ('torte', 7),
#  ('toast', 7),
#  ('camembert', 7),
#  ('Chestnut', 7),
#  ('mash', 7),
#  ('Port', 7),
#  ('mango', 7),
#  ('cups', 7),
#  ('Crispy', 7),
#  ('stuffed', 7),
#  ('parsnips', 7),
#  ('lime', 7),
#  ('thyme', 7),
#  ('Duck', 7),
#  ('chorizo', 7),
#  ('feta', 7),
#  ('Apricot', 7),
#  ('fennel', 7),
#  ('liver', 7),
#  ('squeak', 7),
#  ('carrot', 7),
#  ('roasted', 7),
#  ('pâté', 7),
#  ('cinnamon', 7),
#  ('brownies', 6),
#  ('vanilla', 6),
#  ('Buttered', 6),
#  ('Little', 6),
#  ('cherry', 6),
#  ('almonds', 6),
#  ('Black', 6),
#  ('white', 6),
#  ('gingerbread', 6),
#  ('coffee', 6),
#  ('crispy', 6),
#  ('easy', 6),
#  ('jam', 6),
#  ('Mince', 6),
#  ('Apple', 6),
#  ('Simple', 6),
#  ('maple', 6),
#  ('muffins', 6),
#  ('Triple', 6),
#  ('marmalade', 6),
#  ('baby', 6),
#  ('roll', 6),
#  ('fruitcake', 6),
#  ('fudge', 6),
#  ('chestnuts', 6),
#  ('Coconut', 6),
#  ('sesame', 6),
#  ('mint', 6),
#  ('poppy', 6),
#  ('jelly', 6),
#  ('crown', 6),
#  ('Herby', 6),
#  ('apricot', 6),
#  ('prawns', 6),
#  ('cider', 6),
#  ('raspberry', 6),
#  ('cauliflower', 6),
#  ('Chicken', 6),
#  ('Slow', 6),
#  ('dippers', 6),
#  ('roulade', 6),
#  ('relish', 6),
#  ('Peppermint', 6),
#  ('shallot', 6),
#  ('stilton', 6),
#  ('Cauliflower', 6),
#  ('Caramelised', 6),
#  ('nuts', 6),
#  ('herby', 6),
#  ('parcels', 6),
#  ('peas', 6),
#  ('date', 6),
#  ('toasts', 6),
#  ('bean', 6),
#  ('buns', 5),
#  ('Iced', 5),
#  ('rum', 5),
#  ('Golden', 5),
#  ('Fruity', 5),
#  ('Chocolate,', 5),
#  ('glaze', 5),
#  ('gammon', 5),
#  ('Beef', 5),
#  ('vegetable', 5),
#  ('glazed', 5),
#  ('Cheeseboard', 5),
#  ('Brandy', 5),
#  ('peanut', 5),
#  ('Really', 5),
#  ('prosciutto', 5),
#  ('Pecan', 5),
#  ('braised', 5),
#  ('Mincemeat', 5),
#  ('crunch', 5),
#  ('olive', 5),
#  ('sweet', 5),
#  ('goat’s', 5),
#  ('Braised', 5),
#  ('Thai', 5),
#  ('brioche', 5),
#  ('fraîche', 5),
#  ('dill', 5),
#  ('winter', 5),
#  ('Quick', 5),
#  ('kale', 5),
#  ('Glazed', 5),
#  ('Jewelled', 5),
#  ('panettone', 5),
#  ('berry', 5),
#  ('pickled', 5),
#  ('Sausage', 5),
#  ('parfait', 5),
#  ('Mont', 5),
#  ('Passion', 5),
#  ('tarts', 5),
#  ('fizz', 5),
#  ('risotto', 5),
#  ('green', 5),
#  ('treacle', 5),
#  ('pine', 5),
#  ('cucumber', 5),
#  ('Spinach', 5),
#  ('Prawn', 5),
#  ('sorbet', 5),
#  ('Mushroom', 5),
#  ('roots', 5),
#  ('Stuffed', 5),
#  ('punch', 5),
#  ('pots', 5),
#  ('spring', 5),
#  ('platter', 5),
#  ('and', 5),
#  ('slaw', 4),
#  ('Sparkling', 4),
#  ('citrus', 4),
#  ('Fig', 4),
#  ('saffron', 4),
#  ('pops', 4),
#  ('Lamb', 4),
#  ('Cherry', 4),
#  ('Rudolph', 4),
#  ('forest', 4),
#  ('traybake', 4),
#  ('Boozy', 4),
#  ('veg', 4),
#  ('brownie', 4),
#  ('Chunky', 4),
#  ('Coffee', 4),
#  ('Maple', 4),
#  ('balls', 4),
#  ('Whisky', 4),
#  ('compote', 4),
#  ('Sprouts', 4),
#  ('shortbread', 4),
#  ('avocado', 4),
#  ('pastry', 4),
#  ('blankets', 4),
#  ('Creamed', 4),
#  ('Sugar-dusted', 4),
#  ('hot', 4),
#  ('Chorizo', 4),
#  ('Pineapple', 4),
#  ('Caramel', 4),
#  ('Homemade', 4),
#  ('Bread', 4),
#  ('fritters', 4),
#  ('wings', 4),
#  ('Mustard', 4),
#  ('Hazelnut', 4),
#  ('eggs', 4),
#  ('Parsnip', 4),
#  ('martini', 4),
#  ('cookie', 4),
#  ('tomato', 4),
#  ('Celeriac', 4),
#  ('sour', 4),
#  ('Eccles', 4),
#  ('Truffled', 4),
#  ('vodka', 4),
#  ('recipe', 4),
#  ('Bramley', 4),
#  ('Raspberry', 4),
#  ('Pork', 4),
#  ('parsley', 4),
#  ('Double', 4),
#  ('Butternut', 4),
#  ('brie', 4),
#  ('tarragon', 4),
#  ('Cranberry,', 4),
#  ('curry', 4),
#  ('mushrooms', 4),
#  ('pistachio', 4),
#  ('Reindeer', 4),
#  ('greens', 4),
#  ('cooker', 4),
#  ('pineapple', 4),
#  ('bark', 4),
#  ('Turkish', 4),
#  ('tea', 4),
#  ('party', 4),
#  ('squares', 4),
#  ('anise', 4),
#  ('yogurt', 4),
#  ('port', 4),
#  ('Pickled', 4),
#  ('Squash', 4),
#  ('Wild', 4),
#  ('Salmon', 4),
#  ('caramelised', 4),
#  ('leeks', 4),
#  ('hash', 4),
#  ('Sprout', 4),
#  ('Snowman', 4),
#  ('candied', 4),
#  ('pepper', 4),
#  ('raisin', 4),
#  ('lentil', 4),
#  ('candy', 4),
#  ('Bubble', 4),
#  ('scallops', 4),
#  ('coriander', 4),
#  ('juniper', 4),
#  ('Savoy', 4),
#  ('passion', 4),
#  ('crab', 4),
#  ('prawn', 4),
#  ('fresh', 4),
#  ('fish', 4),
#  ('boozy', 4),
#  ('toasted', 4),
#  ('Cheese', 4),
#  ('chicory', 4),
#  ('beans', 4),
#  ('twists', 4),
#  ('Warm', 4),
#  ('loin', 4),
#  ('Grilled', 4),
#  ('Mary', 3),
#  ('strudel', 3),
#  ('mousse', 3),
#  ('amaretti', 3),
#  ('iced', 3),
#  ('trees', 3),
#  ('soufflés', 3),
#  ('stollen', 3),
#  ('Forest', 3),
#  ('a', 3),
#  ('crostini', 3),
#  ('yule', 3),
#  ('Ho,', 3),
#  ('Ultimate', 3),
#  ('Pistachio', 3),
#  ('semifreddo', 3),
#  ('Snowball', 3),
#  ('Ham,', 3),
#  ('Panettone', 3),
#  ('Melting', 3),
#  ('breast', 3),
#  ('wrapped', 3),
#  ('bauble', 3),
#  ('de', 3),
#  ('milk', 3),
#  ('Pomegranate', 3),
#  ('Chestnut,', 3),
#  ('snowflake', 3),
#  ('Persian', 3),
#  ('fondue', 3),
#  ('pot', 3),
#  ('St', 3),
#  ('butternut', 3),
#  ('bundt', 3),
#  ('Lobster', 3),
#  ('remoulade', 3),
#  ('stacks', 3),
#  ('biscuit', 3),
#  ('Chicory', 3),
#  ('ricotta', 3),
#  ('thins', 3),
#  ('venison', 3),
#  ('chipolatas', 3),
#  ('French', 3),
#  ('soufflé', 3),
#  ('fig', 3),
#  ('Turkey,', 3),
#  ('fillet', 3),
#  ('Baileys', 3),
#  ('Salmon,', 3),
#  ('cranberries', 3),
#  ('crisp', 3),
#  ('tatin', 3),
#  ('Slow-cooked', 3),
#  ('Dauphinoise', 3),
#  ('Buttery', 3),
#  ('caraway', 3),
#  ('Polenta', 3),
#  ('pilaf', 3),
#  ('tagine', 3),
#  ('warm', 3),
#  ('Make-ahead', 3),
#  ('English', 3),
#  ('blinis', 3),
#  ('Healthy', 3),
#  ('pigs', 3),
#  ('lamb', 3),
#  ('filled', 3),
#  ('creams', 3),
#  ('Sloe', 3),
#  ('Fresh', 3),
#  ('mayo', 3),
#  ('Boxing', 3),
#  ('Day', 3),
#  ('scones', 3),
#  ('oatcakes', 3),
#  ('ripple', 3),
#  ('gin', 3),
#  ('Carrot', 3),
#  ('purée', 3),
#  ('celery', 3),
#  ('Venison', 3),
#  ('spicy', 3),
#  ('Chilli', 3),
#  ('raisins', 3),
#  ('Parmesan', 3),
#  ('bruschetta', 3),
#  ('delight', 3),
#  ('stars', 3),
#  ('on', 3),
#  ('sugar', 3),
#  ('sharing', 3),
#  ('bubble', 3),
#  ('decoration', 3),
#  ('Mashed', 3),
#  ('leaf', 3),
#  ('snowman', 3),
#  ('slices', 3),
#  ('Bay', 3),
#  ('Cointreau', 3),
#  ('Stir-fried', 3),
#  ('Poached', 3),
#  ('Pear', 3),
#  ('prunes', 3),
#  ('Giant', 3),
#  ('palmiers', 3),
#  ('confit', 3),
#  ('tartlets', 3),
#  ('Yorkies', 3),
#  ('rose', 3),
#  ('Irish', 3),
#  ('Brown', 3),
#  ('black', 3),
#  ('herb', 3),
#  ('madeira', 3),
#  ('pheasant', 3),
#  ('sticks', 3),
#  ('Cheesy', 3),
#  ('chips', 3),
#  ('rye', 3),
#  ('croutons', 3),
#  ('artichokes', 3),
#  ('Charred', 3),
#  ('Crab', 3),
#  ('Gratin', 3),
#  ('layer', 3),
#  ('plum', 3),
#  ('egg', 3),
#  ('shoulder', 3),
#  ('muffin', 2),
#  ('mix', 2),
#  ('Gingery', 2),
#  ('Honey', 2),
#  ('Granny', 2),
#  ('fruity', 2),
#  ('friands', 2),
#  ('morning', 2),
#  ("Mum's", 2),
#  ('for', 2),
#  ('the', 2),
#  ('fool', 2),
#  ('penguins', 2),
#  ('Last-minute', 2),
#  ('tortilla', 2),
#  ('lollipops', 2),
#  ('Cake', 2),
#  ('membrillo', 2),
#  ('tiramisu', 2),
#  ('match', 2),
#  ('mini', 2),
#  ('salted', 2),
#  ('biscotti', 2),
#  ('ciabatta', 2),
#  ('Moroccan', 2),
#  ('man', 2),
#  ('holly', 2),
#  ('fancies', 2),
#  ('peppermint', 2),
#  ('Mexican', 2),
#  ('cane', 2),
#  ('simple', 2),
#  ('rib', 2),
#  ('Perfect', 2),
#  ('Vanilla', 2),
#  ('dough', 2),
#  ('toddy', 2),
#  ('crumbs', 2),
#  ('chip', 2),
#  ('Eggnog', 2),
#  ('Rocky', 2),
#  ('Bûche', 2),
#  ('Noël', 2),
#  ('spritzer', 2),
#  ('Stuffing', 2),
#  ('Fragrant', 2),
#  ('Sausage,', 2),
#  ('en', 2),
#  ('croûte', 2),
#  ('Zesty', 2),
#  ('American', 2),
#  ('Parsnip,', 2),
#  ('Pavlova', 2),
#  ('prawns,', 2),
#  ('chillies', 2),
#  ('Chelsea', 2),
#  ('satay', 2),
#  ('Potted', 2),
#  ('nutmeg', 2),
#  ('poached', 2),
#  ('hollandaise', 2),
#  ('people', 2),
#  ('doughnuts', 2),
#  ('croquettes', 2),
#  ('juice', 2),
#  ('Bellini', 2),
#  ('Deep-fried', 2),
#  ('guinea', 2),
#  ('fowl', 2),
#  ('Fruitcake', 2),
#  ('icing', 2),
#  ('Goat’s', 2),
#  ('spirals', 2),
#  ('Mincemeat,', 2),
#  ('cardamom', 2),
#  ('stem', 2),
#  ('banana', 2),
#  ('Sherried', 2),
#  ('beer', 2),
#  ('Limoncello', 2),
#  ('food', 2),
#  ('pistachios', 2),
#  ('barley', 2),
#  ('Traditional', 2),
#  ('Squidgy', 2),
#  ('legs', 2),
#  ('straws', 2),
#  ('Wellingtons', 2),
#  ('pesto', 2),
#  ('Deep-filled', 2),
#  ('nougat', 2),
#  ('profiteroles', 2),
#  ('Star', 2),
#  ('sparkle', 2),
#  ('Full', 2),
#  ('twist', 2),
#  ('hock', 2),
#  ('mackerel', 2),
#  ('pink', 2),
#  ('Leftover', 2),
#  ('casserole', 2),
#  ('Sourdough', 2),
#  ('Cauliflower,', 2),
#  ('Honey-roast', 2),
#  ('Smashed', 2),
#  ('fruit,', 2),
#  ('flatbread', 2),
#  ('Gravadlax', 2),
#  ('marshmallow', 2),
#  ('Perky', 2),
#  ('Blanc', 2),
#  ('Faux', 2),
#  ('salsa', 2),
#  ('peppercorn', 2),
#  ('rillettes', 2),
#  ('dates', 2),
#  ('Brie', 2),
#  ('cottage', 2),
#  ('choc', 2),
#  ('Orange,', 2),
#  ('belly', 2),
#  ('chunks', 2),
#  ('Baby', 2),
#  ('Freeze-ahead', 2),
#  ('Stilton', 2),
#  ('rösti', 2),
#  ('Yule', 2),
#  ('Aubergine', 2),
#  ('hotpot', 2),
#  ('Honey-roasted', 2),
#  ('carbonara', 2),
#  ('Salt', 2),
#  ('Rum', 2),
#  ('prune', 2),
#  ('All-the-trimmings', 2),
#  ('turkey,', 2),
#  ('Lime', 2),
#  ('dhal', 2),
#  ('stirrers', 2),
#  ('fridge', 2),
#  ('Artichoke', 2),
#  ('Clementine,', 2),
#  ('Hasselback', 2),
#  ('Bitter', 2),
#  ('Chinese', 2),
#  ('Fennel', 2),
#  ('pumpkin', 2),
#  ('Cinnamon', 2),
#  ('Bacon', 2),
#  ('rice,', 2),
#  ('ice-cream', 2),
#  ('make-ahead', 2),
#  ('Marzipan', 2),
#  ('Seared', 2),
#  ('Pear,', 2),
#  ('falafel', 2),
#  ('Silky', 2),
#  ("Santa's", 2),
#  ('samosas', 2),
#  ('Alaska', 2),
#  ('haddock', 2),
#  ('kedgeree', 2),
#  ('breeze', 2),
#  ('sponge', 2),
#  ('festive', 2),
#  ('spuds', 2),
#  ('paprika', 2),
#  ('sea', 2),
#  ('Walnut', 2),
#  ('Marmalade', 2),
#  ('From-the-freezer', 2),
#  ('Chestnuts', 2),
#  ('minty', 2),
#  ('crackers', 2),
#  ('Microwave', 2),
#  ('Butternut,', 2),
#  ('pavlova', 2),
#  ('’n’', 2),
#  ('vinaigrette', 2),
#  ('Bloody', 2),
#  ('cheddar', 2),
#  ('toastie', 2),
#  ('courgettes', 2),
#  ('fondant', 2),
#  ('Rudolph’s', 2),
#  ('Prosecco', 2),
#  ('Dark', 2),
#  ('Honeyed', 2),
#  ('sandwiches', 2),
#  ('Partridge', 2),
#  ('Root', 2),
#  ('apricots', 2),
#  ('mocktail', 2),
#  ('snowball', 2),
#  ('Oysters', 2),
#  ('meringues', 2),
#  ('Green', 2),
#  ('potted', 2),
#  ('pecans', 2),
#  ('Potato', 2),
#  ('leaves', 2),
#  ('maple-glazed', 2),
#  ('Clotted', 2),
#  ('Prosciutto', 2),
#  ('Griddled', 2),
#  ('hazelnuts', 2),
#  ('elderflower', 2),
#  ('Jerusalem', 2),
#  ('artichoke', 2),
#  ('polenta', 2),
#  ('quince', 2),
#  ('Sautéed', 2),
#  ('Tropical', 2),
#  ('Blancs', 2),
#  ('Korean', 2),
#  ('shots', 2),
#  ('salt', 2),
#  ('sliders', 2),
#  ('pasta', 2),
#  ('Crisp', 2),
#  ('Brie,', 2),
#  ('quiche', 2),
#  ('crust', 2),
#  ('Next', 2),
#  ('level', 2),
#  ('salmon,', 2),
#  ('beetroot,', 2),
#  ('cured', 2),
#  ('crackling', 2),
#  ('burgers', 2),
#  ('cocktails', 2),
#  ('Nutty', 2),
#  ('Rhubarb', 2),
#  ('tatins', 2),
#  ('Jaffa', 2),
#  ('Choc', 2),
#  ('colada', 2),
#  ('filo', 2),
#  ('celeriac,', 2),
#  ('Yogurt', 2),
#  ('vinegar', 2),
#  ('Herb', 2),
#  ("Goat's", 2),
#  ('browns', 2),
#  ('Sesame', 2),
#  ('broccoli', 2),
#  ('creamy', 2),
#  ('Asian', 2),
#  ('tzatziki', 2),
#  ('Redcurrant', 2),
#  ('au', 2),
#  ('Flavoured', 2),
#  ('butters', 2),
#  ('Simmer-&-stir', 1),
#  ('mess', 1),
#  ('cosmopolitan', 1),
#  ('pizza', 1),
#  ('poussin', 1),
#  ("Berry's", 1),
#  ('Make', 1),
#  ('mature', 1),
#  ('Angela', 1),
#  ("Nilsen's", 1),
#  ("Gordon's", 1),
#  ('Sherry', 1),
#  ('liqueur', 1),
#  ("Martin's", 1),
#  ('Individual', 1),
#  ('little', 1),
#  ('Light', 1),
#  ('Christmas-pudding', 1),
#  ('Figgy', 1),
#  ("Chocoholic's", 1),
#  ('spices', 1),
#  ('frosty', 1),
#  ('Suits-all', 1),
#  ('Cupcake', 1),
#  ("Cook's", 1),
#  ('Nancy’s', 1),
#  ('Orange-stuffed', 1),
#  ('puds', 1),
#  ('Gravy', 1),
#  ('Enchanted', 1),
#  ('latte', 1),
#  ('buttercream', 1),
#  ('lunch', 1),
#  ('Nutmeg', 1),
#  ('jar', 1),
#  ('Isaac', 1),
#  ("Scout's", 1),
#  ('Lightly', 1),
#  ('Tutti', 1),
#  ('frutti', 1),
#  ('ceviche', 1),
#  ('guacamole', 1),
#  ('rockies', 1),
#  ('Unbelievably', 1),
#  ('Fruit', 1),
#  ('Rice', 1),
#  ('Krispie', 1),
#  ('Snowy', 1),
#  ('owl', 1),
#  ('Orlando', 1),
#  ("Murrin's", 1),
#  ('Deluxe', 1),
#  ('Let-it-glow', 1),
#  ('bay', 1),
#  ('Pure', 1),
#  ('gold', 1),
#  ('drip', 1),
#  ('sundaes', 1),
#  ('Mix', 1),
#  ('As-you-like-it', 1),
#  ('Blitz-&-bake', 1),
#  ('Mandarin-in-the-middle', 1),
#  ('chocolate,', 1),
#  ('Merry', 1),
#  ('veg,', 1),
#  ('bramble', 1),
#  ('Malt', 1),
#  ('clotted', 1),
#  ('house', 1),
#  ('Nut', 1),
#  ('Cola', 1),
#  ('biryani', 1),
#  ('Parmesan-roasted', 1),
#  ('middle', 1),
#  ('Glitz', 1),
#  ('glam', 1),
#  ('plait', 1),
#  ('shooting', 1),
#  ('orange-glazed', 1),
#  ('bacon-wrapped', 1),
#  ('breadsticks', 1),
#  ('bonbons', 1),
#  ('koftas', 1),
#  ('Candy', 1),
#  ('Toasted', 1),
#  ('malt', 1),
#  ('pressed', 1),
#  ('Mississippi', 1),
#  ('mud', 1),
#  ('Alaskan', 1),
#  ('Herb-scented', 1),
#  ('slow-roasted', 1),
#  ('shallot-stuffed', 1),
#  ('terrines', 1),
#  ('buttery', 1),
#  ('robin', 1),
#  ('Pigs', 1),
#  ('puff', 1),
#  ('bottle', 1),
#  ('Burnt', 1),
#  ('sours', 1),
#  ('Scallop', 1),
#  ('baubles', 1),
#  ('Lebkuchen', 1),
#  ('Snow', 1),
#  ('globe', 1),
#  ('Macadamia', 1),
#  ('velvet', 1),
#  ('Melty', 1),
#  ('Mulling', 1),
#  ('Lucia', 1),
#  ('croquetas', 1),
#  ('Corn', 1),
#  ('Marzipan-in-the-middle', 1),
#  ('fajitas', 1),
#  ('crumpets', 1),
#  ('burnt', 1),
#  ('Magical', 1),
#  ('reindeer', 1),
#  ('three-bird', 1),
#  ('oatmeal', 1),
#  ('rillette', 1),
#  ('Rich', 1),
#  ('slashed', 1),
#  ('butter-basted', 1),
#  ('egg,', 1),
#  ('caviar,', 1),
#  ('watercress', 1),
#  ('Cashew', 1),
#  ('caramels', 1),
#  ('ramen', 1),
#  ('Sunday', 1),
#  ('elf', 1),
#  ('Panforte', 1),
#  ('Yummy', 1),
#  ('Naan,', 1),
#  ('halloumi', 1),
#  ('Reverse', 1),
#  ('espresso', 1),
#  ('olives', 1),
#  ('chestnut,', 1),
#  ('gnocchi,', 1),
#  ('sundried', 1),
#  ('arancello', 1),
#  ('set', 1),
#  ('Favourite', 1),
#  ('tapenade', 1),
#  ('lattice', 1),
#  ('Sugar', 1),
#  ('charms', 1),
#  ('whiskey', 1),
#  ('croque', 1),
#  ('monsieurs', 1),
#  ('coulibiac', 1),
#  ('Raymond’s', 1),
#  ('Spanish', 1),
#  ('blueberry', 1),
#  ('dogs', 1),
#  ('Pancetta', 1),
#  ('sage-wrapped', 1),
#  ('maple-roasted', 1),
#  ('Brioche', 1),
#  ('bacon,', 1),
#  ('Comté', 1),
#  ('tangerine', 1),
#  ('Florentines', 1),
#  ('Pineapple,', 1),
#  ('Eggs', 1),
#  ('Benedict', 1),
#  ('chives', 1),
#  ('mango,', 1),
#  ('Coconut,', 1),
#  ('Ponche', 1),
#  ('stained', 1),
#  ('glass', 1),
#  ('meatloaf', 1),
#  ('Pea', 1),
#  ('Shortbread', 1),
#  ('trifles', 1),
#  ('semi-freddo', 1),
#  ('Snow-topped', 1),
#  ('Devil’s', 1),
#  ('Date', 1),
#  ('Millionaire’s', 1),
#  ('Layered', 1),
#  ('squash,', 1),
#  ('Potage', 1),
#  ('Dubarry', 1),
#  ('(Creamy', 1),
#  ('soup)', 1),
#  ('Olive', 1),
#  ('oil-baked', 1),
#  ('cranachan', 1),
#  ('jalousie', 1),
#  ('cobbler', 1),
#  ('marbled', 1),
#  ('tarte', 1),
#  ('Mint', 1),
#  ('bacon-basted', 1),
#  ('Trifle', 1),
#  ('Sparkly', 1),
#  ('Midwinter', 1),
#  ('candle', 1),
#  ('Decadent', 1),
#  ('snowfetti', 1),
#  ('marsala', 1),
#  ('bunting', 1),
#  ('Sandham', 1),
#  ('family', 1),
#  ('smoothie', 1),
#  ('ivy', 1),
#  ('Sage,', 1),
#  ('Open', 1),
#  ...]

# %% [markdown]
# **Pudding Ingredients:**
# flour, butter, egg, muscovado sugar, breadcrumb

# %%
baked_other_ratios = Counter()
# Calculate the ratios of positive and negative uses of the most common words
# Consider words to be "common" if they've been used at least 100 times
for term, cnt in list(total_method.most_common()):
    if(cnt > 200):
        baked_other_ratio = baked_method[term] / float(other_method[term]+1)
        baked_other_ratios[term] = baked_other_ratio

# %%
print("Pos-to-neg ratio for 'the' = {}".format(baked_other_ratios["the"]))
# Out:
# Pos-to-neg ratio for 'the' = 0.49216365799410333

# %%
for word,ratio in baked_other_ratios.most_common():
    baked_other_ratios[word] = np.log(ratio)

# %%
print("Pos-to-neg ratio for 'the' = {}".format(baked_other_ratios["the"]))
# Out:
# Pos-to-neg ratio for 'the' = -0.7089439796022522

# %%
baked_other_ratios.most_common()
# Out:
# [('cake', 1.2241623536621526),
#  ('icing', 0.926872841204692),
#  ('flour,', 0.7672551527136672),
#  ('pastry', 0.6690496289808848),
#  ('line', 0.472604410945793),
#  ('Roll', 0.2524957633267371),
#  ('out', 0.20840126957700633),
#  ('base', 0.2025242641114741),
#  ('flour', 0.16350528499447856),
#  ('surface', 0.14197026127038728),
#  ('Bake', 0.1375297985912179),
#  ('sides', 0.10536051565782635),
#  ('dough', 0.08855339734144503),
#  ('Use', 0.08855339734144503),
#  ('smooth', 0.05406722127027579),
#  ('bake', 0.03836086787244616),
#  ('an', -0.037563101575648496),
#  ('tin.', -0.06301296782873404),
#  ('Spoon', -0.0659579677917974),
#  ('sugar,', -0.08632808348849726),
#  ('roll', -0.11705655542101755),
#  ('sugar', -0.12883287184296843),
#  ('butter,', -0.135955636236029),
#  ('make', -0.13646442389452534),
#  ('using', -0.14723023698268448),
#  ('together', -0.17205189015649855),
#  ('use', -0.17261274266699378),
#  ('onto', -0.18938872401704707),
#  ('baking', -0.1927514301584507),
#  ('sheet', -0.21357410029805904),
#  ('food', -0.2231435513142097),
#  ('two', -0.23590580292806104),
#  ('cool', -0.24087165460779042),
#  ('top', -0.2411620568168881),
#  ('little', -0.2438040662797268),
#  ('chocolate', -0.26152779432252504),
#  ('tin,', -0.2752286113804943),
#  ('around', -0.27958486221916157),
#  ('enough', -0.2825669717850105),
#  ('whisk', -0.29191040856130207),
#  ('lightly', -0.30368241379822203),
#  ('egg', -0.347966616046948),
#  ('butter', -0.3622322290035988),
#  ('mix', -0.36681939301050476),
#  ('orange', -0.37525132951166773),
#  ('Leave', -0.39759105167725844),
#  ('one', -0.40346710544549125),
#  ('cut', -0.40546510810816444),
#  ('milk', -0.40546510810816444),
#  ('To', -0.411507422564127),
#  ('your', -0.41159633516310085),
#  ('mixture', -0.4116417799998935),
#  ('tin', -0.41531740455117605),
#  ('down', -0.4251701791874968),
#  ('tsp', -0.4313445560959851),
#  ('dry', -0.4360018319682461),
#  ('Mix', -0.4667303039007664),
#  ('small', -0.46759688921517056),
#  ('remaining', -0.4879861317961679),
#  ('half', -0.49278680317631235),
#  ('at', -0.49945689615923095),
#  ('chill', -0.5004628367304442),
#  ('layer', -0.505548566665147),
#  ('you', -0.5117043584446794),
#  ('between', -0.5223864461670668),
#  ('cling', -0.528844129268669),
#  ('of', -0.5412204889408645),
#  ('film', -0.5453862988314581),
#  ('any', -0.5535612790267165),
#  ('cool.', -0.556287997842748),
#  ('If', -0.5610292157325698),
#  ('on', -0.5619049915295572),
#  ('bowl,', -0.5712573629509086),
#  ('will', -0.5768081884757955),
#  ('each', -0.5822845877481356),
#  ('a', -0.5838085927814959),
#  ('30', -0.5928905768202949),
#  ('bowl', -0.5978370007556204),
#  ('another', -0.6011282818396931),
#  ('fan/gas', -0.601871404783858),
#  ('with', -0.6035749827086418),
#  ('by', -0.6101502609889775),
#  ('it', -0.6117696212885716),
#  ('this', -0.6120793574711635),
#  ('', -0.6122405419471448),
#  ('bowl.', -0.6208265189803193),
#  ('foil', -0.6237186741281824),
#  ('Cut', -0.623786052762443),
#  ('have', -0.6286086594223742),
#  ('golden', -0.6327666695710378),
#  ('into', -0.6328393288430622),
#  ('–', -0.6386589952758756),
#  ('oven', -0.6454433826027342),
#  ('then', -0.6558671275666488),
#  ('well', -0.6576404921030355),
#  ('Stir', -0.6626879730752369),
#  ('4', -0.6649763035932491),
#  ('as', -0.6670587444756474),
#  ('to', -0.668647270806711),
#  ('15', -0.6757554378480761),
#  ('When', -0.698288580060364),
#  ('cover', -0.6988452016745831),
#  ('or', -0.7007453597910167),
#  ('just', -0.7046195817221821),
#  ('the', -0.7089439796022522),
#  ('keep', -0.7111656860626236),
#  ('off', -0.713625711903486),
#  ('set', -0.71683695168235),
#  ('leave', -0.7246649408803504),
#  ('so', -0.7301261838010327),
#  ('about', -0.7312712384016836),
#  ('place', -0.7389567165912395),
#  ('The', -0.7419373447293773),
#  ('3', -0.7437326773480516),
#  ('in', -0.7475323668567474),
#  ('until', -0.7508826884014366),
#  ('them', -0.7530453221410143),
#  ('2', -0.7608421933312968),
#  ('gently', -0.7621400520468967),
#  ('few', -0.7642051018256664),
#  ('turn', -0.7701082216960736),
#  ('tbsp', -0.7737512129745747),
#  ('6.', -0.7741162430936124),
#  ('up', -0.7771328366330381),
#  ('more', -0.7846622893957185),
#  ('and', -0.7858819436022603),
#  ('over', -0.7925196543731491),
#  ('Tip', -0.7944553790128237),
#  ('aside', -0.8056251639866356),
#  ('Heat', -0.809280323085087),
#  ('can', -0.8109302162163288),
#  ('remove', -0.8163094653360649),
#  ('everything', -0.8216255053330767),
#  ('if', -0.8232003088081431),
#  ('ingredients', -0.831733343846092),
#  ('warm', -0.8358034809614685),
#  ('put', -0.8360099006133522),
#  ('very', -0.8387324975282806),
#  ('water.', -0.8450632225857873),
#  ('water', -0.8516175215317201),
#  ('spoon', -0.8520484631458014),
#  ('be', -0.8579755799063827),
#  ('for', -0.859905363460337),
#  ('1', -0.8600572041409635),
#  ('stir', -0.8710987376827816),
#  ('is', -0.8791846198630976),
#  ('some', -0.8807457944547437),
#  ('has', -0.883767540168595),
#  ('cream', -0.892829245195157),
#  ('side', -0.8938178760220964),
#  ('back', -0.8979415932059586),
#  ('mins,', -0.8983798053076247),
#  ('10', -0.9046287921263122),
#  ('Cover', -0.908855753386637),
#  ('from', -0.909733331327996),
#  ('mins', -0.9128562694255203),
#  ('5', -0.922425720441671),
#  ('20', -0.925340567394073),
#  ('Put', -0.9287649060993308),
#  ('tray', -0.9459825216815582),
#  ('Add', -0.9464005333455255),
#  ('before', -0.9518706643067806),
#  ('all', -0.9593853713372419),
#  ('not', -0.9727320427791069),
#  ('fridge', -0.9765095918672098),
#  ('200C/180C', -0.9769153536905899),
#  ('serve', -0.9808292530117262),
#  ('Remove', -0.9866263706960521),
#  ('mins.', -0.9979470965286947),
#  ('golden.', -1.002764329877982),
#  ('rest', -1.0138157520080326),
#  ('that', -1.033229529405258),
#  ('but', -1.0360919316867756),
#  ('Meanwhile,', -1.0406250310177603),
#  ('large', -1.0486018680934484),
#  ('tip', -1.0522882169938712),
#  ('pour', -1.0560526742493137),
#  ('ready', -1.0593915755148284),
#  ('medium', -1.0731332033671248),
#  ('they', -1.1169614273363062),
#  ('add', -1.1180303745252114),
#  ('Place', -1.165132971009672),
#  ('are', -1.1723298645646774),
#  ('hot', -1.1834511686051392),
#  ('bring', -1.211635677071505),
#  ('heat', -1.213022639845854),
#  ('Serve', -1.2219913098286144),
#  ('Pour', -1.240674171176364),
#  ('sauce', -1.2554547601610793),
#  ('through', -1.2604553141185237),
#  ('stirring', -1.2766511836700636),
#  ('pan.', -1.295322582914164),
#  ('serve.', -1.303406701314123),
#  ('lemon', -1.3083328196501787),
#  ('serving', -1.3682758556172123),
#  ('onion', -1.4103919126989513),
#  ('Cook', -1.4163266482187657),
#  ('pan,', -1.452252328911688),
#  ('boil', -1.4897299483681326),
#  ('salt', -1.4963850511531185),
#  ('Bring', -1.5040773967762742),
#  ('juice', -1.5105920777974677),
#  ('cook', -1.5339303599259553),
#  ('pan', -1.572506973406812),
#  ('season', -1.6534547978508747),
#  ('oil', -1.6792814858013647),
#  ('simmer', -1.8004931491968097),
#  ('frying', -1.9136492868370918),
#  ('fry', -1.9356536488881242),
#  ('roasting', -2.119086373027076),
#  ('potatoes', -2.2746112409516397),
#  ('turkey', -3.678107357132025)]

# %%
list(reversed(baked_other_ratios.most_common()))[0:50]
# Out:
# [('turkey', -3.678107357132025),
#  ('potatoes', -2.2746112409516397),
#  ('roasting', -2.119086373027076),
#  ('fry', -1.9356536488881242),
#  ('frying', -1.9136492868370918),
#  ('simmer', -1.8004931491968097),
#  ('oil', -1.6792814858013647),
#  ('season', -1.6534547978508747),
#  ('pan', -1.572506973406812),
#  ('cook', -1.5339303599259553),
#  ('juice', -1.5105920777974677),
#  ('Bring', -1.5040773967762742),
#  ('salt', -1.4963850511531185),
#  ('boil', -1.4897299483681326),
#  ('pan,', -1.452252328911688),
#  ('Cook', -1.4163266482187657),
#  ('onion', -1.4103919126989513),
#  ('serving', -1.3682758556172123),
#  ('lemon', -1.3083328196501787),
#  ('serve.', -1.303406701314123),
#  ('pan.', -1.295322582914164),
#  ('stirring', -1.2766511836700636),
#  ('through', -1.2604553141185237),
#  ('sauce', -1.2554547601610793),
#  ('Pour', -1.240674171176364),
#  ('Serve', -1.2219913098286144),
#  ('heat', -1.213022639845854),
#  ('bring', -1.211635677071505),
#  ('hot', -1.1834511686051392),
#  ('are', -1.1723298645646774),
#  ('Place', -1.165132971009672),
#  ('add', -1.1180303745252114),
#  ('they', -1.1169614273363062),
#  ('medium', -1.0731332033671248),
#  ('ready', -1.0593915755148284),
#  ('pour', -1.0560526742493137),
#  ('tip', -1.0522882169938712),
#  ('large', -1.0486018680934484),
#  ('Meanwhile,', -1.0406250310177603),
#  ('but', -1.0360919316867756),
#  ('that', -1.033229529405258),
#  ('rest', -1.0138157520080326),
#  ('golden.', -1.002764329877982),
#  ('mins.', -0.9979470965286947),
#  ('Remove', -0.9866263706960521),
#  ('serve', -0.9808292530117262),
#  ('200C/180C', -0.9769153536905899),
#  ('fridge', -0.9765095918672098),
#  ('not', -0.9727320427791069),
#  ('all', -0.9593853713372419)]

# %%
vocab = set(total_method.keys())

# %%
vocab_size = len(vocab)
print(vocab_size)
# Out:
# 10905

# %%
layer_0 = np.zeros((1,vocab_size))
layer_0.shape
# Out:
# (1, 10905)

# %%
# Create a dictionary of words in the vocabulary mapped to index positions 
# (to be used in layer_0)
word2index = {}
for i,word in enumerate(vocab):
    word2index[word] = i
word2index
# Out:
# {'': 0,
#  'any': 1,
#  'shallots.Whisk': 2,
#  'ginger,\xa0black': 3,
#  'cane-coloured': 4,
#  'setting).': 5,
#  'meticulously': 6,
#  'beetroot': 7,
#  '25-30cm': 8,
#  'Turkish': 9,
#  'floppy.': 10,
#  'criss-crossing': 11,
#  'vary,': 12,
#  'honeyed': 13,
#  'better),': 14,
#  'mess).': 15,
#  'kale,': 16,
#  'garlic,': 17,
#  'drain,': 18,
#  'grill.': 19,
#  'beating': 20,
#  'watertight).': 21,
#  'one)': 22,
#  'instructed': 23,
#  'falafels': 24,
#  'cases.': 25,
#  'perhaps': 26,
#  'drumstick': 27,
#  'together': 28,
#  'sit,': 29,
#  'paella.': 30,
#  'figs': 31,
#  'Tip': 32,
#  'plasticine.': 33,
#  'We': 34,
#  'lengths.': 35,
#  'time.\xa0': 36,
#  'store,': 37,
#  'mins–1': 38,
#  'dragging': 39,
#  'appearance.': 40,
#  'tough.': 41,
#  'twice,': 42,
#  'carefully\xa0turning': 43,
#  'disc': 44,
#  'parchment.)': 45,
#  'corner,': 46,
#  'page': 47,
#  'marinated': 48,
#  'rectangle,': 49,
#  'sawing': 50,
#  'rosemary,': 51,
#  'milk,': 52,
#  'scrunching': 53,
#  '40': 54,
#  'hour,': 55,
#  'pointed': 56,
#  'over.': 57,
#  'carton,': 58,
#  'balloons': 59,
#  'ovens': 60,
#  'point.': 61,
#  'ribbons': 62,
#  '(grease': 63,
#  'tagine.': 64,
#  'onion\xa0until': 65,
#  'spinach.': 66,
#  'Sharpen': 67,
#  'head.': 68,
#  'neat': 69,
#  'thick,': 70,
#  'scramble.': 71,
#  'grind,': 72,
#  'jug,': 73,
#  'reposition': 74,
#  'Slip': 75,
#  'wholemeal': 76,
#  'available': 77,
#  'crispiness.': 78,
#  'hand.': 79,
#  'keep.': 80,
#  'preserve': 81,
#  'smoothing': 82,
#  'rolls': 83,
#  '180C.': 84,
#  'contact': 85,
#  'thicken.': 86,
#  'coated,': 87,
#  'expected.': 88,
#  'needed).': 89,
#  'chocolate-coated': 90,
#  '36': 91,
#  'air,': 92,
#  'tamari,': 93,
#  'sterilised': 94,
#  'assembled': 95,
#  'biscuit),': 96,
#  'bananas,': 97,
#  'carrot.': 98,
#  'container': 99,
#  'If': 100,
#  'relish': 101,
#  'decorate': 102,
#  'gratin,': 103,
#  'Pat': 104,
#  'skin,\xa0on': 105,
#  '130C': 106,
#  'plateful': 107,
#  'lacquered': 108,
#  'slaw': 109,
#  'glasses': 110,
#  'other': 111,
#  'also': 112,
#  "'flooding'": 113,
#  'trimmings),': 114,
#  'beef\xa0stock': 115,
#  '220c/fan': 116,
#  '(each': 117,
#  'stilton.': 118,
#  'chance': 119,
#  'carefully': 120,
#  'Sauté,': 121,
#  'intervals': 122,
#  'quails’': 123,
#  'cornflour.': 124,
#  '(still': 125,
#  'Shaohsing': 126,
#  'heavy': 127,
#  'burger': 128,
#  'burgershaped': 129,
#  'squiggles,': 130,
#  'order,': 131,
#  'two-thirds.': 132,
#  '4cm': 133,
#  'softens': 134,
#  'achieved.': 135,
#  'offering': 136,
#  'rests,': 137,
#  'lidded': 138,
#  '(only': 139,
#  'salad.': 140,
#  'quarter.': 141,
#  'colour,': 142,
#  'pair': 143,
#  'semifreddo.': 144,
#  '125ml.': 145,
#  'large.)': 146,
#  'softening,': 147,
#  'critical,': 148,
#  'meat-eaters.': 149,
#  'Season.': 150,
#  'Place\xa0baking': 151,
#  'edged': 152,
#  'absorb': 153,
#  'overcook': 154,
#  'pancake-wrapped': 155,
#  'little,': 156,
#  'Quickly': 157,
#  'Attach': 158,
#  'plums': 159,
#  'Whatever': 160,
#  'Seal': 161,
#  'dipping': 162,
#  'stripes': 163,
#  're-wrap': 164,
#  'quince': 165,
#  'oregano,': 166,
#  'cold).': 167,
#  'used': 168,
#  '(remember': 169,
#  'voluptuous': 170,
#  'stout': 171,
#  'dissolves': 172,
#  "'crown'": 173,
#  'top.': 174,
#  'passata': 175,
#  'Rocher': 176,
#  'translucent,': 177,
#  '121C': 178,
#  'prawns.': 179,
#  'shavings': 180,
#  'was': 181,
#  'linseed': 182,
#  'loins': 183,
#  'sink.': 184,
#  'breasts:': 185,
#  'teapot': 186,
#  'teapot.': 187,
#  'zest\xa0and': 188,
#  'even-textured': 189,
#  'airy.': 190,
#  'chicory,': 191,
#  'Check': 192,
#  'Brush': 193,
#  'particularly': 194,
#  'breadcrumbs': 195,
#  'creams.': 196,
#  'ahead.)': 197,
#  'folders.': 198,
#  '(Now': 199,
#  'radicchio': 200,
#  'months.': 201,
#  'Port.': 202,
#  'batch,': 203,
#  '8': 204,
#  'timbales': 205,
#  'Marmite': 206,
#  'melty': 207,
#  'rising,': 208,
#  'peach': 209,
#  'room': 210,
#  'oz)': 211,
#  '200C/conventional': 212,
#  'segments': 213,
#  'pea-sized': 214,
#  'two-thirds,': 215,
#  'collar.': 216,
#  'bath,': 217,
#  'using\xa0only': 218,
#  'jackets,': 219,
#  'escape.': 220,
#  'bake.': 221,
#  'rectangle.': 222,
#  'blowtorch,': 223,
#  'lamb,': 224,
#  'Roll': 225,
#  'continuously': 226,
#  'caramelise,': 227,
#  'bits.)': 228,
#  'Reserving': 229,
#  'Run': 230,
#  'cooked,': 231,
#  'our\xa0': 232,
#  'frozen': 233,
#  'gentle': 234,
#  'three-quarters': 235,
#  'Replace': 236,
#  'fragile': 237,
#  'Flake': 238,
#  'mushy,': 239,
#  'have': 240,
#  'dipped': 241,
#  '11': 242,
#  'spices;': 243,
#  'pillowy,': 244,
#  'litre/': 245,
#  'those,': 246,
#  'fragrant': 247,
#  'nuts.': 248,
#  'curdle': 249,
#  'softens.': 250,
#  'wide,': 251,
#  'dash': 252,
#  'detailed': 253,
#  'stirs': 254,
#  'BUTTONS': 255,
#  'baking': 256,
#  'crackling,': 257,
#  'vinegar,': 258,
#  'brioche,': 259,
#  '60': 260,
#  'once,': 261,
#  'petal': 262,
#  'smell,': 263,
#  '2).': 264,
#  'then,': 265,
#  'just-boiled': 266,
#  'slot': 267,
#  'dusted': 268,
#  'fronds,': 269,
#  'jointing,': 270,
#  'connected': 271,
#  'unattended.': 272,
#  'even.': 273,
#  'bottom,': 274,
#  'nicely,': 275,
#  'hazelnuts.': 276,
#  'cooking),': 277,
#  '6.Roll': 278,
#  'Holding': 279,
#  'boil,': 280,
#  '190C/fan': 281,
#  'seconds': 282,
#  'coffee.': 283,
#  'Clean': 284,
#  'Re-freeze': 285,
#  'crusty': 286,
#  '‘wall’': 287,
#  'fortnight,': 288,
#  'fridge': 289,
#  'time,': 290,
#  'of\xa0eight,': 291,
#  'fortunes': 292,
#  'untoasted-side': 293,
#  'details.': 294,
#  'coupe': 295,
#  'sparingly': 296,
#  'milk.\xa0When': 297,
#  'Smartie': 298,
#  'Can': 299,
#  'scales)': 300,
#  'well-drained': 301,
#  'spicy': 302,
#  'curly': 303,
#  'around.': 304,
#  '15–20': 305,
#  'fan/gas': 306,
#  'casserole,': 307,
#  'thicker).': 308,
#  'trivet': 309,
#  'extra-wide': 310,
#  'houses': 311,
#  'someone': 312,
#  'pushed': 313,
#  '4-5': 314,
#  'length.': 315,
#  'melba': 316,
#  'loin,': 317,
#  'scone.': 318,
#  'cheese.': 319,
#  '‘Just': 320,
#  'Quarter': 321,
#  'hot\xa0or': 322,
#  'torte': 323,
#  '1lb': 324,
#  'Baileys': 325,
#  'board': 326,
#  '1/4': 327,
#  '(one': 328,
#  'cloves,': 329,
#  'juices.': 330,
#  'pumpkin': 331,
#  'hard,': 332,
#  'nest': 333,
#  'overnight': 334,
#  'cappuccino.': 335,
#  'jelly,': 336,
#  '(wash': 337,
#  'little': 338,
#  'equal,': 339,
#  'horizontal.': 340,
#  'random': 341,
#  'microwave-safe': 342,
#  'days),': 343,
#  'and\xa0root': 344,
#  'works': 345,
#  'marked.': 346,
#  'gingerbread': 347,
#  'combines\xa0to': 348,
#  'alongside': 349,
#  'cumin,': 350,
#  '77C.': 351,
#  'that': 352,
#  'Cut': 353,
#  'thicker': 354,
#  'rich.': 355,
#  'chutney': 356,
#  'moist': 357,
#  'ducks,': 358,
#  'point:': 359,
#  'eucalyptus': 360,
#  'facing': 361,
#  'leave,': 362,
#  'step': 363,
#  'lot.': 364,
#  'on.\xa0': 365,
#  'settle': 366,
#  'soaked': 367,
#  'day).': 368,
#  'coal': 369,
#  'gratin': 370,
#  'equally': 371,
#  'fork.': 372,
#  'raw,': 373,
#  'stream.': 374,
#  'unattended),': 375,
#  'bend,': 376,
#  'rectangle': 377,
#  'stems': 378,
#  'When': 379,
#  'scum.': 380,
#  'left.)': 381,
#  'day': 382,
#  'Working': 383,
#  'twists': 384,
#  'closer': 385,
#  'pandoro': 386,
#  'figurine': 387,
#  'a': 388,
#  'torch': 389,
#  'pancetta.': 390,
#  'slight': 391,
#  'cone.': 392,
#  'heat,': 393,
#  'lamb': 394,
#  'thickens,': 395,
#  'lemongrass': 396,
#  'steamer.': 397,
#  'helpful': 398,
#  'toasted.': 399,
#  'pairs': 400,
#  'cracks;': 401,
#  'pipe': 402,
#  'rubbing': 403,
#  'sealing.': 404,
#  'weight,': 405,
#  'glitter': 406,
#  'overwrap': 407,
#  'onion': 408,
#  'removing': 409,
#  'layer,': 410,
#  'trimmed': 411,
#  'brackets': 412,
#  'flameproof': 413,
#  'upper': 414,
#  'white)': 415,
#  'raise': 416,
#  'even-shaped': 417,
#  '12-cube': 418,
#  'chocolate': 419,
#  'sterilise': 420,
#  'yeast.': 421,
#  'previous': 422,
#  'yet': 423,
#  'heat.\xa0Keep': 424,
#  'Drape': 425,
#  'icing),': 426,
#  'Snuggle': 427,
#  'eighths': 428,
#  'family,': 429,
#  'jigsaw,': 430,
#  'women': 431,
#  'eggs': 432,
#  'evaporate.': 433,
#  'jam': 434,
#  'uncover': 435,
#  'Separately,': 436,
#  'inch': 437,
#  '220C/fan': 438,
#  'everyone.': 439,
#  'dishwasher': 440,
#  'similar,': 441,
#  'people': 442,
#  'with.': 443,
#  'syrupy.\xa0If': 444,
#  'curdles,': 445,
#  'caramelises': 446,
#  'beets.': 447,
#  'feta.': 448,
#  'baster': 449,
#  'saucy': 450,
#  'burgers,': 451,
#  'sheets': 452,
#  'sieve': 453,
#  'aromatics.': 454,
#  'An': 455,
#  'rock': 456,
#  'you.': 457,
#  'oranges.\xa0Juice': 458,
#  'brandy.': 459,
#  'cake,': 460,
#  'virgin': 461,
#  'heavy-': 462,
#  'carefully.': 463,
#  'cooking.': 464,
#  'Low,': 465,
#  'shrinking': 466,
#  'melted': 467,
#  'lightly-floured': 468,
#  'Sherry': 469,
#  'BEOFRE:': 470,
#  'faux': 471,
#  'attach': 472,
#  'motion.': 473,
#  'sit': 474,
#  'pop.': 475,
#  'masala,': 476,
#  '30cm-long': 477,
#  'trap': 478,
#  'upside-down,': 479,
#  'sausages.': 480,
#  'sandwiched': 481,
#  'neat-looking': 482,
#  'unwrapped': 483,
#  '2/fan': 484,
#  'pre-rolled': 485,
#  'sweets.': 486,
#  'lighter': 487,
#  'batches),': 488,
#  '2/': 489,
#  'use.)': 490,
#  'people,': 491,
#  'two.': 492,
#  'blender': 493,
#  'sugars.': 494,
#  '(approx': 495,
#  'Poach': 496,
#  'curl.': 497,
#  'quickest': 498,
#  'hat,': 499,
#  'rustic': 500,
#  'there’s': 501,
#  'butter': 502,
#  '1': 503,
#  'deliciously': 504,
#  'trim.': 505,
#  'hard.': 506,
#  'loosebottomed': 507,
#  'rapeseed': 508,
#  'walls,': 509,
#  'charms': 510,
#  'saucers': 511,
#  'whizzed-up': 512,
#  'you).': 513,
#  'mm': 514,
#  'wave': 515,
#  'and\xa0whisk\xa0on': 516,
#  'opening': 517,
#  'designs.': 518,
#  'mincemeat:': 519,
#  'flours,': 520,
#  'even-sized': 521,
#  'finish.': 522,
#  '200g),': 523,
#  'cucumber': 524,
#  'splash': 525,
#  '48': 526,
#  'slivers.': 527,
#  'lid)': 528,
#  'sandwich.': 529,
#  'Chestnut': 530,
#  'owl-like': 531,
#  'gaps': 532,
#  'pudding': 533,
#  '(half-fill': 534,
#  'longest': 535,
#  'saucy.': 536,
#  'widthways': 537,
#  'Finally': 538,
#  'tangerines': 539,
#  'gently.': 540,
#  'intestine.': 541,
#  'A,': 542,
#  '700g': 543,
#  'leftovers': 544,
#  'wholegrain': 545,
#  '26cm': 546,
#  'pan,': 547,
#  'secure': 548,
#  'nozzles': 549,
#  'times,': 550,
#  'important': 551,
#  'Season,': 552,
#  'Break': 553,
#  'relax.': 554,
#  'right': 555,
#  '55-60': 556,
#  'blacken.': 557,
#  'marmalade.': 558,
#  'crackled.': 559,
#  'cheat': 560,
#  'and,': 561,
#  'Beat': 562,
#  'level': 563,
#  'Divide\xa0the': 564,
#  'S-shape.': 565,
#  'belly.': 566,
#  'hollows': 567,
#  'constantly,': 568,
#  'minutes.': 569,
#  'whole.': 570,
#  'area)': 571,
#  'warmed': 572,
#  'clap': 573,
#  'images': 574,
#  'dusting': 575,
#  'masala': 576,
#  'cook': 577,
#  'mustard,': 578,
#  'marshmallow.': 579,
#  'physalis': 580,
#  'rotate': 581,
#  'layer\xa0is': 582,
#  'mixture.': 583,
#  'bloody.': 584,
#  'shake': 585,
#  'puffs,': 586,
#  '-side': 587,
#  'Lancashire': 588,
#  'spoon,fold': 589,
#  'partridges': 590,
#  'fluff': 591,
#  'Mince': 592,
#  'stringy': 593,
#  'glazed.': 594,
#  'sheets).': 595,
#  'dips': 596,
#  'curdle,': 597,
#  'extra': 598,
#  'eight': 599,
#  'whisked': 600,
#  'cube': 601,
#  'crater': 602,
#  '3-4cm': 603,
#  'over-brown.': 604,
#  'right.': 605,
#  'frais': 606,
#  'closest': 607,
#  'cheesecakes': 608,
#  'turmeric': 609,
#  'infuse,': 610,
#  'mayo.': 611,
#  'fridge.)': 612,
#  'oil)': 613,
#  'parmesan': 614,
#  'mouth': 615,
#  'wobbly)': 616,
#  'Glue': 617,
#  'oily': 618,
#  'glass': 619,
#  '85g/3oz': 620,
#  'gluten': 621,
#  'peaks,': 622,
#  'spreadable.': 623,
#  'salt.': 624,
#  'cognac': 625,
#  'bird’s': 626,
#  'chia': 627,
#  'thread': 628,
#  'decorating.': 629,
#  'B': 630,
#  'excess.': 631,
#  'becoming': 632,
#  'incorporated,': 633,
#  'hedgehog.': 634,
#  'them).': 635,
#  'hand-held': 636,
#  'tablespoonfuls': 637,
#  'we’ve': 638,
#  'dots': 639,
#  'oyster': 640,
#  'lid/base': 641,
#  'samosas.': 642,
#  'and\xa0': 643,
#  'sauce:': 644,
#  'Steam': 645,
#  'melt': 646,
#  'Blanch': 647,
#  'pulp,': 648,
#  '2⁄2½hours.': 649,
#  'fish.': 650,
#  'chicory.': 651,
#  'stability.': 652,
#  'inside': 653,
#  'stiff-ish': 654,
#  '1½-2': 655,
#  'hash': 656,
#  'ovenight': 657,
#  'Repeat': 658,
#  'overlap': 659,
#  'frosty': 660,
#  'unsifted': 661,
#  'timing': 662,
#  'gum': 663,
#  'cornflour': 664,
#  'bowl),': 665,
#  'bottom': 666,
#  'Kahlúa.': 667,
#  'Suck': 668,
#  'raffia.': 669,
#  'looser': 670,
#  '(strain': 671,
#  'granules': 672,
#  'knuckles': 673,
#  'top.\xa0': 674,
#  'delight,': 675,
#  'pears,': 676,
#  'hardened,': 677,
#  'ganoush': 678,
#  'blinis.': 679,
#  'diamond-shaped': 680,
#  'container)': 681,
#  'hold': 682,
#  'herbs,': 683,
#  'were': 684,
#  'trimmings.': 685,
#  'bits.': 686,
#  'through.\xa0': 687,
#  'these': 688,
#  'Baileys,': 689,
#  'Tobin': 690,
#  'build': 691,
#  'baguette': 692,
#  'Scandinavia,': 693,
#  'slide': 694,
#  '(Don’t': 695,
#  'kirsch,': 696,
#  'granita': 697,
#  'pulpy.': 698,
#  'sturdy,': 699,
#  'Stilton': 700,
#  'Best': 701,
#  'excess,': 702,
#  'ganache': 703,
#  'tarts.': 704,
#  'icing-sugar-dusted': 705,
#  'bad': 706,
#  'chicken': 707,
#  'lack': 708,
#  'elasticated': 709,
#  'made:': 710,
#  'stalks,': 711,
#  'guacamole': 712,
#  'remove': 713,
#  '140C/120C': 714,
#  'diamonds': 715,
#  'Cake': 716,
#  'across)': 717,
#  'guest,': 718,
#  '170C.': 719,
#  'candle': 720,
#  'sprigs': 721,
#  'the\xa0cardamom': 722,
#  'Rub': 723,
#  'Great': 724,
#  'cross': 725,
#  '14': 726,
#  'chopped\xa0shallot,': 727,
#  'stamped-out': 728,
#  'name': 729,
#  'shallow-fry': 730,
#  'frozen).': 731,
#  'gluey': 732,
#  'bamboo': 733,
#  '105C,': 734,
#  'broken-up': 735,
#  'counter': 736,
#  'helps': 737,
#  '2-in': 738,
#  'juices,': 739,
#  'lose': 740,
#  '(8-9': 741,
#  'higgledy-piggledy': 742,
#  'spaces': 743,
#  'sign': 744,
#  'minced': 745,
#  'poking': 746,
#  'cloth': 747,
#  '70C/50C': 748,
#  '(be': 749,
#  'biro,': 750,
#  'help.': 751,
#  'Chilled': 752,
#  'returned': 753,
#  'turning': 754,
#  'pulp.': 755,
#  'gobstopper)': 756,
#  'bakes.': 757,
#  'crisps': 758,
#  'champagne,': 759,
#  'tape.': 760,
#  'butteriness.': 761,
#  'fifth': 762,
#  'finger;': 763,
#  'twice': 764,
#  'setting,': 765,
#  'brine.': 766,
#  'carcass.': 767,
#  'vibrant.)': 768,
#  'saucer,': 769,
#  'ruler,': 770,
#  'flecked': 771,
#  'jagged': 772,
#  'cover)': 773,
#  'whipped': 774,
#  '(reserving': 775,
#  'holly,': 776,
#  'inserted': 777,
#  'snowflakes,': 778,
#  'gin.': 779,
#  'now.)': 780,
#  'Select': 781,
#  'undisturbed,': 782,
#  '225ml/8fl': 783,
#  'baklava,': 784,
#  'High,': 785,
#  '60C.': 786,
#  'dinner': 787,
#  'of\xa0bread.': 788,
#  'cooks’': 789,
#  'pairs,': 790,
#  'size.': 791,
#  '(especially': 792,
#  'Hold': 793,
#  'gap': 794,
#  '120C/': 795,
#  "decorations')": 796,
#  'paste-like': 797,
#  'half-pint': 798,
#  'likely': 799,
#  'chest,': 800,
#  'sticky,': 801,
#  'butter-side': 802,
#  'spray,': 803,
#  'evenly),': 804,
#  'presents,': 805,
#  'seeds': 806,
#  'garlicky.': 807,
#  'changing': 808,
#  'pot.': 809,
#  'pancakes),': 810,
#  'herbs.': 811,
#  'cool.\u2028': 812,
#  'biscuit-': 813,
#  'care,': 814,
#  'reroll.': 815,
#  'Generously': 816,
#  'slashes': 817,
#  '70ml': 818,
#  'measure).': 819,
#  'salami,': 820,
#  'incorporate': 821,
#  'stuffing,': 822,
#  'ten': 823,
#  'timings': 824,
#  'royal': 825,
#  'Mix': 826,
#  'released': 827,
#  'marks.': 828,
#  'You': 829,
#  'flakes': 830,
#  'caramel.': 831,
#  'bresaola': 832,
#  'paper.': 833,
#  'activate': 834,
#  'places,': 835,
#  'Split': 836,
#  'Crisp': 837,
#  'Coat': 838,
#  '£1': 839,
#  'fattier': 840,
#  'hard),': 841,
#  'crisping': 842,
#  '18cm,': 843,
#  'firmly.': 844,
#  'film.Place': 845,
#  'straining': 846,
#  'juice.': 847,
#  'line.': 848,
#  'jostle': 849,
#  'molten': 850,
#  '600ml/1pt': 851,
#  'correct': 852,
#  'Secure': 853,
#  '1¾': 854,
#  'swish': 855,
#  'snowmen,': 856,
#  'béchamel.': 857,
#  'Core,': 858,
#  'savarin': 859,
#  'strip': 860,
#  'cheddar,': 861,
#  'water': 862,
#  'kettleful': 863,
#  'table).': 864,
#  'left)': 865,
#  'Watch': 866,
#  'casually': 867,
#  'wibblywobbly,': 868,
#  'fruits.': 869,
#  'Uncover': 870,
#  '10cm-long': 871,
#  'streaks': 872,
#  'sieved': 873,
#  'wiping': 874,
#  'overly': 875,
#  'gravadlax': 876,
#  'Wrap,': 877,
#  'such': 878,
#  'dependent': 879,
#  '16-18.': 880,
#  'colour': 881,
#  '/gas': 882,
#  '170.': 883,
#  'jam.': 884,
#  'stick,\xa0coriander': 885,
#  'batch': 886,
#  'minimum,': 887,
#  'neatest': 888,
#  'better': 889,
#  '‘ring’,': 890,
#  'disk.': 891,
#  '–': 892,
#  'Cognac,': 893,
#  'biscotti': 894,
#  'juices),': 895,
#  '2-21⁄2': 896,
#  'allspice': 897,
#  'litre': 898,
#  'tumblers': 899,
#  'cloves,\xa0': 900,
#  'forms': 901,
#  'next,': 902,
#  'molasses': 903,
#  'food': 904,
#  'read': 905,
#  'wrapping,': 906,
#  'away),': 907,
#  'gratin.': 908,
#  'sprinkled': 909,
#  'been': 910,
#  'smells': 911,
#  'strainer,': 912,
#  'Cling': 913,
#  '-4': 914,
#  'them\xa0with': 915,
#  'almonds.': 916,
#  'spotless': 917,
#  'Then,\xa0the': 918,
#  'the\xa0butter.': 919,
#  '5mm/¼in': 920,
#  'future': 921,
#  'bananas': 922,
#  'worry,': 923,
#  '105C': 924,
#  'a\xa0cinnamon': 925,
#  'leftover': 926,
#  'loose)': 927,
#  'stock)': 928,
#  'nigella': 929,
#  'sizzle.': 930,
#  'Save': 931,
#  'booze': 932,
#  '(but': 933,
#  'choosing': 934,
#  'Drop': 935,
#  'Colour': 936,
#  'scrunch': 937,
#  'chestnuts,': 938,
#  'sugars,': 939,
#  'required': 940,
#  'antlers.': 941,
#  'motion': 942,
#  're-chill': 943,
#  'scraps.': 944,
#  'Cointreau,': 945,
#  '375g': 946,
#  'baklava': 947,
#  'tofu': 948,
#  'cornmeal.': 949,
#  'sandwiches.': 950,
#  'SOME': 951,
#  'to,': 952,
#  'decoration': 953,
#  'overcooking.': 954,
#  'ham.': 955,
#  'lentils': 956,
#  'softly': 957,
#  'number': 958,
#  'croutons,': 959,
#  'won’t': 960,
#  'one,': 961,
#  'strip,': 962,
#  'really': 963,
#  'golden': 964,
#  'sesame': 965,
#  'rendered': 966,
#  'patches': 967,
#  'thicker.': 968,
#  'cinammon)': 969,
#  '1cm,': 970,
#  'dollop': 971,
#  'mottled': 972,
#  'beak.': 973,
#  'burst,': 974,
#  'video': 975,
#  'vinegar': 976,
#  'brush': 977,
#  '7cm': 978,
#  'thighs': 979,
#  'boils.': 980,
#  'Gruyère': 981,
#  'cabbage.': 982,
#  'clingfilm.': 983,
#  'Christmassy': 984,
#  'face': 985,
#  'tight': 986,
#  'attachment,': 987,
#  'hot.\xa0': 988,
#  'squeezing': 989,
#  '15mm': 990,
#  'guest’s': 991,
#  'emulsion.': 992,
#  'sponges.': 993,
#  'shakes': 994,
#  'next.': 995,
#  'gum.': 996,
#  'done).': 997,
#  'figure-of-eight': 998,
#  'to\xa0come\xa0together': 999,
#  ...}

# %%
def update_input_layer(review):
    """ Modify the global layer_0 to represent the vector form of review.
    The element at a given index of layer_0 should represent
    how many times the given word occurs in the review.
    Args:
        review(string) - the string of the review
    Returns:
        None
    """
     
    global layer_0
    
    # clear out previous state, reset the layer to be all 0s
    layer_0 *= 0
    
    # count how many times each word is used in the given review and store the results in layer_0 
    for word in review.split(" "):
        layer_0[0][word2index[word]] += 1

# %%
for i in range(len(data)):
    for j in range(len(data[i]['Method'])):
        data[i]['Method'][j] += " "
for i in range(len(data)):   
    data[i]['Method'][0:len(data[i]['Method'])] = [' '.join(data[i]['Method'][0:len(data[i]['Method'])])] 

method_description = []
print(data[i]['Method'][0])

for i in range(len(data)):
    method_description.append(data[i]['Method'][0])
    
update_input_layer(method_description[0])
layer_0
# Out:
# Preheat the oven to 230C/Gas 8/fan oven 210C. Brown the duck bits in the oven for about 30 minutes. Transfer to a stockpot. Discard the fat and place the tin over a medium-high flame. Pour in the Marsala and 200ml/7fl oz cold water, bring to the boil and scrape any stuck-on bits into the liquid. Boil for 2 minutes then scrape everything into the stockpot.  Add 2.25 litres/4 pints cold water to the pot and bring to the boil over a medium heat, uncovered. Scoop off any scum, then add the vegetables and herbs. Bring back to the boil, de-scum again.  Now very gently simmer for 2 hours, adding cold water if the liquid falls below the level of the bones. Remove from the heat and drain through muslin-lined colander (or use a clean tea towel) into a heatproof bowl. Cool, then refrigerate until jellied.  Heat the butter and oil in a large, nonstick frying pan over a low-medium heat, then tip in the onions. Cook for about 30 minutes, stirring occasionally, until meltingly soft. Turn heat to high, add the Marsala and boil for 3-4 minutes, stirring often, until onions are syrupy. Set aside.  Meanwhile, remove the solidified fat from the stock and discard. Boil the stock in a saucepan, uncovered, until reduced to 500ml/18fl oz. Add the white wine and boil for 10 minutes, uncovered. Add the onions and sage and bring back to the boil. (Prepare in advance up to this point.)  To finish the sauce, pour in the cream and boil furiously for 4-5 minutes, season to taste. Serve in a warmed jug.
# array([[7., 0., 0., ..., 0., 0., 0.]])

# %%
def get_target_for_label(label):
    """Convert a label to `0` or `1`.
    Args:
        label(string) - Either "POSITIVE" or "NEGATIVE".
    Returns:
        `0` or `1`.
    """
    if(label == 'Baked Good'):
        return 1
    else:
        return 0

# %%
expected_data[0]
# Out:
# 'Baked Good'

# %%
get_target_for_label(expected_data[0])
# Out:
# 1

# %%
expected_data[3]
# Out:
# 'Other'

# %%
get_target_for_label(expected_data[3])
# Out:
# 0

# %%
import time
import sys
import numpy as np

# Encapsulate our neural network in a class
class SentimentNetwork:
    def __init__(self, reviews,labels,hidden_nodes = 10, learning_rate = 0.1):
        """Create a SentimenNetwork with the given settings
        Args:
            reviews(list) - List of reviews used for training
            labels(list) - List of POSITIVE/NEGATIVE labels associated with the given reviews
            hidden_nodes(int) - Number of nodes to create in the hidden layer
            learning_rate(float) - Learning rate to use while training
        
        """
        # Assign a seed to our random number generator to ensure we get
        # reproducable results during development 
        np.random.seed(1)

        # process the reviews and their associated labels so that everything
        # is ready for training
        self.pre_process_data(reviews, labels)
        
        # Build the network to have the number of hidden nodes and the learning rate that
        # were passed into this initializer. Make the same number of input nodes as
        # there are vocabulary words and create a single output node.
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)

    def pre_process_data(self, reviews, labels):
        
        # populate review_vocab with all of the words in the given reviews
        review_vocab = set()
        for review in reviews:
            for word in review.split(" "):
                review_vocab.add(word)

        # Convert the vocabulary set to a list so we can access words via indices
        self.review_vocab = list(review_vocab)
        
        # populate label_vocab with all of the words in the given labels.
        label_vocab = set()
        for label in labels:
            label_vocab.add(label)
        
        # Convert the label vocabulary set to a list so we can access labels via indices
        self.label_vocab = list(label_vocab)
        
        # Store the sizes of the review and label vocabularies.
        self.review_vocab_size = len(self.review_vocab)
        self.label_vocab_size = len(self.label_vocab)
        
        # Create a dictionary of words in the vocabulary mapped to index positions
        self.word2index = {}
        for i, word in enumerate(self.review_vocab):
            self.word2index[word] = i
        
        # Create a dictionary of labels mapped to index positions
        self.label2index = {}
        for i, label in enumerate(self.label_vocab):
            self.label2index[label] = i
        
    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        # Set number of nodes in input, hidden and output layers.
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        # Store the learning rate
        self.learning_rate = learning_rate

        # Initialize weights

        # These are the weights between the input layer and the hidden layer.
        self.weights_0_1 = np.zeros((self.input_nodes,self.hidden_nodes))
    
        # These are the weights between the hidden layer and the output layer.
        self.weights_1_2 = np.random.normal(0.0, self.output_nodes**-0.5, 
                                                (self.hidden_nodes, self.output_nodes))
        
        # The input layer, a two-dimensional matrix with shape 1 x input_nodes
        self.layer_0 = np.zeros((1,input_nodes))
    
    def update_input_layer(self,review):

        # clear out previous state, reset the layer to be all 0s
        self.layer_0 *= 0
        
        for word in review.split(" "):
            # NOTE: This if-check was not in the version of this method created in Project 2,
            #       and it appears in Andrew's Project 3 solution without explanation. 
            #       It simply ensures the word is actually a key in word2index before
            #       accessing it, which is important because accessing an invalid key
            #       with raise an exception in Python. This allows us to ignore unknown
            #       words encountered in new reviews.
            if(word in self.word2index.keys()):
                self.layer_0[0][self.word2index[word]] += 1
                
    def get_target_for_label(self,label):
        if(label == 'Baked Good'):
            return 1
        else:
            return 0
        
    def sigmoid(self,x):
        return 1 / (1 + np.exp(-x))
    
    def sigmoid_output_2_derivative(self,output):
        return output * (1 - output)
    
    def train(self, training_reviews, training_labels):
        
        # make sure out we have a matching number of reviews and labels
        assert(len(training_reviews) == len(training_labels))
        
        # Keep track of correct predictions to display accuracy during training 
        correct_so_far = 0

        # Remember when we started for printing time statistics
        start = time.time()
        
        # loop through all the given reviews and run a forward and backward pass,
        # updating weights for every item
        for i in range(len(training_reviews)):
            
            # Get the next review and its correct label
            review = training_reviews[i]
            label = training_labels[i]
            
            #### Implement the forward pass here ####
            ### Forward pass ###

            # Input Layer
            self.update_input_layer(review)

            # Hidden layer
            layer_1 = self.layer_0.dot(self.weights_0_1)

            # Output layer
            layer_2 = self.sigmoid(layer_1.dot(self.weights_1_2))
            
            #### Implement the backward pass here ####
            ### Backward pass ###

            # Output error
            layer_2_error = layer_2 - self.get_target_for_label(label) # Output layer error is the difference between desired target and actual output.
            layer_2_delta = layer_2_error * self.sigmoid_output_2_derivative(layer_2)

            # Backpropagated error
            layer_1_error = layer_2_delta.dot(self.weights_1_2.T) # errors propagated to the hidden layer
            layer_1_delta = layer_1_error # hidden layer gradients - no nonlinearity so it's the same as the error

            # Update the weights
            self.weights_1_2 -= layer_1.T.dot(layer_2_delta) * self.learning_rate # update hidden-to-output weights with gradient descent step
            self.weights_0_1 -= self.layer_0.T.dot(layer_1_delta) * self.learning_rate # update input-to-hidden weights with gradient descent step

            # Keep track of correct predictions.
            if(layer_2 >= 0.5 and label == 'Baked Good'):
                correct_so_far += 1
            elif(layer_2 < 0.5 and label == 'Other'):
                correct_so_far += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the training process. 
            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) \
                             + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%")
            if(i % 2500 == 0):
                print("")
    
    def test(self, testing_reviews, testing_labels):
        """
        Attempts to predict the labels for the given testing_reviews,
        and uses the test_labels to calculate the accuracy of those predictions.
        """
        
        # keep track of how many correct predictions we make
        correct = 0

        # we'll time how many predictions per second we make
        start = time.time()

        # Loop through each of the given reviews and call run to predict
        # its label. 
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the prediction process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct) + " #Tested:" + str(i+1) \
                             + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
    
    def run(self, review):
        """
        Returns a Baked Good or Other prediction for the given review.
        """
        # Run a forward pass through the network, like in the "train" function.
        
        # Input Layer
        self.update_input_layer(review.lower())

        # Hidden layer
        layer_1 = self.layer_0.dot(self.weights_0_1)

        # Output layer
        layer_2 = self.sigmoid(layer_1.dot(self.weights_1_2))
        
        # Return POSITIVE for values above greater-than-or-equal-to 0.5 in the output layer;
        # return NEGATIVE for other values
        if(layer_2[0] >= 0.5):
            return "Baked Good"
        else:
            return "Other"

# %%
mlp = SentimentNetwork(expected_data[:-1000],expected_data[:-1000], learning_rate=0.1)

# %%
mlp.test(method_description[-1000:],expected_data[-1000:])
# Out:
# Progress:99.9% Speed(reviews/sec):9543. #Correct:204 #Tested:1000 Testing Accuracy:20.4%

# %%
mlp.train(method_description[-1000:],expected_data[-1000:])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:0 #Trained:1 Training Accuracy:0.0%
# Progress:99.9% Speed(reviews/sec):7184. #Correct:204 #Trained:1000 Training Accuracy:20.4%

# %%
mlp = SentimentNetwork(method_description[:-1000],expected_data[:-1000], learning_rate=0.01)
mlp.train(method_description[:-1000],expected_data[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:99.8% Speed(reviews/sec):1584. #Correct:410 #Trained:617 Training Accuracy:66.4%

# %%
mlp = SentimentNetwork(method_description[:-1000],expected_data[:-1000], learning_rate=0.001)
mlp.train(method_description[:-1000],expected_data[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:99.8% Speed(reviews/sec):1565. #Correct:405 #Trained:617 Training Accuracy:65.6%

# %%
mlp = SentimentNetwork(method_description[:-1000],expected_data[:-1000], learning_rate=0.00001)
mlp.train(method_description[:-1000],expected_data[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:98.8% Speed(reviews/sec):1517. #Correct:401 #Trained:611 Training Accuracy:65.6%
# Progress:99.8% Speed(reviews/sec):1509. #Correct:406 #Trained:617 Training Accuracy:65.8%

# %% [markdown]
# With a learning rate of 0.00001, the network should finally have started to improve during training. It's still not very good, but it shows that this solution has potential. We will improve it in the next lesson.

# %% [markdown]
# **Understanding Nueral Noise**

# %%
def update_input_layer(review):
    
    global layer_0
    
    # clear out previous state, reset the layer to be all 0s
    layer_0 *= 0
    for word in review.split(" "):
        layer_0[0][word2index[word]] += 1

update_input_layer(method_description[0])

# %%
layer_0
# Out:
# array([[7., 0., 0., ..., 0., 0., 0.]])

# %%
description_counter = Counter()
for word in method_description[0].split(" "):
    description_counter[word] += 1
description_counter.most_common()
# Out:
# [('the', 23),
#  ('and', 17),
#  ('with', 8),
#  ('', 7),
#  ('to', 6),
#  ('a', 6),
#  ('in', 5),
#  ('of', 5),
#  ('then', 4),
#  ('Heat', 3),
#  ('for', 3),
#  ('chicken', 3),
#  ('out', 3),
#  ('pastry', 3),
#  ('oil', 2),
#  ('frying', 2),
#  ('pan,', 2),
#  ('add', 2),
#  ('onion', 2),
#  ('fry', 2),
#  ('until', 2),
#  ('into', 2),
#  ('mix', 2),
#  ('fillets', 2),
#  ('remaining', 2),
#  ('mins.', 2),
#  ('Roll', 2),
#  ('Press', 2),
#  ('cover', 2),
#  ('Brush', 2),
#  ('edges', 2),
#  ('pie', 2),
#  ('tin', 2),
#  ('cool', 2),
#  ('oven', 1),
#  ('190C/fan', 1),
#  ('170C/gas', 1),
#  ('5.', 1),
#  ('1', 1),
#  ('tbsp', 1),
#  ('butter', 1),
#  ('5', 1),
#  ('mins', 1),
#  ('softened.', 1),
#  ('Cool', 1),
#  ('slightly.', 1),
#  ('Tip', 1),
#  ('sausagemeat,', 1),
#  ('lemon', 1),
#  ('zest,', 1),
#  ('breadcrumbs,', 1),
#  ('apricots,', 1),
#  ('chestnuts', 1),
#  ('thyme', 1),
#  ('bowl.', 1),
#  ('Add', 1),
#  ('cranberries,', 1),
#  ('everything', 1),
#  ('together', 1),
#  ('your', 1),
#  ('hands,', 1),
#  ('adding', 1),
#  ('plenty', 1),
#  ('pepper', 1),
#  ('little', 1),
#  ('salt.', 1),
#  ('Cut', 1),
#  ('each', 1),
#  ('breast', 1),
#  ('three', 1),
#  ('lengthwise', 1),
#  ('season', 1),
#  ('all', 1),
#  ('over', 1),
#  ('salt', 1),
#  ('pepper.', 1),
#  ('quickly', 1),
#  ('browned,', 1),
#  ('about', 1),
#  ('6-8', 1),
#  ('two-thirds', 1),
#  ('line', 1),
#  ('20-23cm', 1),
#  ('springform', 1),
#  ('or', 1),
#  ('deep', 1),
#  ('loose-based', 1),
#  ('tart', 1),
#  ('tin.', 1),
#  ('half', 1),
#  ('sausage', 1),
#  ('spread', 1),
#  ('level.', 1),
#  ('Then', 1),
#  ('pieces', 1),
#  ('one', 1),
#  ('layer', 1),
#  ('rest', 1),
#  ('sausage.', 1),
#  ('down', 1),
#  ('lightly.', 1),
#  ('pastry.', 1),
#  ('beaten', 1),
#  ('egg', 1),
#  ('lid.', 1),
#  ('Pinch', 1),
#  ('seal,', 1),
#  ('trim.', 1),
#  ('top', 1),
#  ('egg,', 1),
#  ('roll', 1),
#  ('trimmings', 1),
#  ('make', 1),
#  ('holly', 1),
#  ('leaf', 1),
#  ('shapes', 1),
#  ('berries.', 1),
#  ('Decorate', 1),
#  ('brush', 1),
#  ('again', 1),
#  ('egg.', 1),
#  ('Set', 1),
#  ('on', 1),
#  ('baking', 1),
#  ('sheet', 1),
#  ('bake', 1),
#  ('50-60', 1),
#  ('mins,', 1),
#  ('15', 1),
#  ('Remove', 1),
#  ('leave', 1),
#  ('completely.', 1),
#  ('Serve', 1),
#  ('winter', 1),
#  ('salad', 1),
#  ('pickles.', 1)]

# %% [markdown]
# # Making the Network More Efficient<a id='project_5'></a>
# **TODO:** Make the `SentimentNetwork` class more efficient by eliminating unnecessary multiplications and additions that occur during forward and backward propagation. To do that, you can do the following:
# * Copy the `SentimentNetwork` class from the previous project into the following cell.
# * Remove the `update_input_layer` function - you will not need it in this version.
# * Modify `init_network`:
# >* You no longer need a separate input layer, so remove any mention of `self.layer_0`
# >* You will be dealing with the old hidden layer more directly, so create `self.layer_1`, a two-dimensional matrix with shape 1 x hidden_nodes, with all values initialized to zero
# * Modify `train`:
# >* Change the name of the input parameter `training_reviews` to `training_reviews_raw`. This will help with the next step.
# >* At the beginning of the function, you'll want to preprocess your reviews to convert them to a list of indices (from `word2index`) that are actually used in the review. This is equivalent to what you saw in the video when Andrew set specific indices to 1. Your code should create a local `list` variable named `training_reviews` that should contain a `list` for each review in `training_reviews_raw`. Those lists should contain the indices for words found in the review.
# >* Remove call to `update_input_layer`
# >* Use `self`'s  `layer_1` instead of a local `layer_1` object.
# >* In the forward pass, replace the code that updates `layer_1` with new logic that only adds the weights for the indices used in the review.
# >* When updating `weights_0_1`, only update the individual weights that were used in the forward pass.
# * Modify `run`:
# >* Remove call to `update_input_layer`
# >* Use `self`'s  `layer_1` instead of a local `layer_1` object.
# >* Much like you did in `train`, you will need to pre-process the `review` so you can work with word indices, then update `layer_1` by adding weights for the indices used in the review.

# %%
import time
import sys
import numpy as np

# Encapsulate our neural network in a class
class SentimentNetwork:
    def __init__(self, reviews,labels,hidden_nodes = 10, learning_rate = 0.1):
        """Create a SentimenNetwork with the given settings
        Args:
            reviews(list) - List of reviews used for training
            labels(list) - List of POSITIVE/NEGATIVE labels associated with the given reviews
            hidden_nodes(int) - Number of nodes to create in the hidden layer
            learning_rate(float) - Learning rate to use while training
        
        """
        # Assign a seed to our random number generator to ensure we get
        # reproducable results during development 
        np.random.seed(1)

        # process the reviews and their associated labels so that everything
        # is ready for training
        self.pre_process_data(reviews, labels)
        
        # Build the network to have the number of hidden nodes and the learning rate that
        # were passed into this initializer. Make the same number of input nodes as
        # there are vocabulary words and create a single output node.
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)

    def pre_process_data(self, reviews, labels):
        
        # populate review_vocab with all of the words in the given reviews
        review_vocab = set()
        for review in reviews:
            for word in review.split(" "):
                review_vocab.add(word)

        # Convert the vocabulary set to a list so we can access words via indices
        self.review_vocab = list(review_vocab)
        
        # populate label_vocab with all of the words in the given labels.
        label_vocab = set()
        for label in labels:
            label_vocab.add(label)
        
        # Convert the label vocabulary set to a list so we can access labels via indices
        self.label_vocab = list(label_vocab)
        
        # Store the sizes of the review and label vocabularies.
        self.review_vocab_size = len(self.review_vocab)
        self.label_vocab_size = len(self.label_vocab)
        
        # Create a dictionary of words in the vocabulary mapped to index positions
        self.word2index = {}
        for i, word in enumerate(self.review_vocab):
            self.word2index[word] = i
        
        # Create a dictionary of labels mapped to index positions
        self.label2index = {}
        for i, label in enumerate(self.label_vocab):
            self.label2index[label] = i

    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        # Set number of nodes in input, hidden and output layers.
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        # Store the learning rate
        self.learning_rate = learning_rate

        # Initialize weights

        # These are the weights between the input layer and the hidden layer.
        self.weights_0_1 = np.zeros((self.input_nodes,self.hidden_nodes))

        # These are the weights between the hidden layer and the output layer.
        self.weights_1_2 = np.random.normal(0.0, self.output_nodes**-0.5, 
                                                (self.hidden_nodes, self.output_nodes))
        
        ## New for Project 5: Removed self.layer_0; added self.layer_1
        # The input layer, a two-dimensional matrix with shape 1 x hidden_nodes
        self.layer_1 = np.zeros((1,hidden_nodes))
    
    ## New for Project 5: Removed update_input_layer function
    
    def get_target_for_label(self,label):
        if(label == 'POSITIVE'):
            return 1
        else:
            return 0
        
    def sigmoid(self,x):
        return 1 / (1 + np.exp(-x))
    
    def sigmoid_output_2_derivative(self,output):
        return output * (1 - output)
    
    ## New for Project 5: changed name of first parameter form 'training_reviews' 
    #                     to 'training_reviews_raw'
    def train(self, training_reviews_raw, training_labels):

        ## New for Project 5: pre-process training reviews so we can deal 
        #                     directly with the indices of non-zero inputs
        training_reviews = list()
        for review in training_reviews_raw:
            indices = set()
            for word in review.split(" "):
                if(word in self.word2index.keys()):
                    indices.add(self.word2index[word])
            training_reviews.append(list(indices))

        # make sure out we have a matching number of reviews and labels
        assert(len(training_reviews) == len(training_labels))
        
        # Keep track of correct predictions to display accuracy during training 
        correct_so_far = 0

        # Remember when we started for printing time statistics
        start = time.time()
        
        # loop through all the given reviews and run a forward and backward pass,
        # updating weights for every item
        for i in range(len(training_reviews)):
            
            # Get the next review and its correct label
            review = training_reviews[i]
            label = training_labels[i]
            
            #### Implement the forward pass here ####
            ### Forward pass ###

            ## New for Project 5: Removed call to 'update_input_layer' function
            #                     because 'layer_0' is no longer used

            # Hidden layer
            ## New for Project 5: Add in only the weights for non-zero items
            self.layer_1 *= 0
            for index in review:
                self.layer_1 += self.weights_0_1[index]

            # Output layer
            ## New for Project 5: changed to use 'self.layer_1' instead of 'local layer_1'
            layer_2 = self.sigmoid(self.layer_1.dot(self.weights_1_2))            
            
            #### Implement the backward pass here ####
            ### Backward pass ###

            # Output error
            layer_2_error = layer_2 - self.get_target_for_label(label) # Output layer error is the difference between desired target and actual output.
            layer_2_delta = layer_2_error * self.sigmoid_output_2_derivative(layer_2)

            # Backpropagated error
            layer_1_error = layer_2_delta.dot(self.weights_1_2.T) # errors propagated to the hidden layer
            layer_1_delta = layer_1_error # hidden layer gradients - no nonlinearity so it's the same as the error

            # Update the weights
            ## New for Project 5: changed to use 'self.layer_1' instead of local 'layer_1'
            self.weights_1_2 -= self.layer_1.T.dot(layer_2_delta) * self.learning_rate # update hidden-to-output weights with gradient descent step
            
            ## New for Project 5: Only update the weights that were used in the forward pass
            for index in review:
                self.weights_0_1[index] -= layer_1_delta[0] * self.learning_rate # update input-to-hidden weights with gradient descent step

            # Keep track of correct predictions.
            if(layer_2 >= 0.5 and label == 'Baked Good'):
                correct_so_far += 1
            elif(layer_2 < 0.5 and label == 'Other'):
                correct_so_far += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the training process. 
            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) \
                             + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%")
            if(i % 2500 == 0):
                print("")
    
    def test(self, testing_reviews, testing_labels):
        """
        Attempts to predict the labels for the given testing_reviews,
        and uses the test_labels to calculate the accuracy of those predictions.
        """
        
        # keep track of how many correct predictions we make
        correct = 0

        # we'll time how many predictions per second we make
        start = time.time()

        # Loop through each of the given reviews and call run to predict
        # its label. 
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the prediction process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct) + " #Tested:" + str(i+1) \
                             + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
    
    def run(self, review):
        """
        Returns a POSITIVE or NEGATIVE prediction for the given review.
        """
        # Run a forward pass through the network, like in the "train" function.
        
        ## New for Project 5: Removed call to update_input_layer function
        #                     because layer_0 is no longer used

        # Hidden layer
        ## New for Project 5: Identify the indices used in the review and then add
        #                     just those weights to layer_1 
        self.layer_1 *= 0
        unique_indices = set()
        for word in review.lower().split(" "):
            if word in self.word2index.keys():
                unique_indices.add(self.word2index[word])
        for index in unique_indices:
            self.layer_1 += self.weights_0_1[index]
        
        # Output layer
        ## New for Project 5: changed to use self.layer_1 instead of local layer_1
        layer_2 = self.sigmoid(self.layer_1.dot(self.weights_1_2))
        
        # Return POSITIVE for values above greater-than-or-equal-to 0.5 in the output layer;
        # return NEGATIVE for other values
        if(layer_2[0] >= 0.5):
            return "Baked Good"
        else:
            return "Other"

# %%
mlp = SentimentNetwork(method_description[:-1000],expected_data[:-1000], learning_rate=0.001)
mlp.train(method_description[:-1000],expected_data[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:99.8% Speed(reviews/sec):1539. #Correct:398 #Trained:617 Training Accuracy:64.5%

# %%
from bokeh.models import ColumnDataSource, LabelSet
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1181">Loading BokehJS ...</span>
#     </div>

# %%
hist, edges = np.histogram(list(map(lambda x:x[1],baked_other_ratios.most_common())), density=True, bins=100, normed=True)

p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="Baked Good/Other Affinity Distribution")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)
# Out:
# /Users/hazel/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: The normed argument is ignored when density is provided. In future passing both will result in an error.
#   """Entry point for launching an IPython kernel.
#   <div class="bk-root" id="87485f30-b9a6-41ac-83e2-af1fd0b39b7b" data-root-id="1183"></div>

# %% [markdown]
# **Reducing Noise by Strategically Reducing the Vocabulary** : Improve the SentimentNetwork's performance by reducing more noise in the vocabulary. Specifically, do the following.

# %%
import time
import sys
import numpy as np

# Encapsulate our neural network in a class
class SentimentNetwork:
    ## New for Project 6: added min_count and polarity_cutoff parameters
    def __init__(self, reviews,labels,min_count = 10,polarity_cutoff = 0.1,hidden_nodes = 10, learning_rate = 0.1):
        """Create a SentimenNetwork with the given settings
        Args:
            reviews(list) - List of reviews used for training
            labels(list) - List of POSITIVE/NEGATIVE labels associated with the given reviews
            min_count(int) - Words should only be added to the vocabulary 
                             if they occur more than this many times
            polarity_cutoff(float) - The absolute value of a word's positive-to-negative
                                     ratio must be at least this big to be considered.
            hidden_nodes(int) - Number of nodes to create in the hidden layer
            learning_rate(float) - Learning rate to use while training
        
        """
        # Assign a seed to our random number generator to ensure we get
        # reproducable results during development 
        np.random.seed(1)

        # process the reviews and their associated labels so that everything
        # is ready for training
        ## New for Project 6: added min_count and polarity_cutoff arguments to pre_process_data call
        self.pre_process_data(reviews, labels, polarity_cutoff, min_count)
        
        # Build the network to have the number of hidden nodes and the learning rate that
        # were passed into this initializer. Make the same number of input nodes as
        # there are vocabulary words and create a single output node.
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)

    ## New for Project 6: added min_count and polarity_cutoff parameters
    def pre_process_data(self, reviews, labels, polarity_cutoff, min_count):
        
        ## ----------------------------------------
        ## New for Project 6: Calculate positive-to-negative ratios for words before
        #                     building vocabulary
        #
        positive_counts = Counter()
        negative_counts = Counter()
        total_counts = Counter()

        for i in range(len(reviews)):
            if(labels[i] == 'Baked Good'):
                for word in reviews[i].split(" "):
                    positive_counts[word] += 1
                    total_counts[word] += 1
            else:
                for word in reviews[i].split(" "):
                    negative_counts[word] += 1
                    total_counts[word] += 1

        pos_neg_ratios = Counter()

        for term,cnt in list(total_counts.most_common()):
            if(cnt >= 50):
                pos_neg_ratio = positive_counts[term] / float(negative_counts[term]+1)
                pos_neg_ratios[term] = pos_neg_ratio

        for word,ratio in pos_neg_ratios.most_common():
            if(ratio > 1):
                pos_neg_ratios[word] = np.log(ratio)
            else:
                pos_neg_ratios[word] = -np.log((1 / (ratio + 0.01)))
        #
        ## end New for Project 6
        ## ----------------------------------------

        # populate review_vocab with all of the words in the given reviews
        review_vocab = set()
        for review in reviews:
            for word in review.split(" "):
                ## New for Project 6: only add words that occur at least min_count times
                #                     and for words with pos/neg ratios, only add words
                #                     that meet the polarity_cutoff
                if(total_counts[word] > min_count):
                    if(word in pos_neg_ratios.keys()):
                        if((pos_neg_ratios[word] >= polarity_cutoff) or (pos_neg_ratios[word] <= -polarity_cutoff)):
                            review_vocab.add(word)
                    else:
                        review_vocab.add(word)

        # Convert the vocabulary set to a list so we can access words via indices
        self.review_vocab = list(review_vocab)
        
        # populate label_vocab with all of the words in the given labels.
        label_vocab = set()
        for label in labels:
            label_vocab.add(label)
        
        # Convert the label vocabulary set to a list so we can access labels via indices
        self.label_vocab = list(label_vocab)
        
        # Store the sizes of the review and label vocabularies.
        self.review_vocab_size = len(self.review_vocab)
        self.label_vocab_size = len(self.label_vocab)
        
        # Create a dictionary of words in the vocabulary mapped to index positions
        self.word2index = {}
        for i, word in enumerate(self.review_vocab):
            self.word2index[word] = i
        
        # Create a dictionary of labels mapped to index positions
        self.label2index = {}
        for i, label in enumerate(self.label_vocab):
            self.label2index[label] = i

    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        # Set number of nodes in input, hidden and output layers.
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        # Store the learning rate
        self.learning_rate = learning_rate

        # Initialize weights

        # These are the weights between the input layer and the hidden layer.
        self.weights_0_1 = np.zeros((self.input_nodes,self.hidden_nodes))

        # These are the weights between the hidden layer and the output layer.
        self.weights_1_2 = np.random.normal(0.0, self.output_nodes**-0.5, 
                                                (self.hidden_nodes, self.output_nodes))
        
        ## New for Project 5: Removed self.layer_0; added self.layer_1
        # The input layer, a two-dimensional matrix with shape 1 x hidden_nodes
        self.layer_1 = np.zeros((1,hidden_nodes))
    
    ## New for Project 5: Removed update_input_layer function
    
    def get_target_for_label(self,label):
        if(label == 'Baked Good'):
            return 1
        else:
            return 0
        
    def sigmoid(self,x):
        return 1 / (1 + np.exp(-x))
    
    def sigmoid_output_2_derivative(self,output):
        return output * (1 - output)
    
    ## New for Project 5: changed name of first parameter form 'training_reviews' 
    #                     to 'training_reviews_raw'
    def train(self, training_reviews_raw, training_labels):

        ## New for Project 5: pre-process training reviews so we can deal 
        #                     directly with the indices of non-zero inputs
        training_reviews = list()
        for review in training_reviews_raw:
            indices = set()
            for word in review.split(" "):
                if(word in self.word2index.keys()):
                    indices.add(self.word2index[word])
            training_reviews.append(list(indices))

        # make sure out we have a matching number of reviews and labels
        assert(len(training_reviews) == len(training_labels))
        
        # Keep track of correct predictions to display accuracy during training 
        correct_so_far = 0

        # Remember when we started for printing time statistics
        start = time.time()
        
        # loop through all the given reviews and run a forward and backward pass,
        # updating weights for every item
        for i in range(len(training_reviews)):
            
            # Get the next review and its correct label
            review = training_reviews[i]
            label = training_labels[i]
            
            #### Implement the forward pass here ####
            ### Forward pass ###

            ## New for Project 5: Removed call to 'update_input_layer' function
            #                     because 'layer_0' is no longer used

            # Hidden layer
            ## New for Project 5: Add in only the weights for non-zero items
            self.layer_1 *= 0
            for index in review:
                self.layer_1 += self.weights_0_1[index]

            # Output layer
            ## New for Project 5: changed to use 'self.layer_1' instead of 'local layer_1'
            layer_2 = self.sigmoid(self.layer_1.dot(self.weights_1_2))            
            
            #### Implement the backward pass here ####
            ### Backward pass ###

            # Output error
            layer_2_error = layer_2 - self.get_target_for_label(label) # Output layer error is the difference between desired target and actual output.
            layer_2_delta = layer_2_error * self.sigmoid_output_2_derivative(layer_2)

            # Backpropagated error
            layer_1_error = layer_2_delta.dot(self.weights_1_2.T) # errors propagated to the hidden layer
            layer_1_delta = layer_1_error # hidden layer gradients - no nonlinearity so it's the same as the error

            # Update the weights
            ## New for Project 5: changed to use 'self.layer_1' instead of local 'layer_1'
            self.weights_1_2 -= self.layer_1.T.dot(layer_2_delta) * self.learning_rate # update hidden-to-output weights with gradient descent step
            
            ## New for Project 5: Only update the weights that were used in the forward pass
            for index in review:
                self.weights_0_1[index] -= layer_1_delta[0] * self.learning_rate # update input-to-hidden weights with gradient descent step

            # Keep track of correct predictions.
            if(layer_2 >= 0.5 and label == 'Baked Good'):
                correct_so_far += 1
            elif(layer_2 < 0.5 and label == 'Other'):
                correct_so_far += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the training process. 
            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) \
                             + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%")
            if(i % 2500 == 0):
                print("")
    
    def test(self, testing_reviews, testing_labels):
        """
        Attempts to predict the labels for the given testing_reviews,
        and uses the test_labels to calculate the accuracy of those predictions.
        """
        
        # keep track of how many correct predictions we make
        correct = 0

        # we'll time how many predictions per second we make
        start = time.time()

        # Loop through each of the given reviews and call run to predict
        # its label. 
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the prediction process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct) + " #Tested:" + str(i+1) \
                             + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
    
    def run(self, review):
        """
        Returns a Baked Good or Other prediction for the given review.
        """
        # Run a forward pass through the network, like in the "train" function.
        
        ## New for Project 5: Removed call to update_input_layer function
        #                     because layer_0 is no longer used

        # Hidden layer
        ## New for Project 5: Identify the indices used in the review and then add
        #                     just those weights to layer_1 
        self.layer_1 *= 0
        unique_indices = set()
        for word in review.lower().split(" "):
            if word in self.word2index.keys():
                unique_indices.add(self.word2index[word])
        for index in unique_indices:
            self.layer_1 += self.weights_0_1[index]
        
        # Output layer
        ## New for Project 5: changed to use self.layer_1 instead of local layer_1
        layer_2 = self.sigmoid(self.layer_1.dot(self.weights_1_2))
         
        # Return POSITIVE for values above greater-than-or-equal-to 0.5 in the output layer;
        # return NEGATIVE for other values
        if(layer_2[0] >= 0.5):
            return "Baked Good"
        else:
            return "Other"

# %% [markdown]
# **1. Run the following cell to train the network with a small polarity cutoff.**

# %%
mlp = SentimentNetwork(method_description[:-1000],expected_data[:-1000],min_count=20,polarity_cutoff=0.05,learning_rate=0.01)
mlp.train(method_description[:-1000],expected_data[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:99.8% Speed(reviews/sec):2084. #Correct:477 #Trained:617 Training Accuracy:77.3%

# %% [markdown]
# **1.1 Run the following cell to test its performance.**

# %%
mlp.test(method_description[-1000:],expected_data[-1000:])
# Out:
# Progress:77.9% Speed(reviews/sec):3731. #Correct:649 #Tested:780 Testing Accuracy:83.2%
# Progress:99.9% Speed(reviews/sec):3622. #Correct:838 #Tested:1000 Testing Accuracy:83.8%

# %% [markdown]
# **2. Run the following cell to train your network with a much larger polarity cutoff.**

# %%
mlp = SentimentNetwork(method_description[:-1000],expected_data[:-1000],min_count=20,polarity_cutoff=0.8,learning_rate=0.01)
mlp.train(method_description[:-1000],expected_data[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:99.8% Speed(reviews/sec):5227. #Correct:493 #Trained:617 Training Accuracy:79.9%

# %% [markdown]
# **2.1 And Run the following cell to test its performance**

# %%
mlp.test(method_description[-1000:], expected_data[-1000:])
# Out:
# Progress:99.9% Speed(reviews/sec):6583. #Correct:839 #Tested:1000 Testing Accuracy:83.9%

# %% [markdown]
# **Analysis: about Weights**

# %%
mlp_full = SentimentNetwork(method_description[:-1000],expected_data[:-1000],min_count=0,polarity_cutoff=0,learning_rate=0.01)
mlp_full.train(method_description[:-1000],expected_data[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:93.0% Speed(reviews/sec):1408. #Correct:446 #Trained:575 Training Accuracy:77.5%
# Progress:99.8% Speed(reviews/sec):1405. #Correct:480 #Trained:617 Training Accuracy:77.7%

# %%
def get_most_similar_words(focus = "horrible"):
    most_similar = Counter()

    for word in mlp_full.word2index.keys():
        most_similar[word] = np.dot(mlp_full.weights_0_1[mlp_full.word2index[word]],mlp_full.weights_0_1[mlp_full.word2index[focus]])
    
    return most_similar.most_common()

# %%
get_most_similar_words
#  ('in.', 0.000724840263683235),
#  ('again,', 0.0007208496130351199),
#  ('sure', 0.0007186096667231698),
#  ('plate', 0.0007170734073820526),
#  ('ribbon.', 0.0007163431187186578),
#  ('loose', 0.0007153462986599601),
#  ('crumb', 0.0007150306777069565),
#  ('dough.', 0.0007113993166518939),
#  ('months,', 0.0007112708678787029),
#  ('trees', 0.0007087198289824467),
#  ('lids', 0.0007081220424585976),
#  ('covered.', 0.0007028950241435306),
#  ('two-thirds', 0.0007001206688620882),
#  ('brush', 0.0006991759026763081),
#  ('ball,', 0.0006981246598993927),
#  ('up.', 0.0006968374266927575),
#  ('tins.', 0.0006945387512943056),
#  ('tops.', 0.0006938812166441437),
#  ('knead', 0.0006938761541234338),
#  ('Remove', 0.0006937950521422094),
#  ('cooked.', 0.0006935744941409178),
#  ('spice', 0.000693547047990758),
#  ('touch', 0.0006915496793347659),
#  ('pastry,', 0.0006887933513277528),
#  ('halves', 0.0006879534586709953),
#  ('Liberally', 0.0006853811224499266),
#  ('pockets', 0.000683701755934299),
#  ('cases', 0.0006824477304630437),
#  ('Crumble', 0.0006818721216789738),
#  ('milk.', 0.0006792382068889951),
#  ('10', 0.0006774130774452346),
#  ('steam', 0.0006772032317082343),
#  ('Mix', 0.0006770521045027133),
#  ('level', 0.0006754187812123444),
#  ('creamy.', 0.0006747470807939418),
#  ('lots', 0.0006745309999199913),
#  ('Reduce', 0.0006728051998897387),
#  ('smaller', 0.0006709702579201044),
#  ('Stamp', 0.0006704456254606676),
#  ('drops', 0.0006701623293828188),
#  ('baking', 0.0006693574091205236),
#  ('rough', 0.0006603164003405918),
#  ('rectangular', 0.0006577972856087485),
#  ('white,', 0.000656865324957683),
#  ('trimming', 0.0006551373826253395),
#  ('darken', 0.0006539737184570058),
#  ('ribbon', 0.0006522285558703804),
#  ('more,', 0.0006477812761034605),
#  ('colour', 0.0006470722809791778),
#  ('processor,', 0.0006456181164573855),
#  ('overhanging.', 0.0006451572383369236),
#  ('briefly.', 0.0006433122534725147),
#  ('extract,', 0.0006431762921586834),
#  ('Use', 0.0006390525683726598),
#  ('it’s', 0.0006383378856264178),
#  ('rather', 0.0006378216162916182),
#  ('any', 0.0006370665678981197),
#  ('rise.', 0.0006366545754367927),
#  ('apricot', 0.0006364996482335599),
#  ('on', 0.0006346117106627613),
#  ('from', 0.0006341780668658075),
#  ('kettle', 0.0006327122814948579),
#  ('white', 0.0006320853705053834),
#  ('spray', 0.000631709026664893),
#  ('bases', 0.0006301343783917954),
#  ('than', 0.0006298949173642996),
#  ('bottom.', 0.0006297358785069153),
#  ('circles', 0.0006294480527669811),
#  ('kitchen', 0.0006280487207080692),
#  ('soft,', 0.0006279837163021228),
#  ('processor.', 0.0006244928547687011),
#  ('syrup', 0.000623280621082677),
#  ('holly', 0.0006231973404226178),
#  ('slightly', 0.0006230671000848398),
#  ('cools', 0.0006213179802406275),
#  ('saucer', 0.0006212656141622408),
#  ('tree,', 0.0006197277468065551),
#  ('Dissolve', 0.0006181113136177117),
#  ('increase', 0.00029541497586808217),
#  ("with').", 0.00029534582142843094),
#  ('Have', 0.0002942137732604669),
#  ('avoid', 0.00029420919272950014),
#  ('Fold', 0.00029405437605896037),
#  ('sausagemeat', 0.00029399614606956945),
#  ('ribbon,', 0.0002933930786634996),
#  ('jelly,', 0.00029334792938462607),
#  ('1/4', 0.0002925600014010176),
#  ('inner', 0.0002923099717667404),
#  ('Smartie', 0.00029130668792572313),
#  ('towel.', 0.0002909062965663746),
#  ('barely', 0.0002898184359150835),
#  ('semolina', 0.00028948369954323155),
#  ('Re-roll', 0.0002874055169856878),
#  ('shiny,', 0.0002873762459416284),
#  ('stem', 0.00028658666420377545),
#  ('can’t', 0.0002861250871232534),
#  ('long,', 0.0002857545177071629),
#  ('hr', 0.00028555394714800133),
#  ('natural', 0.00028465732786525335),
#  ('rubber', 0.0002829154012992832),
#  ('have', 0.00028243258100537315),
#  ('using.', 0.0002819065526075198),
#  ('Line', 0.00028129952524871653),
#  ('poach', 0.0002806770212916065),
#  ('microwave,', 0.000280650490262586),
#  ('meat,', 0.0002793360440741464),
#  ('clove', 0.00027885705573108953),
#  ('pale,', 0.0002787875995654766),
#  ('blast', 0.00027853071110660435),
#  ('apart,', 0.00027839450590314707),
#  ('1-1½', 0.0002783680026355198),
#  ('pliable', 0.00027822062953141216),
#  ('wedges,', 0.0002774872474550787),
#  ('salad,', 0.0002770948645716796),
#  ('fragrant.', 0.0002761973248649659),
#  ('buttermilk', 0.0002758137213643362),
#  ('hung', 0.0002752477796097465),
#  ('20-30', 0.0002745995277094622),
#  ('down.', 0.0002745199628716731),
#  ('nestle', 0.000273521236977564),
#  ('overlapping', 0.00027295416830403786),
#  ('winter', 0.00027251094661873414),
#  ('freeze', 0.0002719944099796414),
#  ('trees.', 0.000271571097045845),
#  ('fluffy.', 0.0002710122473479661),
#  ('scoops', 0.00026975303469495407),
#  ('way.', 0.0002693568758565047),
#  ('Push', 0.0002684343199761334),
#  ('greaseproof', 0.00026776735902334277),
#  ('(add', 0.0002667228790138271),
#  ('curdling.', 0.00026595192514785275),
#  ('leaf,', 0.00026591235558552157),
#  ('On', 0.0002649287875420634),
#  ('lollipops', 0.0002646633973992328),
#  ('bit.', 0.00026461874816858106),
#  ('chocolates,', 0.00026440865818209),
#  ('upright.', 0.000264264602915055),
#  ('1kg', 0.00026367186694204603),
#  ('left', 0.00026341524414241416),
#  ('pies,', 0.00026315067956862254),
#  ('ahead,', 0.0002628060667120492),
#  ('gingerbread.', 0.00026268967110501925),
#  ('cooling', 0.0002626628636426679),
#  ("'goes", 0.0002618678545857143),
#  ('pliable.', 0.0002617582624188247),
#  ('build', 0.0002617097942828852),
#  ('did', 0.00026058567659235254),
#  ('sugar).', 0.0002605806400553796),
#  ('tying', 0.0002604817031906756),
#  ('15-18', 0.0002604665449634941),
#  ('what’s', 0.000260314083393134),
#  ('18cm,', 0.0002602429864971577),
#  ('larger,', 0.0002602429864971577),
#  ('additions', 0.0002602429864971577),
#  ('snowflakes.', 0.0002600917419800472),
#  ('overcook,', 0.00026004696892178655),
#  ('truffle.', 0.00026004223754869105),
#  ('snapped', 0.00026004223754869105),
#  ('necessary)', 0.00026004223754869105),
#  ('(greasing', 0.00026004223754869105),
#  ('cutting.', 0.00025999594705754844),
#  ('gathering', 0.0002598242131797059),
#  ('18-20cm', 0.0002598242131797059),
#  ('sage.', 0.0002598242131797059),
#  ('levelling', 0.0002598242131797059),
#  ('achieve', 0.00025969493295162994),
#  ('tin\xa0–\xa0resting', 0.00025969493295162994),
#  ('pastry\xa0level', 0.00025969493295162994),
#  ('tin\xa0will', 0.00025969493295162994),
#  ('cheeses', 0.00025969493295162994),
#  ('puck-shaped', 0.00025958081376281476),
#  ('50p', 0.00025958081376281476),
#  ('test', 0.00025957125087440735),
#  ('sandwich', 0.00025956536435804906),
#  ('wobble;', 0.00025956529806689106),
#  ('wheel.', 0.00025956529806689106),
#  ('1.3-litre', 0.00025956529806689106),
#  ('little).', 0.00025956529806689106),
#  ('spokes', 0.00025956529806689106),
#  ('days).', 0.00025956529806689106),
#  ('Stand', 0.0002594012476808847),
#  ('90C/gas', 0.00025936659739332504),
#  ('peeler', 0.00025936659739332504),
#  ('rippling', 0.00025936659739332504),
#  ('bar.', 0.00025936659739332504),
#  ('curls:\xa0run', 0.00025936659739332504),
#  ('110C/fan', 0.00025936659739332504),
#  ('swivel', 0.00025936659739332504),
#  ('cheesecake.', 0.00025936659739332504),
#  ('slab', 0.00025936659739332504),
#  ('blended,', 0.00025936659739332504),
#  ('Maria,', 0.00025936659739332504),
#  ('(each', 0.0002591407386545644),
#  ('oz)', 0.0002591407386545644),
#  ('own,', 0.0002591407386545644),
#  ('200ml/7fl', 0.0002591407386545644),
#  ('\xa0for', 0.0002591407386545644),
#  ('\xa0before', 0.0002591407386545644),
#  ('smudge', 0.0002591407386545644),
#  ('overbeat.', 0.0002591407386545644),
#  ('additions.', 0.0002591407386545644),
#  ('well-soaked,', 0.0002591407386545644),
#  ('chill).', 0.0002591407386545644),
#  ('pieces\xa0for', 0.0002591407386545644),
#  ('puddings.', 0.0002591407386545644),
#  ('medium\xa0', 0.0002591407386545644),
#  ('Stone', 0.0002591407386545644),
#  ('medjool', 0.0002591407386545644),
#  ('used.', 0.0002591407386545644),
#  ('curdled', 0.0002591407386545644),
#  ('stickier', 0.0002591407386545644),
#  ('higgledy-piggledy', 0.0002590964494382901),
#  ('11/2', 0.0002590964494382901),
#  ('hula-hoop.', 0.0002590964494382901),
#  ('crispy,', 0.0002590964494382901),
#  ('camembert', 0.0002590964494382901),
#  ('molten.', 0.0002590964494382901),
#  ('millimetres', 0.0002590964494382901),
#  ('connecting', 0.0002590964494382901),
#  ('breadsticks', 0.0002590964494382901),
#  ('breadstick,', 0.0002590964494382901),
#  ('‘knead’', 0.0002590964494382901),
#  ('swing', 0.0002590964494382901),
#  ('moment,', 0.0002590964494382901),
#  ('ready-to-eat', 0.0002590964494382901),
#  ('boxed', 0.0002590964494382901),
#  ('Steadily', 0.0002590964494382901),
#  ('designs', 0.00025905217512813136),
#  ('aquafaba', 0.00025905217512813136),
#  ('disappeared', 0.00025905217512813136),
#  ('faces', 0.00025905217512813136),
#  ('gloopy.', 0.00025905217512813136),
#  ('needed.', 0.0002588215093760468),
#  ('whatever', 0.00025874484975297153),
#  ('soaking,', 0.00025872216373136074),
#  ('150C/gas', 0.00025823742614642807),
#  ('overmix', 0.0002581068080312607),
#  ('cool.', 0.0002578673787993466),
#  ('bigger,', 0.00025742646404225856),
#  ('sizzles.', 0.00025742646404225856),
#  ('worktop,', 0.00025742646404225856),
#  ('6/', 0.00025742646404225856),
#  ('below,', 0.00025742646404225856),
#  ('Chelsea', 0.00025742646404225856),
#  ('keeps', 0.00025742646404225856),
#  ('are.', 0.00025742646404225856),
#  ('squashed', 0.00025742646404225856),
#  ('fix', 0.000257364356368736),
#  ('black', 0.000257356410612955),
#  ('toaster', 0.0002571520315733313),
#  ('nut-brown.', 0.0002571520315733313),
#  ('simmers,', 0.0002571520315733313),
#  ('45', 0.00025696562862664494),
#  ('palate', 0.00025689384321110636),
#  ('compact', 0.00025689384321110636),
#  ('peppery', 0.00025689384321110636),
#  ('tart,', 0.00025689384321110636),
#  ('cordial', 0.0002564144848581319),
#  ('men.', 0.0002564144848581319),
#  ('secure.', 0.00025616541511881897),
#  ('margarine', 0.00025608195550925886),
#  ('margarine,', 0.00025608195550925886),
#  ('dairy-free', 0.00025608195550925886),
#  ('thickness.', 0.0002557282218566298),
#  ('batch', 0.00025557006973648763),
#  ('ready,', 0.0002554260700434628),
#  ('up,', 0.00025524563042268305),
#  ('reheat,', 0.0002550699180636887),
#  ('180C/160', 0.0002548001845418447),
#  ('stollen.', 0.0002548001845418447),
#  ('sprigs.', 0.00025478640938238504),
#  ('carton,', 0.00025458843070747596),
#  ('squeezing', 0.00025458843070747596),
#  ('bulbs.', 0.00025458843070747596),
#  ('bun,', 0.00025458843070747596),
#  ('uppermost', 0.00025458843070747596),
#  ('bulb', 0.00025458843070747596),
#  ('indent', 0.00025458843070747596),
#  ('equal-sized', 0.00025458843070747596),
#  ('carton', 0.00025458843070747596),
#  ('stickers', 0.00025458843070747596),
#  ('upwards', 0.00025458843070747596),
#  ('refrigerate.', 0.00025458843070747596),
#  ('fillings.', 0.00025458843070747596),
#  ('index', 0.00025458843070747596),
#  ('Cup', 0.00025458843070747596),
#  ('toothpick.', 0.00025458843070747596),
#  ('rind.', 0.00025458843070747596),
#  ('foods)', 0.00025458843070747596),
#  ('smell', 0.00025458843070747596),
#  ('hook.', 0.00025458843070747596),
#  ('Position', 0.0002545522482441643),
#  ('listed,', 0.0002544190227845747),
#  ('Lancashire', 0.0002539039781721507),
#  ('fruitcakes', 0.0002539039781721507),
#  ...]

# %%
get_most_similar_words("stir")
# Out:
# [('flour,', 0.0024473765659449344),
#  ('line', 0.002292625432149746),
#  ('cake', 0.002036188131130675),
#  ('flour', 0.0016641568518473437),
#  ('Bake', 0.001629765248413192),
#  ('butter', 0.00162605297358824),
#  ('top', 0.001592060595284146),
#  ('put', 0.00026315982202344454),
#  ('glue', 0.0002630425007146471),
#  ('bottom,', 0.0002624925061470424),
#  ('¼', 0.0002621826058622752),
#  ('frozen.', 0.00026171503822236666),
#  ('double-line', 0.0002613746204755777),
#  ('edge,', 0.0002612557829024682),
#  ('balls', 0.0002601014709990334),
#  ('granulated', 0.00026007353998015146),
#  ('stage', 0.0002593913606555588),
#  ('Squeeze', 0.0002586254765251391),
#  ('newspaper', 0.0002584221660310753),
#  ('knife', 0.0002580957886709578),
#  ('While', 0.00025792215129003026),
#  ('beans,', 0.00025786518744267523),
#  ('come', 0.0002578588771142769),
#  ('trim.', 0.00025737537669250516),
#  ('peaks', 0.0002572466515354071),
#  ('small', 0.0002569971348941128),
#  ('slits', 0.00025691296946354556),
#  ('escape,', 0.0002568763539877953),
#  ('decorate', 0.0002565075004245342),
#  ('flaked', 0.00025648117671750914),
#  ('pleat', 0.00025634069501253697),
#  ('hours.', 0.0002557960550697932),
#  ('salad.', 0.00025530452316589194),
#  ('larger', 0.0002547839135947193),
#  ('they’re', 0.0002541478617217845),
#  ('Level', 0.00025383184079083663),
#  ('layer.', 0.0002527446713021868),
#  ('Melt', 0.0002527247655025664),
#  ('week,', 0.000252478042614811),
#  ('125g', 0.00025225975429323823),
#  ('invert', 0.0002516747056511102),
#  ('gold', 0.00025122651409367774),
#  ('pie.', 0.00025122381058188386),
#  ('fairly', 0.0002510367870224663),
#  ('halve', 0.0002510177311102866),
#  ('dough', 0.0002509438403938758),
#  ('tins,', 0.000250567397668834),
#  ('week.', 0.0002499571319006177),
#  ('worry', 0.00024802296462797746),
#  ('fingers,', 0.0002468183844042785),
#  ('hard', 0.0002464101406775384),
#  ('160C/gas', 0.0002460945228662349),
#  ('mince', 0.0002459342587095022),
#  ('teasing', 0.000245329323034504),
#  ('beets', 0.00024507021305447566),
#  ('removing', 0.00024489863512283346),
#  ('feed', 0.0002445516884987327),
#  ('bow', 0.00024321782824555105),
#  ('sit', 0.00024275418494825192),
#  ('done', 0.000241688303404011),
#  ('foil', 0.00024139838297730667),
#  ('puffed', 0.00024131609408837933),
#  ('dust', 0.00023975265075302854),
#  ('left.', 0.00023961693590403413),
#  ('weigh', 0.00023934326298373168),
#  ('chosen', 0.0002390117609320934),
#  ('brown,', 0.00023898626950707188),
#  ('24cm', 0.00023891830926590154),
#  ('squash', 0.0002388685653188826),
#  ('roughly', 0.0002382702609324194),
#  ('label', 0.00023821691191530883),
#  ('100g/4oz', 0.0002374755863708035),
#  ('overnight,', 0.00023727471384679382),
#  ('a\xa0', 0.00023696601866962766),
#  ('onto', 0.00023681280313941083),
#  ('bun', 0.00023681130332834982),
#  ('cumin,', 0.00023667886273473216),
#  ('decorations.', 0.00023637443628786003),
#  ('processer', 0.00023616173395150567),
#  ('ball', 0.0002360800882183989),
#  ('4', 0.0002356606680382524),
#  ('almonds,', 0.00023555058731642876),
#  ('discarding', 0.0002354102773196345),
#  ('28cm', 0.0002347210671525379),
#  ('extract.', 0.000233537377551304),
#  ('tart.', 0.00018601781854879983),
#  ('Just', 0.00018553278147840968),
#  ('heat.', 0.0001847677573296553),
#  ('layers.', 0.00018464040493785397),
#  ('low', 0.00018449003856055665),
#  ('dot', 0.00018351522696380938),
#  ('Sprinkle', 0.00018325161523404518),
#  ('rack.', 0.0001832240971478723),
#  ('trim', 0.00018320889902781609),
#  ('kneading', 0.0001825575897188653),
#  ('incorporated', 0.0001809513078710615),
#  ('rum,', 0.0001806328081840442),
#  ('50g', 0.0001805426466593527),
#  ('pearl', 0.00018038532080006536),
#  ('lard', 0.0001799879096667634),
#  ('funnel,', 0.0001799879096667634),
#  ('stock,', 0.0001799538984076488),
#  ('consistency,', 0.00017987245623217614),
#  ('side,', 0.00017984773226118844),
#  ('bigger', 0.00017961172170668485),
#  ('year.', 0.00017947820352698206),
#  ('scoop,', 0.0001794034119297224),
#  ('cakes,', 0.00017925202462236155),
#  ('apple,', 0.0001791448587177644),
#  ('hang', 0.0001791105883532297),
#  ('basins', 0.00017858152973009348),
#  ('combined', 0.00017854876370766042),
#  ('dark,', 0.00017845530613344495),
#  ('leaves,', 0.00017818559075926996),
#  ('demerara', 0.00017741770418119694),
#  ('bundt', 0.0001773155216682626),
#  ('extract', 0.00017687800528286453),
#  ('beat', 0.0001766216845070802),
#  ('chia', 0.00017582959332695288),
#  ('pickles.', 0.00017576410453757008),
#  ('may', 0.0001746073876618765),
#  ('cherries', 0.00017452969535073121),
#  ('cling', 0.00017417735674467863),
#  ('consistency.', 0.0001736736992258554),
#  ('marks', 0.00017367097097692786),
#  ('forms.', 0.0001729206563705485),
#  ('ricotta', 0.0001726168377123307),
#  ('fill', 0.00017253016416542114),
#  ('Feed', 0.00017237681683708253),
#  ('100ml', 0.0001720666371760636),
#  ('dishes.', 0.00017199501724068757),
#  ('shine.', 0.00017193913161598154),
#  ('blob', 0.00017139965327076504),
#  ('850g', 0.00017082602016260252),
#  ('buff', 0.00017082602016260252),
#  ('flats', 0.00017082602016260252),
#  ('measure.', 0.00017082602016260252),
#  ('spot', 0.00017038213279370695),
#  ('lower', 0.00017037147833443998),
#  ('like.', 0.00017026092558828786),
#  ('rubbing', 0.00016994263393014608),
#  ('antlers,', 0.00016981805100710665),
#  ('20-22', 0.00016973803543160292),
#  ('30cm', 0.00016962534249001168),
#  ('hook,', 0.00016960437672587026),
#  ('3/4', 0.00016958231338932967),
#  ('glacé', 0.00016940738823828318),
#  ('discs', 0.0001693951825243294),
#  ('swirl', 0.00016939095789926165),
#  ('figs,', 0.0001689925458140894),
#  ('portioned', 0.00016877216839380614),
#  ('this,', 0.0001685595844506347),
#  ('little.', 0.0001681964324515095),
#  ('Maltesers', 0.00016797049432131788),
#  ('blender', 0.0001674261525108402),
#  ('centre,', 0.00016738006165811233),
#  ('pears', 0.00016668321639918854),
#  ('crumbs,', 0.00016658570501267537),
#  ('appear', 0.00016635596623399882),
#  ('burn', 0.00016591351010934252),
#  ('1.5cm', 0.0001657784190899057),
#  ('chance', 0.00016568247584400954),
#  ('increase', 0.00014721494266845553),
#  ("with').", 0.00014718048074979822),
#  ('Have', 0.00014661634412925273),
#  ('avoid', 0.00014661406150088667),
#  ('Fold', 0.00014653691129138676),
#  ('sausagemeat', 0.00014650789338352825),
#  ('ribbon,', 0.00014620736517452696),
#  ('jelly,', 0.00014618486581246396),
#  ('1/4', 0.00014579221553265694),
#  ('inner', 0.00014566761758982288),
#  ('Smartie', 0.00014516764844404233),
#  ('towel.', 0.00014496812033671389),
#  ('barely', 0.00014442600380067678),
#  ('semolina', 0.00014425919372056345),
#  ('Re-roll', 0.00014322356739469969),
#  ('shiny,', 0.0001432089806762695),
#  ('stem', 0.00014281550627664397),
#  ('can’t', 0.00014258548732365607),
#  ('long,', 0.0001424008204658431),
#  ('hr', 0.00014230086959747166),
#  ('natural', 0.0001418540548890524),
#  ('rubber', 0.0001409859959195015),
#  ('have', 0.00014074539077862038),
#  ('using.', 0.00014048325362662123),
#  ('Line', 0.00014018075204368075),
#  ('poach', 0.00013987053796571286),
#  ('microwave,', 0.0001398573166863762),
#  ('meat,', 0.00013920228516773602),
#  ('clove', 0.00013896358961327146),
#  ('pale,', 0.00013892897733470082),
#  ('blast', 0.00013880096141528464),
#  ('apart,', 0.0001387330859084347),
#  ('1-1½', 0.00013871987846350808),
#  ('pliable', 0.00013864643762656902),
#  ('wedges,', 0.00013828096935603114),
#  ('salad,', 0.0001380854321341488),
#  ('fragrant.', 0.00013763815874836917),
#  ('buttermilk', 0.00013744699658001033),
#  ('hung', 0.00013716496929716597),
#  ('20-30', 0.00013684192417714577),
#  ('down.', 0.00013680227441667194),
#  ('nestle', 0.00013630457664488252),
#  ('overlapping', 0.0001360219877814814),
#  ('winter', 0.0001358011159221599),
#  ('freeze', 0.00013554370882393565),
#  ('trees.', 0.00013533275814651475),
#  ('fluffy.', 0.0001350542650674426),
#  ('scoops', 0.00013442675822566573),
#  ('way.', 0.00013422933932190654),
#  ('Push', 0.000133769599558754),
#  ('greaseproof', 0.00013343723110607604),
#  ('(add', 0.0001329167325624008),
#  ('curdling.', 0.00013253254104047158),
#  ('leaf,', 0.0001325128222336207),
#  ('On', 0.00013202267811447872),
#  ('lollipops', 0.00013189042552793744),
#  ('bit.', 0.00013186817535625512),
#  ('chocolates,', 0.00013176348064595608),
#  ('upright.', 0.00013169169319572505),
#  ('1kg', 0.0001313963134776602),
#  ('left', 0.00013126842994493063),
#  ('pies,', 0.00013113658876643796),
#  ('ahead,', 0.00013096485691102279),
#  ('gingerbread.', 0.00013090685317385467),
#  ('cooling', 0.00013089349413874976),
#  ("'goes", 0.00013049731512854076),
#  ('pliable.', 0.00013044270176806993),
#  ('build', 0.00013041854851100293),
#  ('did', 0.0001298583639066914),
#  ('sugar).', 0.00012985585403562093),
#  ('tying', 0.00012980655056066205),
#  ('15-18', 0.0001297989967203771),
#  ('what’s', 0.0001297230201343095),
#  ('18cm,', 0.00012968759022614624),
#  ('larger,', 0.00012968759022614624),
#  ('additions', 0.00012968759022614624),
#  ('snowflakes.', 0.00012961222013751104),
#  ('overcook,', 0.00012958990825848198),
#  ('truffle.', 0.00012958755046055067),
#  ('snapped', 0.00012958755046055067),
#  ('necessary)', 0.00012958755046055067),
#  ('(greasing', 0.00012958755046055067),
#  ('cutting.', 0.00012956448239509583),
#  ('gathering', 0.00012947890178799723),
#  ('18-20cm', 0.00012947890178799723),
#  ('sage.', 0.00012947890178799723),
#  ('levelling', 0.00012947890178799723),
#  ('achieve', 0.00012941447722282937),
#  ('tin\xa0–\xa0resting', 0.00012941447722282937),
#  ('pastry\xa0level', 0.00012941447722282937),
#  ('tin\xa0will', 0.00012941447722282937),
#  ('cheeses', 0.00012941447722282937),
#  ('puck-shaped', 0.0001293576078992975),
#  ('50p', 0.0001293576078992975),
#  ('test', 0.00012935284239929366),
#  ('sandwich', 0.00012934990895570076),
#  ('wobble;', 0.00012934987592064896),
#  ('wheel.', 0.00012934987592064896),
#  ('1.3-litre', 0.00012934987592064896),
#  ('little).', 0.00012934987592064896),
#  ('spokes', 0.00012934987592064896),
#  ('days).', 0.00012934987592064896),
#  ('Stand', 0.00012926812424878572),
#  ('90C/gas', 0.00012925085687741584),
#  ('peeler', 0.00012925085687741584),
#  ('rippling', 0.00012925085687741584),
#  ('bar.', 0.00012925085687741584),
#  ('curls:\xa0run', 0.00012925085687741584),
#  ('110C/fan', 0.00012925085687741584),
#  ('swivel', 0.00012925085687741584),
#  ('cheesecake.', 0.00012925085687741584),
#  ('slab', 0.00012925085687741584),
#  ('blended,', 0.00012925085687741584),
#  ('Maria,', 0.00012925085687741584),
#  ('(each', 0.0001291383040822161),
#  ('oz)', 0.0001291383040822161),
#  ('own,', 0.0001291383040822161),
#  ('200ml/7fl', 0.0001291383040822161),
#  ('\xa0for', 0.0001291383040822161),
#  ('\xa0before', 0.0001291383040822161),
#  ('smudge', 0.0001291383040822161),
#  ('overbeat.', 0.0001291383040822161),
#  ('additions.', 0.0001291383040822161),
#  ('well-soaked,', 0.0001291383040822161),
#  ('chill).', 0.0001291383040822161),
#  ('pieces\xa0for', 0.0001291383040822161),
#  ('puddings.', 0.0001291383040822161),
#  ('medium\xa0', 0.0001291383040822161),
#  ('Stone', 0.0001291383040822161),
#  ('medjool', 0.0001291383040822161),
#  ('used.', 0.0001291383040822161),
#  ('curdled', 0.0001291383040822161),
#  ('stickier', 0.0001291383040822161),
#  ('higgledy-piggledy', 0.00012911623331747068),
#  ('11/2', 0.00012911623331747068),
#  ('hula-hoop.', 0.00012911623331747068),
#  ('crispy,', 0.00012911623331747068),
#  ('camembert', 0.00012911623331747068),
#  ('molten.', 0.00012911623331747068),
#  ('millimetres', 0.00012911623331747068),
#  ('connecting', 0.00012911623331747068),
#  ('breadsticks', 0.00012911623331747068),
#  ('breadstick,', 0.00012911623331747068),
#  ('‘knead’', 0.00012911623331747068),
#  ('swing', 0.00012911623331747068),
#  ('moment,', 0.00012911623331747068),
#  ('ready-to-eat', 0.00012911623331747068),
#  ('boxed', 0.00012911623331747068),
#  ('Steadily', 0.00012911623331747068),
#  ('designs', 0.00012909416998093008),
#  ('aquafaba', 0.00012909416998093008),
#  ('disappeared', 0.00012909416998093008),
#  ('faces', 0.00012909416998093008),
#  ('gloopy.', 0.00012909416998093008),
#  ('needed.', 0.0001289792216937997),
#  ('whatever', 0.00012894101969681954),
#  ('soaking,', 0.00012892971451040845),
#  ('150C/gas', 0.00012868815392071456),
#  ('overmix', 0.00012862306264265958),
#  ('cool.', 0.00012850374722696067),
#  ('bigger,', 0.00012828402498540656),
#  ('sizzles.', 0.00012828402498540656),
#  ('worktop,', 0.00012828402498540656),
#  ('6/', 0.00012828402498540656),
#  ('below,', 0.00012828402498540656),
#  ('Chelsea', 0.00012828402498540656),
#  ('keeps', 0.00012828402498540656),
#  ('are.', 0.00012828402498540656),
#  ('squashed', 0.00012828402498540656),
#  ('fix', 0.0001282530747007433),
#  ('black', 0.00012824911507080815),
#  ('toaster', 0.0001281472663120835),
#  ('nut-brown.', 0.0001281472663120835),
#  ('simmers,', 0.0001281472663120835),
#  ('45', 0.0001280543756282953),
#  ('palate', 0.00012801860260831924),
#  ('compact', 0.00012801860260831924),
#  ('peppery', 0.00012801860260831924),
#  ('tart,', 0.00012801860260831924),
#  ('cordial', 0.00012777972266581322),
#  ('men.', 0.00012777972266581322),
#  ('secure.', 0.00012765560307002885),
#  ('margarine', 0.0001276140124174209),
#  ('margarine,', 0.0001276140124174209),
#  ('dairy-free', 0.0001276140124174209),
#  ('thickness.', 0.00012743773537107728),
#  ('batch', 0.0001273589229979699),
#  ('ready,', 0.00012728716324208537),
#  ('up,', 0.0001271972442785997),
#  ('reheat,', 0.00012710968106424507),
#  ('180C/160', 0.00012697526402991114),
#  ('stollen.', 0.00012697526402991114),
#  ('sprigs.', 0.0001269683994174989),
#  ('carton,', 0.00012686974016980616),
#  ('squeezing', 0.00012686974016980616),
#  ('bulbs.', 0.00012686974016980616),
#  ('bun,', 0.00012686974016980616),
#  ('uppermost', 0.00012686974016980616),
#  ('bulb', 0.00012686974016980616),
#  ('indent', 0.00012686974016980616),
#  ('equal-sized', 0.00012686974016980616),
#  ('carton', 0.00012686974016980616),
#  ('stickers', 0.00012686974016980616),
#  ('upwards', 0.00012686974016980616),
#  ('refrigerate.', 0.00012686974016980616),
#  ('fillings.', 0.00012686974016980616),
#  ('index', 0.00012686974016980616),
#  ('Cup', 0.00012686974016980616),
#  ('toothpick.', 0.00012686974016980616),
#  ('rind.', 0.00012686974016980616),
#  ('foods)', 0.00012686974016980616),
#  ('smell', 0.00012686974016980616),
#  ('hook.', 0.00012686974016980616),
#  ('Position', 0.00012685170926515625),
#  ('listed,', 0.00012678531866211446),
#  ('Lancashire', 0.00012652865508956912),
#  ('fruitcakes', 0.00012652865508956912),
#  ...]

# %%
import matplotlib.colors as colors

words_to_visualize = list()
for word, ratio in baked_other_ratios.most_common(500):
    if(word in mlp_full.word2index.keys()):
        words_to_visualize.append(word)
    
for word, ratio in list(reversed(baked_other_ratios.most_common()))[0:500]:
    if(word in mlp_full.word2index.keys()):
        words_to_visualize.append(word)

# %%
bakedGood = 0
other = 0

colors_list = list()
vectors_list = list()
for word in words_to_visualize:
    if word in baked_other_ratios.keys():
        vectors_list.append(mlp_full.weights_0_1[mlp_full.word2index[word]])
        if(baked_other_ratios[word] > 0):
            bakedGood+=1
            colors_list.append("#00ff00")
        else:
            other+=1
            colors_list.append("#000000")

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)
words_top_ted_tsne = tsne.fit_transform(vectors_list)

# %%
p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="vector T-SNE for most polarized words")

source = ColumnDataSource(data=dict(x1=words_top_ted_tsne[:,0],
                                    x2=words_top_ted_tsne[:,1],
                                    names=words_to_visualize,
                                    color=colors_list))

p.scatter(x="x1", y="x2", size=8, source=source, fill_color="color")

word_labels = LabelSet(x="x1", y="x2", text="names", y_offset=6,
                  text_font_size="8pt", text_color="#555555",
                  source=source, text_align='center')
p.add_layout(word_labels)

show(p)
# Out:
#   <div class="bk-root" id="593188ce-b62b-43a8-8204-1e0d3d5cc997" data-root-id="1281"></div>
